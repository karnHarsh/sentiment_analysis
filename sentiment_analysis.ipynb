# %% [markdown]
# # Importing Basic Libraries

# %%
#importing libraries

import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the dataset

# %%
#loading dataset into data frame

data = pd.read_csv("data/data.csv", encoding = 'latin-1', header=None)

# %%
data.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
data.tail()
# Out:
#          0           1                             2         3  \
# 1599995  4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999  4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                        4                                                  5
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...

# %%
data.shape
# Out:
# (1600000, 6)

# %% [markdown]
# # Data Preprocessing

# %%
#shuffling the data frame so that model remains general and overfit less

from sklearn.utils import shuffle

data = shuffle(data)

# %%
#give column names to data

data.columns = ["sentiment", "id", "date_time", "query", "username", "tweet"]

# %%
#removing id, date_time, query and username from dataframe

data =data.drop(["id","date_time","query","username"],axis =1)

# %%
data.head()
# Out:
#          sentiment                                              tweet
# 46820            0  rejected.... again  2 supermarkets within a mo...
# 1385369          4  we did it. The show opened to an audience. The...
# 201022           0  @sweetflor really!? youre so lucky that theyre...
# 987956           4                   @scotdoc You not working today?
# 1501045          4                  Homeeeee, just chillin!  call me.

# %%
data.tail()
# Out:
#          sentiment                                              tweet
# 1340103          4       Just arrived at taekwondo  tweet ya later  x
# 133520           0  @ComcastMelissa That it is. Permits, digging, ...
# 1566012          4          @xxBeckeh so is alone with the sun rise.
# 561815           0                                         Exhausted
# 1482026          4  @TheBeautyChick3 makes you wonder of the filli...

# %%
# count the number of sentiments in the data set
# 4 stands for positive tweet
# 0 stands for negative tweet
 
data.sentiment.value_counts()
# Out:
# 4    800000
# 0    800000
# Name: sentiment, dtype: int64

# %%
# add a new cloumn tweet_len to store the length of each tweets

data["tweet_len"] = [len(t) for t in data.tweet]

# %%
# check for tweets greater than 140 characters

data[data.tweet_len>140].head(4)
# Out:
#          sentiment                                              tweet  \
# 519840           0  Just watching my videos from the Jonas Brother...
# 1308653          4  @roshnimo i think half-marathons fall into the...
# 1061801          4  @quickenonline Heh... a &quot;reconcile this t...
# 1097254          4  Reading &quot;Klokken i Makedonia&quot; by Knu...
#
#          tweet_len
# 519840         144
# 1308653        145
# 1061801        148
# 1097254        144

# %%
import re

pattern1 = r'@[A-Za-z0-9_]+' # remove @ mention from tweets
pattern2 = r'https?://[^ ]+' #remove urls from tweets
combined_pattern = r'|'.join((pattern1,pattern2)) # joining pattern1 and pattern2
www_pattern = r'www.[^ ]+' #remove urls from tweets

# %%
#converting words like isn't to is not

negations_dic = {"isn't":"is not", "aren't":"are not","wasn't":"was not","weren't":"were not","haven't":"have not","hasn't":"has not","hadn't":"had not","won't":"will not", "wouldn't":"would not","don't":"do not","doesn't":"does not","didn't":"did not","can't":"can not","couldn't":"could not","shouldn't":"should not","mightn't":"might not","mustn't":"must not" }

# %%
neg_pattern = re.compile(r'\b(' + '|'.join(negations_dic.keys())+r')\b')

# %%
#using scraping tools to extract required texts

from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()

# %%
# defining a function to clean the tweets

def clean_tweets(tweet):
    soup = BeautifulSoup(tweet,'lxml')    # create and call an object of BeautifulSoup class
    souped = soup.get_text()  # get only texts from tweets
    # use exception handling as the data frame is not properly structured
    try:
        bom_removed = souped.decode("utf-8-sig").replace(u"\ufffd","?") #remove utf-8-sig encoding
    except:
        bom_removed = souped
    stripped = re.sub(combined_pattern,' ',bom_removed) #calling combined_pattern
    stripped = re.sub(www_pattern,' ',stripped) #remove URLs
    lower_case = stripped.lower() #converting all tweets to lower case so that the compiler don't treat the same word in different cases as different
    neg_handled = neg_pattern.sub(lambda x:negations_dic[x.group()],lower_case) # converting words like isn't to is not
    letters_only = re.sub("[^a-zA-Z]"," ",neg_handled)
    words = [x for x in tok.tokenize(letters_only) if len(x)>1] #tokenize words whose length is greater than 1
    return (" ".join(words)).strip() # join the words and remove any whitespaces at the  beginning and end of the string

# %%
#clean_tweet_texts = [ ] #initialise an empty list 
#for i in range (0,1600000):
 #   clean_tweet_texts.append(clean_tweets(data['tweet'][i]))

# %%
nums = [0,400000,800000,1200000,1600000] #for batch processing
clean_tweet_texts = [ ] #initialise an empty list
for i in range (nums[0],nums[4]):
    clean_tweet_texts.append(clean_tweets(data['tweet'][i]))
# Out:
# E:\Anaconda\lib\site-packages\bs4\__init__.py:294: UserWarning: "b' i just received my G8 viola exam.. and its... well... .. disappointing.. :\\..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# E:\Anaconda\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'E3 ON PLAYSTATION HOME IN ABOUT AN HOUR!!!!!!!!!! \\../  \\../'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
#print clean_tweet_texts list

clean_tweet_texts
# Out:
# ['awww that bummer you shoulda got david carr of third day to do it',
#  'is upset that he can not update his facebook by texting it and might cry as result school today also blah',
#  'dived many times for the ball managed to save the rest go out of bounds',
#  'my whole body feels itchy and like its on fire',
#  'no it not behaving at all mad why am here because can not see you all over there',
#  'not the whole crew',
#  'need hug',
#  'hey long time no see yes rains bit only bit lol fine thanks how you',
#  'nope they did not have it',
#  'que me muera',
#  'spring break in plain city it snowing',
#  'just re pierced my ears',
#  'could not bear to watch it and thought the ua loss was embarrassing',
#  'it it counts idk why did either you never talk to me anymore',
#  'would ve been the first but did not have gun not really though zac snyder just doucheclown',
#  'wish got to watch it with you miss you and how was the premiere',
#  'hollis death scene will hurt me severely to watch on film wry is directors cut not out now',
#  'about to file taxes',
#  'ahh ive always wanted to see rent love the soundtrack',
#  'oh dear were you drinking out of the forgotten table drinks',
#  'was out most of the day so did not get much done',
#  'one of my friend called me and asked to meet with her at mid valley today but ve no time sigh',
#  'baked you cake but ated it',
#  'this week is not going as had hoped',
#  'blagh class at tomorrow',
#  'hate when have to call and wake people up',
#  'just going to cry myself to sleep after watching marley and me',
#  'im sad now miss lilly',
#  'ooooh lol that leslie and ok will not do it again so leslie will not get mad again',
#  'meh almost lover is the exception this track gets me depressed every time',
#  'some hacked my account on aim now have to make new one',
#  'want to go to promote gear and groove but unfornately no ride there may going to the one in anaheim in may though',
#  'thought sleeping in was an option tomorrow but realizing that it now is not evaluations in the morning and work in the afternoon',
#  'awe love you too am here miss you',
#  'cry my asian eyes to sleep at night',
#  'ok sick and spent an hour sitting in the shower cause was too sick to stand and held back the puke like champ bed now',
#  'ill tell ya the story later not good day and ill be workin for like three more hours',
#  'sorry bed time came here gmt',
#  'do not either its depressing do not think even want to know about the kids in suitcases',
#  'bed class work gym or then class another day that gonna fly by miss my girlfriend',
#  'really do not feel like getting up today but got to study to for tomorrows practical exam',
#  'he the reason for the teardrops on my guitar the only one who has enough of me to break my heart',
#  'sad sad sad do not know why but hate this feeling wanna sleep and still can not',
#  'soo wish was there to see you finally comfortable im sad that missed it',
#  'falling asleep just heard about that tracy girl body being found how sad my heart breaks for that family',
#  'yay happy for you with your job but that also means less time for me and you',
#  'just checked my user timeline on my blackberry it looks like the twanking is still happening are ppl still having probs bgs and uids',
#  'oh man was ironing fave top to wear to meeting burnt it',
#  'is strangely sad about lilo and samro breaking up',
#  'oh so sorry did not think about that before retweeting',
#  'broadband plan massive broken promise via still waiting for broadband we are',
#  'wow tons of replies from you may have to unfollow so can see my friends tweets you re scrolling the feed lot',
#  'our duck and chicken are taking wayyy too long to hatch',
#  'put vacation photos online few yrs ago pc crashed and now forget the name of the site',
#  'need hug',
#  'not sure what they are only that they are pos as much as want to dont think can trade away company assets sorry andy',
#  'hate when that happens',
#  'have sad feeling that dallas is not going to show up gotta say though you think more shows would use music from the game mmm',
#  'ugh degrees tomorrow',
#  'where did move to thought were already in sd hmmm random found me glad to hear yer doing well',
#  'miss my ps it out of commission wutcha playing have you copped blood on the sand',
#  'just leaving the parking lot of work',
#  'the life is cool but not for me',
#  'sadly though ve never gotten to experience the post coitus cigarette before and now never will',
#  'had such nice day too bad the rain comes in tomorrow at am',
#  'too bad will not be around lost my job and can not even pay my phone bill lmao aw shucks',
#  'damm back to school tomorrow',
#  'mo jobs no money how in the hell is min wage here clams an hour',
#  'not forever see you soon',
#  'agreed saw the failwhale allllll day today',
#  'oh haha dude dont really look at em unless someone says hey added you sorry so terrible at that need pop up',
#  'sure you re right need to start working out with you and the nikster or jared at least',
#  'really hate how people diss my bands trace is clearly not ugly',
#  'gym attire today was puma singlet adidas shorts and black business socks and leather shoes lucky did not run into any cute girls',
#  'why will not you show my location',
#  'no picnic my phone smells like citrus',
#  'my donkey is sensitive about such comments nevertheless he and me be glad to see your mug asap charger is still awol',
#  'no new csi tonight fml',
#  'think my arms are sore from tennis',
#  'wonders why someone that like so much can make you so unhappy in split seccond depressed',
#  'sleep soon just hate saying bye and see you tomorrow for the night',
#  'just got ur newsletter those fares really are unbelievable shame already booked and paid for mine',
#  'missin the boo',
#  'me too itm',
#  'damn do not have any chalk my chalkboard is useless',
#  'had blast at the getty villa but hates that she had sore throat all day it just getting worse too',
#  'hey missed ya at the meeting sup mama',
#  'my tummy hurts wonder if the hypnosis has anything to do with it if so it working get it stop smoking',
#  'why is it always the fat ones',
#  'sorry babe my fam annoys me too thankfully they re asleep right now muahaha evil laugh',
#  'should have paid more attention when we covered photoshop in my webpage design class in undergrad',
#  'wednesday my day do not know what do',
#  'poor cameron the hills',
#  'pray for me please the ex is threatening to start sh at my our babies st birthday party what jerk and still have headache',
#  'hmm do really enjoy being with him if the problems are too constants should think things more find someone ulike',
#  'strider is sick little puppy',
#  'so rylee grace wana go steve party or not sadly since its easter wnt able do much but ohh well',
#  'hey actually won one of my bracket pools too bad it was not the one for money',
#  'you do not follow me either and work for you',
#  'bad nite for the favorite teams astros and spartans lose the nite out with was good',
#  'body of missing northern calif girl found police have found the remains of missing northern california girl',
#  'hope they will increase the capacity fast yesterday was such pain got the fail whale times in hours',
#  'behind on my classes for work',
#  'watching house',
#  'remember my bum leg strikes back this time its serious',
#  'cool will their are all kinds of complaints about this laptop online about overheating but no recalls',
#  'emily will be glad when mommy is done training at her new job she misses her',
#  'would rather the first party send bad messages than the rd party send mixed ones sophmore year all over again',
#  'it overrated',
#  'know heard it this afternoon and wondered the same thing moscow is so behind the times',
#  'laying in bed with no voice',
#  'sooo sad they killed off kutner on house whyyyyyyyy',
#  'sorry tell them mea culpa from me and that really am sorry',
#  'it did not make any sense to me the suicide thing refuse to believe that that is actually what happened',
#  'hope your ok',
#  'damn the grind is inspirational and saddening at the same time do not want you to stop cuz like what do much love',
#  'yeah aw but know wudnt stand chance',
#  'ugh cant sleep its am',
#  'hanging in crooners wanna sing can not sucks',
#  'aaw miss ya all too im leaving to bh tomorrow morning think aww wanna go to the beach girls',
#  'is pissed off that there no asba for radio station',
#  'wednesday my day do not know what do',
#  'know my life has been flipped upside down when just thought in my head that some ramen sounds good',
#  'am in pain my back and sides hurt not to mention crying is made of fail',
#  'late night snack glass of oj down with the sickness then back to sleep ugh hate getting sick',
#  'but but but not big fan on camilla belle',
#  'wah can not see clip must be el stupido work filters can not wait till get puter something else blame ex he broke mine',
#  'this week just seems to get longer and longer in terms of how much need to do and how much actually going to get done',
#  'so cold',
#  'ehhh do not weather gonna take turn for the ugly tomorrow',
#  'haha its so cooooold in the and no but you should still go to the show they do some incredible stuff',
#  'hoping the tummy rumbles go away soon',
#  'no no notice they told me be working tomorrow and then called the agency to follow up and they said it was over',
#  'almost bedtime',
#  'missing you babe but as long as your alive happy ya tired my love imma try to sleep hopefully you had headstart',
#  'agh snow',
#  'miss kenny powers',
#  'thank you for letting people know but now sad that the direct message got was not actually from bridget',
#  'and india missed out its th test victory th consecutive win without loss',
#  'guess that no then',
#  'sadly is going to bed',
#  'shame to hear this stephan',
#  'hey leavin in the morning',
#  'was intending to finish editing my page novel manuscript tonight but that will probably not happen and only pages are left',
#  'laid around too much today now my head hurts',
#  'still have not read the th th princess diaries saving francesca made me cry at the end hmm those are easy books',
#  'my nokia died',
#  'my mom might have breast cancer will not find out anything for like week so worried',
#  'going to sleep hoping tomorrow is better day',
#  'lol wish they understood daylight savings has ended though and breakfast is an hour later they keep waking the kids up too',
#  'that is lame',
#  'do not understand really do not',
#  'heroes just is not doing it for me this season',
#  'living not downtown sure is not much fun',
#  'not calorie wise wish junk food was calorie free ate thing of sour skittles and big ass cherry coke',
#  'man work is hard',
#  'getting sick time for some hot tea studying and then sleeeep',
#  'getting eyebrows waxed more pain',
#  'no phantasy star yesterday going to work',
#  'oh just got all my macheist apps sweet did not get the espresso serial no though although they said they sent it oh well',
#  'picked mich st to win it all from the get go was feeling pretty good about that pick all the way up until tonight lost too',
#  'is alone downstairs working',
#  'feel bad for doing it',
#  'is it just me or she hates anoop mean seriously she kinda mean to him',
#  'yes sprint has only in baltimore and chicago so far',
#  'stuck awake in the middle of the night for the second day in row and felt terrible yesterday',
#  'thanks for bursting my bubble',
#  'going to school soon can not find anything to wear gosh it so hard',
#  'was serious lol',
#  'had on my page for sooooo long until it got deleted sad day in history',
#  'crazy wind today no birding',
#  'currently at work',
#  'grrr my ipods acting weird too jai ho and thinking of you are not playing the full songs ughh',
#  'send me the dvd cos have missed out on heaps not happy about that',
#  'do not see the big deal with this website',
#  'so sorry you re having to go through this again therapyfail',
#  'far too out of the way for rail any other tips',
#  'not still up swear why do keep losing gaining losing gaining tweeps so heart wrenching',
#  'today realized am too good at hiding things even can not find it',
#  'staying at friends house house sitting neighbors are so loud having party',
#  'danny im upset that wasnt here to watch the live chat was in car for hours on trip im soooo upset',
#  'check out my mug',
#  'borders closed at',
#  'downloading nin new album the slip when the hell did this come out so behind the times these days',
#  'just woke up an already have written some mail ve to go early at university today as have to teach at am',
#  'is watching the hill and its making me sad',
#  'so many channels yet so so boring lazy day again may have to find hobby',
#  'miss my buddy ill be in ny on the th',
#  'love the french tell people here in the south qtr french and they snarl at me french are beautiful people',
#  'opps as said still got one day remain and now problem come',
#  'activated my selfcontrol block early meaning can not check out the new qc regularizing my internal clock is might be difficult fb',
#  'oh no',
#  'spencer is not good guy',
#  'what about reese dying on ttsc and season finale next week boring madame president is crazy woman',
#  'hate the limited letters too hope you and the guys are fine pray for my dog she not well',
#  'did not get shit done today so screwed',
#  'wanttss to go out',
#  'is not going to sleep tonite',
#  'too worried and tired to post tonight',
#  'could not get shit done today so screwed',
#  'job interview in cardiff today wish me luck got about hours sleep',
#  'your show is whack way worse than whack it wiggety whack',
#  'really do not think people choose to be that way but think he chose not to accept my family help he might be dead by now',
#  'you re going to kill me but ve not seen ds ve been waiting till can do it in one solid week sitting',
#  'think ur right hahaha hrs now',
#  'hate to see the spartans so sad',
#  'my mind and body are severely protesting this getting up thing had nightmares to boot',
#  'goin to follow since did not lol go angels',
#  '',
#  'think want to read some books but the library does not have them',
#  'my nap was interrupted so many times today going out for japanese with the rents again',
#  'kind of longs for the bus that shows up at the end of ghost world right now ugh',
#  'but this is canada canada is weird we re supposed to get snow through wednesday ugh',
#  'awwh babs you look so sad underneith that shop entrance of yesterday musik like the look of the new transformer movie',
#  'sad that the feet of my macbook just fell off',
#  'gonna get up late tomorrow and it am here gonna get tipsy by my lonesome that that just sad',
#  'sweating my forthcoming trip to if can not find someone to crash with while out there may be screwed',
#  'has now gotten somebody to read his tweets but cant get them to make an account',
#  'omgawd couldnt handle my cat being in heat all the time',
#  'hope can make it to the auburn show but its not looking good for me',
#  'thats people mag haha couldnt fit it all in dont think those pictures ever made it in the magazine tho haha',
#  'congrats totally forgot to submit photos',
#  'awww good luck paula please do not work too hard but hope you have fun your new album is gonna be amazing xxx',
#  'now your leaving me gets sad',
#  'miss you twitter my phone broke now using stupid nokia phone ughhh miss my advance phone',
#  'shooting outside my house not kidding so scared',
#  'tuesday ll start with reflection then lecture in stress reducing techniques that sure might become very useful for us accompaniers',
#  'what tragedy and disaster in the news this week',
#  'yes yes still trying to find picture that will upload correclty',
#  'why oh why was the red sox game rained out was so looking forward to opening day',
#  'still can not find my keys',
#  'know right dunno what is going on with twitter',
#  'might be getting sore throat again',
#  'my home town my mammy called all depressd pls explain parent let their yr old child walk alone hello its',
#  'think need to find better anti depressants think this paxil wellbutrin combo is losing its efficacy',
#  'restaurant called woodntap has competitive eating tourney round tourney time we place nd',
#  'is in the bathroom wake up lakin',
#  'want tacos and margarhitas telll gay say hello',
#  'im lonely keep me company female california',
#  'bad day at the betfair office',
#  'miss him can not wait to celebrate the tar heel win this weekend though',
#  'really cold do not want to go to sleep yet but there nothing to do',
#  'is this it its officially over me this go round',
#  'monkeys just found out you my twin and you wont even write back heartbroken',
#  'aww know felt like that yesterday at work',
#  'treaty is not defined',
#  'missed brent at praise band no fun to not have the your lead guitarist pout',
#  'poor john this is what happens when you play with fruit and microwave seriously though have you seen doctor xxx',
#  'missing my bff watching home and away it reminds me of her and me we it shout out to courts',
#  '',
#  'new video card is doa',
#  'feeling lost naked and confused jk sort of no iphone for me',
#  'damn am so late at filling this appraisal form people have almost sent it was so occupied in work',
#  'missed brent at praise band no fun to not have your lead guitarist pout',
#  'think to much on the past cant change it deserved so much more then wat got but why am still thinking about him gah',
#  'has lost his ring it no where to be seen',
#  'ooooooh sealclap see download shitloads of zip folders off chan have no internet moneys fuck yeah alicia mikey',
#  'is still nursing my nile but glad he is feeling better hate when my baby is sick',
#  'is fucked to go back to ic',
#  'yoyoyo my internet has been rude tonight it just reconnected and about to go to bed',
#  'well have uni stuff and netball but after netbal if ve done uni stuff we can',
#  'me too is poor',
#  'help me forget th april th july',
#  'dierks bentley is comin to columbus oh wanna go so bad',
#  'have to take my sidekick back',
#  'congrats totally jealous only wish my xm was working',
#  'gr my face is very itchy',
#  'poor socks luvvvvv the golden retriever want one sighhhh',
#  'just saw that they found that tracy girl in piece of luggage how fucking terrible',
#  'aaaaand the nausea is back',
#  'ooh excited and not even going be there long love youtube',
#  'spent hour to reach to axis bank only to find out today is holiday for mahavir jayanti contd',
#  'agree the jobros dont update theres very often',
#  'it is hilarious and linked the clip from lj some time ago but when went back just now it was dead link',
#  'oooooooo who with im not neither but thats because need to study',
#  'have not tweeted nearly all day posted my website tonight hopefully that goes well night time',
#  'miss bentley',
#  'seriously needs to finish these job applications',
#  'my son vincas is sick so stay at home just three tense days at work and am back on holiday with kids',
#  'whinging my client boss do not understand english well rewrote some text unreadable it written by good writer reviewed correctly',
#  'do not want him to ever punch me',
#  'sooo sick of the snow ughh',
#  '',
#  'it does not work your fan is upset',
#  'would like to apologize for the repeated video games live related tweets am going to have stern discussion with koodo soon stern',
#  'but cant figure out how to get there back pay for hotel etc',
#  'fml so much for seniority bc of technological ineptness now have to register for classes again',
#  'feels like she slept the day away not looking forward to any more bouts with my gallbladder at least have pills now for the pain',
#  'but what really want is my old bass back',
#  'mad tired today callin it in early tonight nighty night twittas',
#  'take it easy and be good to you',
#  'afraid had bad code',
#  'think going to bed goodniight hate this',
#  'here friend and love you',
#  'all this time you did not notice was gone just needed db is it',
#  'is in the bathroom and have to pee',
#  'but wanted margarita too',
#  'yup night workouts the worst but unfortunetly my work schedule only allows me to go at night its tough',
#  'just called hillsong again they said they could not tell me where was on the waiting list do not know if it looking so good',
#  'has of milky bar left and around ml of coke',
#  'it stillllll has not arrived',
#  'mraow feel like dancing but first art school wants to rape me some more',
#  'ah bet it does ve been like craving to play softball or basketball but have noo time',
#  'is terrified she accidentally deleted reference in her management assignment and hopes she doesnt get in trouble when she gets back',
#  'amazon plugin not worked in my website it need php but my hosting provider has only php very sad',
#  'argh was suuuper sleepy an hour ago now wide awake hope do not stay up all night',
#  'wish was sold out if you have some time let me know would love to hear more about what you are up to',
#  'just watched tropic thunder dreading tomorrow',
#  'no he still miss',
#  'chiefdelphi is down',
#  'according to my bro our new puppy had poo fight and was covered in poop picture stolen from him',
#  'playing game at home my new boss did not call me yet',
#  'su yin huen tweeted feel unbearable guilt made my staff cry',
#  'poor joshy is sick those damn tejanos',
#  'my thoughts are with sandra cantu family at this difficult and sad time',
#  'know just wanted to let everybody know what was happening',
#  'michigan who do not know them sigh shameful',
#  'have to fill two hours',
#  'so cuuute hey miss you na its not the same not seeing you girls everyday',
#  'oh did mention it gooooood moooorniiiiiiing from germany im back in my cage or better my office',
#  'throat is closing up and had some string cheese not good idea',
#  'aww sandra cantu is found dead in suitcase missing children stories never seem to go good poor family',
#  'wishing was home underneath my covers',
#  'walking home from school drains all my energy',
#  'agree the shapeshifting is copout was so excited for angela ep thought it was this week noah was awesome tho',
#  'dang would have done this if knew it was there earlier any other outings planned',
#  'wish was better at writing it taking me so long to write this paper',
#  'and of course have access to my halo mythic map pack re download but bad news not the legendary map pack ugh ms',
#  'not yet unfortunately another few weeks ve been told how are you ve been little bit busy with my latest project',
#  'ha the sun already gone',
#  'day lot harder than day let see how day goes tomorrow',
#  'my man crush jake peavy let me down gayforpeavy',
#  'megafast trip you have time during day tom weds or you going out tonight want to see you bad tried to warn you tech fail',
#  'michigan state you make me sad',
#  'omg my mouth is in so much pain just wanna sleep untill its time to take my braces off',
#  'getting annoyed easily today biofuel proposal getting annoyed easily today biof',
#  'hey girl the site is back girlyvue is back and they have even more videos',
#  'spending time with my grandma early tomorrow and can not leave skittles by herself',
#  'just got home from watching michigan state get tromped',
#  'oh jew bus two years worth of classes work is alot to organize not finishing tonight it not possible my bones ache',
#  'no exchanging for me my laptop has not arrived',
#  'hope this does not last too long feel miserable',
#  'rachel hang outage is neccessary was gonna be home this wekend but dumb folk make me work so im free and sat until',
#  'not fun furious the new mantra for the bay breakers it was getting rambunctious the city overreacted clamped down',
#  'my hubby for some reason thinks it more important he has good spot for red carpet for the trek movie premiere sod',
#  'swear no matter how long ve been getting up at am it never gets any easier man my eyes hurts wah',
#  'jeffree how do you keep your hair one color my permanent dye fades within the week',
#  'my reaction too whoa did not see that coming',
#  'still sick feeling bit better got some new medicine hope feel good after night of sleep ohh and it suppose to snow wtf',
#  'think maybe you should get couple more hours of sleep hon how productive can you be right now if ur dog tired worry',
#  'thanks lot learned lot of new words but did not find what was looking for',
#  'wish had all the xblm downloads all on the gamertag hitokyri this gamertag thing is nonsense and tired of it',
#  'new testament test at am',
#  'tons no hay troll ahhhh',
#  'stupid movies we watched mirrors ugggggh stooopeeed rip off',
#  'love you buck',
#  'last one but still not done',
#  'homework',
#  'do not understand why things get taken away did not have enough time with him its unfair want him back he was like my baby',
#  'scratch that du in heif two in half cookies my tum just can not take anymore shoog poots',
#  'was just listening to the sweets for the first time in forever miss them so much can we go to chi town for visits plz',
#  'geez what busy afternoon meetings emails meetings and email and more meetings pm and the day is still going ah its dark and',
#  'dang another spring break how cool is that too bad have to work all week oh well more money for phone ttyl everbody',
#  'im afraid too ur reply about uni from ages ago',
#  'feeling down',
#  'lol they are some emotional ass men omg all this late night eating both of us are broke',
#  'aww nick like your hair longer why did you cut it off break my heart',
#  'wonder if jon lost the net',
#  'wow the most depressing thing in the world is losing video that you ve created in matter of seconds fml',
#  'but all says not in stock',
#  'lmao im sorry poohpot ate it all',
#  'any chance softbelly for is not loud',
#  'time to move my posterior and lose some fat my articulation are creaking so no more running but drool for some swimming',
#  'listening to nathan cry',
#  'today sucked gonna die without chris and callum wahhh',
#  'stou site not update no info about exam and open course must wait for mail notices and doc um',
#  'sorry feeling kinda yucky myself am is going to come too quick',
#  'is in love with scrappy and is missin him already',
#  'wants to hear song but myspace is messing with me',
#  'bad news was dad has cancer and is dying good news new business started and am now life coach practising holistic weight management',
#  'man intervention is soo sad',
#  'help need new boyfriend stuck in rut',
#  'feel like complete idiot the only one who does not get how this shit works help me',
#  'saw an ad on craigslist for casting call for female host on was totally psyched but realized it was hoax',
#  'pepperoni rolls in called valentino they said that they had sausage rolls but no pepperoni rolls',
#  'yes it will be it only monday',
#  'want the new gg episode already',
#  'miss watching rocko modern life',
#  'rip sandra its so sad how can someone do something like that',
#  'keeping my fingers crossed for my buddy he is not feeling well',
#  'wait should eat or be skinny for vegas hungry',
#  'tried tweetdeck once and hated it with passion or it hated me not sure',
#  'btw my iphone is acting funny dying quickly and freezing and bs not admitting anything just sayin',
#  'sitting here wondering why ed still has such strong hold on me',
#  'im sorry got you sick lol going to bed too night',
#  'no internet at home have to drive into ox to use internet because of builders',
#  'the weather in canada is freezing',
#  'twiggassssssss been out of range all day back now and hopefully for good',
#  '',
#  'anyone who reads this pray for my grandma she in pain',
#  'woke up and was having an accident it pushing it pushing he was crying because he could not stop from wetting his pants',
#  'home from franklin street almost jumped over fire someone kicked it before could jenny lost her shoe',
#  'hey you just changed your default',
#  'finally gave in and was bored enough to start this thing think the is going to be problem for me tho its like myspace status',
#  'if oooonly we were really so lucky eh and awh definitely too early for work',
#  'buttload of homework',
#  'needs another copy of visual studio',
#  'why to we the only school in the world be in this week my school is silly anyway look on the bright side when off will be in',
#  'omg ve an economics test and dont know all the things have to know and omg im gonna fail',
#  'once upon time hundred islands was the pride of philippine tourism but coral clam rare fish poaching did it in kinda sad',
#  'yeah apparently have really bad taste',
#  'know was really surprised since everyone recommends them on youtube have to call them tomorrow and figure it all out',
#  'waiting at the airport for my ride while get harassed by men trying to sell me ugly hats why me just want to sleep',
#  'left my ids at the location and now can not go out to bars fuckkkkkkkkkkkkk',
#  'sorry do not understand your last comment',
#  'when is the announcement stayed up late last night',
#  'this is strange illegal torrents avlbl everywhere legal dvd not in stock what do do now',
#  'its not enough to say that imiss',
#  'this trolley has up packed in like sardines padre game and they remove car good call mts',
#  'jeez was just trying to help haha',
#  'that happened to me saturday night along with my glittery green lighter',
#  'trying to reduce the number of cigarettes in each day',
#  'yea it is so quiet around here cuz everyone has to work im bored to death with nobody to talk to',
#  'gotta do my cooking assignment its too hard',
#  'okay about the applepears ve talked to few people and they ve all had them before no one ever told me never',
#  'know night owl by nature hahaha am time zone behind you it almost here',
#  'lol nope but did have complete camerafail',
#  'but useless if do not sleep it not fair want all the fun as well',
#  'my pookie has uti have to be nurse gabbie and get him back to no more sodas',
#  'tweet something damn it and hang out with me please',
#  '',
#  'so behind in video games and everything for that matter yesterday news',
#  'did it was the only one left but got tempted and ate it soon as got home had chocolate velvet ate mocha',
#  'is stressing out because my blackberry keeps flashing red alert status for no reason its faking me out and hate it',
#  'wanna wear my doc martens out have not worn them since december',
#  'when to the shoe repair shop and the guy could not find my shoes so have to go back and see if he can find them in couple days',
#  'did not really see that coming',
#  'just woke up from the most vivid sketchy not cool dreams of my life time to stare at the wall with the lights on',
#  'it ll take days for my sister to get her passport',
#  'oh my yes miss',
#  'uh oh think am getting sick',
#  'good god they ruined my belly button',
#  'watching who framed roger rabbit makes me miss toon town',
#  'renting but very cheap renting and awesome house we had buying attempts fall through',
#  'running nose spinning head not good combination for meeting',
#  'negative you lost my vote of confidence',
#  'nasty budget due and my iphone is being sent to apple today',
#  'that bad',
#  'dammit episode of kings will not play for some reason stopped in the middle now will not do anything',
#  'so upset that missed my chat and quiz online because my free internet has ceased',
#  'can not believe it in disbelief of it all in way really how much can take from people and always get hurt by others',
#  'car show season has started without me',
#  'my throat is raw',
#  'just do not get it what in persons mind could even have them on some ish like this my prayers are with her fam for real',
#  'hate you did not need to see that need to call my therapist now',
#  'twilight did not come yesterday fingers crossed for today',
#  'glad was able help you feel better hate to see you sick love you',
#  'is tireddddddd want to sleep but have an assignment to finish and an exam tomorrow to study for',
#  'you know was thinking need money',
#  'omg its jst teusday',
#  'ummmmm cant find it',
#  'just heard that they found sandra cantu she was only yrs old',
#  'ive forgotten how to snoo snoo wonder if snoo snoo and will ever meet again',
#  'wow that last tweet made me seem like giant sexist sorry about that',
#  'my bathtub drain is fired it haz job do it iz fail got all drano on its ass iz still not draining wanna shower dangit',
#  'stuck at home',
#  'mine is how do you get it up',
#  'duckling in famous children book stolen from boston public garden the boston globe via oh no',
#  'thank you however hate to be on the same list that includes convicts',
#  'heading to altrincham again out of hours install',
#  'morning good im bloody knackered work is not for me today helppp xxx',
#  'do not have garage but you can park in my driveway',
#  'what happened',
#  'on popular music by adorno is probably the most difficult reading ever prescribed actually struggling to continue',
#  'cant see the flowers falling dont have camera just my cellphone',
#  'we ve been good not liking the snow right now was getting used to the nice spring like weather how about you',
#  'what pity youtube is currently blocked in china can not see the vids',
#  'what happened to your show it was the hightlight of my life',
#  'this is the best leather sofa in the world it in the office though which means still here working',
#  'still more days until my internet gets uncapped',
#  'if he does not get better in few days he could have something lodged in his belly',
#  'love my atekinzz so much soo miss her',
#  'wanna sneak into the zoo and play with the kitties',
#  'oh no hope you re not getting sick too',
#  'dont think can cause its my cousins birthday party',
#  'our sweet little man just fell asleep while waiting up for daddy and big brother to get home poor baby he missed them so much today',
#  'the angel is going to miss the athlete this weekend',
#  'trust is hard',
#  'have watched that considering today yaknow shawnna tomomorrow need my bestfriend',
#  'grr want to keep reading but if do wont have anything left to read',
#  'atekinzz where in the world are you',
#  'no supposed to be my date',
#  'pears brie bottle of cabernet and win date with tad hamilton oh gawwd my life flashed forward to when with my cats',
#  'crap need more dresses too',
#  'yeah know it was horrible ugh saddening',
#  'geez ur no fun are you',
#  'wanna be in punk rock band again',
#  'that lot of angst for tuesday afternoon',
#  'very glad britney is not crazy anymore that was one hell of show now sad that it over next up ap at cook county',
#  'has huuuge headache omg feel like crap',
#  'sorry',
#  'sorry was rooting for them too',
#  'man that took forever',
#  'see',
#  'am listing more items on ebay to sell takes forever meanwhile coleman is watching the hills season premier without me',
#  'just got my presentation done slides done crying for this week will be the hardest of all weeks',
#  'just lost',
#  'do not like the previously on skins thing that starts at season two like it when it went straight into the intro like before',
#  'wish was there pretty good at scaring the shit out of people',
#  'going to sound vain but running out of my fav lip gloss',
#  'never again will click on link that screams spider spider should have known better yucky',
#  'why is that when you have time off from work you get sick',
#  'same imac came out more in indonesia than the states',
#  'dammit need to stop buying furniture',
#  'no was half asleep and turned off the laptop after that',
#  'death is peaceful life however bites',
#  'think lost the net sure hope not',
#  'and test footage with my girlfriend in hd the dark one is underxposed',
#  'such tough game to watch tonight for state finally going to bed after also staying up to watch the season premiere of the hills',
#  'seems jruby support for hpricot is now two versions behind',
#  'unlike my sister still do not have one',
#  'fraking app store is pissing me off',
#  'logging out need to study',
#  'anyone else having problems accessing ttb cant get on',
#  'strongly dislike people who make stupid comments and dont know the whole story',
#  'sorry emma is swarley goldfish sad for',
#  'all my tweets are already gone are not they missed you guys tonight',
#  'can not sleep again face is kinda swollen do not let me be allergic to the thing that ll get me to thursday school tomorrow doubtful',
#  'if izzy on the cat tree she ll stare him down but if she on the floor he chases and she runs',
#  'am officially banning godaddy com from my comp my head hurts from the small print and wasted that could ve happily gone to boba',
#  'pretty much just scary for me',
#  'mines too finding it well hard to get fit',
#  'good morning ready go but want go back bed',
#  'hates waiting for mails',
#  'wheat bread from the dollar store just does not toast nicely going over my taxes and calling it an early night',
#  'why kutner mean knew something was going to happen to someone but it was so sad house and it was well done but still sad',
#  'aw ok goonite',
#  'ill so cant go to the cinema',
#  'fell asleep really did not mean too christina',
#  'hey you remember that time we used to be friends ugh vomit sick need sleep',
#  'my lymph nodes are as massive as rahm emanuel balls right now',
#  'oh no my computer sucks do not think ll be able to listen to the xbox fancast tonite',
#  'is missing playing my trumpet',
#  'my throat is still really sore was meant to be going on day camp from friday but not so sure now',
#  'know exactly how you feel',
#  'at work',
#  'well bed time now am sighs back to am mornings for week on wednesday',
#  'jesus camp yeah',
#  'oh no with everything that happened today forgot we were going dress shopping for the opera tomorrow',
#  'turtles are better than my mac lasts longer and moves faster',
#  'am soaked this is not pleasant',
#  'sorry to hear about maggie thoughts to your mum',
#  'you may have to email this one to me hope you feel better',
#  'dead yu gettin on wen im leavin',
#  'please tell me that somewhere close to california lol',
#  'where are you',
#  'stupid arranged marriages ll convert so you can marry me love you',
#  'well he said that he is looser and that is what the show implies',
#  'poor sandra cantu the cantu family my prayers go out to them what sick world we live in she was only',
#  'fuck omg austins always there though man love you',
#  'cried so hard when matthew died',
#  'sad that the feet of my macbook just fell off sad that the feet of my macbook just fell off',
#  'why am the last to find out about these things like that you re on the twitter too',
#  'absolutely not',
#  'filled with curry the true indian in me is coming out',
#  'im soooo cold right now',
#  'lol kant believe cam got beat upp sooo embarasssiiiin',
#  'good knight hun looking forward to ur tweets again hate that keep missing out on the fun cuz of the time difference',
#  'tumblr this is exactly how it feels wearing tie',
#  'hahaa just realized impune definitely isnt the word wanted dang so unclever',
#  'watching old videos of dance team and such makes me miss it',
#  'wahh no csi anywhere dvr ed love money though gonna watch it then sleep goodnight tweeters',
#  'struggling hard with inventory',
#  'do you hate us please do not',
#  'haha im not that ballin still got bills to paaaaay',
#  'in one of those days when really just want to work from home crap',
#  'wait is it game or just episodes so confused',
#  'haha cried guess he did',
#  'do not get statistics its all bunch of mumbo jumbo for me',
#  'got it sadly only works for uk us at the moment',
#  'evicted',
#  'does not enjoy learning css',
#  'brian do not make me fuck up lol replied ur message did get my miss',
#  'dvr it and went to watch it apparently the dish network went down so missed it will have to catch rerun',
#  'lmao may have to wait for another season to come thru its summe boo hot nd dry ass weather',
#  'can not set my feet on the ground the missing eyelid people might get me',
#  'my english professor would be ashamed',
#  'wish the frogs were not becoming extinct',
#  'came home from cross county tired as',
#  'do not want to walk home in this snow who wants to pick me up',
#  'lauren is being stubborn she loves you you love her feel so bad for you though it made me cry lol',
#  'is grouchy and wants bmar',
#  'my heart is broken every morning dropping foo at pre school now understand when moms say he has my heart broken',
#  'not feeling well and back hurts',
#  'im in the mood for some chocolate want miniature reeses cups now',
#  'can not take this heat it like an oven in here feel sick nwo',
#  'come to the chat just minutes please',
#  'boredd colddd internet keeps stuffing up',
#  'had horrible nightmare last night which affected my sleep now really tired',
#  'im lonely keep me company female new york',
#  'lost and it was st ignacius prepatory school haha',
#  'yeah it was really depressing stuff like that gets to me',
#  'no problem tongue in cheek remark lots of acronyms but no nz',
#  'hey you said matt was gonna go all ballistic was disappointed good ep tho mostly',
#  'ugh horrible ending to the sandra kantu story prayers go out',
#  'hate allergic want puppy soo bad that ve already thought some cool names',
#  'morning folks am yawn up away to see to horses hope twitter is better behaved today last night was travesty',
#  'miss mine too',
#  'sorry to hear about your loss there have been many this year so far',
#  'gossip girl was repeat',
#  'reckon',
#  'finding it really hard to use twitter',
#  've been stuck in this house for two days',
#  'is really sad and does not really know',
#  'no',
#  'maybe one of these years ll get tax return girl can dream right',
#  'back at work tired as hell and feel cold coming',
#  'april th is not coming soon enough',
#  'cream for his eye and he may have herpes not ocular herpes but different strain he doing okay though',
#  'gotta repeat whole art folio cuz old one with whole terms work got wet',
#  'ready for the weekend already it only monday',
#  'umm nope think im an insomniac plus got the flu lll be sleepin like phuckin fish outta water any minute now',
#  'has finland sleeping for the night not really enough time',
#  'can not wait to try em but prolly have to wait until next weekend at the earliest',
#  'shiner is taking up all my bed and blankets',
#  'april th is not coming soon enough',
#  'wants to cry',
#  'need to go to the bank tomorrow before go broke',
#  'this earthquake in italy has me sadden it only three hours away from naples where my family is',
#  'should be sleeping have stressed out week coming to me',
#  'yea am working tp hack my server to do the player thing for folks',
#  'has hurt her ankle and is going to the dr',
#  'oh noes how did you manage to send something to the trash can and empty it without noticing feel for ya',
#  'lost my free copy of radioactive so can not put it on my ipod grr and can not go out buy nother coz it came with that paper',
#  'doing make up shit',
#  'photoshop hate it when you crash',
#  'vacations makes me feel sick',
#  'you should not have gone',
#  'listening to murd and th wonder just chillen out missing my crazy sex life',
#  'shooting be careful luisa',
#  'sure everyone has ruined my gift to you whitney has my serious cell we doing easter as well',
#  'is at beso in hollywood so tired',
#  'do not want to wake up early tomorrow damn you work',
#  'just finished watching the movie prayers for bobby broke my heart',
#  'is myki really horrible',
#  'had put my dog down today too someone ran her over',
#  'sorry to hear about your dnf run tonight always risk to get bad coords on an ftf',
#  'did get some disgruntled people when wrote my esn but the hits in one day made up for it bill pulls in tops',
#  'ohh omg lmao crying right now lol kutnerrrr was the best',
#  'came back from running and took shower why does my lower stomach still hurt after exercising',
#  'watching fallon with mom and working on project school is hard',
#  'min till home time and counting have craving to visit the mac store but they will have closed by the time get there',
#  'am so sorry to hear that take care',
#  'hmmm greed is good when it motivates the individual to do better not so much when it takes away from others',
#  'brat you have to rub it in do not you want mocha',
#  'kutnerrrr why why and to think that is still on the show ugh kutner kal penn you ve been the bright star in ho',
#  'my mom has it wish you the best of luck',
#  'so hate homeworks my head hurts so bad',
#  'got the ebay blues item want jumped from no bidders to over in an hour still has hours to go better not get my hopes up',
#  'know was little depressed that we ate so much last night there were no leftovers today',
#  'well the pc in my living room suffered fatal partion lost all my itunes library is gone and some docs with pics',
#  'sad day manu out for the season',
#  'you poor spunky its so sad my rotti made it to and had to go down the same path know how you feel',
#  'im sooo sad right now need hug',
#  'wants her step brother home im so worried you dont even know hope he knows how much care for him',
#  'just got done watching the hills loved it excited for the next episode and im sad this is the last season',
#  'aww that stinks hugs',
#  'tired feel like crap and the world feels all crummy make me happy usb disco mouse',
#  'dont want to believe what im reading buu so sad',
#  'wondering why gamebattles is down',
#  'white trash vs us we were outnumbered',
#  'so true have it and do not use it',
#  'spring break is here at last but no one is here to celebrate',
#  'morning bah car will not start waiting for the anwb',
#  'which is pretty anti memorial tattoos but for all but the strictest there no official ban just disapproving family',
#  'balamurugan longterm member of the team is leaving this month we ll miss working with him hope he does well in his next venture',
#  'its sad knowing how they found her body what crazy world we live in no child deserves that ya know',
#  'wanna rock maxi dress coachella but lacking funding',
#  'of course the baby is screaming in the crib the night before my first day back at work so let him cry it out boooo',
#  'am home missing my baby busy week ahead fri is chill day with my guy and kids egg hunt sat spiral and dmb sat night and easter',
#  'never found her everytime click on her twitter thing through your myspace it goes to some dude page',
#  'that horrible sorryto hear that',
#  'cant find it it says dtmafiaofficial doesnt exist there jus dtmafia found dun seem to followin it wht to do',
#  'thought you would support me on this',
#  'augh eff sarth stole some of mil nail polish its pretty',
#  'wishes was on the spring fling tour with dawn neecee sigh knight',
#  'the hoyts distribution nz website is not working for me great and it has to be like this when need it most',
#  'do not like that they only had him in the first movie cillian murphy is hot',
#  'wishes for good old cartoons to come back ie captain planet where wally daria sadness',
#  'not feeling good abt myself',
#  'just got text from sarah',
#  'another day at centre point this time an early start so guessing train will be rammed with commuters',
#  'four games this fall modern warfare halo odst brutal legend and bioshock need more cash',
#  'ugh that disconcerting',
#  'actually the whole site has finally been taken over by those damn russians',
#  'my tweets arent going through',
#  'just finished delicious breakfast my last in paris ll miss milk europe has the tastiest milk in the world do not drink it in us',
#  'ilearn is down and out great considering finals are this week',
#  'stressed outttt',
#  'also shouldve bern asleep an hour ago',
#  'trying to figure out this twitter thing none of my friends are on yet soo much to see',
#  're pinging custom icons made look cool but the edges could be less square might look bad on diff background',
#  'want to be back in la',
#  'dunno how to use the forum and get frustrated with it ll miss talking to you on here',
#  'not an option',
#  'unfortunately one of those moments was not giant squid monster',
#  'want one too is the branch in midv open too',
#  'aw sorry to hear that',
#  'change of plans we ordered macs instead time to hit the books',
#  'yup',
#  'did you see donnie tweet stats almost replies and no jrk',
#  'nah have not received my stimulus yet',
#  'just seen ur tweet plz write bak if get this havnt got one reply bak',
#  'and you were trying to go to sleep hours ago',
#  'so sorry to hear that it always sad when we lose those close to us as we loved them',
#  'cant sleep but im still feelin like piece of shit',
#  'oh my sympathies it hard decision always hope my old border collie will go in her sleep she too hug',
# ...
#  'emailed you yesterday and never responded',
#  'it going to be long year for fans',
#  'just got done watching the new house episode definitely one of the saddest episodes ever',
#  'man taxes suck horrified that did something wrong on them turbotax decided to keep around lot of the stuff turned off',
#  'sleep time tomorrow is gonna suck',
#  'wtf not kutner oh so pissed house mean really wtf',
#  'know dont know why said that',
#  'cash rules everything around me',
#  'just picked up some oats from the market to eat for breakfast with my boy now time to do work at usc late night',
#  'feel sick too much icecream',
#  'this computer does not have shockwave blah no account yet',
#  'could go but its in sydney',
#  'hahaha suriously feel like everyone knows this show is joke except lc',
#  'just can not spell today totally suck',
#  'are you vaccinated against chicken pox should vaccinate my yr old am so confused about this damn thing',
#  'school at least last day',
#  'ya gotta get up early tomorrow who ready for the weekend',
#  'miss being at home for calving season sad that black one died this morning wish had some bottle calves',
#  'so sorry for your loss my brother dog sam is sick cushings disease',
#  'back to work get to spend the next hours alone in the dispatch room',
#  'there new kind of starburst favereds sounds fab bc cherry and strawberry are my fav red but they added watermellon and its yucky',
#  'well so much for being productive on my days off from angels',
#  'oh gee insomnia sucks have you tried melatonin',
#  'good to hear that we have support in netbeans but then its netbeans you know',
#  'wish we would get it the same time at the rest of world unfornately am in cairo and have to wait for mtva to play it',
#  'heartbroken over little sandra prayers are with the family',
#  'at words it all can do ll finish tomorrow maybe',
#  'how come ur background covers the screen but mine is in the corner',
#  'wrote exactly three lines of dialogue tonight then gave up',
#  'my only complaint about facebook is they ve changed it so much it confusing',
#  'sliced my finger',
#  'going thru town and traffic on bypass is stink',
#  'ugh can not sleep wish had good cuddle to make me ass out',
#  'hate when software update downloads updates without telling me never know what downloading when it is',
#  'went to ihop again great for diet at least there were no kung foo pancakes this time rachel',
#  'the internet is hating me night pose',
#  'so jealous missed all of opening day this year',
#  'it so cruel having to wait for reviews to come in so far it looks like star trek will be the best film of the year',
#  'debating if should just shower now so can sleep little later tomorrow',
#  'my stress always culminates with physical pain',
#  'need to sleep but cant',
#  'my little pinky finger hurts so much',
#  'sorry your gift card ran out that suck',
#  'home for spring break no one is home tho',
#  'accessed oneindia mobi from google phone android it does not support indic languages',
#  'why does school take over your life so much you do not get sleep anymore am still doing school work and have more to do as well',
#  'aw wish could can not really speak to my yia yia because she does not speak english',
#  'no free comp lol',
#  'getting ready to clean the house from top to bottom',
#  'crying my friend is moving away tomorrow',
#  'stop nomnoms you did not share night peoples',
#  'thinks she is getting cold that she caught from daddy oh no my trip would be ruined',
#  'yeah is it bcoz kal penn is visiting lecturer somewhere cant be on the show anymore im gonna miss him',
#  'so the procrastination starts early in the quarter do not want to reaaaaad and write paper',
#  'what apparently it degress at pm in washington state miss winter already',
#  'being bored at homee',
#  'massage was great just spilled coke all over my desk lame watching the simpsons as ve finished all my hills dvds',
#  'will wait for you at fanclub chat even tough you re not my favorite',
#  'has mild left inner ear infection and its got this irritating blocked feeling since sunday',
#  'hey there nope my cuteness is away for awhile',
#  'it only tuesday',
#  'haha not even yo just did not know how to do that to you on twitter haha',
#  'someones alarm clock or phone woke me up at am still got my headache from yesterday night',
#  'puppy is she ok',
#  'might break down and eat some buffalo wings tomorrow',
#  'sittin here kayla really really reallly dis like having brother he does not know when to stop waiting for the day when one of',
#  'fed bokkie too many birthday treats sicko',
#  'kinda bummed an agency just told me that did not have the look that they were going for ladies please help me create the look',
#  'work laptop is officially dead not happy at all',
#  'my goodness it freezing down here',
#  'why do you put up with him you should listen to your mom',
#  'is stucked in paris and can not even travel into france for work',
#  'do not think there one close by last time checked the closest one was miles away',
#  'aaaaand back to my literature review at least have friendly cup of coffee to keep me company',
#  'am worried that will not get my even though paid buttload of tax last year',
#  'okay so still no school',
#  'is phoneless now off too sleep',
#  'reeked of alcohol at the dentist this morning was drunk when put on my tshirt realised it had huge stain dentist looked disgusted',
#  'it is really cold',
#  'cant sleep she wants to dream',
#  'can not sleep hate these nights when try to go to bed early and stay awake for hours poo',
#  'yeah too bad people like certain burrito eating man exist',
#  'that sad',
#  'just found out that my mum and my adopted auntie are on twitter check them out my mum is tessm and my awesome as auntie is tania',
#  'cannot sleep wide awake and gotta go to work later too boy am going to have crappy day',
#  'struggling with eam law',
#  'why can not sleep like her',
#  'bouts to start poor linny could not keep her eyes open she tired and has to work tomorrow morning night',
#  'my year old year old is driving me around the twist do not want to be like this',
#  'well that sucked',
#  'have to be out of my place in days any help can get packing painting cleaning is much appreciated oh and rip my wall',
#  'opening partially frozen beer beer on the toaster under the oven and all over the counter the kitchen smells like we run speakeasy',
#  'no dont even know how to ride it',
#  'sadly yes think need counciling now',
#  'making myself ready for school do not feel like going but have two tests',
#  'smugness gone my train also failed to turn up so heading for victoria followed by an unpleasant tube ride to the city',
#  'anybody know where my ipod went',
#  'aww this earthquake in italy has made me sad just saw the pics on the news it terrible',
#  'never been able to afford to get them out much rather go through the extraction than continue with what deal with now',
#  'why do other pet care people try to run others out of business or send suspicious mails fishing for info',
#  'codez they ve been mia tho',
#  'doesnt work on my cell go to sleep',
#  'it going to be nice again tomorrow and then the rain comes back no nice weather for my birthday',
#  'rock band is hard on expert',
#  'roomie was home all day all he had to do was scratch at the door comforter has to goto large laundromat machines',
#  'one of the hardest thing with this schedule no one can chat with at the end of my day usually',
#  'they killed off character on one of my favorite shows and now upset',
#  'jealous of my friends who got to see the new star trek film in austin tonight',
#  'listening to got really bad headache and drivin lesson in ten mins lucky me just wana sleeep',
#  'shut up you am hungry and in britain home of the most boring suckassy breakfast in the world miss dennys',
#  'good morning everybody pkoi fais pas beau bon coffee time',
#  'work again',
#  'essay time',
#  'hey did talk to mom they home yet hope they ok wish was coming home easter',
#  'sure wish could go with you guys tmrw but as per usual school interferes',
#  'say what kal penn leaving house noooooo totally missed it tonight',
#  'no lost loyal',
#  'played another hand very bad and lost half my stack',
#  'it pm early days in looooooong night at work',
#  'it sad it the last season wanna see when spencer calls lauren',
#  'so im done editing the phipstape back crack brew and see what we got no trees though',
#  'do not know what half of that means',
#  'homework homework homework',
#  'worked his heart out today doubling my weight at each station result stiff and pulled muscles ouch',
#  'now feel bad for unfollowing',
#  'so tired god hate the new job and only two days in',
#  'sad about kutner being killed off my fav show house',
#  'happy for coach stringer hof now if can only finish my term paper on her',
#  'feel like shit this is not the way want to spend my birthday eve',
#  'so far have on all my sites put together most of them were me checking out the updates made',
#  'has lot on her mind needs to make some moneys and ideas nowhere is hiring',
#  'miss you',
#  'so sorry to hear about your dog',
#  'too much internet how it plagues me',
#  'miss my ex soo much',
#  'sodding',
#  'oh thought the pirate bay trial verdict was today apparently it in days',
#  'call me back',
#  'is in study hall now and will log off immediately',
#  'it so tired that im crying for no reason at all im about to try to get an hour and half in for tonight half what got last night',
#  'totally have like four girl options and none of them seem viable',
#  'so far have veiws on all my sites put together most of them were me checking out the updates made',
#  'listening to bjork all is full of love crying',
#  'omg the hills then love money aww think becky buckwild goes',
#  'is craving for some tantan nabe',
#  'mon sean man',
#  'watching league of their own makes me miss mint chocolate ice cream cones and my grand ma fuck',
#  'lost my phone some where maybe in the grass its just so long hope it does not rain',
#  'hope you are not referring to me say hello to your new stalker lol',
#  'why were sleeping ur gonna be up all night now how was ur bike ride',
#  'but but but wanna listen to the masters too',
#  've been looking about for good stuff to write but also been doing loads of uni work',
#  'feel unloved dropped tweeters',
#  'off to london for the day on thursday it gonna be raining oh fab will not see much on the london eye still robbie will not care bless him',
#  'completely wiped and reloaded the lost all bbm contacts going to bed sad',
#  'sayyyy whaaaa was not invited',
#  'did not sleep too bad considering have workshop starting today beginnings of sore throat though',
#  'oh my gosh that made me emotional haha idk why dont want to get old',
#  'we re going to post some stories manually due to twitterfeed problem that why we ve been so quiet lately',
#  'do not like lukewarm showers',
#  'who should contact if need for freelance work did on linux com throughout never got one',
#  'connor it me febi are you really really mad at me',
#  'need some help want to buy macbook pro but still inlove with my old powerbook',
#  'man america is so borez anyway lol just realized you sent me msgs on here had no idea have no flash',
#  'knight lovely ladies sleepy now',
#  'does anybody know how to get your electrolytes back in order with vitamin work feel sick',
#  'yes someone has not been reading my posts properly',
#  'almost through with my italian homework weeeeee now if only understood what was doing',
#  'who turned the lights on it will be time to get ip then',
#  'twitter hates us both then',
#  'hate the fact that genuinely excited about my last tweet',
#  'can not sleep either',
#  'between that and the italy earthquake it been very sad news day',
#  'all rain today garden really needs it so not quite so bad',
#  'yawn yawn yawn more minutes in bed',
#  'ouch sounds very sucky',
#  'great idea with the itunes promo codes they do not work in the uk itunes store though',
#  'cry',
#  'an empty rum barrel is sad rum barrel shakes head the horror the horror',
#  'it was sleepless night',
#  'she admitted to being fake',
#  'love chutney',
#  'got highly bored today scanning pages for daddy had to do it',
#  'you cooked risotto without me',
#  'keeeerrrrriiiiii really have nothing better to do then post on this thing at am wonderfullll says alot',
#  'yay for baseball season boo to yankees losing their first game',
#  'lost sucks because have to work today',
#  'omg exams killed me how could not know the difference between haif circle and hemisphere',
#  'in bed suddenly feel wish ma was here me goodnight twitterfam',
#  'do not like goodnights',
#  'greaaat my lappy will not turn on wtffffff',
#  'you stuck in traffic then my journey was traffic free this morning if it any help',
#  'lookin like an all nighter hate it when do this to myself',
#  'you re stranger',
#  'debbugging old vb code the day could have started better',
#  'only quarter of percent babe darn',
#  'coming down with cold or bad allergies either way miserable',
#  'can not believe cutner is dead on house sad day in santa rosa ca',
#  'damnit was really digging this season of reaper',
#  'gah comcast doubled our cable internet bill out telling us so we are quitting can anyone suggest an affordable company in bay area',
#  'another early morn with the duchess although she had not managed to cross her legs this time',
#  'you left without saying hi',
#  'want but can not sleep',
#  'when an xbox shows those three red lights it means it dead and needs to be fixed for month at microsoft hq',
#  'king sized bed is nice but sad and lonely with no hubby puppy or kitty am over this whole conferenceing thing',
#  'im boredd gah wish could just sleep and get it over with but ive had toooo muchh cooooffffeeeeeeeee bahaha',
#  'if may butt in again done being nosey sorry your conversation was just so interesting',
#  'you fell off my list did offend you',
#  'weeks till sisters home missed her call again its the worst feeling in the world',
#  'gonna try to get some sleep in this hotel room',
#  'brilliant idea just bring as much as you think you ll spend ll swap you bring brolly',
#  'get me an autograph and shout out you have to record it though my computer is dead so can not listen',
#  'rt khloe just got fired from the apprentice',
#  'in biology class my lip hurts',
#  'sorry for the next tweet',
#  'grr not down to go to school today',
#  'had to get an hd tivo and just got it set up tonight in order to get channels',
#  'asked everyone how they were doing yesterday and not single tweet back',
#  'ruddy money like it still waiting here oh what surprise by state too hmmm seriously',
#  'am so sad kutner was my favorite of the new team',
#  'wow did not get an hello suck',
#  'bedtime school tomorrow and still have no books being broke suckssss',
#  'seating here helping my baby with his papers well he is forcing me too seat with him im sleepy',
#  'synching my contacts from my old mobile to iphone import does not work well',
#  'can not concentrate',
#  've just spent hour to enter all the bureaucratic nonsense for march what waste of my time',
#  'nw more confused then ever',
#  'not feeling well again stupid migraine making my tummy upset and my whole body aches shoot me now',
#  'reading buyology before bedtime great premise but only turning out to be an ok book lots of info already knew',
#  'home really wana sleep but due to wasting my free line in town have an assignment to finish',
#  'also send some updates in plurk but upload photos on twitter you didnt see any of my updates on plurk zero',
#  'omg the reader is making me',
#  'oh at least you re getting decent exchange rate at the moment sterling is still getting flogged',
#  'tried to download tweetdeck but it wont download',
#  'there an inch of snow on the ground and counting worried about the poor flowers',
#  'why are not you happy camper',
#  'thanks man so very grateful feel unworthy of such attention though because in this because of myself',
#  'miss too totally comin back tho lastnight was sooooooo much fun',
#  'ohhh love it ps sad we did not get to hang out',
#  'and somehow still end up in this place',
#  'oh that is very sad poor boy',
#  ...]

# %% [markdown]
# ## Tokenization

# %%
#tokenize words in clean_tweet_texts

from nltk import word_tokenize

word_tokens = [ ] #initialise an empty list 
for word in clean_tweet_texts:
    word_tokens.append(word_tokenize(word))

# %%
#print word_tokens list

word_tokens
# Out:
# [['awww',
#   'that',
#   'bummer',
#   'you',
#   'shoulda',
#   'got',
#   'david',
#   'carr',
#   'of',
#   'third',
#   'day',
#   'to',
#   'do',
#   'it'],
#  ['is',
#   'upset',
#   'that',
#   'he',
#   'can',
#   'not',
#   'update',
#   'his',
#   'facebook',
#   'by',
#   'texting',
#   'it',
#   'and',
#   'might',
#   'cry',
#   'as',
#   'result',
#   'school',
#   'today',
#   'also',
#   'blah'],
#  ['dived',
#   'many',
#   'times',
#   'for',
#   'the',
#   'ball',
#   'managed',
#   'to',
#   'save',
#   'the',
#   'rest',
#   'go',
#   'out',
#   'of',
#   'bounds'],
#  ['my', 'whole', 'body', 'feels', 'itchy', 'and', 'like', 'its', 'on', 'fire'],
#  ['no',
#   'it',
#   'not',
#   'behaving',
#   'at',
#   'all',
#   'mad',
#   'why',
#   'am',
#   'here',
#   'because',
#   'can',
#   'not',
#   'see',
#   'you',
#   'all',
#   'over',
#   'there'],
#  ['not', 'the', 'whole', 'crew'],
#  ['need', 'hug'],
#  ['hey',
#   'long',
#   'time',
#   'no',
#   'see',
#   'yes',
#   'rains',
#   'bit',
#   'only',
#   'bit',
#   'lol',
#   'fine',
#   'thanks',
#   'how',
#   'you'],
#  ['nope', 'they', 'did', 'not', 'have', 'it'],
#  ['que', 'me', 'muera'],
#  ['spring', 'break', 'in', 'plain', 'city', 'it', 'snowing'],
#  ['just', 're', 'pierced', 'my', 'ears'],
#  ['could',
#   'not',
#   'bear',
#   'to',
#   'watch',
#   'it',
#   'and',
#   'thought',
#   'the',
#   'ua',
#   'loss',
#   'was',
#   'embarrassing'],
#  ['it',
#   'it',
#   'counts',
#   'idk',
#   'why',
#   'did',
#   'either',
#   'you',
#   'never',
#   'talk',
#   'to',
#   'me',
#   'anymore'],
#  ['would',
#   've',
#   'been',
#   'the',
#   'first',
#   'but',
#   'did',
#   'not',
#   'have',
#   'gun',
#   'not',
#   'really',
#   'though',
#   'zac',
#   'snyder',
#   'just',
#   'doucheclown'],
#  ['wish',
#   'got',
#   'to',
#   'watch',
#   'it',
#   'with',
#   'you',
#   'miss',
#   'you',
#   'and',
#   'how',
#   'was',
#   'the',
#   'premiere'],
#  ['hollis',
#   'death',
#   'scene',
#   'will',
#   'hurt',
#   'me',
#   'severely',
#   'to',
#   'watch',
#   'on',
#   'film',
#   'wry',
#   'is',
#   'directors',
#   'cut',
#   'not',
#   'out',
#   'now'],
#  ['about', 'to', 'file', 'taxes'],
#  ['ahh',
#   'ive',
#   'always',
#   'wanted',
#   'to',
#   'see',
#   'rent',
#   'love',
#   'the',
#   'soundtrack'],
#  ['oh',
#   'dear',
#   'were',
#   'you',
#   'drinking',
#   'out',
#   'of',
#   'the',
#   'forgotten',
#   'table',
#   'drinks'],
#  ['was',
#   'out',
#   'most',
#   'of',
#   'the',
#   'day',
#   'so',
#   'did',
#   'not',
#   'get',
#   'much',
#   'done'],
#  ['one',
#   'of',
#   'my',
#   'friend',
#   'called',
#   'me',
#   'and',
#   'asked',
#   'to',
#   'meet',
#   'with',
#   'her',
#   'at',
#   'mid',
#   'valley',
#   'today',
#   'but',
#   've',
#   'no',
#   'time',
#   'sigh'],
#  ['baked', 'you', 'cake', 'but', 'ated', 'it'],
#  ['this', 'week', 'is', 'not', 'going', 'as', 'had', 'hoped'],
#  ['blagh', 'class', 'at', 'tomorrow'],
#  ['hate', 'when', 'have', 'to', 'call', 'and', 'wake', 'people', 'up'],
#  ['just',
#   'going',
#   'to',
#   'cry',
#   'myself',
#   'to',
#   'sleep',
#   'after',
#   'watching',
#   'marley',
#   'and',
#   'me'],
#  ['im', 'sad', 'now', 'miss', 'lilly'],
#  ['ooooh',
#   'lol',
#   'that',
#   'leslie',
#   'and',
#   'ok',
#   'will',
#   'not',
#   'do',
#   'it',
#   'again',
#   'so',
#   'leslie',
#   'will',
#   'not',
#   'get',
#   'mad',
#   'again'],
#  ['meh',
#   'almost',
#   'lover',
#   'is',
#   'the',
#   'exception',
#   'this',
#   'track',
#   'gets',
#   'me',
#   'depressed',
#   'every',
#   'time'],
#  ['some',
#   'hacked',
#   'my',
#   'account',
#   'on',
#   'aim',
#   'now',
#   'have',
#   'to',
#   'make',
#   'new',
#   'one'],
#  ['want',
#   'to',
#   'go',
#   'to',
#   'promote',
#   'gear',
#   'and',
#   'groove',
#   'but',
#   'unfornately',
#   'no',
#   'ride',
#   'there',
#   'may',
#   'going',
#   'to',
#   'the',
#   'one',
#   'in',
#   'anaheim',
#   'in',
#   'may',
#   'though'],
#  ['thought',
#   'sleeping',
#   'in',
#   'was',
#   'an',
#   'option',
#   'tomorrow',
#   'but',
#   'realizing',
#   'that',
#   'it',
#   'now',
#   'is',
#   'not',
#   'evaluations',
#   'in',
#   'the',
#   'morning',
#   'and',
#   'work',
#   'in',
#   'the',
#   'afternoon'],
#  ['awe', 'love', 'you', 'too', 'am', 'here', 'miss', 'you'],
#  ['cry', 'my', 'asian', 'eyes', 'to', 'sleep', 'at', 'night'],
#  ['ok',
#   'sick',
#   'and',
#   'spent',
#   'an',
#   'hour',
#   'sitting',
#   'in',
#   'the',
#   'shower',
#   'cause',
#   'was',
#   'too',
#   'sick',
#   'to',
#   'stand',
#   'and',
#   'held',
#   'back',
#   'the',
#   'puke',
#   'like',
#   'champ',
#   'bed',
#   'now'],
#  ['ill',
#   'tell',
#   'ya',
#   'the',
#   'story',
#   'later',
#   'not',
#   'good',
#   'day',
#   'and',
#   'ill',
#   'be',
#   'workin',
#   'for',
#   'like',
#   'three',
#   'more',
#   'hours'],
#  ['sorry', 'bed', 'time', 'came', 'here', 'gmt'],
#  ['do',
#   'not',
#   'either',
#   'its',
#   'depressing',
#   'do',
#   'not',
#   'think',
#   'even',
#   'want',
#   'to',
#   'know',
#   'about',
#   'the',
#   'kids',
#   'in',
#   'suitcases'],
#  ['bed',
#   'class',
#   'work',
#   'gym',
#   'or',
#   'then',
#   'class',
#   'another',
#   'day',
#   'that',
#   'gon',
#   'na',
#   'fly',
#   'by',
#   'miss',
#   'my',
#   'girlfriend'],
#  ['really',
#   'do',
#   'not',
#   'feel',
#   'like',
#   'getting',
#   'up',
#   'today',
#   'but',
#   'got',
#   'to',
#   'study',
#   'to',
#   'for',
#   'tomorrows',
#   'practical',
#   'exam'],
#  ['he',
#   'the',
#   'reason',
#   'for',
#   'the',
#   'teardrops',
#   'on',
#   'my',
#   'guitar',
#   'the',
#   'only',
#   'one',
#   'who',
#   'has',
#   'enough',
#   'of',
#   'me',
#   'to',
#   'break',
#   'my',
#   'heart'],
#  ['sad',
#   'sad',
#   'sad',
#   'do',
#   'not',
#   'know',
#   'why',
#   'but',
#   'hate',
#   'this',
#   'feeling',
#   'wan',
#   'na',
#   'sleep',
#   'and',
#   'still',
#   'can',
#   'not'],
#  ['soo',
#   'wish',
#   'was',
#   'there',
#   'to',
#   'see',
#   'you',
#   'finally',
#   'comfortable',
#   'im',
#   'sad',
#   'that',
#   'missed',
#   'it'],
#  ['falling',
#   'asleep',
#   'just',
#   'heard',
#   'about',
#   'that',
#   'tracy',
#   'girl',
#   'body',
#   'being',
#   'found',
#   'how',
#   'sad',
#   'my',
#   'heart',
#   'breaks',
#   'for',
#   'that',
#   'family'],
#  ['yay',
#   'happy',
#   'for',
#   'you',
#   'with',
#   'your',
#   'job',
#   'but',
#   'that',
#   'also',
#   'means',
#   'less',
#   'time',
#   'for',
#   'me',
#   'and',
#   'you'],
#  ['just',
#   'checked',
#   'my',
#   'user',
#   'timeline',
#   'on',
#   'my',
#   'blackberry',
#   'it',
#   'looks',
#   'like',
#   'the',
#   'twanking',
#   'is',
#   'still',
#   'happening',
#   'are',
#   'ppl',
#   'still',
#   'having',
#   'probs',
#   'bgs',
#   'and',
#   'uids'],
#  ['oh',
#   'man',
#   'was',
#   'ironing',
#   'fave',
#   'top',
#   'to',
#   'wear',
#   'to',
#   'meeting',
#   'burnt',
#   'it'],
#  ['is', 'strangely', 'sad', 'about', 'lilo', 'and', 'samro', 'breaking', 'up'],
#  ['oh',
#   'so',
#   'sorry',
#   'did',
#   'not',
#   'think',
#   'about',
#   'that',
#   'before',
#   'retweeting'],
#  ['broadband',
#   'plan',
#   'massive',
#   'broken',
#   'promise',
#   'via',
#   'still',
#   'waiting',
#   'for',
#   'broadband',
#   'we',
#   'are'],
#  ['wow',
#   'tons',
#   'of',
#   'replies',
#   'from',
#   'you',
#   'may',
#   'have',
#   'to',
#   'unfollow',
#   'so',
#   'can',
#   'see',
#   'my',
#   'friends',
#   'tweets',
#   'you',
#   're',
#   'scrolling',
#   'the',
#   'feed',
#   'lot'],
#  ['our',
#   'duck',
#   'and',
#   'chicken',
#   'are',
#   'taking',
#   'wayyy',
#   'too',
#   'long',
#   'to',
#   'hatch'],
#  ['put',
#   'vacation',
#   'photos',
#   'online',
#   'few',
#   'yrs',
#   'ago',
#   'pc',
#   'crashed',
#   'and',
#   'now',
#   'forget',
#   'the',
#   'name',
#   'of',
#   'the',
#   'site'],
#  ['need', 'hug'],
#  ['not',
#   'sure',
#   'what',
#   'they',
#   'are',
#   'only',
#   'that',
#   'they',
#   'are',
#   'pos',
#   'as',
#   'much',
#   'as',
#   'want',
#   'to',
#   'dont',
#   'think',
#   'can',
#   'trade',
#   'away',
#   'company',
#   'assets',
#   'sorry',
#   'andy'],
#  ['hate', 'when', 'that', 'happens'],
#  ['have',
#   'sad',
#   'feeling',
#   'that',
#   'dallas',
#   'is',
#   'not',
#   'going',
#   'to',
#   'show',
#   'up',
#   'got',
#   'ta',
#   'say',
#   'though',
#   'you',
#   'think',
#   'more',
#   'shows',
#   'would',
#   'use',
#   'music',
#   'from',
#   'the',
#   'game',
#   'mmm'],
#  ['ugh', 'degrees', 'tomorrow'],
#  ['where',
#   'did',
#   'move',
#   'to',
#   'thought',
#   'were',
#   'already',
#   'in',
#   'sd',
#   'hmmm',
#   'random',
#   'found',
#   'me',
#   'glad',
#   'to',
#   'hear',
#   'yer',
#   'doing',
#   'well'],
#  ['miss',
#   'my',
#   'ps',
#   'it',
#   'out',
#   'of',
#   'commission',
#   'wutcha',
#   'playing',
#   'have',
#   'you',
#   'copped',
#   'blood',
#   'on',
#   'the',
#   'sand'],
#  ['just', 'leaving', 'the', 'parking', 'lot', 'of', 'work'],
#  ['the', 'life', 'is', 'cool', 'but', 'not', 'for', 'me'],
#  ['sadly',
#   'though',
#   've',
#   'never',
#   'gotten',
#   'to',
#   'experience',
#   'the',
#   'post',
#   'coitus',
#   'cigarette',
#   'before',
#   'and',
#   'now',
#   'never',
#   'will'],
#  ['had',
#   'such',
#   'nice',
#   'day',
#   'too',
#   'bad',
#   'the',
#   'rain',
#   'comes',
#   'in',
#   'tomorrow',
#   'at',
#   'am'],
#  ['too',
#   'bad',
#   'will',
#   'not',
#   'be',
#   'around',
#   'lost',
#   'my',
#   'job',
#   'and',
#   'can',
#   'not',
#   'even',
#   'pay',
#   'my',
#   'phone',
#   'bill',
#   'lmao',
#   'aw',
#   'shucks'],
#  ['damm', 'back', 'to', 'school', 'tomorrow'],
#  ['mo',
#   'jobs',
#   'no',
#   'money',
#   'how',
#   'in',
#   'the',
#   'hell',
#   'is',
#   'min',
#   'wage',
#   'here',
#   'clams',
#   'an',
#   'hour'],
#  ['not', 'forever', 'see', 'you', 'soon'],
#  ['agreed', 'saw', 'the', 'failwhale', 'allllll', 'day', 'today'],
#  ['oh',
#   'haha',
#   'dude',
#   'dont',
#   'really',
#   'look',
#   'at',
#   'em',
#   'unless',
#   'someone',
#   'says',
#   'hey',
#   'added',
#   'you',
#   'sorry',
#   'so',
#   'terrible',
#   'at',
#   'that',
#   'need',
#   'pop',
#   'up'],
#  ['sure',
#   'you',
#   're',
#   'right',
#   'need',
#   'to',
#   'start',
#   'working',
#   'out',
#   'with',
#   'you',
#   'and',
#   'the',
#   'nikster',
#   'or',
#   'jared',
#   'at',
#   'least'],
#  ['really',
#   'hate',
#   'how',
#   'people',
#   'diss',
#   'my',
#   'bands',
#   'trace',
#   'is',
#   'clearly',
#   'not',
#   'ugly'],
#  ['gym',
#   'attire',
#   'today',
#   'was',
#   'puma',
#   'singlet',
#   'adidas',
#   'shorts',
#   'and',
#   'black',
#   'business',
#   'socks',
#   'and',
#   'leather',
#   'shoes',
#   'lucky',
#   'did',
#   'not',
#   'run',
#   'into',
#   'any',
#   'cute',
#   'girls'],
#  ['why', 'will', 'not', 'you', 'show', 'my', 'location'],
#  ['no', 'picnic', 'my', 'phone', 'smells', 'like', 'citrus'],
#  ['my',
#   'donkey',
#   'is',
#   'sensitive',
#   'about',
#   'such',
#   'comments',
#   'nevertheless',
#   'he',
#   'and',
#   'me',
#   'be',
#   'glad',
#   'to',
#   'see',
#   'your',
#   'mug',
#   'asap',
#   'charger',
#   'is',
#   'still',
#   'awol'],
#  ['no', 'new', 'csi', 'tonight', 'fml'],
#  ['think', 'my', 'arms', 'are', 'sore', 'from', 'tennis'],
#  ['wonders',
#   'why',
#   'someone',
#   'that',
#   'like',
#   'so',
#   'much',
#   'can',
#   'make',
#   'you',
#   'so',
#   'unhappy',
#   'in',
#   'split',
#   'seccond',
#   'depressed'],
#  ['sleep',
#   'soon',
#   'just',
#   'hate',
#   'saying',
#   'bye',
#   'and',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'the',
#   'night'],
#  ['just',
#   'got',
#   'ur',
#   'newsletter',
#   'those',
#   'fares',
#   'really',
#   'are',
#   'unbelievable',
#   'shame',
#   'already',
#   'booked',
#   'and',
#   'paid',
#   'for',
#   'mine'],
#  ['missin', 'the', 'boo'],
#  ['me', 'too', 'itm'],
#  ['damn',
#   'do',
#   'not',
#   'have',
#   'any',
#   'chalk',
#   'my',
#   'chalkboard',
#   'is',
#   'useless'],
#  ['had',
#   'blast',
#   'at',
#   'the',
#   'getty',
#   'villa',
#   'but',
#   'hates',
#   'that',
#   'she',
#   'had',
#   'sore',
#   'throat',
#   'all',
#   'day',
#   'it',
#   'just',
#   'getting',
#   'worse',
#   'too'],
#  ['hey', 'missed', 'ya', 'at', 'the', 'meeting', 'sup', 'mama'],
#  ['my',
#   'tummy',
#   'hurts',
#   'wonder',
#   'if',
#   'the',
#   'hypnosis',
#   'has',
#   'anything',
#   'to',
#   'do',
#   'with',
#   'it',
#   'if',
#   'so',
#   'it',
#   'working',
#   'get',
#   'it',
#   'stop',
#   'smoking'],
#  ['why', 'is', 'it', 'always', 'the', 'fat', 'ones'],
#  ['sorry',
#   'babe',
#   'my',
#   'fam',
#   'annoys',
#   'me',
#   'too',
#   'thankfully',
#   'they',
#   're',
#   'asleep',
#   'right',
#   'now',
#   'muahaha',
#   'evil',
#   'laugh'],
#  ['should',
#   'have',
#   'paid',
#   'more',
#   'attention',
#   'when',
#   'we',
#   'covered',
#   'photoshop',
#   'in',
#   'my',
#   'webpage',
#   'design',
#   'class',
#   'in',
#   'undergrad'],
#  ['wednesday', 'my', 'day', 'do', 'not', 'know', 'what', 'do'],
#  ['poor', 'cameron', 'the', 'hills'],
#  ['pray',
#   'for',
#   'me',
#   'please',
#   'the',
#   'ex',
#   'is',
#   'threatening',
#   'to',
#   'start',
#   'sh',
#   'at',
#   'my',
#   'our',
#   'babies',
#   'st',
#   'birthday',
#   'party',
#   'what',
#   'jerk',
#   'and',
#   'still',
#   'have',
#   'headache'],
#  ['hmm',
#   'do',
#   'really',
#   'enjoy',
#   'being',
#   'with',
#   'him',
#   'if',
#   'the',
#   'problems',
#   'are',
#   'too',
#   'constants',
#   'should',
#   'think',
#   'things',
#   'more',
#   'find',
#   'someone',
#   'ulike'],
#  ['strider', 'is', 'sick', 'little', 'puppy'],
#  ['so',
#   'rylee',
#   'grace',
#   'wana',
#   'go',
#   'steve',
#   'party',
#   'or',
#   'not',
#   'sadly',
#   'since',
#   'its',
#   'easter',
#   'wnt',
#   'able',
#   'do',
#   'much',
#   'but',
#   'ohh',
#   'well'],
#  ['hey',
#   'actually',
#   'won',
#   'one',
#   'of',
#   'my',
#   'bracket',
#   'pools',
#   'too',
#   'bad',
#   'it',
#   'was',
#   'not',
#   'the',
#   'one',
#   'for',
#   'money'],
#  ['you', 'do', 'not', 'follow', 'me', 'either', 'and', 'work', 'for', 'you'],
#  ['bad',
#   'nite',
#   'for',
#   'the',
#   'favorite',
#   'teams',
#   'astros',
#   'and',
#   'spartans',
#   'lose',
#   'the',
#   'nite',
#   'out',
#   'with',
#   'was',
#   'good'],
#  ['body',
#   'of',
#   'missing',
#   'northern',
#   'calif',
#   'girl',
#   'found',
#   'police',
#   'have',
#   'found',
#   'the',
#   'remains',
#   'of',
#   'missing',
#   'northern',
#   'california',
#   'girl'],
#  ['hope',
#   'they',
#   'will',
#   'increase',
#   'the',
#   'capacity',
#   'fast',
#   'yesterday',
#   'was',
#   'such',
#   'pain',
#   'got',
#   'the',
#   'fail',
#   'whale',
#   'times',
#   'in',
#   'hours'],
#  ['behind', 'on', 'my', 'classes', 'for', 'work'],
#  ['watching', 'house'],
#  ['remember',
#   'my',
#   'bum',
#   'leg',
#   'strikes',
#   'back',
#   'this',
#   'time',
#   'its',
#   'serious'],
#  ['cool',
#   'will',
#   'their',
#   'are',
#   'all',
#   'kinds',
#   'of',
#   'complaints',
#   'about',
#   'this',
#   'laptop',
#   'online',
#   'about',
#   'overheating',
#   'but',
#   'no',
#   'recalls'],
#  ['emily',
#   'will',
#   'be',
#   'glad',
#   'when',
#   'mommy',
#   'is',
#   'done',
#   'training',
#   'at',
#   'her',
#   'new',
#   'job',
#   'she',
#   'misses',
#   'her'],
#  ['would',
#   'rather',
#   'the',
#   'first',
#   'party',
#   'send',
#   'bad',
#   'messages',
#   'than',
#   'the',
#   'rd',
#   'party',
#   'send',
#   'mixed',
#   'ones',
#   'sophmore',
#   'year',
#   'all',
#   'over',
#   'again'],
#  ['it', 'overrated'],
#  ['know',
#   'heard',
#   'it',
#   'this',
#   'afternoon',
#   'and',
#   'wondered',
#   'the',
#   'same',
#   'thing',
#   'moscow',
#   'is',
#   'so',
#   'behind',
#   'the',
#   'times'],
#  ['laying', 'in', 'bed', 'with', 'no', 'voice'],
#  ['sooo',
#   'sad',
#   'they',
#   'killed',
#   'off',
#   'kutner',
#   'on',
#   'house',
#   'whyyyyyyyy'],
#  ['sorry',
#   'tell',
#   'them',
#   'mea',
#   'culpa',
#   'from',
#   'me',
#   'and',
#   'that',
#   'really',
#   'am',
#   'sorry'],
#  ['it',
#   'did',
#   'not',
#   'make',
#   'any',
#   'sense',
#   'to',
#   'me',
#   'the',
#   'suicide',
#   'thing',
#   'refuse',
#   'to',
#   'believe',
#   'that',
#   'that',
#   'is',
#   'actually',
#   'what',
#   'happened'],
#  ['hope', 'your', 'ok'],
#  ['damn',
#   'the',
#   'grind',
#   'is',
#   'inspirational',
#   'and',
#   'saddening',
#   'at',
#   'the',
#   'same',
#   'time',
#   'do',
#   'not',
#   'want',
#   'you',
#   'to',
#   'stop',
#   'cuz',
#   'like',
#   'what',
#   'do',
#   'much',
#   'love'],
#  ['yeah', 'aw', 'but', 'know', 'wudnt', 'stand', 'chance'],
#  ['ugh', 'cant', 'sleep', 'its', 'am'],
#  ['hanging', 'in', 'crooners', 'wan', 'na', 'sing', 'can', 'not', 'sucks'],
#  ['aaw',
#   'miss',
#   'ya',
#   'all',
#   'too',
#   'im',
#   'leaving',
#   'to',
#   'bh',
#   'tomorrow',
#   'morning',
#   'think',
#   'aww',
#   'wan',
#   'na',
#   'go',
#   'to',
#   'the',
#   'beach',
#   'girls'],
#  ['is',
#   'pissed',
#   'off',
#   'that',
#   'there',
#   'no',
#   'asba',
#   'for',
#   'radio',
#   'station'],
#  ['wednesday', 'my', 'day', 'do', 'not', 'know', 'what', 'do'],
#  ['know',
#   'my',
#   'life',
#   'has',
#   'been',
#   'flipped',
#   'upside',
#   'down',
#   'when',
#   'just',
#   'thought',
#   'in',
#   'my',
#   'head',
#   'that',
#   'some',
#   'ramen',
#   'sounds',
#   'good'],
#  ['am',
#   'in',
#   'pain',
#   'my',
#   'back',
#   'and',
#   'sides',
#   'hurt',
#   'not',
#   'to',
#   'mention',
#   'crying',
#   'is',
#   'made',
#   'of',
#   'fail'],
#  ['late',
#   'night',
#   'snack',
#   'glass',
#   'of',
#   'oj',
#   'down',
#   'with',
#   'the',
#   'sickness',
#   'then',
#   'back',
#   'to',
#   'sleep',
#   'ugh',
#   'hate',
#   'getting',
#   'sick'],
#  ['but', 'but', 'but', 'not', 'big', 'fan', 'on', 'camilla', 'belle'],
#  ['wah',
#   'can',
#   'not',
#   'see',
#   'clip',
#   'must',
#   'be',
#   'el',
#   'stupido',
#   'work',
#   'filters',
#   'can',
#   'not',
#   'wait',
#   'till',
#   'get',
#   'puter',
#   'something',
#   'else',
#   'blame',
#   'ex',
#   'he',
#   'broke',
#   'mine'],
#  ['this',
#   'week',
#   'just',
#   'seems',
#   'to',
#   'get',
#   'longer',
#   'and',
#   'longer',
#   'in',
#   'terms',
#   'of',
#   'how',
#   'much',
#   'need',
#   'to',
#   'do',
#   'and',
#   'how',
#   'much',
#   'actually',
#   'going',
#   'to',
#   'get',
#   'done'],
#  ['so', 'cold'],
#  ['ehhh',
#   'do',
#   'not',
#   'weather',
#   'gon',
#   'na',
#   'take',
#   'turn',
#   'for',
#   'the',
#   'ugly',
#   'tomorrow'],
#  ['haha',
#   'its',
#   'so',
#   'cooooold',
#   'in',
#   'the',
#   'and',
#   'no',
#   'but',
#   'you',
#   'should',
#   'still',
#   'go',
#   'to',
#   'the',
#   'show',
#   'they',
#   'do',
#   'some',
#   'incredible',
#   'stuff'],
#  ['hoping', 'the', 'tummy', 'rumbles', 'go', 'away', 'soon'],
#  ['no',
#   'no',
#   'notice',
#   'they',
#   'told',
#   'me',
#   'be',
#   'working',
#   'tomorrow',
#   'and',
#   'then',
#   'called',
#   'the',
#   'agency',
#   'to',
#   'follow',
#   'up',
#   'and',
#   'they',
#   'said',
#   'it',
#   'was',
#   'over'],
#  ['almost', 'bedtime'],
#  ['missing',
#   'you',
#   'babe',
#   'but',
#   'as',
#   'long',
#   'as',
#   'your',
#   'alive',
#   'happy',
#   'ya',
#   'tired',
#   'my',
#   'love',
#   'imma',
#   'try',
#   'to',
#   'sleep',
#   'hopefully',
#   'you',
#   'had',
#   'headstart'],
#  ['agh', 'snow'],
#  ['miss', 'kenny', 'powers'],
#  ['thank',
#   'you',
#   'for',
#   'letting',
#   'people',
#   'know',
#   'but',
#   'now',
#   'sad',
#   'that',
#   'the',
#   'direct',
#   'message',
#   'got',
#   'was',
#   'not',
#   'actually',
#   'from',
#   'bridget'],
#  ['and',
#   'india',
#   'missed',
#   'out',
#   'its',
#   'th',
#   'test',
#   'victory',
#   'th',
#   'consecutive',
#   'win',
#   'without',
#   'loss'],
#  ['guess', 'that', 'no', 'then'],
#  ['sadly', 'is', 'going', 'to', 'bed'],
#  ['shame', 'to', 'hear', 'this', 'stephan'],
#  ['hey', 'leavin', 'in', 'the', 'morning'],
#  ['was',
#   'intending',
#   'to',
#   'finish',
#   'editing',
#   'my',
#   'page',
#   'novel',
#   'manuscript',
#   'tonight',
#   'but',
#   'that',
#   'will',
#   'probably',
#   'not',
#   'happen',
#   'and',
#   'only',
#   'pages',
#   'are',
#   'left'],
#  ['laid', 'around', 'too', 'much', 'today', 'now', 'my', 'head', 'hurts'],
#  ['still',
#   'have',
#   'not',
#   'read',
#   'the',
#   'th',
#   'th',
#   'princess',
#   'diaries',
#   'saving',
#   'francesca',
#   'made',
#   'me',
#   'cry',
#   'at',
#   'the',
#   'end',
#   'hmm',
#   'those',
#   'are',
#   'easy',
#   'books'],
#  ['my', 'nokia', 'died'],
#  ['my',
#   'mom',
#   'might',
#   'have',
#   'breast',
#   'cancer',
#   'will',
#   'not',
#   'find',
#   'out',
#   'anything',
#   'for',
#   'like',
#   'week',
#   'so',
#   'worried'],
#  ['going', 'to', 'sleep', 'hoping', 'tomorrow', 'is', 'better', 'day'],
#  ['lol',
#   'wish',
#   'they',
#   'understood',
#   'daylight',
#   'savings',
#   'has',
#   'ended',
#   'though',
#   'and',
#   'breakfast',
#   'is',
#   'an',
#   'hour',
#   'later',
#   'they',
#   'keep',
#   'waking',
#   'the',
#   'kids',
#   'up',
#   'too'],
#  ['that', 'is', 'lame'],
#  ['do', 'not', 'understand', 'really', 'do', 'not'],
#  ['heroes', 'just', 'is', 'not', 'doing', 'it', 'for', 'me', 'this', 'season'],
#  ['living', 'not', 'downtown', 'sure', 'is', 'not', 'much', 'fun'],
#  ['not',
#   'calorie',
#   'wise',
#   'wish',
#   'junk',
#   'food',
#   'was',
#   'calorie',
#   'free',
#   'ate',
#   'thing',
#   'of',
#   'sour',
#   'skittles',
#   'and',
#   'big',
#   'ass',
#   'cherry',
#   'coke'],
#  ['man', 'work', 'is', 'hard'],
#  ['getting',
#   'sick',
#   'time',
#   'for',
#   'some',
#   'hot',
#   'tea',
#   'studying',
#   'and',
#   'then',
#   'sleeeep'],
#  ['getting', 'eyebrows', 'waxed', 'more', 'pain'],
#  ['no', 'phantasy', 'star', 'yesterday', 'going', 'to', 'work'],
#  ['oh',
#   'just',
#   'got',
#   'all',
#   'my',
#   'macheist',
#   'apps',
#   'sweet',
#   'did',
#   'not',
#   'get',
#   'the',
#   'espresso',
#   'serial',
#   'no',
#   'though',
#   'although',
#   'they',
#   'said',
#   'they',
#   'sent',
#   'it',
#   'oh',
#   'well'],
#  ['picked',
#   'mich',
#   'st',
#   'to',
#   'win',
#   'it',
#   'all',
#   'from',
#   'the',
#   'get',
#   'go',
#   'was',
#   'feeling',
#   'pretty',
#   'good',
#   'about',
#   'that',
#   'pick',
#   'all',
#   'the',
#   'way',
#   'up',
#   'until',
#   'tonight',
#   'lost',
#   'too'],
#  ['is', 'alone', 'downstairs', 'working'],
#  ['feel', 'bad', 'for', 'doing', 'it'],
#  ['is',
#   'it',
#   'just',
#   'me',
#   'or',
#   'she',
#   'hates',
#   'anoop',
#   'mean',
#   'seriously',
#   'she',
#   'kinda',
#   'mean',
#   'to',
#   'him'],
#  ['yes',
#   'sprint',
#   'has',
#   'only',
#   'in',
#   'baltimore',
#   'and',
#   'chicago',
#   'so',
#   'far'],
#  ['stuck',
#   'awake',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'night',
#   'for',
#   'the',
#   'second',
#   'day',
#   'in',
#   'row',
#   'and',
#   'felt',
#   'terrible',
#   'yesterday'],
#  ['thanks', 'for', 'bursting', 'my', 'bubble'],
#  ['going',
#   'to',
#   'school',
#   'soon',
#   'can',
#   'not',
#   'find',
#   'anything',
#   'to',
#   'wear',
#   'gosh',
#   'it',
#   'so',
#   'hard'],
#  ['was', 'serious', 'lol'],
#  ['had',
#   'on',
#   'my',
#   'page',
#   'for',
#   'sooooo',
#   'long',
#   'until',
#   'it',
#   'got',
#   'deleted',
#   'sad',
#   'day',
#   'in',
#   'history'],
#  ['crazy', 'wind', 'today', 'no', 'birding'],
#  ['currently', 'at', 'work'],
#  ['grrr',
#   'my',
#   'ipods',
#   'acting',
#   'weird',
#   'too',
#   'jai',
#   'ho',
#   'and',
#   'thinking',
#   'of',
#   'you',
#   'are',
#   'not',
#   'playing',
#   'the',
#   'full',
#   'songs',
#   'ughh'],
#  ['send',
#   'me',
#   'the',
#   'dvd',
#   'cos',
#   'have',
#   'missed',
#   'out',
#   'on',
#   'heaps',
#   'not',
#   'happy',
#   'about',
#   'that'],
#  ['do', 'not', 'see', 'the', 'big', 'deal', 'with', 'this', 'website'],
#  ['so',
#   'sorry',
#   'you',
#   're',
#   'having',
#   'to',
#   'go',
#   'through',
#   'this',
#   'again',
#   'therapyfail'],
#  ['far',
#   'too',
#   'out',
#   'of',
#   'the',
#   'way',
#   'for',
#   'rail',
#   'any',
#   'other',
#   'tips'],
#  ['not',
#   'still',
#   'up',
#   'swear',
#   'why',
#   'do',
#   'keep',
#   'losing',
#   'gaining',
#   'losing',
#   'gaining',
#   'tweeps',
#   'so',
#   'heart',
#   'wrenching'],
#  ['today',
#   'realized',
#   'am',
#   'too',
#   'good',
#   'at',
#   'hiding',
#   'things',
#   'even',
#   'can',
#   'not',
#   'find',
#   'it'],
#  ['staying',
#   'at',
#   'friends',
#   'house',
#   'house',
#   'sitting',
#   'neighbors',
#   'are',
#   'so',
#   'loud',
#   'having',
#   'party'],
#  ['danny',
#   'im',
#   'upset',
#   'that',
#   'wasnt',
#   'here',
#   'to',
#   'watch',
#   'the',
#   'live',
#   'chat',
#   'was',
#   'in',
#   'car',
#   'for',
#   'hours',
#   'on',
#   'trip',
#   'im',
#   'soooo',
#   'upset'],
#  ['check', 'out', 'my', 'mug'],
#  ['borders', 'closed', 'at'],
#  ['downloading',
#   'nin',
#   'new',
#   'album',
#   'the',
#   'slip',
#   'when',
#   'the',
#   'hell',
#   'did',
#   'this',
#   'come',
#   'out',
#   'so',
#   'behind',
#   'the',
#   'times',
#   'these',
#   'days'],
#  ['just',
#   'woke',
#   'up',
#   'an',
#   'already',
#   'have',
#   'written',
#   'some',
#   'mail',
#   've',
#   'to',
#   'go',
#   'early',
#   'at',
#   'university',
#   'today',
#   'as',
#   'have',
#   'to',
#   'teach',
#   'at',
#   'am'],
#  ['is', 'watching', 'the', 'hill', 'and', 'its', 'making', 'me', 'sad'],
#  ['so',
#   'many',
#   'channels',
#   'yet',
#   'so',
#   'so',
#   'boring',
#   'lazy',
#   'day',
#   'again',
#   'may',
#   'have',
#   'to',
#   'find',
#   'hobby'],
#  ['miss', 'my', 'buddy', 'ill', 'be', 'in', 'ny', 'on', 'the', 'th'],
#  ['love',
#   'the',
#   'french',
#   'tell',
#   'people',
#   'here',
#   'in',
#   'the',
#   'south',
#   'qtr',
#   'french',
#   'and',
#   'they',
#   'snarl',
#   'at',
#   'me',
#   'french',
#   'are',
#   'beautiful',
#   'people'],
#  ['opps',
#   'as',
#   'said',
#   'still',
#   'got',
#   'one',
#   'day',
#   'remain',
#   'and',
#   'now',
#   'problem',
#   'come'],
#  ['activated',
#   'my',
#   'selfcontrol',
#   'block',
#   'early',
#   'meaning',
#   'can',
#   'not',
#   'check',
#   'out',
#   'the',
#   'new',
#   'qc',
#   'regularizing',
#   'my',
#   'internal',
#   'clock',
#   'is',
#   'might',
#   'be',
#   'difficult',
#   'fb'],
#  ['oh', 'no'],
#  ['spencer', 'is', 'not', 'good', 'guy'],
#  ['what',
#   'about',
#   'reese',
#   'dying',
#   'on',
#   'ttsc',
#   'and',
#   'season',
#   'finale',
#   'next',
#   'week',
#   'boring',
#   'madame',
#   'president',
#   'is',
#   'crazy',
#   'woman'],
#  ['hate',
#   'the',
#   'limited',
#   'letters',
#   'too',
#   'hope',
#   'you',
#   'and',
#   'the',
#   'guys',
#   'are',
#   'fine',
#   'pray',
#   'for',
#   'my',
#   'dog',
#   'she',
#   'not',
#   'well'],
#  ['did', 'not', 'get', 'shit', 'done', 'today', 'so', 'screwed'],
#  ['wanttss', 'to', 'go', 'out'],
#  ['is', 'not', 'going', 'to', 'sleep', 'tonite'],
#  ['too', 'worried', 'and', 'tired', 'to', 'post', 'tonight'],
#  ['could', 'not', 'get', 'shit', 'done', 'today', 'so', 'screwed'],
#  ['job',
#   'interview',
#   'in',
#   'cardiff',
#   'today',
#   'wish',
#   'me',
#   'luck',
#   'got',
#   'about',
#   'hours',
#   'sleep'],
#  ['your',
#   'show',
#   'is',
#   'whack',
#   'way',
#   'worse',
#   'than',
#   'whack',
#   'it',
#   'wiggety',
#   'whack'],
#  ['really',
#   'do',
#   'not',
#   'think',
#   'people',
#   'choose',
#   'to',
#   'be',
#   'that',
#   'way',
#   'but',
#   'think',
#   'he',
#   'chose',
#   'not',
#   'to',
#   'accept',
#   'my',
#   'family',
#   'help',
#   'he',
#   'might',
#   'be',
#   'dead',
#   'by',
#   'now'],
#  ['you',
#   're',
#   'going',
#   'to',
#   'kill',
#   'me',
#   'but',
#   've',
#   'not',
#   'seen',
#   'ds',
#   've',
#   'been',
#   'waiting',
#   'till',
#   'can',
#   'do',
#   'it',
#   'in',
#   'one',
#   'solid',
#   'week',
#   'sitting'],
#  ['think', 'ur', 'right', 'hahaha', 'hrs', 'now'],
#  ['hate', 'to', 'see', 'the', 'spartans', 'so', 'sad'],
#  ['my',
#   'mind',
#   'and',
#   'body',
#   'are',
#   'severely',
#   'protesting',
#   'this',
#   'getting',
#   'up',
#   'thing',
#   'had',
#   'nightmares',
#   'to',
#   'boot'],
#  ['goin', 'to', 'follow', 'since', 'did', 'not', 'lol', 'go', 'angels'],
#  [],
#  ['think',
#   'want',
#   'to',
#   'read',
#   'some',
#   'books',
#   'but',
#   'the',
#   'library',
#   'does',
#   'not',
#   'have',
#   'them'],
#  ['my',
#   'nap',
#   'was',
#   'interrupted',
#   'so',
#   'many',
#   'times',
#   'today',
#   'going',
#   'out',
#   'for',
#   'japanese',
#   'with',
#   'the',
#   'rents',
#   'again'],
#  ['kind',
#   'of',
#   'longs',
#   'for',
#   'the',
#   'bus',
#   'that',
#   'shows',
#   'up',
#   'at',
#   'the',
#   'end',
#   'of',
#   'ghost',
#   'world',
#   'right',
#   'now',
#   'ugh'],
#  ['but',
#   'this',
#   'is',
#   'canada',
#   'canada',
#   'is',
#   'weird',
#   'we',
#   're',
#   'supposed',
#   'to',
#   'get',
#   'snow',
#   'through',
#   'wednesday',
#   'ugh'],
#  ['awwh',
#   'babs',
#   'you',
#   'look',
#   'so',
#   'sad',
#   'underneith',
#   'that',
#   'shop',
#   'entrance',
#   'of',
#   'yesterday',
#   'musik',
#   'like',
#   'the',
#   'look',
#   'of',
#   'the',
#   'new',
#   'transformer',
#   'movie'],
#  ['sad', 'that', 'the', 'feet', 'of', 'my', 'macbook', 'just', 'fell', 'off'],
#  ['gon',
#   'na',
#   'get',
#   'up',
#   'late',
#   'tomorrow',
#   'and',
#   'it',
#   'am',
#   'here',
#   'gon',
#   'na',
#   'get',
#   'tipsy',
#   'by',
#   'my',
#   'lonesome',
#   'that',
#   'that',
#   'just',
#   'sad'],
#  ['sweating',
#   'my',
#   'forthcoming',
#   'trip',
#   'to',
#   'if',
#   'can',
#   'not',
#   'find',
#   'someone',
#   'to',
#   'crash',
#   'with',
#   'while',
#   'out',
#   'there',
#   'may',
#   'be',
#   'screwed'],
#  ['has',
#   'now',
#   'gotten',
#   'somebody',
#   'to',
#   'read',
#   'his',
#   'tweets',
#   'but',
#   'cant',
#   'get',
#   'them',
#   'to',
#   'make',
#   'an',
#   'account'],
#  ['omgawd',
#   'couldnt',
#   'handle',
#   'my',
#   'cat',
#   'being',
#   'in',
#   'heat',
#   'all',
#   'the',
#   'time'],
#  ['hope',
#   'can',
#   'make',
#   'it',
#   'to',
#   'the',
#   'auburn',
#   'show',
#   'but',
#   'its',
#   'not',
#   'looking',
#   'good',
#   'for',
#   'me'],
#  ['thats',
#   'people',
#   'mag',
#   'haha',
#   'couldnt',
#   'fit',
#   'it',
#   'all',
#   'in',
#   'dont',
#   'think',
#   'those',
#   'pictures',
#   'ever',
#   'made',
#   'it',
#   'in',
#   'the',
#   'magazine',
#   'tho',
#   'haha'],
#  ['congrats', 'totally', 'forgot', 'to', 'submit', 'photos'],
#  ['awww',
#   'good',
#   'luck',
#   'paula',
#   'please',
#   'do',
#   'not',
#   'work',
#   'too',
#   'hard',
#   'but',
#   'hope',
#   'you',
#   'have',
#   'fun',
#   'your',
#   'new',
#   'album',
#   'is',
#   'gon',
#   'na',
#   'be',
#   'amazing',
#   'xxx'],
#  ['now', 'your', 'leaving', 'me', 'gets', 'sad'],
#  ['miss',
#   'you',
#   'twitter',
#   'my',
#   'phone',
#   'broke',
#   'now',
#   'using',
#   'stupid',
#   'nokia',
#   'phone',
#   'ughhh',
#   'miss',
#   'my',
#   'advance',
#   'phone'],
#  ['shooting', 'outside', 'my', 'house', 'not', 'kidding', 'so', 'scared'],
#  ['tuesday',
#   'll',
#   'start',
#   'with',
#   'reflection',
#   'then',
#   'lecture',
#   'in',
#   'stress',
#   'reducing',
#   'techniques',
#   'that',
#   'sure',
#   'might',
#   'become',
#   'very',
#   'useful',
#   'for',
#   'us',
#   'accompaniers'],
#  ['what', 'tragedy', 'and', 'disaster', 'in', 'the', 'news', 'this', 'week'],
#  ['yes',
#   'yes',
#   'still',
#   'trying',
#   'to',
#   'find',
#   'picture',
#   'that',
#   'will',
#   'upload',
#   'correclty'],
#  ['why',
#   'oh',
#   'why',
#   'was',
#   'the',
#   'red',
#   'sox',
#   'game',
#   'rained',
#   'out',
#   'was',
#   'so',
#   'looking',
#   'forward',
#   'to',
#   'opening',
#   'day'],
#  ['still', 'can', 'not', 'find', 'my', 'keys'],
#  ['know', 'right', 'dunno', 'what', 'is', 'going', 'on', 'with', 'twitter'],
#  ['might', 'be', 'getting', 'sore', 'throat', 'again'],
#  ['my',
#   'home',
#   'town',
#   'my',
#   'mammy',
#   'called',
#   'all',
#   'depressd',
#   'pls',
#   'explain',
#   'parent',
#   'let',
#   'their',
#   'yr',
#   'old',
#   'child',
#   'walk',
#   'alone',
#   'hello',
#   'its'],
#  ['think',
#   'need',
#   'to',
#   'find',
#   'better',
#   'anti',
#   'depressants',
#   'think',
#   'this',
#   'paxil',
#   'wellbutrin',
#   'combo',
#   'is',
#   'losing',
#   'its',
#   'efficacy'],
#  ['restaurant',
#   'called',
#   'woodntap',
#   'has',
#   'competitive',
#   'eating',
#   'tourney',
#   'round',
#   'tourney',
#   'time',
#   'we',
#   'place',
#   'nd'],
#  ['is', 'in', 'the', 'bathroom', 'wake', 'up', 'lakin'],
#  ['want', 'tacos', 'and', 'margarhitas', 'telll', 'gay', 'say', 'hello'],
#  ['im', 'lonely', 'keep', 'me', 'company', 'female', 'california'],
#  ['bad', 'day', 'at', 'the', 'betfair', 'office'],
#  ['miss',
#   'him',
#   'can',
#   'not',
#   'wait',
#   'to',
#   'celebrate',
#   'the',
#   'tar',
#   'heel',
#   'win',
#   'this',
#   'weekend',
#   'though'],
#  ['really',
#   'cold',
#   'do',
#   'not',
#   'want',
#   'to',
#   'go',
#   'to',
#   'sleep',
#   'yet',
#   'but',
#   'there',
#   'nothing',
#   'to',
#   'do'],
#  ['is',
#   'this',
#   'it',
#   'its',
#   'officially',
#   'over',
#   'me',
#   'this',
#   'go',
#   'round'],
#  ['monkeys',
#   'just',
#   'found',
#   'out',
#   'you',
#   'my',
#   'twin',
#   'and',
#   'you',
#   'wont',
#   'even',
#   'write',
#   'back',
#   'heartbroken'],
#  ['aww', 'know', 'felt', 'like', 'that', 'yesterday', 'at', 'work'],
#  ['treaty', 'is', 'not', 'defined'],
#  ['missed',
#   'brent',
#   'at',
#   'praise',
#   'band',
#   'no',
#   'fun',
#   'to',
#   'not',
#   'have',
#   'the',
#   'your',
#   'lead',
#   'guitarist',
#   'pout'],
#  ['poor',
#   'john',
#   'this',
#   'is',
#   'what',
#   'happens',
#   'when',
#   'you',
#   'play',
#   'with',
#   'fruit',
#   'and',
#   'microwave',
#   'seriously',
#   'though',
#   'have',
#   'you',
#   'seen',
#   'doctor',
#   'xxx'],
#  ['missing',
#   'my',
#   'bff',
#   'watching',
#   'home',
#   'and',
#   'away',
#   'it',
#   'reminds',
#   'me',
#   'of',
#   'her',
#   'and',
#   'me',
#   'we',
#   'it',
#   'shout',
#   'out',
#   'to',
#   'courts'],
#  [],
#  ['new', 'video', 'card', 'is', 'doa'],
#  ['feeling',
#   'lost',
#   'naked',
#   'and',
#   'confused',
#   'jk',
#   'sort',
#   'of',
#   'no',
#   'iphone',
#   'for',
#   'me'],
#  ['damn',
#   'am',
#   'so',
#   'late',
#   'at',
#   'filling',
#   'this',
#   'appraisal',
#   'form',
#   'people',
#   'have',
#   'almost',
#   'sent',
#   'it',
#   'was',
#   'so',
#   'occupied',
#   'in',
#   'work'],
#  ['missed',
#   'brent',
#   'at',
#   'praise',
#   'band',
#   'no',
#   'fun',
#   'to',
#   'not',
#   'have',
#   'your',
#   'lead',
#   'guitarist',
#   'pout'],
#  ['think',
#   'to',
#   'much',
#   'on',
#   'the',
#   'past',
#   'cant',
#   'change',
#   'it',
#   'deserved',
#   'so',
#   'much',
#   'more',
#   'then',
#   'wat',
#   'got',
#   'but',
#   'why',
#   'am',
#   'still',
#   'thinking',
#   'about',
#   'him',
#   'gah'],
#  ['has', 'lost', 'his', 'ring', 'it', 'no', 'where', 'to', 'be', 'seen'],
#  ['ooooooh',
#   'sealclap',
#   'see',
#   'download',
#   'shitloads',
#   'of',
#   'zip',
#   'folders',
#   'off',
#   'chan',
#   'have',
#   'no',
#   'internet',
#   'moneys',
#   'fuck',
#   'yeah',
#   'alicia',
#   'mikey'],
#  ['is',
#   'still',
#   'nursing',
#   'my',
#   'nile',
#   'but',
#   'glad',
#   'he',
#   'is',
#   'feeling',
#   'better',
#   'hate',
#   'when',
#   'my',
#   'baby',
#   'is',
#   'sick'],
#  ['is', 'fucked', 'to', 'go', 'back', 'to', 'ic'],
#  ['yoyoyo',
#   'my',
#   'internet',
#   'has',
#   'been',
#   'rude',
#   'tonight',
#   'it',
#   'just',
#   'reconnected',
#   'and',
#   'about',
#   'to',
#   'go',
#   'to',
#   'bed'],
#  ['well',
#   'have',
#   'uni',
#   'stuff',
#   'and',
#   'netball',
#   'but',
#   'after',
#   'netbal',
#   'if',
#   've',
#   'done',
#   'uni',
#   'stuff',
#   'we',
#   'can'],
#  ['me', 'too', 'is', 'poor'],
#  ['help', 'me', 'forget', 'th', 'april', 'th', 'july'],
#  ['dierks',
#   'bentley',
#   'is',
#   'comin',
#   'to',
#   'columbus',
#   'oh',
#   'wan',
#   'na',
#   'go',
#   'so',
#   'bad'],
#  ['have', 'to', 'take', 'my', 'sidekick', 'back'],
#  ['congrats',
#   'totally',
#   'jealous',
#   'only',
#   'wish',
#   'my',
#   'xm',
#   'was',
#   'working'],
#  ['gr', 'my', 'face', 'is', 'very', 'itchy'],
#  ['poor',
#   'socks',
#   'luvvvvv',
#   'the',
#   'golden',
#   'retriever',
#   'want',
#   'one',
#   'sighhhh'],
#  ['just',
#   'saw',
#   'that',
#   'they',
#   'found',
#   'that',
#   'tracy',
#   'girl',
#   'in',
#   'piece',
#   'of',
#   'luggage',
#   'how',
#   'fucking',
#   'terrible'],
#  ['aaaaand', 'the', 'nausea', 'is', 'back'],
#  ['ooh',
#   'excited',
#   'and',
#   'not',
#   'even',
#   'going',
#   'be',
#   'there',
#   'long',
#   'love',
#   'youtube'],
#  ['spent',
#   'hour',
#   'to',
#   'reach',
#   'to',
#   'axis',
#   'bank',
#   'only',
#   'to',
#   'find',
#   'out',
#   'today',
#   'is',
#   'holiday',
#   'for',
#   'mahavir',
#   'jayanti',
#   'contd'],
#  ['agree', 'the', 'jobros', 'dont', 'update', 'theres', 'very', 'often'],
#  ['it',
#   'is',
#   'hilarious',
#   'and',
#   'linked',
#   'the',
#   'clip',
#   'from',
#   'lj',
#   'some',
#   'time',
#   'ago',
#   'but',
#   'when',
#   'went',
#   'back',
#   'just',
#   'now',
#   'it',
#   'was',
#   'dead',
#   'link'],
#  ['oooooooo',
#   'who',
#   'with',
#   'im',
#   'not',
#   'neither',
#   'but',
#   'thats',
#   'because',
#   'need',
#   'to',
#   'study'],
#  ['have',
#   'not',
#   'tweeted',
#   'nearly',
#   'all',
#   'day',
#   'posted',
#   'my',
#   'website',
#   'tonight',
#   'hopefully',
#   'that',
#   'goes',
#   'well',
#   'night',
#   'time'],
#  ['miss', 'bentley'],
#  ['seriously', 'needs', 'to', 'finish', 'these', 'job', 'applications'],
#  ['my',
#   'son',
#   'vincas',
#   'is',
#   'sick',
#   'so',
#   'stay',
#   'at',
#   'home',
#   'just',
#   'three',
#   'tense',
#   'days',
#   'at',
#   'work',
#   'and',
#   'am',
#   'back',
#   'on',
#   'holiday',
#   'with',
#   'kids'],
#  ['whinging',
#   'my',
#   'client',
#   'boss',
#   'do',
#   'not',
#   'understand',
#   'english',
#   'well',
#   'rewrote',
#   'some',
#   'text',
#   'unreadable',
#   'it',
#   'written',
#   'by',
#   'good',
#   'writer',
#   'reviewed',
#   'correctly'],
#  ['do', 'not', 'want', 'him', 'to', 'ever', 'punch', 'me'],
#  ['sooo', 'sick', 'of', 'the', 'snow', 'ughh'],
#  [],
#  ['it', 'does', 'not', 'work', 'your', 'fan', 'is', 'upset'],
#  ['would',
#   'like',
#   'to',
#   'apologize',
#   'for',
#   'the',
#   'repeated',
#   'video',
#   'games',
#   'live',
#   'related',
#   'tweets',
#   'am',
#   'going',
#   'to',
#   'have',
#   'stern',
#   'discussion',
#   'with',
#   'koodo',
#   'soon',
#   'stern'],
#  ['but',
#   'cant',
#   'figure',
#   'out',
#   'how',
#   'to',
#   'get',
#   'there',
#   'back',
#   'pay',
#   'for',
#   'hotel',
#   'etc'],
#  ['fml',
#   'so',
#   'much',
#   'for',
#   'seniority',
#   'bc',
#   'of',
#   'technological',
#   'ineptness',
#   'now',
#   'have',
#   'to',
#   'register',
#   'for',
#   'classes',
#   'again'],
#  ['feels',
#   'like',
#   'she',
#   'slept',
#   'the',
#   'day',
#   'away',
#   'not',
#   'looking',
#   'forward',
#   'to',
#   'any',
#   'more',
#   'bouts',
#   'with',
#   'my',
#   'gallbladder',
#   'at',
#   'least',
#   'have',
#   'pills',
#   'now',
#   'for',
#   'the',
#   'pain'],
#  ['but', 'what', 'really', 'want', 'is', 'my', 'old', 'bass', 'back'],
#  ['mad',
#   'tired',
#   'today',
#   'callin',
#   'it',
#   'in',
#   'early',
#   'tonight',
#   'nighty',
#   'night',
#   'twittas'],
#  ['take', 'it', 'easy', 'and', 'be', 'good', 'to', 'you'],
#  ['afraid', 'had', 'bad', 'code'],
#  ['think', 'going', 'to', 'bed', 'goodniight', 'hate', 'this'],
#  ['here', 'friend', 'and', 'love', 'you'],
#  ['all',
#   'this',
#   'time',
#   'you',
#   'did',
#   'not',
#   'notice',
#   'was',
#   'gone',
#   'just',
#   'needed',
#   'db',
#   'is',
#   'it'],
#  ['is', 'in', 'the', 'bathroom', 'and', 'have', 'to', 'pee'],
#  ['but', 'wanted', 'margarita', 'too'],
#  ['yup',
#   'night',
#   'workouts',
#   'the',
#   'worst',
#   'but',
#   'unfortunetly',
#   'my',
#   'work',
#   'schedule',
#   'only',
#   'allows',
#   'me',
#   'to',
#   'go',
#   'at',
#   'night',
#   'its',
#   'tough'],
#  ['just',
#   'called',
#   'hillsong',
#   'again',
#   'they',
#   'said',
#   'they',
#   'could',
#   'not',
#   'tell',
#   'me',
#   'where',
#   'was',
#   'on',
#   'the',
#   'waiting',
#   'list',
#   'do',
#   'not',
#   'know',
#   'if',
#   'it',
#   'looking',
#   'so',
#   'good'],
#  ['has', 'of', 'milky', 'bar', 'left', 'and', 'around', 'ml', 'of', 'coke'],
#  ['it', 'stillllll', 'has', 'not', 'arrived'],
#  ['mraow',
#   'feel',
#   'like',
#   'dancing',
#   'but',
#   'first',
#   'art',
#   'school',
#   'wants',
#   'to',
#   'rape',
#   'me',
#   'some',
#   'more'],
#  ['ah',
#   'bet',
#   'it',
#   'does',
#   've',
#   'been',
#   'like',
#   'craving',
#   'to',
#   'play',
#   'softball',
#   'or',
#   'basketball',
#   'but',
#   'have',
#   'noo',
#   'time'],
#  ['is',
#   'terrified',
#   'she',
#   'accidentally',
#   'deleted',
#   'reference',
#   'in',
#   'her',
#   'management',
#   'assignment',
#   'and',
#   'hopes',
#   'she',
#   'doesnt',
#   'get',
#   'in',
#   'trouble',
#   'when',
#   'she',
#   'gets',
#   'back'],
#  ['amazon',
#   'plugin',
#   'not',
#   'worked',
#   'in',
#   'my',
#   'website',
#   'it',
#   'need',
#   'php',
#   'but',
#   'my',
#   'hosting',
#   'provider',
#   'has',
#   'only',
#   'php',
#   'very',
#   'sad'],
#  ['argh',
#   'was',
#   'suuuper',
#   'sleepy',
#   'an',
#   'hour',
#   'ago',
#   'now',
#   'wide',
#   'awake',
#   'hope',
#   'do',
#   'not',
#   'stay',
#   'up',
#   'all',
#   'night'],
#  ['wish',
#   'was',
#   'sold',
#   'out',
#   'if',
#   'you',
#   'have',
#   'some',
#   'time',
#   'let',
#   'me',
#   'know',
#   'would',
#   'love',
#   'to',
#   'hear',
#   'more',
#   'about',
#   'what',
#   'you',
#   'are',
#   'up',
#   'to'],
#  ['just', 'watched', 'tropic', 'thunder', 'dreading', 'tomorrow'],
#  ['no', 'he', 'still', 'miss'],
#  ['chiefdelphi', 'is', 'down'],
#  ['according',
#   'to',
#   'my',
#   'bro',
#   'our',
#   'new',
#   'puppy',
#   'had',
#   'poo',
#   'fight',
#   'and',
#   'was',
#   'covered',
#   'in',
#   'poop',
#   'picture',
#   'stolen',
#   'from',
#   'him'],
#  ['playing',
#   'game',
#   'at',
#   'home',
#   'my',
#   'new',
#   'boss',
#   'did',
#   'not',
#   'call',
#   'me',
#   'yet'],
#  ['su',
#   'yin',
#   'huen',
#   'tweeted',
#   'feel',
#   'unbearable',
#   'guilt',
#   'made',
#   'my',
#   'staff',
#   'cry'],
#  ['poor', 'joshy', 'is', 'sick', 'those', 'damn', 'tejanos'],
#  ['my',
#   'thoughts',
#   'are',
#   'with',
#   'sandra',
#   'cantu',
#   'family',
#   'at',
#   'this',
#   'difficult',
#   'and',
#   'sad',
#   'time'],
#  ['know',
#   'just',
#   'wanted',
#   'to',
#   'let',
#   'everybody',
#   'know',
#   'what',
#   'was',
#   'happening'],
#  ['michigan', 'who', 'do', 'not', 'know', 'them', 'sigh', 'shameful'],
#  ['have', 'to', 'fill', 'two', 'hours'],
#  ['so',
#   'cuuute',
#   'hey',
#   'miss',
#   'you',
#   'na',
#   'its',
#   'not',
#   'the',
#   'same',
#   'not',
#   'seeing',
#   'you',
#   'girls',
#   'everyday'],
#  ['oh',
#   'did',
#   'mention',
#   'it',
#   'gooooood',
#   'moooorniiiiiiing',
#   'from',
#   'germany',
#   'im',
#   'back',
#   'in',
#   'my',
#   'cage',
#   'or',
#   'better',
#   'my',
#   'office'],
#  ['throat',
#   'is',
#   'closing',
#   'up',
#   'and',
#   'had',
#   'some',
#   'string',
#   'cheese',
#   'not',
#   'good',
#   'idea'],
#  ['aww',
#   'sandra',
#   'cantu',
#   'is',
#   'found',
#   'dead',
#   'in',
#   'suitcase',
#   'missing',
#   'children',
#   'stories',
#   'never',
#   'seem',
#   'to',
#   'go',
#   'good',
#   'poor',
#   'family'],
#  ['wishing', 'was', 'home', 'underneath', 'my', 'covers'],
#  ['walking', 'home', 'from', 'school', 'drains', 'all', 'my', 'energy'],
#  ['agree',
#   'the',
#   'shapeshifting',
#   'is',
#   'copout',
#   'was',
#   'so',
#   'excited',
#   'for',
#   'angela',
#   'ep',
#   'thought',
#   'it',
#   'was',
#   'this',
#   'week',
#   'noah',
#   'was',
#   'awesome',
#   'tho'],
#  ['dang',
#   'would',
#   'have',
#   'done',
#   'this',
#   'if',
#   'knew',
#   'it',
#   'was',
#   'there',
#   'earlier',
#   'any',
#   'other',
#   'outings',
#   'planned'],
#  ['wish',
#   'was',
#   'better',
#   'at',
#   'writing',
#   'it',
#   'taking',
#   'me',
#   'so',
#   'long',
#   'to',
#   'write',
#   'this',
#   'paper'],
#  ['and',
#   'of',
#   'course',
#   'have',
#   'access',
#   'to',
#   'my',
#   'halo',
#   'mythic',
#   'map',
#   'pack',
#   're',
#   'download',
#   'but',
#   'bad',
#   'news',
#   'not',
#   'the',
#   'legendary',
#   'map',
#   'pack',
#   'ugh',
#   'ms'],
#  ['not',
#   'yet',
#   'unfortunately',
#   'another',
#   'few',
#   'weeks',
#   've',
#   'been',
#   'told',
#   'how',
#   'are',
#   'you',
#   've',
#   'been',
#   'little',
#   'bit',
#   'busy',
#   'with',
#   'my',
#   'latest',
#   'project'],
#  ['ha', 'the', 'sun', 'already', 'gone'],
#  ['day',
#   'lot',
#   'harder',
#   'than',
#   'day',
#   'let',
#   'see',
#   'how',
#   'day',
#   'goes',
#   'tomorrow'],
#  ['my', 'man', 'crush', 'jake', 'peavy', 'let', 'me', 'down', 'gayforpeavy'],
#  ['megafast',
#   'trip',
#   'you',
#   'have',
#   'time',
#   'during',
#   'day',
#   'tom',
#   'weds',
#   'or',
#   'you',
#   'going',
#   'out',
#   'tonight',
#   'want',
#   'to',
#   'see',
#   'you',
#   'bad',
#   'tried',
#   'to',
#   'warn',
#   'you',
#   'tech',
#   'fail'],
#  ['michigan', 'state', 'you', 'make', 'me', 'sad'],
#  ['omg',
#   'my',
#   'mouth',
#   'is',
#   'in',
#   'so',
#   'much',
#   'pain',
#   'just',
#   'wan',
#   'na',
#   'sleep',
#   'untill',
#   'its',
#   'time',
#   'to',
#   'take',
#   'my',
#   'braces',
#   'off'],
#  ['getting',
#   'annoyed',
#   'easily',
#   'today',
#   'biofuel',
#   'proposal',
#   'getting',
#   'annoyed',
#   'easily',
#   'today',
#   'biof'],
#  ['hey',
#   'girl',
#   'the',
#   'site',
#   'is',
#   'back',
#   'girlyvue',
#   'is',
#   'back',
#   'and',
#   'they',
#   'have',
#   'even',
#   'more',
#   'videos'],
#  ['spending',
#   'time',
#   'with',
#   'my',
#   'grandma',
#   'early',
#   'tomorrow',
#   'and',
#   'can',
#   'not',
#   'leave',
#   'skittles',
#   'by',
#   'herself'],
#  ['just',
#   'got',
#   'home',
#   'from',
#   'watching',
#   'michigan',
#   'state',
#   'get',
#   'tromped'],
#  ['oh',
#   'jew',
#   'bus',
#   'two',
#   'years',
#   'worth',
#   'of',
#   'classes',
#   'work',
#   'is',
#   'alot',
#   'to',
#   'organize',
#   'not',
#   'finishing',
#   'tonight',
#   'it',
#   'not',
#   'possible',
#   'my',
#   'bones',
#   'ache'],
#  ['no', 'exchanging', 'for', 'me', 'my', 'laptop', 'has', 'not', 'arrived'],
#  ['hope', 'this', 'does', 'not', 'last', 'too', 'long', 'feel', 'miserable'],
#  ['rachel',
#   'hang',
#   'outage',
#   'is',
#   'neccessary',
#   'was',
#   'gon',
#   'na',
#   'be',
#   'home',
#   'this',
#   'wekend',
#   'but',
#   'dumb',
#   'folk',
#   'make',
#   'me',
#   'work',
#   'so',
#   'im',
#   'free',
#   'and',
#   'sat',
#   'until'],
#  ['not',
#   'fun',
#   'furious',
#   'the',
#   'new',
#   'mantra',
#   'for',
#   'the',
#   'bay',
#   'breakers',
#   'it',
#   'was',
#   'getting',
#   'rambunctious',
#   'the',
#   'city',
#   'overreacted',
#   'clamped',
#   'down'],
#  ['my',
#   'hubby',
#   'for',
#   'some',
#   'reason',
#   'thinks',
#   'it',
#   'more',
#   'important',
#   'he',
#   'has',
#   'good',
#   'spot',
#   'for',
#   'red',
#   'carpet',
#   'for',
#   'the',
#   'trek',
#   'movie',
#   'premiere',
#   'sod'],
#  ['swear',
#   'no',
#   'matter',
#   'how',
#   'long',
#   've',
#   'been',
#   'getting',
#   'up',
#   'at',
#   'am',
#   'it',
#   'never',
#   'gets',
#   'any',
#   'easier',
#   'man',
#   'my',
#   'eyes',
#   'hurts',
#   'wah'],
#  ['jeffree',
#   'how',
#   'do',
#   'you',
#   'keep',
#   'your',
#   'hair',
#   'one',
#   'color',
#   'my',
#   'permanent',
#   'dye',
#   'fades',
#   'within',
#   'the',
#   'week'],
#  ['my', 'reaction', 'too', 'whoa', 'did', 'not', 'see', 'that', 'coming'],
#  ['still',
#   'sick',
#   'feeling',
#   'bit',
#   'better',
#   'got',
#   'some',
#   'new',
#   'medicine',
#   'hope',
#   'feel',
#   'good',
#   'after',
#   'night',
#   'of',
#   'sleep',
#   'ohh',
#   'and',
#   'it',
#   'suppose',
#   'to',
#   'snow',
#   'wtf'],
#  ['think',
#   'maybe',
#   'you',
#   'should',
#   'get',
#   'couple',
#   'more',
#   'hours',
#   'of',
#   'sleep',
#   'hon',
#   'how',
#   'productive',
#   'can',
#   'you',
#   'be',
#   'right',
#   'now',
#   'if',
#   'ur',
#   'dog',
#   'tired',
#   'worry'],
#  ['thanks',
#   'lot',
#   'learned',
#   'lot',
#   'of',
#   'new',
#   'words',
#   'but',
#   'did',
#   'not',
#   'find',
#   'what',
#   'was',
#   'looking',
#   'for'],
#  ['wish',
#   'had',
#   'all',
#   'the',
#   'xblm',
#   'downloads',
#   'all',
#   'on',
#   'the',
#   'gamertag',
#   'hitokyri',
#   'this',
#   'gamertag',
#   'thing',
#   'is',
#   'nonsense',
#   'and',
#   'tired',
#   'of',
#   'it'],
#  ['new', 'testament', 'test', 'at', 'am'],
#  ['tons', 'no', 'hay', 'troll', 'ahhhh'],
#  ['stupid',
#   'movies',
#   'we',
#   'watched',
#   'mirrors',
#   'ugggggh',
#   'stooopeeed',
#   'rip',
#   'off'],
#  ['love', 'you', 'buck'],
#  ['last', 'one', 'but', 'still', 'not', 'done'],
#  ['homework'],
#  ['do',
#   'not',
#   'understand',
#   'why',
#   'things',
#   'get',
#   'taken',
#   'away',
#   'did',
#   'not',
#   'have',
#   'enough',
#   'time',
#   'with',
#   'him',
#   'its',
#   'unfair',
#   'want',
#   'him',
#   'back',
#   'he',
#   'was',
#   'like',
#   'my',
#   'baby'],
#  ['scratch',
#   'that',
#   'du',
#   'in',
#   'heif',
#   'two',
#   'in',
#   'half',
#   'cookies',
#   'my',
#   'tum',
#   'just',
#   'can',
#   'not',
#   'take',
#   'anymore',
#   'shoog',
#   'poots'],
#  ['was',
#   'just',
#   'listening',
#   'to',
#   'the',
#   'sweets',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'forever',
#   'miss',
#   'them',
#   'so',
#   'much',
#   'can',
#   'we',
#   'go',
#   'to',
#   'chi',
#   'town',
#   'for',
#   'visits',
#   'plz'],
#  ['geez',
#   'what',
#   'busy',
#   'afternoon',
#   'meetings',
#   'emails',
#   'meetings',
#   'and',
#   'email',
#   'and',
#   'more',
#   'meetings',
#   'pm',
#   'and',
#   'the',
#   'day',
#   'is',
#   'still',
#   'going',
#   'ah',
#   'its',
#   'dark',
#   'and'],
#  ['dang',
#   'another',
#   'spring',
#   'break',
#   'how',
#   'cool',
#   'is',
#   'that',
#   'too',
#   'bad',
#   'have',
#   'to',
#   'work',
#   'all',
#   'week',
#   'oh',
#   'well',
#   'more',
#   'money',
#   'for',
#   'phone',
#   'ttyl',
#   'everbody'],
#  ['im', 'afraid', 'too', 'ur', 'reply', 'about', 'uni', 'from', 'ages', 'ago'],
#  ['feeling', 'down'],
#  ['lol',
#   'they',
#   'are',
#   'some',
#   'emotional',
#   'ass',
#   'men',
#   'omg',
#   'all',
#   'this',
#   'late',
#   'night',
#   'eating',
#   'both',
#   'of',
#   'us',
#   'are',
#   'broke'],
#  ['aww',
#   'nick',
#   'like',
#   'your',
#   'hair',
#   'longer',
#   'why',
#   'did',
#   'you',
#   'cut',
#   'it',
#   'off',
#   'break',
#   'my',
#   'heart'],
#  ['wonder', 'if', 'jon', 'lost', 'the', 'net'],
#  ['wow',
#   'the',
#   'most',
#   'depressing',
#   'thing',
#   'in',
#   'the',
#   'world',
#   'is',
#   'losing',
#   'video',
#   'that',
#   'you',
#   've',
#   'created',
#   'in',
#   'matter',
#   'of',
#   'seconds',
#   'fml'],
#  ['but', 'all', 'says', 'not', 'in', 'stock'],
#  ['lmao', 'im', 'sorry', 'poohpot', 'ate', 'it', 'all'],
#  ['any', 'chance', 'softbelly', 'for', 'is', 'not', 'loud'],
#  ['time',
#   'to',
#   'move',
#   'my',
#   'posterior',
#   'and',
#   'lose',
#   'some',
#   'fat',
#   'my',
#   'articulation',
#   'are',
#   'creaking',
#   'so',
#   'no',
#   'more',
#   'running',
#   'but',
#   'drool',
#   'for',
#   'some',
#   'swimming'],
#  ['listening', 'to', 'nathan', 'cry'],
#  ['today',
#   'sucked',
#   'gon',
#   'na',
#   'die',
#   'without',
#   'chris',
#   'and',
#   'callum',
#   'wahhh'],
#  ['stou',
#   'site',
#   'not',
#   'update',
#   'no',
#   'info',
#   'about',
#   'exam',
#   'and',
#   'open',
#   'course',
#   'must',
#   'wait',
#   'for',
#   'mail',
#   'notices',
#   'and',
#   'doc',
#   'um'],
#  ['sorry',
#   'feeling',
#   'kinda',
#   'yucky',
#   'myself',
#   'am',
#   'is',
#   'going',
#   'to',
#   'come',
#   'too',
#   'quick'],
#  ['is',
#   'in',
#   'love',
#   'with',
#   'scrappy',
#   'and',
#   'is',
#   'missin',
#   'him',
#   'already'],
#  ['wants',
#   'to',
#   'hear',
#   'song',
#   'but',
#   'myspace',
#   'is',
#   'messing',
#   'with',
#   'me'],
#  ['bad',
#   'news',
#   'was',
#   'dad',
#   'has',
#   'cancer',
#   'and',
#   'is',
#   'dying',
#   'good',
#   'news',
#   'new',
#   'business',
#   'started',
#   'and',
#   'am',
#   'now',
#   'life',
#   'coach',
#   'practising',
#   'holistic',
#   'weight',
#   'management'],
#  ['man', 'intervention', 'is', 'soo', 'sad'],
#  ['help', 'need', 'new', 'boyfriend', 'stuck', 'in', 'rut'],
#  ['feel',
#   'like',
#   'complete',
#   'idiot',
#   'the',
#   'only',
#   'one',
#   'who',
#   'does',
#   'not',
#   'get',
#   'how',
#   'this',
#   'shit',
#   'works',
#   'help',
#   'me'],
#  ['saw',
#   'an',
#   'ad',
#   'on',
#   'craigslist',
#   'for',
#   'casting',
#   'call',
#   'for',
#   'female',
#   'host',
#   'on',
#   'was',
#   'totally',
#   'psyched',
#   'but',
#   'realized',
#   'it',
#   'was',
#   'hoax'],
#  ['pepperoni',
#   'rolls',
#   'in',
#   'called',
#   'valentino',
#   'they',
#   'said',
#   'that',
#   'they',
#   'had',
#   'sausage',
#   'rolls',
#   'but',
#   'no',
#   'pepperoni',
#   'rolls'],
# ...
#  ['roomie',
#   'was',
#   'home',
#   'all',
#   'day',
#   'all',
#   'he',
#   'had',
#   'to',
#   'do',
#   'was',
#   'scratch',
#   'at',
#   'the',
#   'door',
#   'comforter',
#   'has',
#   'to',
#   'goto',
#   'large',
#   'laundromat',
#   'machines'],
#  ['one',
#   'of',
#   'the',
#   'hardest',
#   'thing',
#   'with',
#   'this',
#   'schedule',
#   'no',
#   'one',
#   'can',
#   'chat',
#   'with',
#   'at',
#   'the',
#   'end',
#   'of',
#   'my',
#   'day',
#   'usually'],
#  ['they',
#   'killed',
#   'off',
#   'character',
#   'on',
#   'one',
#   'of',
#   'my',
#   'favorite',
#   'shows',
#   'and',
#   'now',
#   'upset'],
#  ['jealous',
#   'of',
#   'my',
#   'friends',
#   'who',
#   'got',
#   'to',
#   'see',
#   'the',
#   'new',
#   'star',
#   'trek',
#   'film',
#   'in',
#   'austin',
#   'tonight'],
#  ['listening',
#   'to',
#   'got',
#   'really',
#   'bad',
#   'headache',
#   'and',
#   'drivin',
#   'lesson',
#   'in',
#   'ten',
#   'mins',
#   'lucky',
#   'me',
#   'just',
#   'wana',
#   'sleeep'],
#  ['shut',
#   'up',
#   'you',
#   'am',
#   'hungry',
#   'and',
#   'in',
#   'britain',
#   'home',
#   'of',
#   'the',
#   'most',
#   'boring',
#   'suckassy',
#   'breakfast',
#   'in',
#   'the',
#   'world',
#   'miss',
#   'dennys'],
#  ['good',
#   'morning',
#   'everybody',
#   'pkoi',
#   'fais',
#   'pas',
#   'beau',
#   'bon',
#   'coffee',
#   'time'],
#  ['work', 'again'],
#  ['essay', 'time'],
#  ['hey',
#   'did',
#   'talk',
#   'to',
#   'mom',
#   'they',
#   'home',
#   'yet',
#   'hope',
#   'they',
#   'ok',
#   'wish',
#   'was',
#   'coming',
#   'home',
#   'easter'],
#  ['sure',
#   'wish',
#   'could',
#   'go',
#   'with',
#   'you',
#   'guys',
#   'tmrw',
#   'but',
#   'as',
#   'per',
#   'usual',
#   'school',
#   'interferes'],
#  ['say',
#   'what',
#   'kal',
#   'penn',
#   'leaving',
#   'house',
#   'noooooo',
#   'totally',
#   'missed',
#   'it',
#   'tonight'],
#  ['no', 'lost', 'loyal'],
#  ['played',
#   'another',
#   'hand',
#   'very',
#   'bad',
#   'and',
#   'lost',
#   'half',
#   'my',
#   'stack'],
#  ['it', 'pm', 'early', 'days', 'in', 'looooooong', 'night', 'at', 'work'],
#  ['it',
#   'sad',
#   'it',
#   'the',
#   'last',
#   'season',
#   'wan',
#   'na',
#   'see',
#   'when',
#   'spencer',
#   'calls',
#   'lauren'],
#  ['so',
#   'im',
#   'done',
#   'editing',
#   'the',
#   'phipstape',
#   'back',
#   'crack',
#   'brew',
#   'and',
#   'see',
#   'what',
#   'we',
#   'got',
#   'no',
#   'trees',
#   'though'],
#  ['do', 'not', 'know', 'what', 'half', 'of', 'that', 'means'],
#  ['homework', 'homework', 'homework'],
#  ['worked',
#   'his',
#   'heart',
#   'out',
#   'today',
#   'doubling',
#   'my',
#   'weight',
#   'at',
#   'each',
#   'station',
#   'result',
#   'stiff',
#   'and',
#   'pulled',
#   'muscles',
#   'ouch'],
#  ['now', 'feel', 'bad', 'for', 'unfollowing'],
#  ['so',
#   'tired',
#   'god',
#   'hate',
#   'the',
#   'new',
#   'job',
#   'and',
#   'only',
#   'two',
#   'days',
#   'in'],
#  ['sad',
#   'about',
#   'kutner',
#   'being',
#   'killed',
#   'off',
#   'my',
#   'fav',
#   'show',
#   'house'],
#  ['happy',
#   'for',
#   'coach',
#   'stringer',
#   'hof',
#   'now',
#   'if',
#   'can',
#   'only',
#   'finish',
#   'my',
#   'term',
#   'paper',
#   'on',
#   'her'],
#  ['feel',
#   'like',
#   'shit',
#   'this',
#   'is',
#   'not',
#   'the',
#   'way',
#   'want',
#   'to',
#   'spend',
#   'my',
#   'birthday',
#   'eve'],
#  ['so',
#   'far',
#   'have',
#   'on',
#   'all',
#   'my',
#   'sites',
#   'put',
#   'together',
#   'most',
#   'of',
#   'them',
#   'were',
#   'me',
#   'checking',
#   'out',
#   'the',
#   'updates',
#   'made'],
#  ['has',
#   'lot',
#   'on',
#   'her',
#   'mind',
#   'needs',
#   'to',
#   'make',
#   'some',
#   'moneys',
#   'and',
#   'ideas',
#   'nowhere',
#   'is',
#   'hiring'],
#  ['miss', 'you'],
#  ['so', 'sorry', 'to', 'hear', 'about', 'your', 'dog'],
#  ['too', 'much', 'internet', 'how', 'it', 'plagues', 'me'],
#  ['miss', 'my', 'ex', 'soo', 'much'],
#  ['sodding'],
#  ['oh',
#   'thought',
#   'the',
#   'pirate',
#   'bay',
#   'trial',
#   'verdict',
#   'was',
#   'today',
#   'apparently',
#   'it',
#   'in',
#   'days'],
#  ['call', 'me', 'back'],
#  ['is',
#   'in',
#   'study',
#   'hall',
#   'now',
#   'and',
#   'will',
#   'log',
#   'off',
#   'immediately'],
#  ['it',
#   'so',
#   'tired',
#   'that',
#   'im',
#   'crying',
#   'for',
#   'no',
#   'reason',
#   'at',
#   'all',
#   'im',
#   'about',
#   'to',
#   'try',
#   'to',
#   'get',
#   'an',
#   'hour',
#   'and',
#   'half',
#   'in',
#   'for',
#   'tonight',
#   'half',
#   'what',
#   'got',
#   'last',
#   'night'],
#  ['totally',
#   'have',
#   'like',
#   'four',
#   'girl',
#   'options',
#   'and',
#   'none',
#   'of',
#   'them',
#   'seem',
#   'viable'],
#  ['so',
#   'far',
#   'have',
#   'veiws',
#   'on',
#   'all',
#   'my',
#   'sites',
#   'put',
#   'together',
#   'most',
#   'of',
#   'them',
#   'were',
#   'me',
#   'checking',
#   'out',
#   'the',
#   'updates',
#   'made'],
#  ['listening', 'to', 'bjork', 'all', 'is', 'full', 'of', 'love', 'crying'],
#  ['omg',
#   'the',
#   'hills',
#   'then',
#   'love',
#   'money',
#   'aww',
#   'think',
#   'becky',
#   'buckwild',
#   'goes'],
#  ['is', 'craving', 'for', 'some', 'tantan', 'nabe'],
#  ['mon', 'sean', 'man'],
#  ['watching',
#   'league',
#   'of',
#   'their',
#   'own',
#   'makes',
#   'me',
#   'miss',
#   'mint',
#   'chocolate',
#   'ice',
#   'cream',
#   'cones',
#   'and',
#   'my',
#   'grand',
#   'ma',
#   'fuck'],
#  ['lost',
#   'my',
#   'phone',
#   'some',
#   'where',
#   'maybe',
#   'in',
#   'the',
#   'grass',
#   'its',
#   'just',
#   'so',
#   'long',
#   'hope',
#   'it',
#   'does',
#   'not',
#   'rain'],
#  ['hope',
#   'you',
#   'are',
#   'not',
#   'referring',
#   'to',
#   'me',
#   'say',
#   'hello',
#   'to',
#   'your',
#   'new',
#   'stalker',
#   'lol'],
#  ['why',
#   'were',
#   'sleeping',
#   'ur',
#   'gon',
#   'na',
#   'be',
#   'up',
#   'all',
#   'night',
#   'now',
#   'how',
#   'was',
#   'ur',
#   'bike',
#   'ride'],
#  ['but', 'but', 'but', 'wan', 'na', 'listen', 'to', 'the', 'masters', 'too'],
#  ['ve',
#   'been',
#   'looking',
#   'about',
#   'for',
#   'good',
#   'stuff',
#   'to',
#   'write',
#   'but',
#   'also',
#   'been',
#   'doing',
#   'loads',
#   'of',
#   'uni',
#   'work'],
#  ['feel', 'unloved', 'dropped', 'tweeters'],
#  ['off',
#   'to',
#   'london',
#   'for',
#   'the',
#   'day',
#   'on',
#   'thursday',
#   'it',
#   'gon',
#   'na',
#   'be',
#   'raining',
#   'oh',
#   'fab',
#   'will',
#   'not',
#   'see',
#   'much',
#   'on',
#   'the',
#   'london',
#   'eye',
#   'still',
#   'robbie',
#   'will',
#   'not',
#   'care',
#   'bless',
#   'him'],
#  ['completely',
#   'wiped',
#   'and',
#   'reloaded',
#   'the',
#   'lost',
#   'all',
#   'bbm',
#   'contacts',
#   'going',
#   'to',
#   'bed',
#   'sad'],
#  ['sayyyy', 'whaaaa', 'was', 'not', 'invited'],
#  ['did',
#   'not',
#   'sleep',
#   'too',
#   'bad',
#   'considering',
#   'have',
#   'workshop',
#   'starting',
#   'today',
#   'beginnings',
#   'of',
#   'sore',
#   'throat',
#   'though'],
#  ['oh',
#   'my',
#   'gosh',
#   'that',
#   'made',
#   'me',
#   'emotional',
#   'haha',
#   'idk',
#   'why',
#   'dont',
#   'want',
#   'to',
#   'get',
#   'old'],
#  ['we',
#   're',
#   'going',
#   'to',
#   'post',
#   'some',
#   'stories',
#   'manually',
#   'due',
#   'to',
#   'twitterfeed',
#   'problem',
#   'that',
#   'why',
#   'we',
#   've',
#   'been',
#   'so',
#   'quiet',
#   'lately'],
#  ['do', 'not', 'like', 'lukewarm', 'showers'],
#  ['who',
#   'should',
#   'contact',
#   'if',
#   'need',
#   'for',
#   'freelance',
#   'work',
#   'did',
#   'on',
#   'linux',
#   'com',
#   'throughout',
#   'never',
#   'got',
#   'one'],
#  ['connor',
#   'it',
#   'me',
#   'febi',
#   'are',
#   'you',
#   'really',
#   'really',
#   'mad',
#   'at',
#   'me'],
#  ['need',
#   'some',
#   'help',
#   'want',
#   'to',
#   'buy',
#   'macbook',
#   'pro',
#   'but',
#   'still',
#   'inlove',
#   'with',
#   'my',
#   'old',
#   'powerbook'],
#  ['man',
#   'america',
#   'is',
#   'so',
#   'borez',
#   'anyway',
#   'lol',
#   'just',
#   'realized',
#   'you',
#   'sent',
#   'me',
#   'msgs',
#   'on',
#   'here',
#   'had',
#   'no',
#   'idea',
#   'have',
#   'no',
#   'flash'],
#  ['knight', 'lovely', 'ladies', 'sleepy', 'now'],
#  ['does',
#   'anybody',
#   'know',
#   'how',
#   'to',
#   'get',
#   'your',
#   'electrolytes',
#   'back',
#   'in',
#   'order',
#   'with',
#   'vitamin',
#   'work',
#   'feel',
#   'sick'],
#  ['yes',
#   'someone',
#   'has',
#   'not',
#   'been',
#   'reading',
#   'my',
#   'posts',
#   'properly'],
#  ['almost',
#   'through',
#   'with',
#   'my',
#   'italian',
#   'homework',
#   'weeeeee',
#   'now',
#   'if',
#   'only',
#   'understood',
#   'what',
#   'was',
#   'doing'],
#  ['who',
#   'turned',
#   'the',
#   'lights',
#   'on',
#   'it',
#   'will',
#   'be',
#   'time',
#   'to',
#   'get',
#   'ip',
#   'then'],
#  ['twitter', 'hates', 'us', 'both', 'then'],
#  ['hate',
#   'the',
#   'fact',
#   'that',
#   'genuinely',
#   'excited',
#   'about',
#   'my',
#   'last',
#   'tweet'],
#  ['can', 'not', 'sleep', 'either'],
#  ['between',
#   'that',
#   'and',
#   'the',
#   'italy',
#   'earthquake',
#   'it',
#   'been',
#   'very',
#   'sad',
#   'news',
#   'day'],
#  ['all',
#   'rain',
#   'today',
#   'garden',
#   'really',
#   'needs',
#   'it',
#   'so',
#   'not',
#   'quite',
#   'so',
#   'bad'],
#  ['yawn', 'yawn', 'yawn', 'more', 'minutes', 'in', 'bed'],
#  ['ouch', 'sounds', 'very', 'sucky'],
#  ['great',
#   'idea',
#   'with',
#   'the',
#   'itunes',
#   'promo',
#   'codes',
#   'they',
#   'do',
#   'not',
#   'work',
#   'in',
#   'the',
#   'uk',
#   'itunes',
#   'store',
#   'though'],
#  ['cry'],
#  ['an',
#   'empty',
#   'rum',
#   'barrel',
#   'is',
#   'sad',
#   'rum',
#   'barrel',
#   'shakes',
#   'head',
#   'the',
#   'horror',
#   'the',
#   'horror'],
#  ['it', 'was', 'sleepless', 'night'],
#  ['she', 'admitted', 'to', 'being', 'fake'],
#  ['love', 'chutney'],
#  ['got',
#   'highly',
#   'bored',
#   'today',
#   'scanning',
#   'pages',
#   'for',
#   'daddy',
#   'had',
#   'to',
#   'do',
#   'it'],
#  ['you', 'cooked', 'risotto', 'without', 'me'],
#  ['keeeerrrrriiiiii',
#   'really',
#   'have',
#   'nothing',
#   'better',
#   'to',
#   'do',
#   'then',
#   'post',
#   'on',
#   'this',
#   'thing',
#   'at',
#   'am',
#   'wonderfullll',
#   'says',
#   'alot'],
#  ['yay',
#   'for',
#   'baseball',
#   'season',
#   'boo',
#   'to',
#   'yankees',
#   'losing',
#   'their',
#   'first',
#   'game'],
#  ['lost', 'sucks', 'because', 'have', 'to', 'work', 'today'],
#  ['omg',
#   'exams',
#   'killed',
#   'me',
#   'how',
#   'could',
#   'not',
#   'know',
#   'the',
#   'difference',
#   'between',
#   'haif',
#   'circle',
#   'and',
#   'hemisphere'],
#  ['in',
#   'bed',
#   'suddenly',
#   'feel',
#   'wish',
#   'ma',
#   'was',
#   'here',
#   'me',
#   'goodnight',
#   'twitterfam'],
#  ['do', 'not', 'like', 'goodnights'],
#  ['greaaat', 'my', 'lappy', 'will', 'not', 'turn', 'on', 'wtffffff'],
#  ['you',
#   'stuck',
#   'in',
#   'traffic',
#   'then',
#   'my',
#   'journey',
#   'was',
#   'traffic',
#   'free',
#   'this',
#   'morning',
#   'if',
#   'it',
#   'any',
#   'help'],
#  ['lookin',
#   'like',
#   'an',
#   'all',
#   'nighter',
#   'hate',
#   'it',
#   'when',
#   'do',
#   'this',
#   'to',
#   'myself'],
#  ['you', 're', 'stranger'],
#  ['debbugging',
#   'old',
#   'vb',
#   'code',
#   'the',
#   'day',
#   'could',
#   'have',
#   'started',
#   'better'],
#  ['only', 'quarter', 'of', 'percent', 'babe', 'darn'],
#  ['coming',
#   'down',
#   'with',
#   'cold',
#   'or',
#   'bad',
#   'allergies',
#   'either',
#   'way',
#   'miserable'],
#  ['can',
#   'not',
#   'believe',
#   'cutner',
#   'is',
#   'dead',
#   'on',
#   'house',
#   'sad',
#   'day',
#   'in',
#   'santa',
#   'rosa',
#   'ca'],
#  ['damnit', 'was', 'really', 'digging', 'this', 'season', 'of', 'reaper'],
#  ['gah',
#   'comcast',
#   'doubled',
#   'our',
#   'cable',
#   'internet',
#   'bill',
#   'out',
#   'telling',
#   'us',
#   'so',
#   'we',
#   'are',
#   'quitting',
#   'can',
#   'anyone',
#   'suggest',
#   'an',
#   'affordable',
#   'company',
#   'in',
#   'bay',
#   'area'],
#  ['another',
#   'early',
#   'morn',
#   'with',
#   'the',
#   'duchess',
#   'although',
#   'she',
#   'had',
#   'not',
#   'managed',
#   'to',
#   'cross',
#   'her',
#   'legs',
#   'this',
#   'time'],
#  ['you', 'left', 'without', 'saying', 'hi'],
#  ['want', 'but', 'can', 'not', 'sleep'],
#  ['when',
#   'an',
#   'xbox',
#   'shows',
#   'those',
#   'three',
#   'red',
#   'lights',
#   'it',
#   'means',
#   'it',
#   'dead',
#   'and',
#   'needs',
#   'to',
#   'be',
#   'fixed',
#   'for',
#   'month',
#   'at',
#   'microsoft',
#   'hq'],
#  ['king',
#   'sized',
#   'bed',
#   'is',
#   'nice',
#   'but',
#   'sad',
#   'and',
#   'lonely',
#   'with',
#   'no',
#   'hubby',
#   'puppy',
#   'or',
#   'kitty',
#   'am',
#   'over',
#   'this',
#   'whole',
#   'conferenceing',
#   'thing'],
#  ['im',
#   'boredd',
#   'gah',
#   'wish',
#   'could',
#   'just',
#   'sleep',
#   'and',
#   'get',
#   'it',
#   'over',
#   'with',
#   'but',
#   'ive',
#   'had',
#   'toooo',
#   'muchh',
#   'cooooffffeeeeeeeee',
#   'bahaha'],
#  ['if',
#   'may',
#   'butt',
#   'in',
#   'again',
#   'done',
#   'being',
#   'nosey',
#   'sorry',
#   'your',
#   'conversation',
#   'was',
#   'just',
#   'so',
#   'interesting'],
#  ['you', 'fell', 'off', 'my', 'list', 'did', 'offend', 'you'],
#  ['weeks',
#   'till',
#   'sisters',
#   'home',
#   'missed',
#   'her',
#   'call',
#   'again',
#   'its',
#   'the',
#   'worst',
#   'feeling',
#   'in',
#   'the',
#   'world'],
#  ['gon',
#   'na',
#   'try',
#   'to',
#   'get',
#   'some',
#   'sleep',
#   'in',
#   'this',
#   'hotel',
#   'room'],
#  ['brilliant',
#   'idea',
#   'just',
#   'bring',
#   'as',
#   'much',
#   'as',
#   'you',
#   'think',
#   'you',
#   'll',
#   'spend',
#   'll',
#   'swap',
#   'you',
#   'bring',
#   'brolly'],
#  ['get',
#   'me',
#   'an',
#   'autograph',
#   'and',
#   'shout',
#   'out',
#   'you',
#   'have',
#   'to',
#   'record',
#   'it',
#   'though',
#   'my',
#   'computer',
#   'is',
#   'dead',
#   'so',
#   'can',
#   'not',
#   'listen'],
#  ['rt', 'khloe', 'just', 'got', 'fired', 'from', 'the', 'apprentice'],
#  ['in', 'biology', 'class', 'my', 'lip', 'hurts'],
#  ['sorry', 'for', 'the', 'next', 'tweet'],
#  ['grr', 'not', 'down', 'to', 'go', 'to', 'school', 'today'],
#  ['had',
#   'to',
#   'get',
#   'an',
#   'hd',
#   'tivo',
#   'and',
#   'just',
#   'got',
#   'it',
#   'set',
#   'up',
#   'tonight',
#   'in',
#   'order',
#   'to',
#   'get',
#   'channels'],
#  ['asked',
#   'everyone',
#   'how',
#   'they',
#   'were',
#   'doing',
#   'yesterday',
#   'and',
#   'not',
#   'single',
#   'tweet',
#   'back'],
#  ['ruddy',
#   'money',
#   'like',
#   'it',
#   'still',
#   'waiting',
#   'here',
#   'oh',
#   'what',
#   'surprise',
#   'by',
#   'state',
#   'too',
#   'hmmm',
#   'seriously'],
#  ['am',
#   'so',
#   'sad',
#   'kutner',
#   'was',
#   'my',
#   'favorite',
#   'of',
#   'the',
#   'new',
#   'team'],
#  ['wow', 'did', 'not', 'get', 'an', 'hello', 'suck'],
#  ['bedtime',
#   'school',
#   'tomorrow',
#   'and',
#   'still',
#   'have',
#   'no',
#   'books',
#   'being',
#   'broke',
#   'suckssss'],
#  ['seating',
#   'here',
#   'helping',
#   'my',
#   'baby',
#   'with',
#   'his',
#   'papers',
#   'well',
#   'he',
#   'is',
#   'forcing',
#   'me',
#   'too',
#   'seat',
#   'with',
#   'him',
#   'im',
#   'sleepy'],
#  ['synching',
#   'my',
#   'contacts',
#   'from',
#   'my',
#   'old',
#   'mobile',
#   'to',
#   'iphone',
#   'import',
#   'does',
#   'not',
#   'work',
#   'well'],
#  ['can', 'not', 'concentrate'],
#  ['ve',
#   'just',
#   'spent',
#   'hour',
#   'to',
#   'enter',
#   'all',
#   'the',
#   'bureaucratic',
#   'nonsense',
#   'for',
#   'march',
#   'what',
#   'waste',
#   'of',
#   'my',
#   'time'],
#  ['nw', 'more', 'confused', 'then', 'ever'],
#  ['not',
#   'feeling',
#   'well',
#   'again',
#   'stupid',
#   'migraine',
#   'making',
#   'my',
#   'tummy',
#   'upset',
#   'and',
#   'my',
#   'whole',
#   'body',
#   'aches',
#   'shoot',
#   'me',
#   'now'],
#  ['reading',
#   'buyology',
#   'before',
#   'bedtime',
#   'great',
#   'premise',
#   'but',
#   'only',
#   'turning',
#   'out',
#   'to',
#   'be',
#   'an',
#   'ok',
#   'book',
#   'lots',
#   'of',
#   'info',
#   'already',
#   'knew'],
#  ['home',
#   'really',
#   'wana',
#   'sleep',
#   'but',
#   'due',
#   'to',
#   'wasting',
#   'my',
#   'free',
#   'line',
#   'in',
#   'town',
#   'have',
#   'an',
#   'assignment',
#   'to',
#   'finish'],
#  ['also',
#   'send',
#   'some',
#   'updates',
#   'in',
#   'plurk',
#   'but',
#   'upload',
#   'photos',
#   'on',
#   'twitter',
#   'you',
#   'didnt',
#   'see',
#   'any',
#   'of',
#   'my',
#   'updates',
#   'on',
#   'plurk',
#   'zero'],
#  ['omg', 'the', 'reader', 'is', 'making', 'me'],
#  ['oh',
#   'at',
#   'least',
#   'you',
#   're',
#   'getting',
#   'decent',
#   'exchange',
#   'rate',
#   'at',
#   'the',
#   'moment',
#   'sterling',
#   'is',
#   'still',
#   'getting',
#   'flogged'],
#  ['tried', 'to', 'download', 'tweetdeck', 'but', 'it', 'wont', 'download'],
#  ['there',
#   'an',
#   'inch',
#   'of',
#   'snow',
#   'on',
#   'the',
#   'ground',
#   'and',
#   'counting',
#   'worried',
#   'about',
#   'the',
#   'poor',
#   'flowers'],
#  ['why', 'are', 'not', 'you', 'happy', 'camper'],
#  ['thanks',
#   'man',
#   'so',
#   'very',
#   'grateful',
#   'feel',
#   'unworthy',
#   'of',
#   'such',
#   'attention',
#   'though',
#   'because',
#   'in',
#   'this',
#   'because',
#   'of',
#   'myself'],
#  ['miss',
#   'too',
#   'totally',
#   'comin',
#   'back',
#   'tho',
#   'lastnight',
#   'was',
#   'sooooooo',
#   'much',
#   'fun'],
#  ['ohhh',
#   'love',
#   'it',
#   'ps',
#   'sad',
#   'we',
#   'did',
#   'not',
#   'get',
#   'to',
#   'hang',
#   'out'],
#  ['and', 'somehow', 'still', 'end', 'up', 'in', 'this', 'place'],
#  ['oh', 'that', 'is', 'very', 'sad', 'poor', 'boy'],
#  ...]

# %% [markdown]
# ## Stop Words Removal

# %%
#stop words removal

from nltk.corpus import stopwords

stop = set(stopwords.words('english'))

clean_data = [ ]

for m in word_tokens:
    a = [w for w in m if not w in stop]
    clean_data.append(a)

# %%
# print clean_data

clean_data
# Out:
# [['awww', 'bummer', 'shoulda', 'got', 'david', 'carr', 'third', 'day'],
#  ['upset',
#   'update',
#   'facebook',
#   'texting',
#   'might',
#   'cry',
#   'result',
#   'school',
#   'today',
#   'also',
#   'blah'],
#  ['dived', 'many', 'times', 'ball', 'managed', 'save', 'rest', 'go', 'bounds'],
#  ['whole', 'body', 'feels', 'itchy', 'like', 'fire'],
#  ['behaving', 'mad', 'see'],
#  ['whole', 'crew'],
#  ['need', 'hug'],
#  ['hey',
#   'long',
#   'time',
#   'see',
#   'yes',
#   'rains',
#   'bit',
#   'bit',
#   'lol',
#   'fine',
#   'thanks'],
#  ['nope'],
#  ['que', 'muera'],
#  ['spring', 'break', 'plain', 'city', 'snowing'],
#  ['pierced', 'ears'],
#  ['could', 'bear', 'watch', 'thought', 'ua', 'loss', 'embarrassing'],
#  ['counts', 'idk', 'either', 'never', 'talk', 'anymore'],
#  ['would', 'first', 'gun', 'really', 'though', 'zac', 'snyder', 'doucheclown'],
#  ['wish', 'got', 'watch', 'miss', 'premiere'],
#  ['hollis',
#   'death',
#   'scene',
#   'hurt',
#   'severely',
#   'watch',
#   'film',
#   'wry',
#   'directors',
#   'cut'],
#  ['file', 'taxes'],
#  ['ahh', 'ive', 'always', 'wanted', 'see', 'rent', 'love', 'soundtrack'],
#  ['oh', 'dear', 'drinking', 'forgotten', 'table', 'drinks'],
#  ['day', 'get', 'much', 'done'],
#  ['one',
#   'friend',
#   'called',
#   'asked',
#   'meet',
#   'mid',
#   'valley',
#   'today',
#   'time',
#   'sigh'],
#  ['baked', 'cake', 'ated'],
#  ['week', 'going', 'hoped'],
#  ['blagh', 'class', 'tomorrow'],
#  ['hate', 'call', 'wake', 'people'],
#  ['going', 'cry', 'sleep', 'watching', 'marley'],
#  ['im', 'sad', 'miss', 'lilly'],
#  ['ooooh', 'lol', 'leslie', 'ok', 'leslie', 'get', 'mad'],
#  ['meh',
#   'almost',
#   'lover',
#   'exception',
#   'track',
#   'gets',
#   'depressed',
#   'every',
#   'time'],
#  ['hacked', 'account', 'aim', 'make', 'new', 'one'],
#  ['want',
#   'go',
#   'promote',
#   'gear',
#   'groove',
#   'unfornately',
#   'ride',
#   'may',
#   'going',
#   'one',
#   'anaheim',
#   'may',
#   'though'],
#  ['thought',
#   'sleeping',
#   'option',
#   'tomorrow',
#   'realizing',
#   'evaluations',
#   'morning',
#   'work',
#   'afternoon'],
#  ['awe', 'love', 'miss'],
#  ['cry', 'asian', 'eyes', 'sleep', 'night'],
#  ['ok',
#   'sick',
#   'spent',
#   'hour',
#   'sitting',
#   'shower',
#   'cause',
#   'sick',
#   'stand',
#   'held',
#   'back',
#   'puke',
#   'like',
#   'champ',
#   'bed'],
#  ['ill',
#   'tell',
#   'ya',
#   'story',
#   'later',
#   'good',
#   'day',
#   'ill',
#   'workin',
#   'like',
#   'three',
#   'hours'],
#  ['sorry', 'bed', 'time', 'came', 'gmt'],
#  ['either',
#   'depressing',
#   'think',
#   'even',
#   'want',
#   'know',
#   'kids',
#   'suitcases'],
#  ['bed',
#   'class',
#   'work',
#   'gym',
#   'class',
#   'another',
#   'day',
#   'gon',
#   'na',
#   'fly',
#   'miss',
#   'girlfriend'],
#  ['really',
#   'feel',
#   'like',
#   'getting',
#   'today',
#   'got',
#   'study',
#   'tomorrows',
#   'practical',
#   'exam'],
#  ['reason', 'teardrops', 'guitar', 'one', 'enough', 'break', 'heart'],
#  ['sad',
#   'sad',
#   'sad',
#   'know',
#   'hate',
#   'feeling',
#   'wan',
#   'na',
#   'sleep',
#   'still'],
#  ['soo', 'wish', 'see', 'finally', 'comfortable', 'im', 'sad', 'missed'],
#  ['falling',
#   'asleep',
#   'heard',
#   'tracy',
#   'girl',
#   'body',
#   'found',
#   'sad',
#   'heart',
#   'breaks',
#   'family'],
#  ['yay', 'happy', 'job', 'also', 'means', 'less', 'time'],
#  ['checked',
#   'user',
#   'timeline',
#   'blackberry',
#   'looks',
#   'like',
#   'twanking',
#   'still',
#   'happening',
#   'ppl',
#   'still',
#   'probs',
#   'bgs',
#   'uids'],
#  ['oh', 'man', 'ironing', 'fave', 'top', 'wear', 'meeting', 'burnt'],
#  ['strangely', 'sad', 'lilo', 'samro', 'breaking'],
#  ['oh', 'sorry', 'think', 'retweeting'],
#  ['broadband',
#   'plan',
#   'massive',
#   'broken',
#   'promise',
#   'via',
#   'still',
#   'waiting',
#   'broadband'],
#  ['wow',
#   'tons',
#   'replies',
#   'may',
#   'unfollow',
#   'see',
#   'friends',
#   'tweets',
#   'scrolling',
#   'feed',
#   'lot'],
#  ['duck', 'chicken', 'taking', 'wayyy', 'long', 'hatch'],
#  ['put',
#   'vacation',
#   'photos',
#   'online',
#   'yrs',
#   'ago',
#   'pc',
#   'crashed',
#   'forget',
#   'name',
#   'site'],
#  ['need', 'hug'],
#  ['sure',
#   'pos',
#   'much',
#   'want',
#   'dont',
#   'think',
#   'trade',
#   'away',
#   'company',
#   'assets',
#   'sorry',
#   'andy'],
#  ['hate', 'happens'],
#  ['sad',
#   'feeling',
#   'dallas',
#   'going',
#   'show',
#   'got',
#   'ta',
#   'say',
#   'though',
#   'think',
#   'shows',
#   'would',
#   'use',
#   'music',
#   'game',
#   'mmm'],
#  ['ugh', 'degrees', 'tomorrow'],
#  ['move',
#   'thought',
#   'already',
#   'sd',
#   'hmmm',
#   'random',
#   'found',
#   'glad',
#   'hear',
#   'yer',
#   'well'],
#  ['miss', 'ps', 'commission', 'wutcha', 'playing', 'copped', 'blood', 'sand'],
#  ['leaving', 'parking', 'lot', 'work'],
#  ['life', 'cool'],
#  ['sadly',
#   'though',
#   'never',
#   'gotten',
#   'experience',
#   'post',
#   'coitus',
#   'cigarette',
#   'never'],
#  ['nice', 'day', 'bad', 'rain', 'comes', 'tomorrow'],
#  ['bad',
#   'around',
#   'lost',
#   'job',
#   'even',
#   'pay',
#   'phone',
#   'bill',
#   'lmao',
#   'aw',
#   'shucks'],
#  ['damm', 'back', 'school', 'tomorrow'],
#  ['mo', 'jobs', 'money', 'hell', 'min', 'wage', 'clams', 'hour'],
#  ['forever', 'see', 'soon'],
#  ['agreed', 'saw', 'failwhale', 'allllll', 'day', 'today'],
#  ['oh',
#   'haha',
#   'dude',
#   'dont',
#   'really',
#   'look',
#   'em',
#   'unless',
#   'someone',
#   'says',
#   'hey',
#   'added',
#   'sorry',
#   'terrible',
#   'need',
#   'pop'],
#  ['sure', 'right', 'need', 'start', 'working', 'nikster', 'jared', 'least'],
#  ['really', 'hate', 'people', 'diss', 'bands', 'trace', 'clearly', 'ugly'],
#  ['gym',
#   'attire',
#   'today',
#   'puma',
#   'singlet',
#   'adidas',
#   'shorts',
#   'black',
#   'business',
#   'socks',
#   'leather',
#   'shoes',
#   'lucky',
#   'run',
#   'cute',
#   'girls'],
#  ['show', 'location'],
#  ['picnic', 'phone', 'smells', 'like', 'citrus'],
#  ['donkey',
#   'sensitive',
#   'comments',
#   'nevertheless',
#   'glad',
#   'see',
#   'mug',
#   'asap',
#   'charger',
#   'still',
#   'awol'],
#  ['new', 'csi', 'tonight', 'fml'],
#  ['think', 'arms', 'sore', 'tennis'],
#  ['wonders',
#   'someone',
#   'like',
#   'much',
#   'make',
#   'unhappy',
#   'split',
#   'seccond',
#   'depressed'],
#  ['sleep', 'soon', 'hate', 'saying', 'bye', 'see', 'tomorrow', 'night'],
#  ['got',
#   'ur',
#   'newsletter',
#   'fares',
#   'really',
#   'unbelievable',
#   'shame',
#   'already',
#   'booked',
#   'paid',
#   'mine'],
#  ['missin', 'boo'],
#  ['itm'],
#  ['damn', 'chalk', 'chalkboard', 'useless'],
#  ['blast',
#   'getty',
#   'villa',
#   'hates',
#   'sore',
#   'throat',
#   'day',
#   'getting',
#   'worse'],
#  ['hey', 'missed', 'ya', 'meeting', 'sup', 'mama'],
#  ['tummy',
#   'hurts',
#   'wonder',
#   'hypnosis',
#   'anything',
#   'working',
#   'get',
#   'stop',
#   'smoking'],
#  ['always', 'fat', 'ones'],
#  ['sorry',
#   'babe',
#   'fam',
#   'annoys',
#   'thankfully',
#   'asleep',
#   'right',
#   'muahaha',
#   'evil',
#   'laugh'],
#  ['paid',
#   'attention',
#   'covered',
#   'photoshop',
#   'webpage',
#   'design',
#   'class',
#   'undergrad'],
#  ['wednesday', 'day', 'know'],
#  ['poor', 'cameron', 'hills'],
#  ['pray',
#   'please',
#   'ex',
#   'threatening',
#   'start',
#   'sh',
#   'babies',
#   'st',
#   'birthday',
#   'party',
#   'jerk',
#   'still',
#   'headache'],
#  ['hmm',
#   'really',
#   'enjoy',
#   'problems',
#   'constants',
#   'think',
#   'things',
#   'find',
#   'someone',
#   'ulike'],
#  ['strider', 'sick', 'little', 'puppy'],
#  ['rylee',
#   'grace',
#   'wana',
#   'go',
#   'steve',
#   'party',
#   'sadly',
#   'since',
#   'easter',
#   'wnt',
#   'able',
#   'much',
#   'ohh',
#   'well'],
#  ['hey', 'actually', 'one', 'bracket', 'pools', 'bad', 'one', 'money'],
#  ['follow', 'either', 'work'],
#  ['bad',
#   'nite',
#   'favorite',
#   'teams',
#   'astros',
#   'spartans',
#   'lose',
#   'nite',
#   'good'],
#  ['body',
#   'missing',
#   'northern',
#   'calif',
#   'girl',
#   'found',
#   'police',
#   'found',
#   'remains',
#   'missing',
#   'northern',
#   'california',
#   'girl'],
#  ['hope',
#   'increase',
#   'capacity',
#   'fast',
#   'yesterday',
#   'pain',
#   'got',
#   'fail',
#   'whale',
#   'times',
#   'hours'],
#  ['behind', 'classes', 'work'],
#  ['watching', 'house'],
#  ['remember', 'bum', 'leg', 'strikes', 'back', 'time', 'serious'],
#  ['cool', 'kinds', 'complaints', 'laptop', 'online', 'overheating', 'recalls'],
#  ['emily', 'glad', 'mommy', 'done', 'training', 'new', 'job', 'misses'],
#  ['would',
#   'rather',
#   'first',
#   'party',
#   'send',
#   'bad',
#   'messages',
#   'rd',
#   'party',
#   'send',
#   'mixed',
#   'ones',
#   'sophmore',
#   'year'],
#  ['overrated'],
#  ['know',
#   'heard',
#   'afternoon',
#   'wondered',
#   'thing',
#   'moscow',
#   'behind',
#   'times'],
#  ['laying', 'bed', 'voice'],
#  ['sooo', 'sad', 'killed', 'kutner', 'house', 'whyyyyyyyy'],
#  ['sorry', 'tell', 'mea', 'culpa', 'really', 'sorry'],
#  ['make',
#   'sense',
#   'suicide',
#   'thing',
#   'refuse',
#   'believe',
#   'actually',
#   'happened'],
#  ['hope', 'ok'],
#  ['damn',
#   'grind',
#   'inspirational',
#   'saddening',
#   'time',
#   'want',
#   'stop',
#   'cuz',
#   'like',
#   'much',
#   'love'],
#  ['yeah', 'aw', 'know', 'wudnt', 'stand', 'chance'],
#  ['ugh', 'cant', 'sleep'],
#  ['hanging', 'crooners', 'wan', 'na', 'sing', 'sucks'],
#  ['aaw',
#   'miss',
#   'ya',
#   'im',
#   'leaving',
#   'bh',
#   'tomorrow',
#   'morning',
#   'think',
#   'aww',
#   'wan',
#   'na',
#   'go',
#   'beach',
#   'girls'],
#  ['pissed', 'asba', 'radio', 'station'],
#  ['wednesday', 'day', 'know'],
#  ['know',
#   'life',
#   'flipped',
#   'upside',
#   'thought',
#   'head',
#   'ramen',
#   'sounds',
#   'good'],
#  ['pain', 'back', 'sides', 'hurt', 'mention', 'crying', 'made', 'fail'],
#  ['late',
#   'night',
#   'snack',
#   'glass',
#   'oj',
#   'sickness',
#   'back',
#   'sleep',
#   'ugh',
#   'hate',
#   'getting',
#   'sick'],
#  ['big', 'fan', 'camilla', 'belle'],
#  ['wah',
#   'see',
#   'clip',
#   'must',
#   'el',
#   'stupido',
#   'work',
#   'filters',
#   'wait',
#   'till',
#   'get',
#   'puter',
#   'something',
#   'else',
#   'blame',
#   'ex',
#   'broke',
#   'mine'],
#  ['week',
#   'seems',
#   'get',
#   'longer',
#   'longer',
#   'terms',
#   'much',
#   'need',
#   'much',
#   'actually',
#   'going',
#   'get',
#   'done'],
#  ['cold'],
#  ['ehhh', 'weather', 'gon', 'na', 'take', 'turn', 'ugly', 'tomorrow'],
#  ['haha', 'cooooold', 'still', 'go', 'show', 'incredible', 'stuff'],
#  ['hoping', 'tummy', 'rumbles', 'go', 'away', 'soon'],
#  ['notice',
#   'told',
#   'working',
#   'tomorrow',
#   'called',
#   'agency',
#   'follow',
#   'said'],
#  ['almost', 'bedtime'],
#  ['missing',
#   'babe',
#   'long',
#   'alive',
#   'happy',
#   'ya',
#   'tired',
#   'love',
#   'imma',
#   'try',
#   'sleep',
#   'hopefully',
#   'headstart'],
#  ['agh', 'snow'],
#  ['miss', 'kenny', 'powers'],
#  ['thank',
#   'letting',
#   'people',
#   'know',
#   'sad',
#   'direct',
#   'message',
#   'got',
#   'actually',
#   'bridget'],
#  ['india',
#   'missed',
#   'th',
#   'test',
#   'victory',
#   'th',
#   'consecutive',
#   'win',
#   'without',
#   'loss'],
#  ['guess'],
#  ['sadly', 'going', 'bed'],
#  ['shame', 'hear', 'stephan'],
#  ['hey', 'leavin', 'morning'],
#  ['intending',
#   'finish',
#   'editing',
#   'page',
#   'novel',
#   'manuscript',
#   'tonight',
#   'probably',
#   'happen',
#   'pages',
#   'left'],
#  ['laid', 'around', 'much', 'today', 'head', 'hurts'],
#  ['still',
#   'read',
#   'th',
#   'th',
#   'princess',
#   'diaries',
#   'saving',
#   'francesca',
#   'made',
#   'cry',
#   'end',
#   'hmm',
#   'easy',
#   'books'],
#  ['nokia', 'died'],
#  ['mom',
#   'might',
#   'breast',
#   'cancer',
#   'find',
#   'anything',
#   'like',
#   'week',
#   'worried'],
#  ['going', 'sleep', 'hoping', 'tomorrow', 'better', 'day'],
#  ['lol',
#   'wish',
#   'understood',
#   'daylight',
#   'savings',
#   'ended',
#   'though',
#   'breakfast',
#   'hour',
#   'later',
#   'keep',
#   'waking',
#   'kids'],
#  ['lame'],
#  ['understand', 'really'],
#  ['heroes', 'season'],
#  ['living', 'downtown', 'sure', 'much', 'fun'],
#  ['calorie',
#   'wise',
#   'wish',
#   'junk',
#   'food',
#   'calorie',
#   'free',
#   'ate',
#   'thing',
#   'sour',
#   'skittles',
#   'big',
#   'ass',
#   'cherry',
#   'coke'],
#  ['man', 'work', 'hard'],
#  ['getting', 'sick', 'time', 'hot', 'tea', 'studying', 'sleeeep'],
#  ['getting', 'eyebrows', 'waxed', 'pain'],
#  ['phantasy', 'star', 'yesterday', 'going', 'work'],
#  ['oh',
#   'got',
#   'macheist',
#   'apps',
#   'sweet',
#   'get',
#   'espresso',
#   'serial',
#   'though',
#   'although',
#   'said',
#   'sent',
#   'oh',
#   'well'],
#  ['picked',
#   'mich',
#   'st',
#   'win',
#   'get',
#   'go',
#   'feeling',
#   'pretty',
#   'good',
#   'pick',
#   'way',
#   'tonight',
#   'lost'],
#  ['alone', 'downstairs', 'working'],
#  ['feel', 'bad'],
#  ['hates', 'anoop', 'mean', 'seriously', 'kinda', 'mean'],
#  ['yes', 'sprint', 'baltimore', 'chicago', 'far'],
#  ['stuck',
#   'awake',
#   'middle',
#   'night',
#   'second',
#   'day',
#   'row',
#   'felt',
#   'terrible',
#   'yesterday'],
#  ['thanks', 'bursting', 'bubble'],
#  ['going', 'school', 'soon', 'find', 'anything', 'wear', 'gosh', 'hard'],
#  ['serious', 'lol'],
#  ['page', 'sooooo', 'long', 'got', 'deleted', 'sad', 'day', 'history'],
#  ['crazy', 'wind', 'today', 'birding'],
#  ['currently', 'work'],
#  ['grrr',
#   'ipods',
#   'acting',
#   'weird',
#   'jai',
#   'ho',
#   'thinking',
#   'playing',
#   'full',
#   'songs',
#   'ughh'],
#  ['send', 'dvd', 'cos', 'missed', 'heaps', 'happy'],
#  ['see', 'big', 'deal', 'website'],
#  ['sorry', 'go', 'therapyfail'],
#  ['far', 'way', 'rail', 'tips'],
#  ['still',
#   'swear',
#   'keep',
#   'losing',
#   'gaining',
#   'losing',
#   'gaining',
#   'tweeps',
#   'heart',
#   'wrenching'],
#  ['today', 'realized', 'good', 'hiding', 'things', 'even', 'find'],
#  ['staying',
#   'friends',
#   'house',
#   'house',
#   'sitting',
#   'neighbors',
#   'loud',
#   'party'],
#  ['danny',
#   'im',
#   'upset',
#   'wasnt',
#   'watch',
#   'live',
#   'chat',
#   'car',
#   'hours',
#   'trip',
#   'im',
#   'soooo',
#   'upset'],
#  ['check', 'mug'],
#  ['borders', 'closed'],
#  ['downloading',
#   'nin',
#   'new',
#   'album',
#   'slip',
#   'hell',
#   'come',
#   'behind',
#   'times',
#   'days'],
#  ['woke',
#   'already',
#   'written',
#   'mail',
#   'go',
#   'early',
#   'university',
#   'today',
#   'teach'],
#  ['watching', 'hill', 'making', 'sad'],
#  ['many', 'channels', 'yet', 'boring', 'lazy', 'day', 'may', 'find', 'hobby'],
#  ['miss', 'buddy', 'ill', 'ny', 'th'],
#  ['love',
#   'french',
#   'tell',
#   'people',
#   'south',
#   'qtr',
#   'french',
#   'snarl',
#   'french',
#   'beautiful',
#   'people'],
#  ['opps', 'said', 'still', 'got', 'one', 'day', 'remain', 'problem', 'come'],
#  ['activated',
#   'selfcontrol',
#   'block',
#   'early',
#   'meaning',
#   'check',
#   'new',
#   'qc',
#   'regularizing',
#   'internal',
#   'clock',
#   'might',
#   'difficult',
#   'fb'],
#  ['oh'],
#  ['spencer', 'good', 'guy'],
#  ['reese',
#   'dying',
#   'ttsc',
#   'season',
#   'finale',
#   'next',
#   'week',
#   'boring',
#   'madame',
#   'president',
#   'crazy',
#   'woman'],
#  ['hate', 'limited', 'letters', 'hope', 'guys', 'fine', 'pray', 'dog', 'well'],
#  ['get', 'shit', 'done', 'today', 'screwed'],
#  ['wanttss', 'go'],
#  ['going', 'sleep', 'tonite'],
#  ['worried', 'tired', 'post', 'tonight'],
#  ['could', 'get', 'shit', 'done', 'today', 'screwed'],
#  ['job',
#   'interview',
#   'cardiff',
#   'today',
#   'wish',
#   'luck',
#   'got',
#   'hours',
#   'sleep'],
#  ['show', 'whack', 'way', 'worse', 'whack', 'wiggety', 'whack'],
#  ['really',
#   'think',
#   'people',
#   'choose',
#   'way',
#   'think',
#   'chose',
#   'accept',
#   'family',
#   'help',
#   'might',
#   'dead'],
#  ['going',
#   'kill',
#   'seen',
#   'ds',
#   'waiting',
#   'till',
#   'one',
#   'solid',
#   'week',
#   'sitting'],
#  ['think', 'ur', 'right', 'hahaha', 'hrs'],
#  ['hate', 'see', 'spartans', 'sad'],
#  ['mind',
#   'body',
#   'severely',
#   'protesting',
#   'getting',
#   'thing',
#   'nightmares',
#   'boot'],
#  ['goin', 'follow', 'since', 'lol', 'go', 'angels'],
#  [],
#  ['think', 'want', 'read', 'books', 'library'],
#  ['nap',
#   'interrupted',
#   'many',
#   'times',
#   'today',
#   'going',
#   'japanese',
#   'rents'],
#  ['kind', 'longs', 'bus', 'shows', 'end', 'ghost', 'world', 'right', 'ugh'],
#  ['canada', 'canada', 'weird', 'supposed', 'get', 'snow', 'wednesday', 'ugh'],
#  ['awwh',
#   'babs',
#   'look',
#   'sad',
#   'underneith',
#   'shop',
#   'entrance',
#   'yesterday',
#   'musik',
#   'like',
#   'look',
#   'new',
#   'transformer',
#   'movie'],
#  ['sad', 'feet', 'macbook', 'fell'],
#  ['gon',
#   'na',
#   'get',
#   'late',
#   'tomorrow',
#   'gon',
#   'na',
#   'get',
#   'tipsy',
#   'lonesome',
#   'sad'],
#  ['sweating',
#   'forthcoming',
#   'trip',
#   'find',
#   'someone',
#   'crash',
#   'may',
#   'screwed'],
#  ['gotten', 'somebody', 'read', 'tweets', 'cant', 'get', 'make', 'account'],
#  ['omgawd', 'couldnt', 'handle', 'cat', 'heat', 'time'],
#  ['hope', 'make', 'auburn', 'show', 'looking', 'good'],
#  ['thats',
#   'people',
#   'mag',
#   'haha',
#   'couldnt',
#   'fit',
#   'dont',
#   'think',
#   'pictures',
#   'ever',
#   'made',
#   'magazine',
#   'tho',
#   'haha'],
#  ['congrats', 'totally', 'forgot', 'submit', 'photos'],
#  ['awww',
#   'good',
#   'luck',
#   'paula',
#   'please',
#   'work',
#   'hard',
#   'hope',
#   'fun',
#   'new',
#   'album',
#   'gon',
#   'na',
#   'amazing',
#   'xxx'],
#  ['leaving', 'gets', 'sad'],
#  ['miss',
#   'twitter',
#   'phone',
#   'broke',
#   'using',
#   'stupid',
#   'nokia',
#   'phone',
#   'ughhh',
#   'miss',
#   'advance',
#   'phone'],
#  ['shooting', 'outside', 'house', 'kidding', 'scared'],
#  ['tuesday',
#   'start',
#   'reflection',
#   'lecture',
#   'stress',
#   'reducing',
#   'techniques',
#   'sure',
#   'might',
#   'become',
#   'useful',
#   'us',
#   'accompaniers'],
#  ['tragedy', 'disaster', 'news', 'week'],
#  ['yes', 'yes', 'still', 'trying', 'find', 'picture', 'upload', 'correclty'],
#  ['oh',
#   'red',
#   'sox',
#   'game',
#   'rained',
#   'looking',
#   'forward',
#   'opening',
#   'day'],
#  ['still', 'find', 'keys'],
#  ['know', 'right', 'dunno', 'going', 'twitter'],
#  ['might', 'getting', 'sore', 'throat'],
#  ['home',
#   'town',
#   'mammy',
#   'called',
#   'depressd',
#   'pls',
#   'explain',
#   'parent',
#   'let',
#   'yr',
#   'old',
#   'child',
#   'walk',
#   'alone',
#   'hello'],
#  ['think',
#   'need',
#   'find',
#   'better',
#   'anti',
#   'depressants',
#   'think',
#   'paxil',
#   'wellbutrin',
#   'combo',
#   'losing',
#   'efficacy'],
#  ['restaurant',
#   'called',
#   'woodntap',
#   'competitive',
#   'eating',
#   'tourney',
#   'round',
#   'tourney',
#   'time',
#   'place',
#   'nd'],
#  ['bathroom', 'wake', 'lakin'],
#  ['want', 'tacos', 'margarhitas', 'telll', 'gay', 'say', 'hello'],
#  ['im', 'lonely', 'keep', 'company', 'female', 'california'],
#  ['bad', 'day', 'betfair', 'office'],
#  ['miss', 'wait', 'celebrate', 'tar', 'heel', 'win', 'weekend', 'though'],
#  ['really', 'cold', 'want', 'go', 'sleep', 'yet', 'nothing'],
#  ['officially', 'go', 'round'],
#  ['monkeys', 'found', 'twin', 'wont', 'even', 'write', 'back', 'heartbroken'],
#  ['aww', 'know', 'felt', 'like', 'yesterday', 'work'],
#  ['treaty', 'defined'],
#  ['missed', 'brent', 'praise', 'band', 'fun', 'lead', 'guitarist', 'pout'],
#  ['poor',
#   'john',
#   'happens',
#   'play',
#   'fruit',
#   'microwave',
#   'seriously',
#   'though',
#   'seen',
#   'doctor',
#   'xxx'],
#  ['missing', 'bff', 'watching', 'home', 'away', 'reminds', 'shout', 'courts'],
#  [],
#  ['new', 'video', 'card', 'doa'],
#  ['feeling', 'lost', 'naked', 'confused', 'jk', 'sort', 'iphone'],
#  ['damn',
#   'late',
#   'filling',
#   'appraisal',
#   'form',
#   'people',
#   'almost',
#   'sent',
#   'occupied',
#   'work'],
#  ['missed', 'brent', 'praise', 'band', 'fun', 'lead', 'guitarist', 'pout'],
#  ['think',
#   'much',
#   'past',
#   'cant',
#   'change',
#   'deserved',
#   'much',
#   'wat',
#   'got',
#   'still',
#   'thinking',
#   'gah'],
#  ['lost', 'ring', 'seen'],
#  ['ooooooh',
#   'sealclap',
#   'see',
#   'download',
#   'shitloads',
#   'zip',
#   'folders',
#   'chan',
#   'internet',
#   'moneys',
#   'fuck',
#   'yeah',
#   'alicia',
#   'mikey'],
#  ['still',
#   'nursing',
#   'nile',
#   'glad',
#   'feeling',
#   'better',
#   'hate',
#   'baby',
#   'sick'],
#  ['fucked', 'go', 'back', 'ic'],
#  ['yoyoyo', 'internet', 'rude', 'tonight', 'reconnected', 'go', 'bed'],
#  ['well', 'uni', 'stuff', 'netball', 'netbal', 'done', 'uni', 'stuff'],
#  ['poor'],
#  ['help', 'forget', 'th', 'april', 'th', 'july'],
#  ['dierks', 'bentley', 'comin', 'columbus', 'oh', 'wan', 'na', 'go', 'bad'],
#  ['take', 'sidekick', 'back'],
#  ['congrats', 'totally', 'jealous', 'wish', 'xm', 'working'],
#  ['gr', 'face', 'itchy'],
#  ['poor', 'socks', 'luvvvvv', 'golden', 'retriever', 'want', 'one', 'sighhhh'],
#  ['saw', 'found', 'tracy', 'girl', 'piece', 'luggage', 'fucking', 'terrible'],
#  ['aaaaand', 'nausea', 'back'],
#  ['ooh', 'excited', 'even', 'going', 'long', 'love', 'youtube'],
#  ['spent',
#   'hour',
#   'reach',
#   'axis',
#   'bank',
#   'find',
#   'today',
#   'holiday',
#   'mahavir',
#   'jayanti',
#   'contd'],
#  ['agree', 'jobros', 'dont', 'update', 'theres', 'often'],
#  ['hilarious',
#   'linked',
#   'clip',
#   'lj',
#   'time',
#   'ago',
#   'went',
#   'back',
#   'dead',
#   'link'],
#  ['oooooooo', 'im', 'neither', 'thats', 'need', 'study'],
#  ['tweeted',
#   'nearly',
#   'day',
#   'posted',
#   'website',
#   'tonight',
#   'hopefully',
#   'goes',
#   'well',
#   'night',
#   'time'],
#  ['miss', 'bentley'],
#  ['seriously', 'needs', 'finish', 'job', 'applications'],
#  ['son',
#   'vincas',
#   'sick',
#   'stay',
#   'home',
#   'three',
#   'tense',
#   'days',
#   'work',
#   'back',
#   'holiday',
#   'kids'],
#  ['whinging',
#   'client',
#   'boss',
#   'understand',
#   'english',
#   'well',
#   'rewrote',
#   'text',
#   'unreadable',
#   'written',
#   'good',
#   'writer',
#   'reviewed',
#   'correctly'],
#  ['want', 'ever', 'punch'],
#  ['sooo', 'sick', 'snow', 'ughh'],
#  [],
#  ['work', 'fan', 'upset'],
#  ['would',
#   'like',
#   'apologize',
#   'repeated',
#   'video',
#   'games',
#   'live',
#   'related',
#   'tweets',
#   'going',
#   'stern',
#   'discussion',
#   'koodo',
#   'soon',
#   'stern'],
#  ['cant', 'figure', 'get', 'back', 'pay', 'hotel', 'etc'],
#  ['fml',
#   'much',
#   'seniority',
#   'bc',
#   'technological',
#   'ineptness',
#   'register',
#   'classes'],
#  ['feels',
#   'like',
#   'slept',
#   'day',
#   'away',
#   'looking',
#   'forward',
#   'bouts',
#   'gallbladder',
#   'least',
#   'pills',
#   'pain'],
#  ['really', 'want', 'old', 'bass', 'back'],
#  ['mad',
#   'tired',
#   'today',
#   'callin',
#   'early',
#   'tonight',
#   'nighty',
#   'night',
#   'twittas'],
#  ['take', 'easy', 'good'],
#  ['afraid', 'bad', 'code'],
#  ['think', 'going', 'bed', 'goodniight', 'hate'],
#  ['friend', 'love'],
#  ['time', 'notice', 'gone', 'needed', 'db'],
#  ['bathroom', 'pee'],
#  ['wanted', 'margarita'],
#  ['yup',
#   'night',
#   'workouts',
#   'worst',
#   'unfortunetly',
#   'work',
#   'schedule',
#   'allows',
#   'go',
#   'night',
#   'tough'],
#  ['called',
#   'hillsong',
#   'said',
#   'could',
#   'tell',
#   'waiting',
#   'list',
#   'know',
#   'looking',
#   'good'],
#  ['milky', 'bar', 'left', 'around', 'ml', 'coke'],
#  ['stillllll', 'arrived'],
#  ['mraow',
#   'feel',
#   'like',
#   'dancing',
#   'first',
#   'art',
#   'school',
#   'wants',
#   'rape'],
#  ['ah',
#   'bet',
#   'like',
#   'craving',
#   'play',
#   'softball',
#   'basketball',
#   'noo',
#   'time'],
#  ['terrified',
#   'accidentally',
#   'deleted',
#   'reference',
#   'management',
#   'assignment',
#   'hopes',
#   'doesnt',
#   'get',
#   'trouble',
#   'gets',
#   'back'],
#  ['amazon',
#   'plugin',
#   'worked',
#   'website',
#   'need',
#   'php',
#   'hosting',
#   'provider',
#   'php',
#   'sad'],
#  ['argh',
#   'suuuper',
#   'sleepy',
#   'hour',
#   'ago',
#   'wide',
#   'awake',
#   'hope',
#   'stay',
#   'night'],
#  ['wish', 'sold', 'time', 'let', 'know', 'would', 'love', 'hear'],
#  ['watched', 'tropic', 'thunder', 'dreading', 'tomorrow'],
#  ['still', 'miss'],
#  ['chiefdelphi'],
#  ['according',
#   'bro',
#   'new',
#   'puppy',
#   'poo',
#   'fight',
#   'covered',
#   'poop',
#   'picture',
#   'stolen'],
#  ['playing', 'game', 'home', 'new', 'boss', 'call', 'yet'],
#  ['su',
#   'yin',
#   'huen',
#   'tweeted',
#   'feel',
#   'unbearable',
#   'guilt',
#   'made',
#   'staff',
#   'cry'],
#  ['poor', 'joshy', 'sick', 'damn', 'tejanos'],
#  ['thoughts', 'sandra', 'cantu', 'family', 'difficult', 'sad', 'time'],
#  ['know', 'wanted', 'let', 'everybody', 'know', 'happening'],
#  ['michigan', 'know', 'sigh', 'shameful'],
#  ['fill', 'two', 'hours'],
#  ['cuuute', 'hey', 'miss', 'na', 'seeing', 'girls', 'everyday'],
#  ['oh',
#   'mention',
#   'gooooood',
#   'moooorniiiiiiing',
#   'germany',
#   'im',
#   'back',
#   'cage',
#   'better',
#   'office'],
#  ['throat', 'closing', 'string', 'cheese', 'good', 'idea'],
#  ['aww',
#   'sandra',
#   'cantu',
#   'found',
#   'dead',
#   'suitcase',
#   'missing',
#   'children',
#   'stories',
#   'never',
#   'seem',
#   'go',
#   'good',
#   'poor',
#   'family'],
#  ['wishing', 'home', 'underneath', 'covers'],
#  ['walking', 'home', 'school', 'drains', 'energy'],
#  ['agree',
#   'shapeshifting',
#   'copout',
#   'excited',
#   'angela',
#   'ep',
#   'thought',
#   'week',
#   'noah',
#   'awesome',
#   'tho'],
#  ['dang', 'would', 'done', 'knew', 'earlier', 'outings', 'planned'],
#  ['wish', 'better', 'writing', 'taking', 'long', 'write', 'paper'],
#  ['course',
#   'access',
#   'halo',
#   'mythic',
#   'map',
#   'pack',
#   'download',
#   'bad',
#   'news',
#   'legendary',
#   'map',
#   'pack',
#   'ugh',
#   'ms'],
#  ['yet',
#   'unfortunately',
#   'another',
#   'weeks',
#   'told',
#   'little',
#   'bit',
#   'busy',
#   'latest',
#   'project'],
#  ['ha', 'sun', 'already', 'gone'],
#  ['day', 'lot', 'harder', 'day', 'let', 'see', 'day', 'goes', 'tomorrow'],
#  ['man', 'crush', 'jake', 'peavy', 'let', 'gayforpeavy'],
#  ['megafast',
#   'trip',
#   'time',
#   'day',
#   'tom',
#   'weds',
#   'going',
#   'tonight',
#   'want',
#   'see',
#   'bad',
#   'tried',
#   'warn',
#   'tech',
#   'fail'],
#  ['michigan', 'state', 'make', 'sad'],
#  ['omg',
#   'mouth',
#   'much',
#   'pain',
#   'wan',
#   'na',
#   'sleep',
#   'untill',
#   'time',
#   'take',
#   'braces'],
#  ['getting',
#   'annoyed',
#   'easily',
#   'today',
#   'biofuel',
#   'proposal',
#   'getting',
#   'annoyed',
#   'easily',
#   'today',
#   'biof'],
#  ['hey', 'girl', 'site', 'back', 'girlyvue', 'back', 'even', 'videos'],
#  ['spending', 'time', 'grandma', 'early', 'tomorrow', 'leave', 'skittles'],
#  ['got', 'home', 'watching', 'michigan', 'state', 'get', 'tromped'],
#  ['oh',
#   'jew',
#   'bus',
#   'two',
#   'years',
#   'worth',
#   'classes',
#   'work',
#   'alot',
#   'organize',
#   'finishing',
#   'tonight',
#   'possible',
#   'bones',
#   'ache'],
#  ['exchanging', 'laptop', 'arrived'],
#  ['hope', 'last', 'long', 'feel', 'miserable'],
#  ['rachel',
#   'hang',
#   'outage',
#   'neccessary',
#   'gon',
#   'na',
#   'home',
#   'wekend',
#   'dumb',
#   'folk',
#   'make',
#   'work',
#   'im',
#   'free',
#   'sat'],
#  ['fun',
#   'furious',
#   'new',
#   'mantra',
#   'bay',
#   'breakers',
#   'getting',
#   'rambunctious',
#   'city',
#   'overreacted',
#   'clamped'],
#  ['hubby',
#   'reason',
#   'thinks',
#   'important',
#   'good',
#   'spot',
#   'red',
#   'carpet',
#   'trek',
#   'movie',
#   'premiere',
#   'sod'],
#  ['swear',
#   'matter',
#   'long',
#   'getting',
#   'never',
#   'gets',
#   'easier',
#   'man',
#   'eyes',
#   'hurts',
#   'wah'],
#  ['jeffree',
#   'keep',
#   'hair',
#   'one',
#   'color',
#   'permanent',
#   'dye',
#   'fades',
#   'within',
#   'week'],
#  ['reaction', 'whoa', 'see', 'coming'],
#  ['still',
#   'sick',
#   'feeling',
#   'bit',
#   'better',
#   'got',
#   'new',
#   'medicine',
#   'hope',
#   'feel',
#   'good',
#   'night',
#   'sleep',
#   'ohh',
#   'suppose',
#   'snow',
#   'wtf'],
#  ['think',
#   'maybe',
#   'get',
#   'couple',
#   'hours',
#   'sleep',
#   'hon',
#   'productive',
#   'right',
#   'ur',
#   'dog',
#   'tired',
#   'worry'],
#  ['thanks', 'lot', 'learned', 'lot', 'new', 'words', 'find', 'looking'],
#  ['wish',
#   'xblm',
#   'downloads',
#   'gamertag',
#   'hitokyri',
#   'gamertag',
#   'thing',
#   'nonsense',
#   'tired'],
#  ['new', 'testament', 'test'],
#  ['tons', 'hay', 'troll', 'ahhhh'],
#  ['stupid', 'movies', 'watched', 'mirrors', 'ugggggh', 'stooopeeed', 'rip'],
#  ['love', 'buck'],
#  ['last', 'one', 'still', 'done'],
#  ['homework'],
#  ['understand',
#   'things',
#   'get',
#   'taken',
#   'away',
#   'enough',
#   'time',
#   'unfair',
#   'want',
#   'back',
#   'like',
#   'baby'],
#  ['scratch',
#   'du',
#   'heif',
#   'two',
#   'half',
#   'cookies',
#   'tum',
#   'take',
#   'anymore',
#   'shoog',
#   'poots'],
#  ['listening',
#   'sweets',
#   'first',
#   'time',
#   'forever',
#   'miss',
#   'much',
#   'go',
#   'chi',
#   'town',
#   'visits',
#   'plz'],
#  ['geez',
#   'busy',
#   'afternoon',
#   'meetings',
#   'emails',
#   'meetings',
#   'email',
#   'meetings',
#   'pm',
#   'day',
#   'still',
#   'going',
#   'ah',
#   'dark'],
#  ['dang',
#   'another',
#   'spring',
#   'break',
#   'cool',
#   'bad',
#   'work',
#   'week',
#   'oh',
#   'well',
#   'money',
#   'phone',
#   'ttyl',
#   'everbody'],
#  ['im', 'afraid', 'ur', 'reply', 'uni', 'ages', 'ago'],
#  ['feeling'],
#  ['lol',
#   'emotional',
#   'ass',
#   'men',
#   'omg',
#   'late',
#   'night',
#   'eating',
#   'us',
#   'broke'],
#  ['aww', 'nick', 'like', 'hair', 'longer', 'cut', 'break', 'heart'],
#  ['wonder', 'jon', 'lost', 'net'],
#  ['wow',
#   'depressing',
#   'thing',
#   'world',
#   'losing',
#   'video',
#   'created',
#   'matter',
#   'seconds',
#   'fml'],
#  ['says', 'stock'],
#  ['lmao', 'im', 'sorry', 'poohpot', 'ate'],
#  ['chance', 'softbelly', 'loud'],
#  ['time',
#   'move',
#   'posterior',
#   'lose',
#   'fat',
#   'articulation',
#   'creaking',
#   'running',
#   'drool',
#   'swimming'],
#  ['listening', 'nathan', 'cry'],
#  ['today',
#   'sucked',
#   'gon',
#   'na',
#   'die',
#   'without',
#   'chris',
#   'callum',
#   'wahhh'],
#  ['stou',
#   'site',
#   'update',
#   'info',
#   'exam',
#   'open',
#   'course',
#   'must',
#   'wait',
#   'mail',
#   'notices',
#   'doc',
#   'um'],
#  ['sorry', 'feeling', 'kinda', 'yucky', 'going', 'come', 'quick'],
#  ['love', 'scrappy', 'missin', 'already'],
#  ['wants', 'hear', 'song', 'myspace', 'messing'],
#  ['bad',
#   'news',
#   'dad',
#   'cancer',
#   'dying',
#   'good',
#   'news',
#   'new',
#   'business',
#   'started',
#   'life',
#   'coach',
#   'practising',
#   'holistic',
#   'weight',
#   'management'],
#  ['man', 'intervention', 'soo', 'sad'],
#  ['help', 'need', 'new', 'boyfriend', 'stuck', 'rut'],
#  ['feel', 'like', 'complete', 'idiot', 'one', 'get', 'shit', 'works', 'help'],
#  ['saw',
#   'ad',
#   'craigslist',
#   'casting',
#   'call',
#   'female',
#   'host',
#   'totally',
#   'psyched',
#   'realized',
#   'hoax'],
#  ['pepperoni',
#   'rolls',
#   'called',
#   'valentino',
#   'said',
#   'sausage',
#   'rolls',
#   'pepperoni',
#   'rolls'],
#  ['yes', 'monday'],
#  ['want', 'new', 'gg', 'episode', 'already'],
#  ['miss', 'watching', 'rocko', 'modern', 'life'],
#  ['rip', 'sandra', 'sad', 'someone', 'something', 'like'],
#  ['keeping', 'fingers', 'crossed', 'buddy', 'feeling', 'well'],
#  ['wait', 'eat', 'skinny', 'vegas', 'hungry'],
#  ['tried', 'tweetdeck', 'hated', 'passion', 'hated', 'sure'],
#  ['btw',
#   'iphone',
#   'acting',
#   'funny',
#   'dying',
#   'quickly',
#   'freezing',
#   'bs',
#   'admitting',
#   'anything',
#   'sayin'],
#  ['sitting', 'wondering', 'ed', 'still', 'strong', 'hold'],
#  ['im', 'sorry', 'got', 'sick', 'lol', 'going', 'bed', 'night'],
#  ['internet', 'home', 'drive', 'ox', 'use', 'internet', 'builders'],
#  ['weather', 'canada', 'freezing'],
#  ['twiggassssssss', 'range', 'day', 'back', 'hopefully', 'good'],
#  [],
#  ['anyone', 'reads', 'pray', 'grandma', 'pain'],
#  ['woke',
#   'accident',
#   'pushing',
#   'pushing',
#   'crying',
#   'could',
#   'stop',
#   'wetting',
#   'pants'],
#  ['home',
#   'franklin',
#   'street',
#   'almost',
#   'jumped',
#   'fire',
#   'someone',
#   'kicked',
#   'could',
#   'jenny',
#   'lost',
#   'shoe'],
#  ['hey', 'changed', 'default'],
#  ['finally',
#   'gave',
#   'bored',
#   'enough',
#   'start',
#   'thing',
#   'think',
#   'going',
#   'problem',
#   'tho',
#   'like',
#   'myspace',
#   'status'],
#  ['oooonly', 'really', 'lucky', 'eh', 'awh', 'definitely', 'early', 'work'],
#  ['buttload', 'homework'],
#  ['needs', 'another', 'copy', 'visual', 'studio'],
#  ['school',
#   'world',
#   'week',
#   'school',
#   'silly',
#   'anyway',
#   'look',
#   'bright',
#   'side'],
#  ['omg',
#   'economics',
#   'test',
#   'dont',
#   'know',
#   'things',
#   'know',
#   'omg',
#   'im',
#   'gon',
#   'na',
#   'fail'],
#  ['upon',
#   'time',
#   'hundred',
#   'islands',
#   'pride',
#   'philippine',
#   'tourism',
#   'coral',
#   'clam',
#   'rare',
#   'fish',
#   'poaching',
#   'kinda',
#   'sad'],
#  ['yeah', 'apparently', 'really', 'bad', 'taste'],
#  ['know',
#   'really',
#   'surprised',
#   'since',
#   'everyone',
#   'recommends',
#   'youtube',
#   'call',
#   'tomorrow',
#   'figure'],
#  ['waiting',
#   'airport',
#   'ride',
#   'get',
#   'harassed',
#   'men',
#   'trying',
#   'sell',
#   'ugly',
#   'hats',
#   'want',
#   'sleep'],
#  ['left', 'ids', 'location', 'go', 'bars', 'fuckkkkkkkkkkkkk'],
#  ['sorry', 'understand', 'last', 'comment'],
#  ['announcement', 'stayed', 'late', 'last', 'night'],
#  ['strange',
#   'illegal',
#   'torrents',
#   'avlbl',
#   'everywhere',
#   'legal',
#   'dvd',
#   'stock'],
#  ['enough', 'say', 'imiss'],
#  ['trolley',
#   'packed',
#   'like',
#   'sardines',
#   'padre',
#   'game',
#   'remove',
#   'car',
#   'good',
#   'call',
#   'mts'],
#  ['jeez', 'trying', 'help', 'haha'],
#  ['happened', 'saturday', 'night', 'along', 'glittery', 'green', 'lighter'],
#  ['trying', 'reduce', 'number', 'cigarettes', 'day'],
#  ['yea',
#   'quiet',
#   'around',
#   'cuz',
#   'everyone',
#   'work',
#   'im',
#   'bored',
#   'death',
#   'nobody',
#   'talk'],
#  ['got', 'ta', 'cooking', 'assignment', 'hard'],
#  ['okay', 'applepears', 'talked', 'people', 'one', 'ever', 'told', 'never'],
#  ['know',
#   'night',
#   'owl',
#   'nature',
#   'hahaha',
#   'time',
#   'zone',
#   'behind',
#   'almost'],
#  ['lol', 'nope', 'complete', 'camerafail'],
#  ['useless', 'sleep', 'fair', 'want', 'fun', 'well'],
#  ['pookie', 'uti', 'nurse', 'gabbie', 'get', 'back', 'sodas'],
#  ['tweet', 'something', 'damn', 'hang', 'please'],
#  [],
#  ['behind', 'video', 'games', 'everything', 'matter', 'yesterday', 'news'],
#  ['one',
#   'left',
#   'got',
#   'tempted',
#   'ate',
#   'soon',
#   'got',
#   'home',
#   'chocolate',
#   'velvet',
#   'ate',
#   'mocha'],
#  ['stressing',
#   'blackberry',
#   'keeps',
#   'flashing',
#   'red',
#   'alert',
#   'status',
#   'reason',
#   'faking',
#   'hate'],
#  ['wan', 'na', 'wear', 'doc', 'martens', 'worn', 'since', 'december'],
#  ['shoe',
#   'repair',
#   'shop',
#   'guy',
#   'could',
#   'find',
#   'shoes',
#   'go',
#   'back',
#   'see',
#   'find',
#   'couple',
#   'days'],
#  ['really', 'see', 'coming'],
#  ['woke',
#   'vivid',
#   'sketchy',
#   'cool',
#   'dreams',
#   'life',
#   'time',
#   'stare',
#   'wall',
#   'lights'],
#  ['take', 'days', 'sister', 'get', 'passport'],
#  ['oh', 'yes', 'miss'],
#  ['uh', 'oh', 'think', 'getting', 'sick'],
#  ['good', 'god', 'ruined', 'belly', 'button'],
#  ['watching', 'framed', 'roger', 'rabbit', 'makes', 'miss', 'toon', 'town'],
#  ['renting',
#   'cheap',
#   'renting',
#   'awesome',
#   'house',
#   'buying',
#   'attempts',
#   'fall'],
#  ['running', 'nose', 'spinning', 'head', 'good', 'combination', 'meeting'],
#  ['negative', 'lost', 'vote', 'confidence'],
#  ['nasty', 'budget', 'due', 'iphone', 'sent', 'apple', 'today'],
#  ['bad'],
#  ['dammit',
#   'episode',
#   'kings',
#   'play',
#   'reason',
#   'stopped',
#   'middle',
#   'anything'],
#  ['upset', 'missed', 'chat', 'quiz', 'online', 'free', 'internet', 'ceased'],
#  ['believe',
#   'disbelief',
#   'way',
#   'really',
#   'much',
#   'take',
#   'people',
#   'always',
#   'get',
#   'hurt',
#   'others'],
#  ['car', 'show', 'season', 'started', 'without'],
#  ['throat', 'raw'],
#  ['get',
#   'persons',
#   'mind',
#   'could',
#   'even',
#   'ish',
#   'like',
#   'prayers',
#   'fam',
#   'real'],
#  ['hate', 'need', 'see', 'need', 'call', 'therapist'],
#  ['twilight', 'come', 'yesterday', 'fingers', 'crossed', 'today'],
#  ['glad', 'able', 'help', 'feel', 'better', 'hate', 'see', 'sick', 'love'],
#  ['tireddddddd',
#   'want',
#   'sleep',
#   'assignment',
#   'finish',
#   'exam',
#   'tomorrow',
#   'study'],
#  ['know', 'thinking', 'need', 'money'],
#  ['omg', 'jst', 'teusday'],
#  ['ummmmm', 'cant', 'find'],
#  ['heard', 'found', 'sandra', 'cantu', 'yrs', 'old'],
#  ['ive',
#   'forgotten',
#   'snoo',
#   'snoo',
#   'wonder',
#   'snoo',
#   'snoo',
#   'ever',
#   'meet'],
#  ['wow', 'last', 'tweet', 'made', 'seem', 'like', 'giant', 'sexist', 'sorry'],
#  ['bathtub',
#   'drain',
#   'fired',
#   'haz',
#   'job',
#   'iz',
#   'fail',
#   'got',
#   'drano',
#   'ass',
#   'iz',
#   'still',
#   'draining',
#   'wan',
#   'na',
#   'shower',
#   'dangit'],
#  ['stuck', 'home'],
#  ['mine', 'get'],
#  ['duckling',
#   'famous',
#   'children',
#   'book',
#   'stolen',
#   'boston',
#   'public',
#   'garden',
#   'boston',
#   'globe',
#   'via',
#   'oh'],
#  ['thank', 'however', 'hate', 'list', 'includes', 'convicts'],
#  ['heading', 'altrincham', 'hours', 'install'],
#  ['morning',
#   'good',
#   'im',
#   'bloody',
#   'knackered',
#   'work',
#   'today',
#   'helppp',
#   'xxx'],
#  ['garage', 'park', 'driveway'],
#  ['happened'],
#  ['popular',
#   'music',
#   'adorno',
#   'probably',
#   'difficult',
#   'reading',
#   'ever',
#   'prescribed',
#   'actually',
#   'struggling',
#   'continue'],
#  ['cant', 'see', 'flowers', 'falling', 'dont', 'camera', 'cellphone'],
#  ['good',
#   'liking',
#   'snow',
#   'right',
#   'getting',
#   'used',
#   'nice',
#   'spring',
#   'like',
#   'weather'],
#  ['pity', 'youtube', 'currently', 'blocked', 'china', 'see', 'vids'],
#  ['happened', 'show', 'hightlight', 'life'],
#  ['best',
#   'leather',
#   'sofa',
#   'world',
#   'office',
#   'though',
#   'means',
#   'still',
#   'working'],
#  ['still', 'days', 'internet', 'gets', 'uncapped'],
#  ['get', 'better', 'days', 'could', 'something', 'lodged', 'belly'],
#  ['love', 'atekinzz', 'much', 'soo', 'miss'],
#  ['wan', 'na', 'sneak', 'zoo', 'play', 'kitties'],
#  ['oh', 'hope', 'getting', 'sick'],
#  ['dont', 'think', 'cause', 'cousins', 'birthday', 'party'],
#  ['sweet',
#   'little',
#   'man',
#   'fell',
#   'asleep',
#   'waiting',
#   'daddy',
#   'big',
#   'brother',
#   'get',
#   'home',
#   'poor',
#   'baby',
#   'missed',
#   'much',
#   'today'],
#  ['angel', 'going', 'miss', 'athlete', 'weekend'],
#  ['trust', 'hard'],
#  ['watched',
#   'considering',
#   'today',
#   'yaknow',
#   'shawnna',
#   'tomomorrow',
#   'need',
#   'bestfriend'],
#  ['grr', 'want', 'keep', 'reading', 'wont', 'anything', 'left', 'read'],
#  ['atekinzz', 'world'],
#  ['supposed', 'date'],
#  ['pears',
#   'brie',
#   'bottle',
#   'cabernet',
#   'win',
#   'date',
#   'tad',
#   'hamilton',
#   'oh',
#   'gawwd',
#   'life',
#   'flashed',
#   'forward',
#   'cats'],
#  ['crap', 'need', 'dresses'],
#  ['yeah', 'know', 'horrible', 'ugh', 'saddening'],
#  ['geez', 'ur', 'fun'],
#  ['wan', 'na', 'punk', 'rock', 'band'],
#  ['lot', 'angst', 'tuesday', 'afternoon'],
#  ['glad',
#   'britney',
#   'crazy',
#   'anymore',
#   'one',
#   'hell',
#   'show',
#   'sad',
#   'next',
#   'ap',
#   'cook',
#   'county'],
#  ['huuuge', 'headache', 'omg', 'feel', 'like', 'crap'],
#  ['sorry'],
#  ['sorry', 'rooting'],
#  ['man', 'took', 'forever'],
#  ['see'],
#  ['listing',
#   'items',
#   'ebay',
#   'sell',
#   'takes',
#   'forever',
#   'meanwhile',
#   'coleman',
#   'watching',
#   'hills',
#   'season',
#   'premier',
#   'without'],
#  ['got',
#   'presentation',
#   'done',
#   'slides',
#   'done',
#   'crying',
#   'week',
#   'hardest',
#   'weeks'],
#  ['lost'],
#  ['like',
#   'previously',
#   'skins',
#   'thing',
#   'starts',
#   'season',
#   'two',
#   'like',
#   'went',
#   'straight',
#   'intro',
#   'like'],
#  ['wish', 'pretty', 'good', 'scaring', 'shit', 'people'],
#  ['going', 'sound', 'vain', 'running', 'fav', 'lip', 'gloss'],
#  ['never',
#   'click',
#   'link',
#   'screams',
#   'spider',
#   'spider',
#   'known',
#   'better',
#   'yucky'],
#  ['time', 'work', 'get', 'sick'],
#  ['imac', 'came', 'indonesia', 'states'],
#  ['dammit', 'need', 'stop', 'buying', 'furniture'],
#  ['half', 'asleep', 'turned', 'laptop'],
#  ['death', 'peaceful', 'life', 'however', 'bites'],
#  ['think', 'lost', 'net', 'sure', 'hope'],
#  ['test', 'footage', 'girlfriend', 'hd', 'dark', 'one', 'underxposed'],
#  ['tough',
#   'game',
#   'watch',
#   'tonight',
#   'state',
#   'finally',
#   'going',
#   'bed',
#   'also',
#   'staying',
#   'watch',
#   'season',
#   'premiere',
#   'hills'],
#  ['seems', 'jruby', 'support', 'hpricot', 'two', 'versions', 'behind'],
#  ['unlike', 'sister', 'still', 'one'],
#  ['fraking', 'app', 'store', 'pissing'],
#  ['logging', 'need', 'study'],
#  ['anyone', 'else', 'problems', 'accessing', 'ttb', 'cant', 'get'],
#  ['strongly',
#   'dislike',
#   'people',
#   'make',
#   'stupid',
#   'comments',
#   'dont',
#   'know',
#   'whole',
#   'story'],
#  ['sorry', 'emma', 'swarley', 'goldfish', 'sad'],
#  ['tweets', 'already', 'gone', 'missed', 'guys', 'tonight'],
#  ['sleep',
#   'face',
#   'kinda',
#   'swollen',
#   'let',
#   'allergic',
#   'thing',
#   'get',
#   'thursday',
#   'school',
#   'tomorrow',
#   'doubtful'],
#  ['izzy', 'cat', 'tree', 'stare', 'floor', 'chases', 'runs'],
#  ['officially',
#   'banning',
#   'godaddy',
#   'com',
#   'comp',
#   'head',
#   'hurts',
#   'small',
#   'print',
#   'wasted',
#   'could',
#   'happily',
#   'gone',
#   'boba'],
#  ['pretty', 'much', 'scary'],
#  ['mines', 'finding', 'well', 'hard', 'get', 'fit'],
#  ['good', 'morning', 'ready', 'go', 'want', 'go', 'back', 'bed'],
#  ['hates', 'waiting', 'mails'],
#  ['wheat',
#   'bread',
#   'dollar',
#   'store',
#   'toast',
#   'nicely',
#   'going',
#   'taxes',
#   'calling',
#   'early',
#   'night'],
#  ['kutner',
#   'mean',
#   'knew',
#   'something',
#   'going',
#   'happen',
#   'someone',
#   'sad',
#   'house',
#   'well',
#   'done',
#   'still',
#   'sad'],
#  ['aw', 'ok', 'goonite'],
#  ['ill', 'cant', 'go', 'cinema'],
#  ['fell', 'asleep', 'really', 'mean', 'christina'],
#  ['hey',
#   'remember',
#   'time',
#   'used',
#   'friends',
#   'ugh',
#   'vomit',
#   'sick',
#   'need',
#   'sleep'],
#  ['lymph', 'nodes', 'massive', 'rahm', 'emanuel', 'balls', 'right'],
#  ['oh',
#   'computer',
#   'sucks',
#   'think',
#   'able',
#   'listen',
#   'xbox',
#   'fancast',
#   'tonite'],
#  ['missing', 'playing', 'trumpet'],
#  ['throat',
#   'still',
#   'really',
#   'sore',
#   'meant',
#   'going',
#   'day',
#   'camp',
#   'friday',
#   'sure'],
#  ['know', 'exactly', 'feel'],
#  ['work'],
#  ['well', 'bed', 'time', 'sighs', 'back', 'mornings', 'week', 'wednesday'],
#  ['jesus', 'camp', 'yeah'],
#  ['oh',
#   'everything',
#   'happened',
#   'today',
#   'forgot',
#   'going',
#   'dress',
#   'shopping',
#   'opera',
#   'tomorrow'],
#  ['turtles', 'better', 'mac', 'lasts', 'longer', 'moves', 'faster'],
#  ['soaked', 'pleasant'],
#  ['sorry', 'hear', 'maggie', 'thoughts', 'mum'],
#  ['may', 'email', 'one', 'hope', 'feel', 'better'],
#  ['dead', 'yu', 'gettin', 'wen', 'im', 'leavin'],
#  ['please', 'tell', 'somewhere', 'close', 'california', 'lol'],
#  [],
#  ['stupid', 'arranged', 'marriages', 'convert', 'marry', 'love'],
#  ['well', 'said', 'looser', 'show', 'implies'],
#  ['poor',
#   'sandra',
#   'cantu',
#   'cantu',
#   'family',
#   'prayers',
#   'go',
#   'sick',
#   'world',
#   'live'],
#  ['fuck', 'omg', 'austins', 'always', 'though', 'man', 'love'],
#  ['cried', 'hard', 'matthew', 'died'],
#  ['sad', 'feet', 'macbook', 'fell', 'sad', 'feet', 'macbook', 'fell'],
#  ['last', 'find', 'things', 'like', 'twitter'],
#  ['absolutely'],
#  ['filled', 'curry', 'true', 'indian', 'coming'],
#  ['im', 'soooo', 'cold', 'right'],
#  ['lol',
#   'kant',
#   'believe',
#   'cam',
#   'got',
#   'beat',
#   'upp',
#   'sooo',
#   'embarasssiiiin'],
#  ['good',
#   'knight',
#   'hun',
#   'looking',
#   'forward',
#   'ur',
#   'tweets',
#   'hate',
#   'keep',
#   'missing',
#   'fun',
#   'cuz',
#   'time',
#   'difference'],
#  ['tumblr', 'exactly', 'feels', 'wearing', 'tie'],
#  ['hahaa',
#   'realized',
#   'impune',
#   'definitely',
#   'isnt',
#   'word',
#   'wanted',
#   'dang',
#   'unclever'],
#  ['watching', 'old', 'videos', 'dance', 'team', 'makes', 'miss'],
#  ['wahh',
#   'csi',
#   'anywhere',
#   'dvr',
#   'ed',
#   'love',
#   'money',
#   'though',
#   'gon',
#   'na',
#   'watch',
#   'sleep',
#   'goodnight',
#   'tweeters'],
#  ['struggling', 'hard', 'inventory'],
#  ['hate', 'us', 'please'],
#  ['haha', 'im', 'ballin', 'still', 'got', 'bills', 'paaaaay'],
#  ['one', 'days', 'really', 'want', 'work', 'home', 'crap'],
#  ['wait', 'game', 'episodes', 'confused'],
#  ['haha', 'cried', 'guess'],
#  ['get', 'statistics', 'bunch', 'mumbo', 'jumbo'],
#  ['got', 'sadly', 'works', 'uk', 'us', 'moment'],
#  ['evicted'],
#  ['enjoy', 'learning', 'css'],
#  ['brian', 'make', 'fuck', 'lol', 'replied', 'ur', 'message', 'get', 'miss'],
#  ['dvr',
#   'went',
#   'watch',
#   'apparently',
#   'dish',
#   'network',
#   'went',
#   'missed',
#   'catch',
#   'rerun'],
#  ['lmao',
#   'may',
#   'wait',
#   'another',
#   'season',
#   'come',
#   'thru',
#   'summe',
#   'boo',
#   'hot',
#   'nd',
#   'dry',
#   'ass',
#   'weather'],
#  ['set', 'feet', 'ground', 'missing', 'eyelid', 'people', 'might', 'get'],
#  ['english', 'professor', 'would', 'ashamed'],
#  ['wish', 'frogs', 'becoming', 'extinct'],
#  ['came', 'home', 'cross', 'county', 'tired'],
#  ['want', 'walk', 'home', 'snow', 'wants', 'pick'],
#  ['lauren',
#   'stubborn',
#   'loves',
#   'love',
#   'feel',
#   'bad',
#   'though',
#   'made',
#   'cry',
#   'lol'],
#  ['grouchy', 'wants', 'bmar'],
#  ['heart',
#   'broken',
#   'every',
#   'morning',
#   'dropping',
#   'foo',
#   'pre',
#   'school',
#   'understand',
#   'moms',
#   'say',
#   'heart',
#   'broken'],
#  ['feeling', 'well', 'back', 'hurts'],
#  ['im', 'mood', 'chocolate', 'want', 'miniature', 'reeses', 'cups'],
#  ['take', 'heat', 'like', 'oven', 'feel', 'sick', 'nwo'],
#  ['come', 'chat', 'minutes', 'please'],
#  ['boredd', 'colddd', 'internet', 'keeps', 'stuffing'],
#  ['horrible',
#   'nightmare',
#   'last',
#   'night',
#   'affected',
#   'sleep',
#   'really',
#   'tired'],
#  ['im', 'lonely', 'keep', 'company', 'female', 'new', 'york'],
#  ['lost', 'st', 'ignacius', 'prepatory', 'school', 'haha'],
#  ['yeah', 'really', 'depressing', 'stuff', 'like', 'gets'],
#  ['problem', 'tongue', 'cheek', 'remark', 'lots', 'acronyms', 'nz'],
#  ['hey',
#   'said',
#   'matt',
#   'gon',
#   'na',
#   'go',
#   'ballistic',
#   'disappointed',
#   'good',
#   'ep',
#   'tho',
#   'mostly'],
#  ['ugh', 'horrible', 'ending', 'sandra', 'kantu', 'story', 'prayers', 'go'],
#  ['hate',
#   'allergic',
#   'want',
#   'puppy',
#   'soo',
#   'bad',
#   'already',
#   'thought',
#   'cool',
#   'names'],
#  ['morning',
#   'folks',
#   'yawn',
#   'away',
#   'see',
#   'horses',
#   'hope',
#   'twitter',
#   'better',
#   'behaved',
#   'today',
#   'last',
#   'night',
#   'travesty'],
#  ['miss', 'mine'],
#  ['sorry', 'hear', 'loss', 'many', 'year', 'far'],
#  ['gossip', 'girl', 'repeat'],
#  ['reckon'],
#  ['finding', 'really', 'hard', 'use', 'twitter'],
#  ['stuck', 'house', 'two', 'days'],
#  ['really', 'sad', 'really', 'know'],
#  [],
#  ['maybe', 'one', 'years', 'get', 'tax', 'return', 'girl', 'dream', 'right'],
#  ['back', 'work', 'tired', 'hell', 'feel', 'cold', 'coming'],
#  ['april', 'th', 'coming', 'soon', 'enough'],
#  ['cream',
#   'eye',
#   'may',
#   'herpes',
#   'ocular',
#   'herpes',
#   'different',
#   'strain',
#   'okay',
#   'though'],
#  ['got',
#   'ta',
#   'repeat',
#   'whole',
#   'art',
#   'folio',
#   'cuz',
#   'old',
#   'one',
#   'whole',
#   'terms',
#   'work',
#   'got',
#   'wet'],
#  ['ready', 'weekend', 'already', 'monday'],
#  ['umm',
#   'nope',
#   'think',
#   'im',
#   'insomniac',
#   'plus',
#   'got',
#   'flu',
#   'lll',
#   'sleepin',
#   'like',
#   'phuckin',
#   'fish',
#   'outta',
#   'water',
#   'minute'],
#  ['finland', 'sleeping', 'night', 'really', 'enough', 'time'],
#  ['wait', 'try', 'em', 'prolly', 'wait', 'next', 'weekend', 'earliest'],
#  ['shiner', 'taking', 'bed', 'blankets'],
#  ['april', 'th', 'coming', 'soon', 'enough'],
#  ['wants', 'cry'],
#  ['need', 'go', 'bank', 'tomorrow', 'go', 'broke'],
#  ['earthquake',
#   'italy',
#   'sadden',
#   'three',
#   'hours',
#   'away',
#   'naples',
#   'family'],
#  ['sleeping', 'stressed', 'week', 'coming'],
#  ['yea', 'working', 'tp', 'hack', 'server', 'player', 'thing', 'folks'],
#  ['hurt', 'ankle', 'going', 'dr'],
#  ['oh',
#   'noes',
#   'manage',
#   'send',
#   'something',
#   'trash',
#   'empty',
#   'without',
#   'noticing',
#   'feel',
#   'ya'],
#  ['lost',
#   'free',
#   'copy',
#   'radioactive',
#   'put',
#   'ipod',
#   'grr',
#   'go',
#   'buy',
#   'nother',
#   'coz',
#   'came',
#   'paper'],
#  ['make', 'shit'],
#  ['photoshop', 'hate', 'crash'],
#  ['vacations', 'makes', 'feel', 'sick'],
#  ['gone'],
#  ['listening',
#   'murd',
#   'th',
#   'wonder',
#   'chillen',
#   'missing',
#   'crazy',
#   'sex',
#   'life'],
#  ['shooting', 'careful', 'luisa'],
#  ['sure',
#   'everyone',
#   'ruined',
#   'gift',
#   'whitney',
#   'serious',
#   'cell',
#   'easter',
#   'well'],
#  ['beso', 'hollywood', 'tired'],
#  ['want', 'wake', 'early', 'tomorrow', 'damn', 'work'],
#  ['finished', 'watching', 'movie', 'prayers', 'bobby', 'broke', 'heart'],
#  ['myki', 'really', 'horrible'],
#  ['put', 'dog', 'today', 'someone', 'ran'],
#  ['sorry',
#   'hear',
#   'dnf',
#   'run',
#   'tonight',
#   'always',
#   'risk',
#   'get',
#   'bad',
#   'coords',
#   'ftf'],
#  ['get',
#   'disgruntled',
#   'people',
#   'wrote',
#   'esn',
#   'hits',
#   'one',
#   'day',
#   'made',
#   'bill',
#   'pulls',
#   'tops'],
#  ['ohh', 'omg', 'lmao', 'crying', 'right', 'lol', 'kutnerrrr', 'best'],
#  ['came',
#   'back',
#   'running',
#   'took',
#   'shower',
#   'lower',
#   'stomach',
#   'still',
#   'hurt',
#   'exercising'],
#  ['watching', 'fallon', 'mom', 'working', 'project', 'school', 'hard'],
#  ['min',
#   'till',
#   'home',
#   'time',
#   'counting',
#   'craving',
#   'visit',
#   'mac',
#   'store',
#   'closed',
#   'time',
#   'get'],
#  ['sorry', 'hear', 'take', 'care'],
#  ['hmmm',
#   'greed',
#   'good',
#   'motivates',
#   'individual',
#   'better',
#   'much',
#   'takes',
#   'away',
#   'others'],
#  ['brat', 'rub', 'want', 'mocha'],
#  ['kutnerrrr',
#   'think',
#   'still',
#   'show',
#   'ugh',
#   'kutner',
#   'kal',
#   'penn',
#   'bright',
#   'star',
#   'ho'],
#  ['mom', 'wish', 'best', 'luck'],
#  ['hate', 'homeworks', 'head', 'hurts', 'bad'],
#  ['got',
#   'ebay',
#   'blues',
#   'item',
#   'want',
#   'jumped',
#   'bidders',
#   'hour',
#   'still',
#   'hours',
#   'go',
#   'better',
#   'get',
#   'hopes'],
#  ['know',
#   'little',
#   'depressed',
#   'ate',
#   'much',
#   'last',
#   'night',
#   'leftovers',
#   'today'],
#  ['well',
#   'pc',
#   'living',
#   'room',
#   'suffered',
#   'fatal',
#   'partion',
#   'lost',
#   'itunes',
#   'library',
#   'gone',
#   'docs',
#   'pics'],
#  ['sad', 'day', 'manu', 'season'],
#  ['poor', 'spunky', 'sad', 'rotti', 'made', 'go', 'path', 'know', 'feel'],
# ...
#  ['back',
#   'work',
#   'get',
#   'spend',
#   'next',
#   'hours',
#   'alone',
#   'dispatch',
#   'room'],
#  ['new',
#   'kind',
#   'starburst',
#   'favereds',
#   'sounds',
#   'fab',
#   'bc',
#   'cherry',
#   'strawberry',
#   'fav',
#   'red',
#   'added',
#   'watermellon',
#   'yucky'],
#  ['well', 'much', 'productive', 'days', 'angels'],
#  ['oh', 'gee', 'insomnia', 'sucks', 'tried', 'melatonin'],
#  ['good', 'hear', 'support', 'netbeans', 'netbeans', 'know'],
#  ['wish',
#   'would',
#   'get',
#   'time',
#   'rest',
#   'world',
#   'unfornately',
#   'cairo',
#   'wait',
#   'mtva',
#   'play'],
#  ['heartbroken', 'little', 'sandra', 'prayers', 'family'],
#  ['words', 'finish', 'tomorrow', 'maybe'],
#  ['come', 'ur', 'background', 'covers', 'screen', 'mine', 'corner'],
#  ['wrote', 'exactly', 'three', 'lines', 'dialogue', 'tonight', 'gave'],
#  ['complaint', 'facebook', 'changed', 'much', 'confusing'],
#  ['sliced', 'finger'],
#  ['going', 'thru', 'town', 'traffic', 'bypass', 'stink'],
#  ['ugh', 'sleep', 'wish', 'good', 'cuddle', 'make', 'ass'],
#  ['hate',
#   'software',
#   'update',
#   'downloads',
#   'updates',
#   'without',
#   'telling',
#   'never',
#   'know',
#   'downloading'],
#  ['went',
#   'ihop',
#   'great',
#   'diet',
#   'least',
#   'kung',
#   'foo',
#   'pancakes',
#   'time',
#   'rachel'],
#  ['internet', 'hating', 'night', 'pose'],
#  ['jealous', 'missed', 'opening', 'day', 'year'],
#  ['cruel',
#   'wait',
#   'reviews',
#   'come',
#   'far',
#   'looks',
#   'like',
#   'star',
#   'trek',
#   'best',
#   'film',
#   'year'],
#  ['debating', 'shower', 'sleep', 'little', 'later', 'tomorrow'],
#  ['stress', 'always', 'culminates', 'physical', 'pain'],
#  ['need', 'sleep', 'cant'],
#  ['little', 'pinky', 'finger', 'hurts', 'much'],
#  ['sorry', 'gift', 'card', 'ran', 'suck'],
#  ['home', 'spring', 'break', 'one', 'home', 'tho'],
#  ['accessed',
#   'oneindia',
#   'mobi',
#   'google',
#   'phone',
#   'android',
#   'support',
#   'indic',
#   'languages'],
#  ['school',
#   'take',
#   'life',
#   'much',
#   'get',
#   'sleep',
#   'anymore',
#   'still',
#   'school',
#   'work',
#   'well'],
#  ['aw', 'wish', 'could', 'really', 'speak', 'yia', 'yia', 'speak', 'english'],
#  ['free', 'comp', 'lol'],
#  ['getting', 'ready', 'clean', 'house', 'top', 'bottom'],
#  ['crying', 'friend', 'moving', 'away', 'tomorrow'],
#  ['stop', 'nomnoms', 'share', 'night', 'peoples'],
#  ['thinks',
#   'getting',
#   'cold',
#   'caught',
#   'daddy',
#   'oh',
#   'trip',
#   'would',
#   'ruined'],
#  ['yeah',
#   'bcoz',
#   'kal',
#   'penn',
#   'visiting',
#   'lecturer',
#   'somewhere',
#   'cant',
#   'show',
#   'anymore',
#   'im',
#   'gon',
#   'na',
#   'miss'],
#  ['procrastination',
#   'starts',
#   'early',
#   'quarter',
#   'want',
#   'reaaaaad',
#   'write',
#   'paper'],
#  ['apparently',
#   'degress',
#   'pm',
#   'washington',
#   'state',
#   'miss',
#   'winter',
#   'already'],
#  ['bored', 'homee'],
#  ['massage',
#   'great',
#   'spilled',
#   'coke',
#   'desk',
#   'lame',
#   'watching',
#   'simpsons',
#   'finished',
#   'hills',
#   'dvds'],
#  ['wait', 'fanclub', 'chat', 'even', 'tough', 'favorite'],
#  ['mild',
#   'left',
#   'inner',
#   'ear',
#   'infection',
#   'got',
#   'irritating',
#   'blocked',
#   'feeling',
#   'since',
#   'sunday'],
#  ['hey', 'nope', 'cuteness', 'away', 'awhile'],
#  ['tuesday'],
#  ['haha', 'even', 'yo', 'know', 'twitter', 'haha'],
#  ['someones',
#   'alarm',
#   'clock',
#   'phone',
#   'woke',
#   'still',
#   'got',
#   'headache',
#   'yesterday',
#   'night'],
#  ['puppy', 'ok'],
#  ['might', 'break', 'eat', 'buffalo', 'wings', 'tomorrow'],
#  ['sittin',
#   'kayla',
#   'really',
#   'really',
#   'reallly',
#   'dis',
#   'like',
#   'brother',
#   'know',
#   'stop',
#   'waiting',
#   'day',
#   'one'],
#  ['fed', 'bokkie', 'many', 'birthday', 'treats', 'sicko'],
#  ['kinda',
#   'bummed',
#   'agency',
#   'told',
#   'look',
#   'going',
#   'ladies',
#   'please',
#   'help',
#   'create',
#   'look'],
#  ['work', 'laptop', 'officially', 'dead', 'happy'],
#  ['goodness', 'freezing'],
#  ['put', 'listen', 'mom'],
#  ['stucked', 'paris', 'even', 'travel', 'france', 'work'],
#  ['think',
#   'one',
#   'close',
#   'last',
#   'time',
#   'checked',
#   'closest',
#   'one',
#   'miles',
#   'away'],
#  ['aaaaand',
#   'back',
#   'literature',
#   'review',
#   'least',
#   'friendly',
#   'cup',
#   'coffee',
#   'keep',
#   'company'],
#  ['worried',
#   'get',
#   'even',
#   'though',
#   'paid',
#   'buttload',
#   'tax',
#   'last',
#   'year'],
#  ['okay', 'still', 'school'],
#  ['phoneless', 'sleep'],
#  ['reeked',
#   'alcohol',
#   'dentist',
#   'morning',
#   'drunk',
#   'put',
#   'tshirt',
#   'realised',
#   'huge',
#   'stain',
#   'dentist',
#   'looked',
#   'disgusted'],
#  ['really', 'cold'],
#  ['cant', 'sleep', 'wants', 'dream'],
#  ['sleep',
#   'hate',
#   'nights',
#   'try',
#   'go',
#   'bed',
#   'early',
#   'stay',
#   'awake',
#   'hours',
#   'poo'],
#  ['yeah',
#   'bad',
#   'people',
#   'like',
#   'certain',
#   'burrito',
#   'eating',
#   'man',
#   'exist'],
#  ['sad'],
#  ['found',
#   'mum',
#   'adopted',
#   'auntie',
#   'twitter',
#   'check',
#   'mum',
#   'tessm',
#   'awesome',
#   'auntie',
#   'tania'],
#  ['sleep',
#   'wide',
#   'awake',
#   'got',
#   'ta',
#   'go',
#   'work',
#   'later',
#   'boy',
#   'going',
#   'crappy',
#   'day'],
#  ['struggling', 'eam', 'law'],
#  ['sleep', 'like'],
#  ['bouts',
#   'start',
#   'poor',
#   'linny',
#   'could',
#   'keep',
#   'eyes',
#   'open',
#   'tired',
#   'work',
#   'tomorrow',
#   'morning',
#   'night'],
#  ['year', 'old', 'year', 'old', 'driving', 'around', 'twist', 'want', 'like'],
#  ['well', 'sucked'],
#  ['place',
#   'days',
#   'help',
#   'get',
#   'packing',
#   'painting',
#   'cleaning',
#   'much',
#   'appreciated',
#   'oh',
#   'rip',
#   'wall'],
#  ['opening',
#   'partially',
#   'frozen',
#   'beer',
#   'beer',
#   'toaster',
#   'oven',
#   'counter',
#   'kitchen',
#   'smells',
#   'like',
#   'run',
#   'speakeasy'],
#  ['dont', 'even', 'know', 'ride'],
#  ['sadly', 'yes', 'think', 'need', 'counciling'],
#  ['making', 'ready', 'school', 'feel', 'like', 'going', 'two', 'tests'],
#  ['smugness',
#   'gone',
#   'train',
#   'also',
#   'failed',
#   'turn',
#   'heading',
#   'victoria',
#   'followed',
#   'unpleasant',
#   'tube',
#   'ride',
#   'city'],
#  ['anybody', 'know', 'ipod', 'went'],
#  ['aww',
#   'earthquake',
#   'italy',
#   'made',
#   'sad',
#   'saw',
#   'pics',
#   'news',
#   'terrible'],
#  ['never',
#   'able',
#   'afford',
#   'get',
#   'much',
#   'rather',
#   'go',
#   'extraction',
#   'continue',
#   'deal'],
#  ['pet',
#   'care',
#   'people',
#   'try',
#   'run',
#   'others',
#   'business',
#   'send',
#   'suspicious',
#   'mails',
#   'fishing',
#   'info'],
#  ['codez', 'mia', 'tho'],
#  ['doesnt', 'work', 'cell', 'go', 'sleep'],
#  ['going',
#   'nice',
#   'tomorrow',
#   'rain',
#   'comes',
#   'back',
#   'nice',
#   'weather',
#   'birthday'],
#  ['rock', 'band', 'hard', 'expert'],
#  ['roomie',
#   'home',
#   'day',
#   'scratch',
#   'door',
#   'comforter',
#   'goto',
#   'large',
#   'laundromat',
#   'machines'],
#  ['one',
#   'hardest',
#   'thing',
#   'schedule',
#   'one',
#   'chat',
#   'end',
#   'day',
#   'usually'],
#  ['killed', 'character', 'one', 'favorite', 'shows', 'upset'],
#  ['jealous',
#   'friends',
#   'got',
#   'see',
#   'new',
#   'star',
#   'trek',
#   'film',
#   'austin',
#   'tonight'],
#  ['listening',
#   'got',
#   'really',
#   'bad',
#   'headache',
#   'drivin',
#   'lesson',
#   'ten',
#   'mins',
#   'lucky',
#   'wana',
#   'sleeep'],
#  ['shut',
#   'hungry',
#   'britain',
#   'home',
#   'boring',
#   'suckassy',
#   'breakfast',
#   'world',
#   'miss',
#   'dennys'],
#  ['good',
#   'morning',
#   'everybody',
#   'pkoi',
#   'fais',
#   'pas',
#   'beau',
#   'bon',
#   'coffee',
#   'time'],
#  ['work'],
#  ['essay', 'time'],
#  ['hey',
#   'talk',
#   'mom',
#   'home',
#   'yet',
#   'hope',
#   'ok',
#   'wish',
#   'coming',
#   'home',
#   'easter'],
#  ['sure',
#   'wish',
#   'could',
#   'go',
#   'guys',
#   'tmrw',
#   'per',
#   'usual',
#   'school',
#   'interferes'],
#  ['say',
#   'kal',
#   'penn',
#   'leaving',
#   'house',
#   'noooooo',
#   'totally',
#   'missed',
#   'tonight'],
#  ['lost', 'loyal'],
#  ['played', 'another', 'hand', 'bad', 'lost', 'half', 'stack'],
#  ['pm', 'early', 'days', 'looooooong', 'night', 'work'],
#  ['sad', 'last', 'season', 'wan', 'na', 'see', 'spencer', 'calls', 'lauren'],
#  ['im',
#   'done',
#   'editing',
#   'phipstape',
#   'back',
#   'crack',
#   'brew',
#   'see',
#   'got',
#   'trees',
#   'though'],
#  ['know', 'half', 'means'],
#  ['homework', 'homework', 'homework'],
#  ['worked',
#   'heart',
#   'today',
#   'doubling',
#   'weight',
#   'station',
#   'result',
#   'stiff',
#   'pulled',
#   'muscles',
#   'ouch'],
#  ['feel', 'bad', 'unfollowing'],
#  ['tired', 'god', 'hate', 'new', 'job', 'two', 'days'],
#  ['sad', 'kutner', 'killed', 'fav', 'show', 'house'],
#  ['happy', 'coach', 'stringer', 'hof', 'finish', 'term', 'paper'],
#  ['feel', 'like', 'shit', 'way', 'want', 'spend', 'birthday', 'eve'],
#  ['far', 'sites', 'put', 'together', 'checking', 'updates', 'made'],
#  ['lot', 'mind', 'needs', 'make', 'moneys', 'ideas', 'nowhere', 'hiring'],
#  ['miss'],
#  ['sorry', 'hear', 'dog'],
#  ['much', 'internet', 'plagues'],
#  ['miss', 'ex', 'soo', 'much'],
#  ['sodding'],
#  ['oh',
#   'thought',
#   'pirate',
#   'bay',
#   'trial',
#   'verdict',
#   'today',
#   'apparently',
#   'days'],
#  ['call', 'back'],
#  ['study', 'hall', 'log', 'immediately'],
#  ['tired',
#   'im',
#   'crying',
#   'reason',
#   'im',
#   'try',
#   'get',
#   'hour',
#   'half',
#   'tonight',
#   'half',
#   'got',
#   'last',
#   'night'],
#  ['totally', 'like', 'four', 'girl', 'options', 'none', 'seem', 'viable'],
#  ['far', 'veiws', 'sites', 'put', 'together', 'checking', 'updates', 'made'],
#  ['listening', 'bjork', 'full', 'love', 'crying'],
#  ['omg',
#   'hills',
#   'love',
#   'money',
#   'aww',
#   'think',
#   'becky',
#   'buckwild',
#   'goes'],
#  ['craving', 'tantan', 'nabe'],
#  ['mon', 'sean', 'man'],
#  ['watching',
#   'league',
#   'makes',
#   'miss',
#   'mint',
#   'chocolate',
#   'ice',
#   'cream',
#   'cones',
#   'grand',
#   'fuck'],
#  ['lost', 'phone', 'maybe', 'grass', 'long', 'hope', 'rain'],
#  ['hope', 'referring', 'say', 'hello', 'new', 'stalker', 'lol'],
#  ['sleeping', 'ur', 'gon', 'na', 'night', 'ur', 'bike', 'ride'],
#  ['wan', 'na', 'listen', 'masters'],
#  ['looking', 'good', 'stuff', 'write', 'also', 'loads', 'uni', 'work'],
#  ['feel', 'unloved', 'dropped', 'tweeters'],
#  ['london',
#   'day',
#   'thursday',
#   'gon',
#   'na',
#   'raining',
#   'oh',
#   'fab',
#   'see',
#   'much',
#   'london',
#   'eye',
#   'still',
#   'robbie',
#   'care',
#   'bless'],
#  ['completely',
#   'wiped',
#   'reloaded',
#   'lost',
#   'bbm',
#   'contacts',
#   'going',
#   'bed',
#   'sad'],
#  ['sayyyy', 'whaaaa', 'invited'],
#  ['sleep',
#   'bad',
#   'considering',
#   'workshop',
#   'starting',
#   'today',
#   'beginnings',
#   'sore',
#   'throat',
#   'though'],
#  ['oh',
#   'gosh',
#   'made',
#   'emotional',
#   'haha',
#   'idk',
#   'dont',
#   'want',
#   'get',
#   'old'],
#  ['going',
#   'post',
#   'stories',
#   'manually',
#   'due',
#   'twitterfeed',
#   'problem',
#   'quiet',
#   'lately'],
#  ['like', 'lukewarm', 'showers'],
#  ['contact',
#   'need',
#   'freelance',
#   'work',
#   'linux',
#   'com',
#   'throughout',
#   'never',
#   'got',
#   'one'],
#  ['connor', 'febi', 'really', 'really', 'mad'],
#  ['need',
#   'help',
#   'want',
#   'buy',
#   'macbook',
#   'pro',
#   'still',
#   'inlove',
#   'old',
#   'powerbook'],
#  ['man',
#   'america',
#   'borez',
#   'anyway',
#   'lol',
#   'realized',
#   'sent',
#   'msgs',
#   'idea',
#   'flash'],
#  ['knight', 'lovely', 'ladies', 'sleepy'],
#  ['anybody',
#   'know',
#   'get',
#   'electrolytes',
#   'back',
#   'order',
#   'vitamin',
#   'work',
#   'feel',
#   'sick'],
#  ['yes', 'someone', 'reading', 'posts', 'properly'],
#  ['almost', 'italian', 'homework', 'weeeeee', 'understood'],
#  ['turned', 'lights', 'time', 'get', 'ip'],
#  ['twitter', 'hates', 'us'],
#  ['hate', 'fact', 'genuinely', 'excited', 'last', 'tweet'],
#  ['sleep', 'either'],
#  ['italy', 'earthquake', 'sad', 'news', 'day'],
#  ['rain', 'today', 'garden', 'really', 'needs', 'quite', 'bad'],
#  ['yawn', 'yawn', 'yawn', 'minutes', 'bed'],
#  ['ouch', 'sounds', 'sucky'],
#  ['great',
#   'idea',
#   'itunes',
#   'promo',
#   'codes',
#   'work',
#   'uk',
#   'itunes',
#   'store',
#   'though'],
#  ['cry'],
#  ['empty',
#   'rum',
#   'barrel',
#   'sad',
#   'rum',
#   'barrel',
#   'shakes',
#   'head',
#   'horror',
#   'horror'],
#  ['sleepless', 'night'],
#  ['admitted', 'fake'],
#  ['love', 'chutney'],
#  ['got', 'highly', 'bored', 'today', 'scanning', 'pages', 'daddy'],
#  ['cooked', 'risotto', 'without'],
#  ['keeeerrrrriiiiii',
#   'really',
#   'nothing',
#   'better',
#   'post',
#   'thing',
#   'wonderfullll',
#   'says',
#   'alot'],
#  ['yay', 'baseball', 'season', 'boo', 'yankees', 'losing', 'first', 'game'],
#  ['lost', 'sucks', 'work', 'today'],
#  ['omg',
#   'exams',
#   'killed',
#   'could',
#   'know',
#   'difference',
#   'haif',
#   'circle',
#   'hemisphere'],
#  ['bed', 'suddenly', 'feel', 'wish', 'goodnight', 'twitterfam'],
#  ['like', 'goodnights'],
#  ['greaaat', 'lappy', 'turn', 'wtffffff'],
#  ['stuck', 'traffic', 'journey', 'traffic', 'free', 'morning', 'help'],
#  ['lookin', 'like', 'nighter', 'hate'],
#  ['stranger'],
#  ['debbugging', 'old', 'vb', 'code', 'day', 'could', 'started', 'better'],
#  ['quarter', 'percent', 'babe', 'darn'],
#  ['coming', 'cold', 'bad', 'allergies', 'either', 'way', 'miserable'],
#  ['believe', 'cutner', 'dead', 'house', 'sad', 'day', 'santa', 'rosa', 'ca'],
#  ['damnit', 'really', 'digging', 'season', 'reaper'],
#  ['gah',
#   'comcast',
#   'doubled',
#   'cable',
#   'internet',
#   'bill',
#   'telling',
#   'us',
#   'quitting',
#   'anyone',
#   'suggest',
#   'affordable',
#   'company',
#   'bay',
#   'area'],
#  ['another',
#   'early',
#   'morn',
#   'duchess',
#   'although',
#   'managed',
#   'cross',
#   'legs',
#   'time'],
#  ['left', 'without', 'saying', 'hi'],
#  ['want', 'sleep'],
#  ['xbox',
#   'shows',
#   'three',
#   'red',
#   'lights',
#   'means',
#   'dead',
#   'needs',
#   'fixed',
#   'month',
#   'microsoft',
#   'hq'],
#  ['king',
#   'sized',
#   'bed',
#   'nice',
#   'sad',
#   'lonely',
#   'hubby',
#   'puppy',
#   'kitty',
#   'whole',
#   'conferenceing',
#   'thing'],
#  ['im',
#   'boredd',
#   'gah',
#   'wish',
#   'could',
#   'sleep',
#   'get',
#   'ive',
#   'toooo',
#   'muchh',
#   'cooooffffeeeeeeeee',
#   'bahaha'],
#  ['may', 'butt', 'done', 'nosey', 'sorry', 'conversation', 'interesting'],
#  ['fell', 'list', 'offend'],
#  ['weeks',
#   'till',
#   'sisters',
#   'home',
#   'missed',
#   'call',
#   'worst',
#   'feeling',
#   'world'],
#  ['gon', 'na', 'try', 'get', 'sleep', 'hotel', 'room'],
#  ['brilliant',
#   'idea',
#   'bring',
#   'much',
#   'think',
#   'spend',
#   'swap',
#   'bring',
#   'brolly'],
#  ['get',
#   'autograph',
#   'shout',
#   'record',
#   'though',
#   'computer',
#   'dead',
#   'listen'],
#  ['rt', 'khloe', 'got', 'fired', 'apprentice'],
#  ['biology', 'class', 'lip', 'hurts'],
#  ['sorry', 'next', 'tweet'],
#  ['grr', 'go', 'school', 'today'],
#  ['get', 'hd', 'tivo', 'got', 'set', 'tonight', 'order', 'get', 'channels'],
#  ['asked', 'everyone', 'yesterday', 'single', 'tweet', 'back'],
#  ['ruddy',
#   'money',
#   'like',
#   'still',
#   'waiting',
#   'oh',
#   'surprise',
#   'state',
#   'hmmm',
#   'seriously'],
#  ['sad', 'kutner', 'favorite', 'new', 'team'],
#  ['wow', 'get', 'hello', 'suck'],
#  ['bedtime', 'school', 'tomorrow', 'still', 'books', 'broke', 'suckssss'],
#  ['seating',
#   'helping',
#   'baby',
#   'papers',
#   'well',
#   'forcing',
#   'seat',
#   'im',
#   'sleepy'],
#  ['synching', 'contacts', 'old', 'mobile', 'iphone', 'import', 'work', 'well'],
#  ['concentrate'],
#  ['spent',
#   'hour',
#   'enter',
#   'bureaucratic',
#   'nonsense',
#   'march',
#   'waste',
#   'time'],
#  ['nw', 'confused', 'ever'],
#  ['feeling',
#   'well',
#   'stupid',
#   'migraine',
#   'making',
#   'tummy',
#   'upset',
#   'whole',
#   'body',
#   'aches',
#   'shoot'],
#  ['reading',
#   'buyology',
#   'bedtime',
#   'great',
#   'premise',
#   'turning',
#   'ok',
#   'book',
#   'lots',
#   'info',
#   'already',
#   'knew'],
#  ['home',
#   'really',
#   'wana',
#   'sleep',
#   'due',
#   'wasting',
#   'free',
#   'line',
#   'town',
#   'assignment',
#   'finish'],
#  ['also',
#   'send',
#   'updates',
#   'plurk',
#   'upload',
#   'photos',
#   'twitter',
#   'didnt',
#   'see',
#   'updates',
#   'plurk',
#   'zero'],
#  ['omg', 'reader', 'making'],
#  ['oh',
#   'least',
#   'getting',
#   'decent',
#   'exchange',
#   'rate',
#   'moment',
#   'sterling',
#   'still',
#   'getting',
#   'flogged'],
#  ['tried', 'download', 'tweetdeck', 'wont', 'download'],
#  ['inch', 'snow', 'ground', 'counting', 'worried', 'poor', 'flowers'],
#  ['happy', 'camper'],
#  ['thanks', 'man', 'grateful', 'feel', 'unworthy', 'attention', 'though'],
#  ['miss',
#   'totally',
#   'comin',
#   'back',
#   'tho',
#   'lastnight',
#   'sooooooo',
#   'much',
#   'fun'],
#  ['ohhh', 'love', 'ps', 'sad', 'get', 'hang'],
#  ['somehow', 'still', 'end', 'place'],
#  ['oh', 'sad', 'poor', 'boy'],
#  ...]

# %% [markdown]
# ## Lemmatization

# %%
#lemmatization

from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer() #create an object of WordNetLemmatizer class
data1 = [ ]
for l in word_tokens:
    b = [lemmatizer.lemmatize(q) for q in l]
    data1.append(b)

# %%
#print data1
data1
# Out:
# [['awww',
#   'that',
#   'bummer',
#   'you',
#   'shoulda',
#   'got',
#   'david',
#   'carr',
#   'of',
#   'third',
#   'day',
#   'to',
#   'do',
#   'it'],
#  ['is',
#   'upset',
#   'that',
#   'he',
#   'can',
#   'not',
#   'update',
#   'his',
#   'facebook',
#   'by',
#   'texting',
#   'it',
#   'and',
#   'might',
#   'cry',
#   'a',
#   'result',
#   'school',
#   'today',
#   'also',
#   'blah'],
#  ['dived',
#   'many',
#   'time',
#   'for',
#   'the',
#   'ball',
#   'managed',
#   'to',
#   'save',
#   'the',
#   'rest',
#   'go',
#   'out',
#   'of',
#   'bound'],
#  ['my', 'whole', 'body', 'feel', 'itchy', 'and', 'like', 'it', 'on', 'fire'],
#  ['no',
#   'it',
#   'not',
#   'behaving',
#   'at',
#   'all',
#   'mad',
#   'why',
#   'am',
#   'here',
#   'because',
#   'can',
#   'not',
#   'see',
#   'you',
#   'all',
#   'over',
#   'there'],
#  ['not', 'the', 'whole', 'crew'],
#  ['need', 'hug'],
#  ['hey',
#   'long',
#   'time',
#   'no',
#   'see',
#   'yes',
#   'rain',
#   'bit',
#   'only',
#   'bit',
#   'lol',
#   'fine',
#   'thanks',
#   'how',
#   'you'],
#  ['nope', 'they', 'did', 'not', 'have', 'it'],
#  ['que', 'me', 'muera'],
#  ['spring', 'break', 'in', 'plain', 'city', 'it', 'snowing'],
#  ['just', 're', 'pierced', 'my', 'ear'],
#  ['could',
#   'not',
#   'bear',
#   'to',
#   'watch',
#   'it',
#   'and',
#   'thought',
#   'the',
#   'ua',
#   'loss',
#   'wa',
#   'embarrassing'],
#  ['it',
#   'it',
#   'count',
#   'idk',
#   'why',
#   'did',
#   'either',
#   'you',
#   'never',
#   'talk',
#   'to',
#   'me',
#   'anymore'],
#  ['would',
#   've',
#   'been',
#   'the',
#   'first',
#   'but',
#   'did',
#   'not',
#   'have',
#   'gun',
#   'not',
#   'really',
#   'though',
#   'zac',
#   'snyder',
#   'just',
#   'doucheclown'],
#  ['wish',
#   'got',
#   'to',
#   'watch',
#   'it',
#   'with',
#   'you',
#   'miss',
#   'you',
#   'and',
#   'how',
#   'wa',
#   'the',
#   'premiere'],
#  ['hollis',
#   'death',
#   'scene',
#   'will',
#   'hurt',
#   'me',
#   'severely',
#   'to',
#   'watch',
#   'on',
#   'film',
#   'wry',
#   'is',
#   'director',
#   'cut',
#   'not',
#   'out',
#   'now'],
#  ['about', 'to', 'file', 'tax'],
#  ['ahh',
#   'ive',
#   'always',
#   'wanted',
#   'to',
#   'see',
#   'rent',
#   'love',
#   'the',
#   'soundtrack'],
#  ['oh',
#   'dear',
#   'were',
#   'you',
#   'drinking',
#   'out',
#   'of',
#   'the',
#   'forgotten',
#   'table',
#   'drink'],
#  ['wa',
#   'out',
#   'most',
#   'of',
#   'the',
#   'day',
#   'so',
#   'did',
#   'not',
#   'get',
#   'much',
#   'done'],
#  ['one',
#   'of',
#   'my',
#   'friend',
#   'called',
#   'me',
#   'and',
#   'asked',
#   'to',
#   'meet',
#   'with',
#   'her',
#   'at',
#   'mid',
#   'valley',
#   'today',
#   'but',
#   've',
#   'no',
#   'time',
#   'sigh'],
#  ['baked', 'you', 'cake', 'but', 'ated', 'it'],
#  ['this', 'week', 'is', 'not', 'going', 'a', 'had', 'hoped'],
#  ['blagh', 'class', 'at', 'tomorrow'],
#  ['hate', 'when', 'have', 'to', 'call', 'and', 'wake', 'people', 'up'],
#  ['just',
#   'going',
#   'to',
#   'cry',
#   'myself',
#   'to',
#   'sleep',
#   'after',
#   'watching',
#   'marley',
#   'and',
#   'me'],
#  ['im', 'sad', 'now', 'miss', 'lilly'],
#  ['ooooh',
#   'lol',
#   'that',
#   'leslie',
#   'and',
#   'ok',
#   'will',
#   'not',
#   'do',
#   'it',
#   'again',
#   'so',
#   'leslie',
#   'will',
#   'not',
#   'get',
#   'mad',
#   'again'],
#  ['meh',
#   'almost',
#   'lover',
#   'is',
#   'the',
#   'exception',
#   'this',
#   'track',
#   'get',
#   'me',
#   'depressed',
#   'every',
#   'time'],
#  ['some',
#   'hacked',
#   'my',
#   'account',
#   'on',
#   'aim',
#   'now',
#   'have',
#   'to',
#   'make',
#   'new',
#   'one'],
#  ['want',
#   'to',
#   'go',
#   'to',
#   'promote',
#   'gear',
#   'and',
#   'groove',
#   'but',
#   'unfornately',
#   'no',
#   'ride',
#   'there',
#   'may',
#   'going',
#   'to',
#   'the',
#   'one',
#   'in',
#   'anaheim',
#   'in',
#   'may',
#   'though'],
#  ['thought',
#   'sleeping',
#   'in',
#   'wa',
#   'an',
#   'option',
#   'tomorrow',
#   'but',
#   'realizing',
#   'that',
#   'it',
#   'now',
#   'is',
#   'not',
#   'evaluation',
#   'in',
#   'the',
#   'morning',
#   'and',
#   'work',
#   'in',
#   'the',
#   'afternoon'],
#  ['awe', 'love', 'you', 'too', 'am', 'here', 'miss', 'you'],
#  ['cry', 'my', 'asian', 'eye', 'to', 'sleep', 'at', 'night'],
#  ['ok',
#   'sick',
#   'and',
#   'spent',
#   'an',
#   'hour',
#   'sitting',
#   'in',
#   'the',
#   'shower',
#   'cause',
#   'wa',
#   'too',
#   'sick',
#   'to',
#   'stand',
#   'and',
#   'held',
#   'back',
#   'the',
#   'puke',
#   'like',
#   'champ',
#   'bed',
#   'now'],
#  ['ill',
#   'tell',
#   'ya',
#   'the',
#   'story',
#   'later',
#   'not',
#   'good',
#   'day',
#   'and',
#   'ill',
#   'be',
#   'workin',
#   'for',
#   'like',
#   'three',
#   'more',
#   'hour'],
#  ['sorry', 'bed', 'time', 'came', 'here', 'gmt'],
#  ['do',
#   'not',
#   'either',
#   'it',
#   'depressing',
#   'do',
#   'not',
#   'think',
#   'even',
#   'want',
#   'to',
#   'know',
#   'about',
#   'the',
#   'kid',
#   'in',
#   'suitcase'],
#  ['bed',
#   'class',
#   'work',
#   'gym',
#   'or',
#   'then',
#   'class',
#   'another',
#   'day',
#   'that',
#   'gon',
#   'na',
#   'fly',
#   'by',
#   'miss',
#   'my',
#   'girlfriend'],
#  ['really',
#   'do',
#   'not',
#   'feel',
#   'like',
#   'getting',
#   'up',
#   'today',
#   'but',
#   'got',
#   'to',
#   'study',
#   'to',
#   'for',
#   'tomorrow',
#   'practical',
#   'exam'],
#  ['he',
#   'the',
#   'reason',
#   'for',
#   'the',
#   'teardrop',
#   'on',
#   'my',
#   'guitar',
#   'the',
#   'only',
#   'one',
#   'who',
#   'ha',
#   'enough',
#   'of',
#   'me',
#   'to',
#   'break',
#   'my',
#   'heart'],
#  ['sad',
#   'sad',
#   'sad',
#   'do',
#   'not',
#   'know',
#   'why',
#   'but',
#   'hate',
#   'this',
#   'feeling',
#   'wan',
#   'na',
#   'sleep',
#   'and',
#   'still',
#   'can',
#   'not'],
#  ['soo',
#   'wish',
#   'wa',
#   'there',
#   'to',
#   'see',
#   'you',
#   'finally',
#   'comfortable',
#   'im',
#   'sad',
#   'that',
#   'missed',
#   'it'],
#  ['falling',
#   'asleep',
#   'just',
#   'heard',
#   'about',
#   'that',
#   'tracy',
#   'girl',
#   'body',
#   'being',
#   'found',
#   'how',
#   'sad',
#   'my',
#   'heart',
#   'break',
#   'for',
#   'that',
#   'family'],
#  ['yay',
#   'happy',
#   'for',
#   'you',
#   'with',
#   'your',
#   'job',
#   'but',
#   'that',
#   'also',
#   'mean',
#   'le',
#   'time',
#   'for',
#   'me',
#   'and',
#   'you'],
#  ['just',
#   'checked',
#   'my',
#   'user',
#   'timeline',
#   'on',
#   'my',
#   'blackberry',
#   'it',
#   'look',
#   'like',
#   'the',
#   'twanking',
#   'is',
#   'still',
#   'happening',
#   'are',
#   'ppl',
#   'still',
#   'having',
#   'probs',
#   'bgs',
#   'and',
#   'uids'],
#  ['oh',
#   'man',
#   'wa',
#   'ironing',
#   'fave',
#   'top',
#   'to',
#   'wear',
#   'to',
#   'meeting',
#   'burnt',
#   'it'],
#  ['is', 'strangely', 'sad', 'about', 'lilo', 'and', 'samro', 'breaking', 'up'],
#  ['oh',
#   'so',
#   'sorry',
#   'did',
#   'not',
#   'think',
#   'about',
#   'that',
#   'before',
#   'retweeting'],
#  ['broadband',
#   'plan',
#   'massive',
#   'broken',
#   'promise',
#   'via',
#   'still',
#   'waiting',
#   'for',
#   'broadband',
#   'we',
#   'are'],
#  ['wow',
#   'ton',
#   'of',
#   'reply',
#   'from',
#   'you',
#   'may',
#   'have',
#   'to',
#   'unfollow',
#   'so',
#   'can',
#   'see',
#   'my',
#   'friend',
#   'tweet',
#   'you',
#   're',
#   'scrolling',
#   'the',
#   'feed',
#   'lot'],
#  ['our',
#   'duck',
#   'and',
#   'chicken',
#   'are',
#   'taking',
#   'wayyy',
#   'too',
#   'long',
#   'to',
#   'hatch'],
#  ['put',
#   'vacation',
#   'photo',
#   'online',
#   'few',
#   'yr',
#   'ago',
#   'pc',
#   'crashed',
#   'and',
#   'now',
#   'forget',
#   'the',
#   'name',
#   'of',
#   'the',
#   'site'],
#  ['need', 'hug'],
#  ['not',
#   'sure',
#   'what',
#   'they',
#   'are',
#   'only',
#   'that',
#   'they',
#   'are',
#   'po',
#   'a',
#   'much',
#   'a',
#   'want',
#   'to',
#   'dont',
#   'think',
#   'can',
#   'trade',
#   'away',
#   'company',
#   'asset',
#   'sorry',
#   'andy'],
#  ['hate', 'when', 'that', 'happens'],
#  ['have',
#   'sad',
#   'feeling',
#   'that',
#   'dallas',
#   'is',
#   'not',
#   'going',
#   'to',
#   'show',
#   'up',
#   'got',
#   'ta',
#   'say',
#   'though',
#   'you',
#   'think',
#   'more',
#   'show',
#   'would',
#   'use',
#   'music',
#   'from',
#   'the',
#   'game',
#   'mmm'],
#  ['ugh', 'degree', 'tomorrow'],
#  ['where',
#   'did',
#   'move',
#   'to',
#   'thought',
#   'were',
#   'already',
#   'in',
#   'sd',
#   'hmmm',
#   'random',
#   'found',
#   'me',
#   'glad',
#   'to',
#   'hear',
#   'yer',
#   'doing',
#   'well'],
#  ['miss',
#   'my',
#   'p',
#   'it',
#   'out',
#   'of',
#   'commission',
#   'wutcha',
#   'playing',
#   'have',
#   'you',
#   'copped',
#   'blood',
#   'on',
#   'the',
#   'sand'],
#  ['just', 'leaving', 'the', 'parking', 'lot', 'of', 'work'],
#  ['the', 'life', 'is', 'cool', 'but', 'not', 'for', 'me'],
#  ['sadly',
#   'though',
#   've',
#   'never',
#   'gotten',
#   'to',
#   'experience',
#   'the',
#   'post',
#   'coitus',
#   'cigarette',
#   'before',
#   'and',
#   'now',
#   'never',
#   'will'],
#  ['had',
#   'such',
#   'nice',
#   'day',
#   'too',
#   'bad',
#   'the',
#   'rain',
#   'come',
#   'in',
#   'tomorrow',
#   'at',
#   'am'],
#  ['too',
#   'bad',
#   'will',
#   'not',
#   'be',
#   'around',
#   'lost',
#   'my',
#   'job',
#   'and',
#   'can',
#   'not',
#   'even',
#   'pay',
#   'my',
#   'phone',
#   'bill',
#   'lmao',
#   'aw',
#   'shuck'],
#  ['damm', 'back', 'to', 'school', 'tomorrow'],
#  ['mo',
#   'job',
#   'no',
#   'money',
#   'how',
#   'in',
#   'the',
#   'hell',
#   'is',
#   'min',
#   'wage',
#   'here',
#   'clam',
#   'an',
#   'hour'],
#  ['not', 'forever', 'see', 'you', 'soon'],
#  ['agreed', 'saw', 'the', 'failwhale', 'allllll', 'day', 'today'],
#  ['oh',
#   'haha',
#   'dude',
#   'dont',
#   'really',
#   'look',
#   'at',
#   'em',
#   'unless',
#   'someone',
#   'say',
#   'hey',
#   'added',
#   'you',
#   'sorry',
#   'so',
#   'terrible',
#   'at',
#   'that',
#   'need',
#   'pop',
#   'up'],
#  ['sure',
#   'you',
#   're',
#   'right',
#   'need',
#   'to',
#   'start',
#   'working',
#   'out',
#   'with',
#   'you',
#   'and',
#   'the',
#   'nikster',
#   'or',
#   'jared',
#   'at',
#   'least'],
#  ['really',
#   'hate',
#   'how',
#   'people',
#   'dis',
#   'my',
#   'band',
#   'trace',
#   'is',
#   'clearly',
#   'not',
#   'ugly'],
#  ['gym',
#   'attire',
#   'today',
#   'wa',
#   'puma',
#   'singlet',
#   'adidas',
#   'short',
#   'and',
#   'black',
#   'business',
#   'sock',
#   'and',
#   'leather',
#   'shoe',
#   'lucky',
#   'did',
#   'not',
#   'run',
#   'into',
#   'any',
#   'cute',
#   'girl'],
#  ['why', 'will', 'not', 'you', 'show', 'my', 'location'],
#  ['no', 'picnic', 'my', 'phone', 'smell', 'like', 'citrus'],
#  ['my',
#   'donkey',
#   'is',
#   'sensitive',
#   'about',
#   'such',
#   'comment',
#   'nevertheless',
#   'he',
#   'and',
#   'me',
#   'be',
#   'glad',
#   'to',
#   'see',
#   'your',
#   'mug',
#   'asap',
#   'charger',
#   'is',
#   'still',
#   'awol'],
#  ['no', 'new', 'csi', 'tonight', 'fml'],
#  ['think', 'my', 'arm', 'are', 'sore', 'from', 'tennis'],
#  ['wonder',
#   'why',
#   'someone',
#   'that',
#   'like',
#   'so',
#   'much',
#   'can',
#   'make',
#   'you',
#   'so',
#   'unhappy',
#   'in',
#   'split',
#   'seccond',
#   'depressed'],
#  ['sleep',
#   'soon',
#   'just',
#   'hate',
#   'saying',
#   'bye',
#   'and',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'the',
#   'night'],
#  ['just',
#   'got',
#   'ur',
#   'newsletter',
#   'those',
#   'fare',
#   'really',
#   'are',
#   'unbelievable',
#   'shame',
#   'already',
#   'booked',
#   'and',
#   'paid',
#   'for',
#   'mine'],
#  ['missin', 'the', 'boo'],
#  ['me', 'too', 'itm'],
#  ['damn',
#   'do',
#   'not',
#   'have',
#   'any',
#   'chalk',
#   'my',
#   'chalkboard',
#   'is',
#   'useless'],
#  ['had',
#   'blast',
#   'at',
#   'the',
#   'getty',
#   'villa',
#   'but',
#   'hate',
#   'that',
#   'she',
#   'had',
#   'sore',
#   'throat',
#   'all',
#   'day',
#   'it',
#   'just',
#   'getting',
#   'worse',
#   'too'],
#  ['hey', 'missed', 'ya', 'at', 'the', 'meeting', 'sup', 'mama'],
#  ['my',
#   'tummy',
#   'hurt',
#   'wonder',
#   'if',
#   'the',
#   'hypnosis',
#   'ha',
#   'anything',
#   'to',
#   'do',
#   'with',
#   'it',
#   'if',
#   'so',
#   'it',
#   'working',
#   'get',
#   'it',
#   'stop',
#   'smoking'],
#  ['why', 'is', 'it', 'always', 'the', 'fat', 'one'],
#  ['sorry',
#   'babe',
#   'my',
#   'fam',
#   'annoys',
#   'me',
#   'too',
#   'thankfully',
#   'they',
#   're',
#   'asleep',
#   'right',
#   'now',
#   'muahaha',
#   'evil',
#   'laugh'],
#  ['should',
#   'have',
#   'paid',
#   'more',
#   'attention',
#   'when',
#   'we',
#   'covered',
#   'photoshop',
#   'in',
#   'my',
#   'webpage',
#   'design',
#   'class',
#   'in',
#   'undergrad'],
#  ['wednesday', 'my', 'day', 'do', 'not', 'know', 'what', 'do'],
#  ['poor', 'cameron', 'the', 'hill'],
#  ['pray',
#   'for',
#   'me',
#   'please',
#   'the',
#   'ex',
#   'is',
#   'threatening',
#   'to',
#   'start',
#   'sh',
#   'at',
#   'my',
#   'our',
#   'baby',
#   'st',
#   'birthday',
#   'party',
#   'what',
#   'jerk',
#   'and',
#   'still',
#   'have',
#   'headache'],
#  ['hmm',
#   'do',
#   'really',
#   'enjoy',
#   'being',
#   'with',
#   'him',
#   'if',
#   'the',
#   'problem',
#   'are',
#   'too',
#   'constant',
#   'should',
#   'think',
#   'thing',
#   'more',
#   'find',
#   'someone',
#   'ulike'],
#  ['strider', 'is', 'sick', 'little', 'puppy'],
#  ['so',
#   'rylee',
#   'grace',
#   'wana',
#   'go',
#   'steve',
#   'party',
#   'or',
#   'not',
#   'sadly',
#   'since',
#   'it',
#   'easter',
#   'wnt',
#   'able',
#   'do',
#   'much',
#   'but',
#   'ohh',
#   'well'],
#  ['hey',
#   'actually',
#   'won',
#   'one',
#   'of',
#   'my',
#   'bracket',
#   'pool',
#   'too',
#   'bad',
#   'it',
#   'wa',
#   'not',
#   'the',
#   'one',
#   'for',
#   'money'],
#  ['you', 'do', 'not', 'follow', 'me', 'either', 'and', 'work', 'for', 'you'],
#  ['bad',
#   'nite',
#   'for',
#   'the',
#   'favorite',
#   'team',
#   'astros',
#   'and',
#   'spartan',
#   'lose',
#   'the',
#   'nite',
#   'out',
#   'with',
#   'wa',
#   'good'],
#  ['body',
#   'of',
#   'missing',
#   'northern',
#   'calif',
#   'girl',
#   'found',
#   'police',
#   'have',
#   'found',
#   'the',
#   'remains',
#   'of',
#   'missing',
#   'northern',
#   'california',
#   'girl'],
#  ['hope',
#   'they',
#   'will',
#   'increase',
#   'the',
#   'capacity',
#   'fast',
#   'yesterday',
#   'wa',
#   'such',
#   'pain',
#   'got',
#   'the',
#   'fail',
#   'whale',
#   'time',
#   'in',
#   'hour'],
#  ['behind', 'on', 'my', 'class', 'for', 'work'],
#  ['watching', 'house'],
#  ['remember',
#   'my',
#   'bum',
#   'leg',
#   'strike',
#   'back',
#   'this',
#   'time',
#   'it',
#   'serious'],
#  ['cool',
#   'will',
#   'their',
#   'are',
#   'all',
#   'kind',
#   'of',
#   'complaint',
#   'about',
#   'this',
#   'laptop',
#   'online',
#   'about',
#   'overheating',
#   'but',
#   'no',
#   'recall'],
#  ['emily',
#   'will',
#   'be',
#   'glad',
#   'when',
#   'mommy',
#   'is',
#   'done',
#   'training',
#   'at',
#   'her',
#   'new',
#   'job',
#   'she',
#   'miss',
#   'her'],
#  ['would',
#   'rather',
#   'the',
#   'first',
#   'party',
#   'send',
#   'bad',
#   'message',
#   'than',
#   'the',
#   'rd',
#   'party',
#   'send',
#   'mixed',
#   'one',
#   'sophmore',
#   'year',
#   'all',
#   'over',
#   'again'],
#  ['it', 'overrated'],
#  ['know',
#   'heard',
#   'it',
#   'this',
#   'afternoon',
#   'and',
#   'wondered',
#   'the',
#   'same',
#   'thing',
#   'moscow',
#   'is',
#   'so',
#   'behind',
#   'the',
#   'time'],
#  ['laying', 'in', 'bed', 'with', 'no', 'voice'],
#  ['sooo',
#   'sad',
#   'they',
#   'killed',
#   'off',
#   'kutner',
#   'on',
#   'house',
#   'whyyyyyyyy'],
#  ['sorry',
#   'tell',
#   'them',
#   'mea',
#   'culpa',
#   'from',
#   'me',
#   'and',
#   'that',
#   'really',
#   'am',
#   'sorry'],
#  ['it',
#   'did',
#   'not',
#   'make',
#   'any',
#   'sense',
#   'to',
#   'me',
#   'the',
#   'suicide',
#   'thing',
#   'refuse',
#   'to',
#   'believe',
#   'that',
#   'that',
#   'is',
#   'actually',
#   'what',
#   'happened'],
#  ['hope', 'your', 'ok'],
#  ['damn',
#   'the',
#   'grind',
#   'is',
#   'inspirational',
#   'and',
#   'saddening',
#   'at',
#   'the',
#   'same',
#   'time',
#   'do',
#   'not',
#   'want',
#   'you',
#   'to',
#   'stop',
#   'cuz',
#   'like',
#   'what',
#   'do',
#   'much',
#   'love'],
#  ['yeah', 'aw', 'but', 'know', 'wudnt', 'stand', 'chance'],
#  ['ugh', 'cant', 'sleep', 'it', 'am'],
#  ['hanging', 'in', 'crooner', 'wan', 'na', 'sing', 'can', 'not', 'suck'],
#  ['aaw',
#   'miss',
#   'ya',
#   'all',
#   'too',
#   'im',
#   'leaving',
#   'to',
#   'bh',
#   'tomorrow',
#   'morning',
#   'think',
#   'aww',
#   'wan',
#   'na',
#   'go',
#   'to',
#   'the',
#   'beach',
#   'girl'],
#  ['is',
#   'pissed',
#   'off',
#   'that',
#   'there',
#   'no',
#   'asba',
#   'for',
#   'radio',
#   'station'],
#  ['wednesday', 'my', 'day', 'do', 'not', 'know', 'what', 'do'],
#  ['know',
#   'my',
#   'life',
#   'ha',
#   'been',
#   'flipped',
#   'upside',
#   'down',
#   'when',
#   'just',
#   'thought',
#   'in',
#   'my',
#   'head',
#   'that',
#   'some',
#   'ramen',
#   'sound',
#   'good'],
#  ['am',
#   'in',
#   'pain',
#   'my',
#   'back',
#   'and',
#   'side',
#   'hurt',
#   'not',
#   'to',
#   'mention',
#   'cry',
#   'is',
#   'made',
#   'of',
#   'fail'],
#  ['late',
#   'night',
#   'snack',
#   'glass',
#   'of',
#   'oj',
#   'down',
#   'with',
#   'the',
#   'sickness',
#   'then',
#   'back',
#   'to',
#   'sleep',
#   'ugh',
#   'hate',
#   'getting',
#   'sick'],
#  ['but', 'but', 'but', 'not', 'big', 'fan', 'on', 'camilla', 'belle'],
#  ['wah',
#   'can',
#   'not',
#   'see',
#   'clip',
#   'must',
#   'be',
#   'el',
#   'stupido',
#   'work',
#   'filter',
#   'can',
#   'not',
#   'wait',
#   'till',
#   'get',
#   'puter',
#   'something',
#   'else',
#   'blame',
#   'ex',
#   'he',
#   'broke',
#   'mine'],
#  ['this',
#   'week',
#   'just',
#   'seems',
#   'to',
#   'get',
#   'longer',
#   'and',
#   'longer',
#   'in',
#   'term',
#   'of',
#   'how',
#   'much',
#   'need',
#   'to',
#   'do',
#   'and',
#   'how',
#   'much',
#   'actually',
#   'going',
#   'to',
#   'get',
#   'done'],
#  ['so', 'cold'],
#  ['ehhh',
#   'do',
#   'not',
#   'weather',
#   'gon',
#   'na',
#   'take',
#   'turn',
#   'for',
#   'the',
#   'ugly',
#   'tomorrow'],
#  ['haha',
#   'it',
#   'so',
#   'cooooold',
#   'in',
#   'the',
#   'and',
#   'no',
#   'but',
#   'you',
#   'should',
#   'still',
#   'go',
#   'to',
#   'the',
#   'show',
#   'they',
#   'do',
#   'some',
#   'incredible',
#   'stuff'],
#  ['hoping', 'the', 'tummy', 'rumble', 'go', 'away', 'soon'],
#  ['no',
#   'no',
#   'notice',
#   'they',
#   'told',
#   'me',
#   'be',
#   'working',
#   'tomorrow',
#   'and',
#   'then',
#   'called',
#   'the',
#   'agency',
#   'to',
#   'follow',
#   'up',
#   'and',
#   'they',
#   'said',
#   'it',
#   'wa',
#   'over'],
#  ['almost', 'bedtime'],
#  ['missing',
#   'you',
#   'babe',
#   'but',
#   'a',
#   'long',
#   'a',
#   'your',
#   'alive',
#   'happy',
#   'ya',
#   'tired',
#   'my',
#   'love',
#   'imma',
#   'try',
#   'to',
#   'sleep',
#   'hopefully',
#   'you',
#   'had',
#   'headstart'],
#  ['agh', 'snow'],
#  ['miss', 'kenny', 'power'],
#  ['thank',
#   'you',
#   'for',
#   'letting',
#   'people',
#   'know',
#   'but',
#   'now',
#   'sad',
#   'that',
#   'the',
#   'direct',
#   'message',
#   'got',
#   'wa',
#   'not',
#   'actually',
#   'from',
#   'bridget'],
#  ['and',
#   'india',
#   'missed',
#   'out',
#   'it',
#   'th',
#   'test',
#   'victory',
#   'th',
#   'consecutive',
#   'win',
#   'without',
#   'loss'],
#  ['guess', 'that', 'no', 'then'],
#  ['sadly', 'is', 'going', 'to', 'bed'],
#  ['shame', 'to', 'hear', 'this', 'stephan'],
#  ['hey', 'leavin', 'in', 'the', 'morning'],
#  ['wa',
#   'intending',
#   'to',
#   'finish',
#   'editing',
#   'my',
#   'page',
#   'novel',
#   'manuscript',
#   'tonight',
#   'but',
#   'that',
#   'will',
#   'probably',
#   'not',
#   'happen',
#   'and',
#   'only',
#   'page',
#   'are',
#   'left'],
#  ['laid', 'around', 'too', 'much', 'today', 'now', 'my', 'head', 'hurt'],
#  ['still',
#   'have',
#   'not',
#   'read',
#   'the',
#   'th',
#   'th',
#   'princess',
#   'diary',
#   'saving',
#   'francesca',
#   'made',
#   'me',
#   'cry',
#   'at',
#   'the',
#   'end',
#   'hmm',
#   'those',
#   'are',
#   'easy',
#   'book'],
#  ['my', 'nokia', 'died'],
#  ['my',
#   'mom',
#   'might',
#   'have',
#   'breast',
#   'cancer',
#   'will',
#   'not',
#   'find',
#   'out',
#   'anything',
#   'for',
#   'like',
#   'week',
#   'so',
#   'worried'],
#  ['going', 'to', 'sleep', 'hoping', 'tomorrow', 'is', 'better', 'day'],
#  ['lol',
#   'wish',
#   'they',
#   'understood',
#   'daylight',
#   'saving',
#   'ha',
#   'ended',
#   'though',
#   'and',
#   'breakfast',
#   'is',
#   'an',
#   'hour',
#   'later',
#   'they',
#   'keep',
#   'waking',
#   'the',
#   'kid',
#   'up',
#   'too'],
#  ['that', 'is', 'lame'],
#  ['do', 'not', 'understand', 'really', 'do', 'not'],
#  ['hero', 'just', 'is', 'not', 'doing', 'it', 'for', 'me', 'this', 'season'],
#  ['living', 'not', 'downtown', 'sure', 'is', 'not', 'much', 'fun'],
#  ['not',
#   'calorie',
#   'wise',
#   'wish',
#   'junk',
#   'food',
#   'wa',
#   'calorie',
#   'free',
#   'ate',
#   'thing',
#   'of',
#   'sour',
#   'skittle',
#   'and',
#   'big',
#   'as',
#   'cherry',
#   'coke'],
#  ['man', 'work', 'is', 'hard'],
#  ['getting',
#   'sick',
#   'time',
#   'for',
#   'some',
#   'hot',
#   'tea',
#   'studying',
#   'and',
#   'then',
#   'sleeeep'],
#  ['getting', 'eyebrow', 'waxed', 'more', 'pain'],
#  ['no', 'phantasy', 'star', 'yesterday', 'going', 'to', 'work'],
#  ['oh',
#   'just',
#   'got',
#   'all',
#   'my',
#   'macheist',
#   'apps',
#   'sweet',
#   'did',
#   'not',
#   'get',
#   'the',
#   'espresso',
#   'serial',
#   'no',
#   'though',
#   'although',
#   'they',
#   'said',
#   'they',
#   'sent',
#   'it',
#   'oh',
#   'well'],
#  ['picked',
#   'mich',
#   'st',
#   'to',
#   'win',
#   'it',
#   'all',
#   'from',
#   'the',
#   'get',
#   'go',
#   'wa',
#   'feeling',
#   'pretty',
#   'good',
#   'about',
#   'that',
#   'pick',
#   'all',
#   'the',
#   'way',
#   'up',
#   'until',
#   'tonight',
#   'lost',
#   'too'],
#  ['is', 'alone', 'downstairs', 'working'],
#  ['feel', 'bad', 'for', 'doing', 'it'],
#  ['is',
#   'it',
#   'just',
#   'me',
#   'or',
#   'she',
#   'hate',
#   'anoop',
#   'mean',
#   'seriously',
#   'she',
#   'kinda',
#   'mean',
#   'to',
#   'him'],
#  ['yes',
#   'sprint',
#   'ha',
#   'only',
#   'in',
#   'baltimore',
#   'and',
#   'chicago',
#   'so',
#   'far'],
#  ['stuck',
#   'awake',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'night',
#   'for',
#   'the',
#   'second',
#   'day',
#   'in',
#   'row',
#   'and',
#   'felt',
#   'terrible',
#   'yesterday'],
#  ['thanks', 'for', 'bursting', 'my', 'bubble'],
#  ['going',
#   'to',
#   'school',
#   'soon',
#   'can',
#   'not',
#   'find',
#   'anything',
#   'to',
#   'wear',
#   'gosh',
#   'it',
#   'so',
#   'hard'],
#  ['wa', 'serious', 'lol'],
#  ['had',
#   'on',
#   'my',
#   'page',
#   'for',
#   'sooooo',
#   'long',
#   'until',
#   'it',
#   'got',
#   'deleted',
#   'sad',
#   'day',
#   'in',
#   'history'],
#  ['crazy', 'wind', 'today', 'no', 'birding'],
#  ['currently', 'at', 'work'],
#  ['grrr',
#   'my',
#   'ipod',
#   'acting',
#   'weird',
#   'too',
#   'jai',
#   'ho',
#   'and',
#   'thinking',
#   'of',
#   'you',
#   'are',
#   'not',
#   'playing',
#   'the',
#   'full',
#   'song',
#   'ughh'],
#  ['send',
#   'me',
#   'the',
#   'dvd',
#   'co',
#   'have',
#   'missed',
#   'out',
#   'on',
#   'heap',
#   'not',
#   'happy',
#   'about',
#   'that'],
#  ['do', 'not', 'see', 'the', 'big', 'deal', 'with', 'this', 'website'],
#  ['so',
#   'sorry',
#   'you',
#   're',
#   'having',
#   'to',
#   'go',
#   'through',
#   'this',
#   'again',
#   'therapyfail'],
#  ['far',
#   'too',
#   'out',
#   'of',
#   'the',
#   'way',
#   'for',
#   'rail',
#   'any',
#   'other',
#   'tip'],
#  ['not',
#   'still',
#   'up',
#   'swear',
#   'why',
#   'do',
#   'keep',
#   'losing',
#   'gaining',
#   'losing',
#   'gaining',
#   'tweeps',
#   'so',
#   'heart',
#   'wrenching'],
#  ['today',
#   'realized',
#   'am',
#   'too',
#   'good',
#   'at',
#   'hiding',
#   'thing',
#   'even',
#   'can',
#   'not',
#   'find',
#   'it'],
#  ['staying',
#   'at',
#   'friend',
#   'house',
#   'house',
#   'sitting',
#   'neighbor',
#   'are',
#   'so',
#   'loud',
#   'having',
#   'party'],
#  ['danny',
#   'im',
#   'upset',
#   'that',
#   'wasnt',
#   'here',
#   'to',
#   'watch',
#   'the',
#   'live',
#   'chat',
#   'wa',
#   'in',
#   'car',
#   'for',
#   'hour',
#   'on',
#   'trip',
#   'im',
#   'soooo',
#   'upset'],
#  ['check', 'out', 'my', 'mug'],
#  ['border', 'closed', 'at'],
#  ['downloading',
#   'nin',
#   'new',
#   'album',
#   'the',
#   'slip',
#   'when',
#   'the',
#   'hell',
#   'did',
#   'this',
#   'come',
#   'out',
#   'so',
#   'behind',
#   'the',
#   'time',
#   'these',
#   'day'],
#  ['just',
#   'woke',
#   'up',
#   'an',
#   'already',
#   'have',
#   'written',
#   'some',
#   'mail',
#   've',
#   'to',
#   'go',
#   'early',
#   'at',
#   'university',
#   'today',
#   'a',
#   'have',
#   'to',
#   'teach',
#   'at',
#   'am'],
#  ['is', 'watching', 'the', 'hill', 'and', 'it', 'making', 'me', 'sad'],
#  ['so',
#   'many',
#   'channel',
#   'yet',
#   'so',
#   'so',
#   'boring',
#   'lazy',
#   'day',
#   'again',
#   'may',
#   'have',
#   'to',
#   'find',
#   'hobby'],
#  ['miss', 'my', 'buddy', 'ill', 'be', 'in', 'ny', 'on', 'the', 'th'],
#  ['love',
#   'the',
#   'french',
#   'tell',
#   'people',
#   'here',
#   'in',
#   'the',
#   'south',
#   'qtr',
#   'french',
#   'and',
#   'they',
#   'snarl',
#   'at',
#   'me',
#   'french',
#   'are',
#   'beautiful',
#   'people'],
#  ['opps',
#   'a',
#   'said',
#   'still',
#   'got',
#   'one',
#   'day',
#   'remain',
#   'and',
#   'now',
#   'problem',
#   'come'],
#  ['activated',
#   'my',
#   'selfcontrol',
#   'block',
#   'early',
#   'meaning',
#   'can',
#   'not',
#   'check',
#   'out',
#   'the',
#   'new',
#   'qc',
#   'regularizing',
#   'my',
#   'internal',
#   'clock',
#   'is',
#   'might',
#   'be',
#   'difficult',
#   'fb'],
#  ['oh', 'no'],
#  ['spencer', 'is', 'not', 'good', 'guy'],
#  ['what',
#   'about',
#   'reese',
#   'dying',
#   'on',
#   'ttsc',
#   'and',
#   'season',
#   'finale',
#   'next',
#   'week',
#   'boring',
#   'madame',
#   'president',
#   'is',
#   'crazy',
#   'woman'],
#  ['hate',
#   'the',
#   'limited',
#   'letter',
#   'too',
#   'hope',
#   'you',
#   'and',
#   'the',
#   'guy',
#   'are',
#   'fine',
#   'pray',
#   'for',
#   'my',
#   'dog',
#   'she',
#   'not',
#   'well'],
#  ['did', 'not', 'get', 'shit', 'done', 'today', 'so', 'screwed'],
#  ['wanttss', 'to', 'go', 'out'],
#  ['is', 'not', 'going', 'to', 'sleep', 'tonite'],
#  ['too', 'worried', 'and', 'tired', 'to', 'post', 'tonight'],
#  ['could', 'not', 'get', 'shit', 'done', 'today', 'so', 'screwed'],
#  ['job',
#   'interview',
#   'in',
#   'cardiff',
#   'today',
#   'wish',
#   'me',
#   'luck',
#   'got',
#   'about',
#   'hour',
#   'sleep'],
#  ['your',
#   'show',
#   'is',
#   'whack',
#   'way',
#   'worse',
#   'than',
#   'whack',
#   'it',
#   'wiggety',
#   'whack'],
#  ['really',
#   'do',
#   'not',
#   'think',
#   'people',
#   'choose',
#   'to',
#   'be',
#   'that',
#   'way',
#   'but',
#   'think',
#   'he',
#   'chose',
#   'not',
#   'to',
#   'accept',
#   'my',
#   'family',
#   'help',
#   'he',
#   'might',
#   'be',
#   'dead',
#   'by',
#   'now'],
#  ['you',
#   're',
#   'going',
#   'to',
#   'kill',
#   'me',
#   'but',
#   've',
#   'not',
#   'seen',
#   'd',
#   've',
#   'been',
#   'waiting',
#   'till',
#   'can',
#   'do',
#   'it',
#   'in',
#   'one',
#   'solid',
#   'week',
#   'sitting'],
#  ['think', 'ur', 'right', 'hahaha', 'hr', 'now'],
#  ['hate', 'to', 'see', 'the', 'spartan', 'so', 'sad'],
#  ['my',
#   'mind',
#   'and',
#   'body',
#   'are',
#   'severely',
#   'protesting',
#   'this',
#   'getting',
#   'up',
#   'thing',
#   'had',
#   'nightmare',
#   'to',
#   'boot'],
#  ['goin', 'to', 'follow', 'since', 'did', 'not', 'lol', 'go', 'angel'],
#  [],
#  ['think',
#   'want',
#   'to',
#   'read',
#   'some',
#   'book',
#   'but',
#   'the',
#   'library',
#   'doe',
#   'not',
#   'have',
#   'them'],
#  ['my',
#   'nap',
#   'wa',
#   'interrupted',
#   'so',
#   'many',
#   'time',
#   'today',
#   'going',
#   'out',
#   'for',
#   'japanese',
#   'with',
#   'the',
#   'rent',
#   'again'],
#  ['kind',
#   'of',
#   'longs',
#   'for',
#   'the',
#   'bus',
#   'that',
#   'show',
#   'up',
#   'at',
#   'the',
#   'end',
#   'of',
#   'ghost',
#   'world',
#   'right',
#   'now',
#   'ugh'],
#  ['but',
#   'this',
#   'is',
#   'canada',
#   'canada',
#   'is',
#   'weird',
#   'we',
#   're',
#   'supposed',
#   'to',
#   'get',
#   'snow',
#   'through',
#   'wednesday',
#   'ugh'],
#  ['awwh',
#   'babs',
#   'you',
#   'look',
#   'so',
#   'sad',
#   'underneith',
#   'that',
#   'shop',
#   'entrance',
#   'of',
#   'yesterday',
#   'musik',
#   'like',
#   'the',
#   'look',
#   'of',
#   'the',
#   'new',
#   'transformer',
#   'movie'],
#  ['sad', 'that', 'the', 'foot', 'of', 'my', 'macbook', 'just', 'fell', 'off'],
#  ['gon',
#   'na',
#   'get',
#   'up',
#   'late',
#   'tomorrow',
#   'and',
#   'it',
#   'am',
#   'here',
#   'gon',
#   'na',
#   'get',
#   'tipsy',
#   'by',
#   'my',
#   'lonesome',
#   'that',
#   'that',
#   'just',
#   'sad'],
#  ['sweating',
#   'my',
#   'forthcoming',
#   'trip',
#   'to',
#   'if',
#   'can',
#   'not',
#   'find',
#   'someone',
#   'to',
#   'crash',
#   'with',
#   'while',
#   'out',
#   'there',
#   'may',
#   'be',
#   'screwed'],
#  ['ha',
#   'now',
#   'gotten',
#   'somebody',
#   'to',
#   'read',
#   'his',
#   'tweet',
#   'but',
#   'cant',
#   'get',
#   'them',
#   'to',
#   'make',
#   'an',
#   'account'],
#  ['omgawd',
#   'couldnt',
#   'handle',
#   'my',
#   'cat',
#   'being',
#   'in',
#   'heat',
#   'all',
#   'the',
#   'time'],
#  ['hope',
#   'can',
#   'make',
#   'it',
#   'to',
#   'the',
#   'auburn',
#   'show',
#   'but',
#   'it',
#   'not',
#   'looking',
#   'good',
#   'for',
#   'me'],
#  ['thats',
#   'people',
#   'mag',
#   'haha',
#   'couldnt',
#   'fit',
#   'it',
#   'all',
#   'in',
#   'dont',
#   'think',
#   'those',
#   'picture',
#   'ever',
#   'made',
#   'it',
#   'in',
#   'the',
#   'magazine',
#   'tho',
#   'haha'],
#  ['congrats', 'totally', 'forgot', 'to', 'submit', 'photo'],
#  ['awww',
#   'good',
#   'luck',
#   'paula',
#   'please',
#   'do',
#   'not',
#   'work',
#   'too',
#   'hard',
#   'but',
#   'hope',
#   'you',
#   'have',
#   'fun',
#   'your',
#   'new',
#   'album',
#   'is',
#   'gon',
#   'na',
#   'be',
#   'amazing',
#   'xxx'],
#  ['now', 'your', 'leaving', 'me', 'get', 'sad'],
#  ['miss',
#   'you',
#   'twitter',
#   'my',
#   'phone',
#   'broke',
#   'now',
#   'using',
#   'stupid',
#   'nokia',
#   'phone',
#   'ughhh',
#   'miss',
#   'my',
#   'advance',
#   'phone'],
#  ['shooting', 'outside', 'my', 'house', 'not', 'kidding', 'so', 'scared'],
#  ['tuesday',
#   'll',
#   'start',
#   'with',
#   'reflection',
#   'then',
#   'lecture',
#   'in',
#   'stress',
#   'reducing',
#   'technique',
#   'that',
#   'sure',
#   'might',
#   'become',
#   'very',
#   'useful',
#   'for',
#   'u',
#   'accompaniers'],
#  ['what', 'tragedy', 'and', 'disaster', 'in', 'the', 'news', 'this', 'week'],
#  ['yes',
#   'yes',
#   'still',
#   'trying',
#   'to',
#   'find',
#   'picture',
#   'that',
#   'will',
#   'upload',
#   'correclty'],
#  ['why',
#   'oh',
#   'why',
#   'wa',
#   'the',
#   'red',
#   'sox',
#   'game',
#   'rained',
#   'out',
#   'wa',
#   'so',
#   'looking',
#   'forward',
#   'to',
#   'opening',
#   'day'],
#  ['still', 'can', 'not', 'find', 'my', 'key'],
#  ['know', 'right', 'dunno', 'what', 'is', 'going', 'on', 'with', 'twitter'],
#  ['might', 'be', 'getting', 'sore', 'throat', 'again'],
#  ['my',
#   'home',
#   'town',
#   'my',
#   'mammy',
#   'called',
#   'all',
#   'depressd',
#   'pls',
#   'explain',
#   'parent',
#   'let',
#   'their',
#   'yr',
#   'old',
#   'child',
#   'walk',
#   'alone',
#   'hello',
#   'it'],
#  ['think',
#   'need',
#   'to',
#   'find',
#   'better',
#   'anti',
#   'depressant',
#   'think',
#   'this',
#   'paxil',
#   'wellbutrin',
#   'combo',
#   'is',
#   'losing',
#   'it',
#   'efficacy'],
#  ['restaurant',
#   'called',
#   'woodntap',
#   'ha',
#   'competitive',
#   'eating',
#   'tourney',
#   'round',
#   'tourney',
#   'time',
#   'we',
#   'place',
#   'nd'],
#  ['is', 'in', 'the', 'bathroom', 'wake', 'up', 'lakin'],
#  ['want', 'taco', 'and', 'margarhitas', 'telll', 'gay', 'say', 'hello'],
#  ['im', 'lonely', 'keep', 'me', 'company', 'female', 'california'],
#  ['bad', 'day', 'at', 'the', 'betfair', 'office'],
#  ['miss',
#   'him',
#   'can',
#   'not',
#   'wait',
#   'to',
#   'celebrate',
#   'the',
#   'tar',
#   'heel',
#   'win',
#   'this',
#   'weekend',
#   'though'],
#  ['really',
#   'cold',
#   'do',
#   'not',
#   'want',
#   'to',
#   'go',
#   'to',
#   'sleep',
#   'yet',
#   'but',
#   'there',
#   'nothing',
#   'to',
#   'do'],
#  ['is', 'this', 'it', 'it', 'officially', 'over', 'me', 'this', 'go', 'round'],
#  ['monkey',
#   'just',
#   'found',
#   'out',
#   'you',
#   'my',
#   'twin',
#   'and',
#   'you',
#   'wont',
#   'even',
#   'write',
#   'back',
#   'heartbroken'],
#  ['aww', 'know', 'felt', 'like', 'that', 'yesterday', 'at', 'work'],
#  ['treaty', 'is', 'not', 'defined'],
#  ['missed',
#   'brent',
#   'at',
#   'praise',
#   'band',
#   'no',
#   'fun',
#   'to',
#   'not',
#   'have',
#   'the',
#   'your',
#   'lead',
#   'guitarist',
#   'pout'],
#  ['poor',
#   'john',
#   'this',
#   'is',
#   'what',
#   'happens',
#   'when',
#   'you',
#   'play',
#   'with',
#   'fruit',
#   'and',
#   'microwave',
#   'seriously',
#   'though',
#   'have',
#   'you',
#   'seen',
#   'doctor',
#   'xxx'],
#  ['missing',
#   'my',
#   'bff',
#   'watching',
#   'home',
#   'and',
#   'away',
#   'it',
#   'reminds',
#   'me',
#   'of',
#   'her',
#   'and',
#   'me',
#   'we',
#   'it',
#   'shout',
#   'out',
#   'to',
#   'court'],
#  [],
#  ['new', 'video', 'card', 'is', 'doa'],
#  ['feeling',
#   'lost',
#   'naked',
#   'and',
#   'confused',
#   'jk',
#   'sort',
#   'of',
#   'no',
#   'iphone',
#   'for',
#   'me'],
#  ['damn',
#   'am',
#   'so',
#   'late',
#   'at',
#   'filling',
#   'this',
#   'appraisal',
#   'form',
#   'people',
#   'have',
#   'almost',
#   'sent',
#   'it',
#   'wa',
#   'so',
#   'occupied',
#   'in',
#   'work'],
#  ['missed',
#   'brent',
#   'at',
#   'praise',
#   'band',
#   'no',
#   'fun',
#   'to',
#   'not',
#   'have',
#   'your',
#   'lead',
#   'guitarist',
#   'pout'],
#  ['think',
#   'to',
#   'much',
#   'on',
#   'the',
#   'past',
#   'cant',
#   'change',
#   'it',
#   'deserved',
#   'so',
#   'much',
#   'more',
#   'then',
#   'wat',
#   'got',
#   'but',
#   'why',
#   'am',
#   'still',
#   'thinking',
#   'about',
#   'him',
#   'gah'],
#  ['ha', 'lost', 'his', 'ring', 'it', 'no', 'where', 'to', 'be', 'seen'],
#  ['ooooooh',
#   'sealclap',
#   'see',
#   'download',
#   'shitloads',
#   'of',
#   'zip',
#   'folder',
#   'off',
#   'chan',
#   'have',
#   'no',
#   'internet',
#   'money',
#   'fuck',
#   'yeah',
#   'alicia',
#   'mikey'],
#  ['is',
#   'still',
#   'nursing',
#   'my',
#   'nile',
#   'but',
#   'glad',
#   'he',
#   'is',
#   'feeling',
#   'better',
#   'hate',
#   'when',
#   'my',
#   'baby',
#   'is',
#   'sick'],
#  ['is', 'fucked', 'to', 'go', 'back', 'to', 'ic'],
#  ['yoyoyo',
#   'my',
#   'internet',
#   'ha',
#   'been',
#   'rude',
#   'tonight',
#   'it',
#   'just',
#   'reconnected',
#   'and',
#   'about',
#   'to',
#   'go',
#   'to',
#   'bed'],
#  ['well',
#   'have',
#   'uni',
#   'stuff',
#   'and',
#   'netball',
#   'but',
#   'after',
#   'netbal',
#   'if',
#   've',
#   'done',
#   'uni',
#   'stuff',
#   'we',
#   'can'],
#  ['me', 'too', 'is', 'poor'],
#  ['help', 'me', 'forget', 'th', 'april', 'th', 'july'],
#  ['dierks',
#   'bentley',
#   'is',
#   'comin',
#   'to',
#   'columbus',
#   'oh',
#   'wan',
#   'na',
#   'go',
#   'so',
#   'bad'],
#  ['have', 'to', 'take', 'my', 'sidekick', 'back'],
#  ['congrats',
#   'totally',
#   'jealous',
#   'only',
#   'wish',
#   'my',
#   'xm',
#   'wa',
#   'working'],
#  ['gr', 'my', 'face', 'is', 'very', 'itchy'],
#  ['poor',
#   'sock',
#   'luvvvvv',
#   'the',
#   'golden',
#   'retriever',
#   'want',
#   'one',
#   'sighhhh'],
#  ['just',
#   'saw',
#   'that',
#   'they',
#   'found',
#   'that',
#   'tracy',
#   'girl',
#   'in',
#   'piece',
#   'of',
#   'luggage',
#   'how',
#   'fucking',
#   'terrible'],
#  ['aaaaand', 'the', 'nausea', 'is', 'back'],
#  ['ooh',
#   'excited',
#   'and',
#   'not',
#   'even',
#   'going',
#   'be',
#   'there',
#   'long',
#   'love',
#   'youtube'],
#  ['spent',
#   'hour',
#   'to',
#   'reach',
#   'to',
#   'axis',
#   'bank',
#   'only',
#   'to',
#   'find',
#   'out',
#   'today',
#   'is',
#   'holiday',
#   'for',
#   'mahavir',
#   'jayanti',
#   'contd'],
#  ['agree', 'the', 'jobros', 'dont', 'update', 'there', 'very', 'often'],
#  ['it',
#   'is',
#   'hilarious',
#   'and',
#   'linked',
#   'the',
#   'clip',
#   'from',
#   'lj',
#   'some',
#   'time',
#   'ago',
#   'but',
#   'when',
#   'went',
#   'back',
#   'just',
#   'now',
#   'it',
#   'wa',
#   'dead',
#   'link'],
#  ['oooooooo',
#   'who',
#   'with',
#   'im',
#   'not',
#   'neither',
#   'but',
#   'thats',
#   'because',
#   'need',
#   'to',
#   'study'],
#  ['have',
#   'not',
#   'tweeted',
#   'nearly',
#   'all',
#   'day',
#   'posted',
#   'my',
#   'website',
#   'tonight',
#   'hopefully',
#   'that',
#   'go',
#   'well',
#   'night',
#   'time'],
#  ['miss', 'bentley'],
#  ['seriously', 'need', 'to', 'finish', 'these', 'job', 'application'],
#  ['my',
#   'son',
#   'vinca',
#   'is',
#   'sick',
#   'so',
#   'stay',
#   'at',
#   'home',
#   'just',
#   'three',
#   'tense',
#   'day',
#   'at',
#   'work',
#   'and',
#   'am',
#   'back',
#   'on',
#   'holiday',
#   'with',
#   'kid'],
#  ['whinging',
#   'my',
#   'client',
#   'bos',
#   'do',
#   'not',
#   'understand',
#   'english',
#   'well',
#   'rewrote',
#   'some',
#   'text',
#   'unreadable',
#   'it',
#   'written',
#   'by',
#   'good',
#   'writer',
#   'reviewed',
#   'correctly'],
#  ['do', 'not', 'want', 'him', 'to', 'ever', 'punch', 'me'],
#  ['sooo', 'sick', 'of', 'the', 'snow', 'ughh'],
#  [],
#  ['it', 'doe', 'not', 'work', 'your', 'fan', 'is', 'upset'],
#  ['would',
#   'like',
#   'to',
#   'apologize',
#   'for',
#   'the',
#   'repeated',
#   'video',
#   'game',
#   'live',
#   'related',
#   'tweet',
#   'am',
#   'going',
#   'to',
#   'have',
#   'stern',
#   'discussion',
#   'with',
#   'koodo',
#   'soon',
#   'stern'],
#  ['but',
#   'cant',
#   'figure',
#   'out',
#   'how',
#   'to',
#   'get',
#   'there',
#   'back',
#   'pay',
#   'for',
#   'hotel',
#   'etc'],
#  ['fml',
#   'so',
#   'much',
#   'for',
#   'seniority',
#   'bc',
#   'of',
#   'technological',
#   'ineptness',
#   'now',
#   'have',
#   'to',
#   'register',
#   'for',
#   'class',
#   'again'],
#  ['feel',
#   'like',
#   'she',
#   'slept',
#   'the',
#   'day',
#   'away',
#   'not',
#   'looking',
#   'forward',
#   'to',
#   'any',
#   'more',
#   'bout',
#   'with',
#   'my',
#   'gallbladder',
#   'at',
#   'least',
#   'have',
#   'pill',
#   'now',
#   'for',
#   'the',
#   'pain'],
#  ['but', 'what', 'really', 'want', 'is', 'my', 'old', 'bass', 'back'],
#  ['mad',
#   'tired',
#   'today',
#   'callin',
#   'it',
#   'in',
#   'early',
#   'tonight',
#   'nighty',
#   'night',
#   'twittas'],
#  ['take', 'it', 'easy', 'and', 'be', 'good', 'to', 'you'],
#  ['afraid', 'had', 'bad', 'code'],
#  ['think', 'going', 'to', 'bed', 'goodniight', 'hate', 'this'],
#  ['here', 'friend', 'and', 'love', 'you'],
#  ['all',
#   'this',
#   'time',
#   'you',
#   'did',
#   'not',
#   'notice',
#   'wa',
#   'gone',
#   'just',
#   'needed',
#   'db',
#   'is',
#   'it'],
#  ['is', 'in', 'the', 'bathroom', 'and', 'have', 'to', 'pee'],
#  ['but', 'wanted', 'margarita', 'too'],
#  ['yup',
#   'night',
#   'workout',
#   'the',
#   'worst',
#   'but',
#   'unfortunetly',
#   'my',
#   'work',
#   'schedule',
#   'only',
#   'allows',
#   'me',
#   'to',
#   'go',
#   'at',
#   'night',
#   'it',
#   'tough'],
#  ['just',
#   'called',
#   'hillsong',
#   'again',
#   'they',
#   'said',
#   'they',
#   'could',
#   'not',
#   'tell',
#   'me',
#   'where',
#   'wa',
#   'on',
#   'the',
#   'waiting',
#   'list',
#   'do',
#   'not',
#   'know',
#   'if',
#   'it',
#   'looking',
#   'so',
#   'good'],
#  ['ha', 'of', 'milky', 'bar', 'left', 'and', 'around', 'ml', 'of', 'coke'],
#  ['it', 'stillllll', 'ha', 'not', 'arrived'],
#  ['mraow',
#   'feel',
#   'like',
#   'dancing',
#   'but',
#   'first',
#   'art',
#   'school',
#   'want',
#   'to',
#   'rape',
#   'me',
#   'some',
#   'more'],
#  ['ah',
#   'bet',
#   'it',
#   'doe',
#   've',
#   'been',
#   'like',
#   'craving',
#   'to',
#   'play',
#   'softball',
#   'or',
#   'basketball',
#   'but',
#   'have',
#   'noo',
#   'time'],
#  ['is',
#   'terrified',
#   'she',
#   'accidentally',
#   'deleted',
#   'reference',
#   'in',
#   'her',
#   'management',
#   'assignment',
#   'and',
#   'hope',
#   'she',
#   'doesnt',
#   'get',
#   'in',
#   'trouble',
#   'when',
#   'she',
#   'get',
#   'back'],
#  ['amazon',
#   'plugin',
#   'not',
#   'worked',
#   'in',
#   'my',
#   'website',
#   'it',
#   'need',
#   'php',
#   'but',
#   'my',
#   'hosting',
#   'provider',
#   'ha',
#   'only',
#   'php',
#   'very',
#   'sad'],
#  ['argh',
#   'wa',
#   'suuuper',
#   'sleepy',
#   'an',
#   'hour',
#   'ago',
#   'now',
#   'wide',
#   'awake',
#   'hope',
#   'do',
#   'not',
#   'stay',
#   'up',
#   'all',
#   'night'],
#  ['wish',
#   'wa',
#   'sold',
#   'out',
#   'if',
#   'you',
#   'have',
#   'some',
#   'time',
#   'let',
#   'me',
#   'know',
#   'would',
#   'love',
#   'to',
#   'hear',
#   'more',
#   'about',
#   'what',
#   'you',
#   'are',
#   'up',
#   'to'],
#  ['just', 'watched', 'tropic', 'thunder', 'dreading', 'tomorrow'],
#  ['no', 'he', 'still', 'miss'],
#  ['chiefdelphi', 'is', 'down'],
#  ['according',
#   'to',
#   'my',
#   'bro',
#   'our',
#   'new',
#   'puppy',
#   'had',
#   'poo',
#   'fight',
#   'and',
#   'wa',
#   'covered',
#   'in',
#   'poop',
#   'picture',
#   'stolen',
#   'from',
#   'him'],
#  ['playing',
#   'game',
#   'at',
#   'home',
#   'my',
#   'new',
#   'bos',
#   'did',
#   'not',
#   'call',
#   'me',
#   'yet'],
#  ['su',
#   'yin',
#   'huen',
#   'tweeted',
#   'feel',
#   'unbearable',
#   'guilt',
#   'made',
#   'my',
#   'staff',
#   'cry'],
#  ['poor', 'joshy', 'is', 'sick', 'those', 'damn', 'tejanos'],
#  ['my',
#   'thought',
#   'are',
#   'with',
#   'sandra',
#   'cantu',
#   'family',
#   'at',
#   'this',
#   'difficult',
#   'and',
#   'sad',
#   'time'],
#  ['know',
#   'just',
#   'wanted',
#   'to',
#   'let',
#   'everybody',
#   'know',
#   'what',
#   'wa',
#   'happening'],
#  ['michigan', 'who', 'do', 'not', 'know', 'them', 'sigh', 'shameful'],
#  ['have', 'to', 'fill', 'two', 'hour'],
#  ['so',
#   'cuuute',
#   'hey',
#   'miss',
#   'you',
#   'na',
#   'it',
#   'not',
#   'the',
#   'same',
#   'not',
#   'seeing',
#   'you',
#   'girl',
#   'everyday'],
#  ['oh',
#   'did',
#   'mention',
#   'it',
#   'gooooood',
#   'moooorniiiiiiing',
#   'from',
#   'germany',
#   'im',
#   'back',
#   'in',
#   'my',
#   'cage',
#   'or',
#   'better',
#   'my',
#   'office'],
#  ['throat',
#   'is',
#   'closing',
#   'up',
#   'and',
#   'had',
#   'some',
#   'string',
#   'cheese',
#   'not',
#   'good',
#   'idea'],
#  ['aww',
#   'sandra',
#   'cantu',
#   'is',
#   'found',
#   'dead',
#   'in',
#   'suitcase',
#   'missing',
#   'child',
#   'story',
#   'never',
#   'seem',
#   'to',
#   'go',
#   'good',
#   'poor',
#   'family'],
#  ['wishing', 'wa', 'home', 'underneath', 'my', 'cover'],
#  ['walking', 'home', 'from', 'school', 'drain', 'all', 'my', 'energy'],
#  ['agree',
#   'the',
#   'shapeshifting',
#   'is',
#   'copout',
#   'wa',
#   'so',
#   'excited',
#   'for',
#   'angela',
#   'ep',
#   'thought',
#   'it',
#   'wa',
#   'this',
#   'week',
#   'noah',
#   'wa',
#   'awesome',
#   'tho'],
#  ['dang',
#   'would',
#   'have',
#   'done',
#   'this',
#   'if',
#   'knew',
#   'it',
#   'wa',
#   'there',
#   'earlier',
#   'any',
#   'other',
#   'outing',
#   'planned'],
#  ['wish',
#   'wa',
#   'better',
#   'at',
#   'writing',
#   'it',
#   'taking',
#   'me',
#   'so',
#   'long',
#   'to',
#   'write',
#   'this',
#   'paper'],
#  ['and',
#   'of',
#   'course',
#   'have',
#   'access',
#   'to',
#   'my',
#   'halo',
#   'mythic',
#   'map',
#   'pack',
#   're',
#   'download',
#   'but',
#   'bad',
#   'news',
#   'not',
#   'the',
#   'legendary',
#   'map',
#   'pack',
#   'ugh',
#   'm'],
#  ['not',
#   'yet',
#   'unfortunately',
#   'another',
#   'few',
#   'week',
#   've',
#   'been',
#   'told',
#   'how',
#   'are',
#   'you',
#   've',
#   'been',
#   'little',
#   'bit',
#   'busy',
#   'with',
#   'my',
#   'latest',
#   'project'],
#  ['ha', 'the', 'sun', 'already', 'gone'],
#  ['day',
#   'lot',
#   'harder',
#   'than',
#   'day',
#   'let',
#   'see',
#   'how',
#   'day',
#   'go',
#   'tomorrow'],
#  ['my', 'man', 'crush', 'jake', 'peavy', 'let', 'me', 'down', 'gayforpeavy'],
#  ['megafast',
#   'trip',
#   'you',
#   'have',
#   'time',
#   'during',
#   'day',
#   'tom',
#   'wed',
#   'or',
#   'you',
#   'going',
#   'out',
#   'tonight',
#   'want',
#   'to',
#   'see',
#   'you',
#   'bad',
#   'tried',
#   'to',
#   'warn',
#   'you',
#   'tech',
#   'fail'],
#  ['michigan', 'state', 'you', 'make', 'me', 'sad'],
#  ['omg',
#   'my',
#   'mouth',
#   'is',
#   'in',
#   'so',
#   'much',
#   'pain',
#   'just',
#   'wan',
#   'na',
#   'sleep',
#   'untill',
#   'it',
#   'time',
#   'to',
#   'take',
#   'my',
#   'brace',
#   'off'],
#  ['getting',
#   'annoyed',
#   'easily',
#   'today',
#   'biofuel',
#   'proposal',
#   'getting',
#   'annoyed',
#   'easily',
#   'today',
#   'biof'],
#  ['hey',
#   'girl',
#   'the',
#   'site',
#   'is',
#   'back',
#   'girlyvue',
#   'is',
#   'back',
#   'and',
#   'they',
#   'have',
#   'even',
#   'more',
#   'video'],
#  ['spending',
#   'time',
#   'with',
#   'my',
#   'grandma',
#   'early',
#   'tomorrow',
#   'and',
#   'can',
#   'not',
#   'leave',
#   'skittle',
#   'by',
#   'herself'],
#  ['just',
#   'got',
#   'home',
#   'from',
#   'watching',
#   'michigan',
#   'state',
#   'get',
#   'tromped'],
#  ['oh',
#   'jew',
#   'bus',
#   'two',
#   'year',
#   'worth',
#   'of',
#   'class',
#   'work',
#   'is',
#   'alot',
#   'to',
#   'organize',
#   'not',
#   'finishing',
#   'tonight',
#   'it',
#   'not',
#   'possible',
#   'my',
#   'bone',
#   'ache'],
#  ['no', 'exchanging', 'for', 'me', 'my', 'laptop', 'ha', 'not', 'arrived'],
#  ['hope', 'this', 'doe', 'not', 'last', 'too', 'long', 'feel', 'miserable'],
#  ['rachel',
#   'hang',
#   'outage',
#   'is',
#   'neccessary',
#   'wa',
#   'gon',
#   'na',
#   'be',
#   'home',
#   'this',
#   'wekend',
#   'but',
#   'dumb',
#   'folk',
#   'make',
#   'me',
#   'work',
#   'so',
#   'im',
#   'free',
#   'and',
#   'sat',
#   'until'],
#  ['not',
#   'fun',
#   'furious',
#   'the',
#   'new',
#   'mantra',
#   'for',
#   'the',
#   'bay',
#   'breaker',
#   'it',
#   'wa',
#   'getting',
#   'rambunctious',
#   'the',
#   'city',
#   'overreacted',
#   'clamped',
#   'down'],
#  ['my',
#   'hubby',
#   'for',
#   'some',
#   'reason',
#   'think',
#   'it',
#   'more',
#   'important',
#   'he',
#   'ha',
#   'good',
#   'spot',
#   'for',
#   'red',
#   'carpet',
#   'for',
#   'the',
#   'trek',
#   'movie',
#   'premiere',
#   'sod'],
#  ['swear',
#   'no',
#   'matter',
#   'how',
#   'long',
#   've',
#   'been',
#   'getting',
#   'up',
#   'at',
#   'am',
#   'it',
#   'never',
#   'get',
#   'any',
#   'easier',
#   'man',
#   'my',
#   'eye',
#   'hurt',
#   'wah'],
#  ['jeffree',
#   'how',
#   'do',
#   'you',
#   'keep',
#   'your',
#   'hair',
#   'one',
#   'color',
#   'my',
#   'permanent',
#   'dye',
#   'fade',
#   'within',
#   'the',
#   'week'],
#  ['my', 'reaction', 'too', 'whoa', 'did', 'not', 'see', 'that', 'coming'],
#  ['still',
#   'sick',
#   'feeling',
#   'bit',
#   'better',
#   'got',
#   'some',
#   'new',
#   'medicine',
#   'hope',
#   'feel',
#   'good',
#   'after',
#   'night',
#   'of',
#   'sleep',
#   'ohh',
#   'and',
#   'it',
#   'suppose',
#   'to',
#   'snow',
#   'wtf'],
#  ['think',
#   'maybe',
#   'you',
#   'should',
#   'get',
#   'couple',
#   'more',
#   'hour',
#   'of',
#   'sleep',
#   'hon',
#   'how',
#   'productive',
#   'can',
#   'you',
#   'be',
#   'right',
#   'now',
#   'if',
#   'ur',
#   'dog',
#   'tired',
#   'worry'],
#  ['thanks',
#   'lot',
#   'learned',
#   'lot',
#   'of',
#   'new',
#   'word',
#   'but',
#   'did',
#   'not',
#   'find',
#   'what',
#   'wa',
#   'looking',
#   'for'],
#  ['wish',
#   'had',
#   'all',
#   'the',
#   'xblm',
#   'downloads',
#   'all',
#   'on',
#   'the',
#   'gamertag',
#   'hitokyri',
#   'this',
#   'gamertag',
#   'thing',
#   'is',
#   'nonsense',
#   'and',
#   'tired',
#   'of',
#   'it'],
#  ['new', 'testament', 'test', 'at', 'am'],
#  ['ton', 'no', 'hay', 'troll', 'ahhhh'],
#  ['stupid',
#   'movie',
#   'we',
#   'watched',
#   'mirror',
#   'ugggggh',
#   'stooopeeed',
#   'rip',
#   'off'],
#  ['love', 'you', 'buck'],
#  ['last', 'one', 'but', 'still', 'not', 'done'],
#  ['homework'],
#  ['do',
#   'not',
#   'understand',
#   'why',
#   'thing',
#   'get',
#   'taken',
#   'away',
#   'did',
#   'not',
#   'have',
#   'enough',
#   'time',
#   'with',
#   'him',
#   'it',
#   'unfair',
#   'want',
#   'him',
#   'back',
#   'he',
#   'wa',
#   'like',
#   'my',
#   'baby'],
#  ['scratch',
#   'that',
#   'du',
#   'in',
#   'heif',
#   'two',
#   'in',
#   'half',
#   'cooky',
#   'my',
#   'tum',
#   'just',
#   'can',
#   'not',
#   'take',
#   'anymore',
#   'shoog',
#   'poots'],
#  ['wa',
#   'just',
#   'listening',
#   'to',
#   'the',
#   'sweet',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'forever',
#   'miss',
#   'them',
#   'so',
#   'much',
#   'can',
#   'we',
#   'go',
#   'to',
#   'chi',
#   'town',
#   'for',
#   'visit',
#   'plz'],
#  ['geez',
#   'what',
#   'busy',
#   'afternoon',
#   'meeting',
#   'email',
#   'meeting',
#   'and',
#   'email',
#   'and',
#   'more',
#   'meeting',
#   'pm',
#   'and',
#   'the',
#   'day',
#   'is',
#   'still',
#   'going',
#   'ah',
#   'it',
#   'dark',
#   'and'],
#  ['dang',
#   'another',
#   'spring',
#   'break',
#   'how',
#   'cool',
#   'is',
#   'that',
#   'too',
#   'bad',
#   'have',
#   'to',
#   'work',
#   'all',
#   'week',
#   'oh',
#   'well',
#   'more',
#   'money',
#   'for',
#   'phone',
#   'ttyl',
#   'everbody'],
#  ['im', 'afraid', 'too', 'ur', 'reply', 'about', 'uni', 'from', 'age', 'ago'],
#  ['feeling', 'down'],
#  ['lol',
#   'they',
#   'are',
#   'some',
#   'emotional',
#   'as',
#   'men',
#   'omg',
#   'all',
#   'this',
#   'late',
#   'night',
#   'eating',
#   'both',
#   'of',
#   'u',
#   'are',
#   'broke'],
#  ['aww',
#   'nick',
#   'like',
#   'your',
#   'hair',
#   'longer',
#   'why',
#   'did',
#   'you',
#   'cut',
#   'it',
#   'off',
#   'break',
#   'my',
#   'heart'],
#  ['wonder', 'if', 'jon', 'lost', 'the', 'net'],
#  ['wow',
#   'the',
#   'most',
#   'depressing',
#   'thing',
#   'in',
#   'the',
#   'world',
#   'is',
#   'losing',
#   'video',
#   'that',
#   'you',
#   've',
#   'created',
#   'in',
#   'matter',
#   'of',
#   'second',
#   'fml'],
#  ['but', 'all', 'say', 'not', 'in', 'stock'],
#  ['lmao', 'im', 'sorry', 'poohpot', 'ate', 'it', 'all'],
#  ['any', 'chance', 'softbelly', 'for', 'is', 'not', 'loud'],
#  ['time',
#   'to',
#   'move',
#   'my',
#   'posterior',
#   'and',
#   'lose',
#   'some',
#   'fat',
#   'my',
#   'articulation',
#   'are',
#   'creaking',
#   'so',
#   'no',
#   'more',
#   'running',
#   'but',
#   'drool',
#   'for',
#   'some',
#   'swimming'],
#  ['listening', 'to', 'nathan', 'cry'],
#  ['today',
#   'sucked',
#   'gon',
#   'na',
#   'die',
#   'without',
#   'chris',
#   'and',
#   'callum',
#   'wahhh'],
#  ['stou',
#   'site',
#   'not',
#   'update',
#   'no',
#   'info',
#   'about',
#   'exam',
#   'and',
#   'open',
#   'course',
#   'must',
#   'wait',
#   'for',
#   'mail',
#   'notice',
#   'and',
#   'doc',
#   'um'],
#  ['sorry',
#   'feeling',
#   'kinda',
#   'yucky',
#   'myself',
#   'am',
#   'is',
#   'going',
#   'to',
#   'come',
#   'too',
#   'quick'],
#  ['is',
#   'in',
#   'love',
#   'with',
#   'scrappy',
#   'and',
#   'is',
#   'missin',
#   'him',
#   'already'],
#  ['want',
#   'to',
#   'hear',
#   'song',
#   'but',
#   'myspace',
#   'is',
#   'messing',
#   'with',
#   'me'],
#  ['bad',
#   'news',
#   'wa',
#   'dad',
#   'ha',
#   'cancer',
#   'and',
#   'is',
#   'dying',
#   'good',
#   'news',
#   'new',
#   'business',
#   'started',
#   'and',
#   'am',
#   'now',
#   'life',
#   'coach',
#   'practising',
#   'holistic',
#   'weight',
#   'management'],
#  ['man', 'intervention', 'is', 'soo', 'sad'],
#  ['help', 'need', 'new', 'boyfriend', 'stuck', 'in', 'rut'],
#  ['feel',
#   'like',
#   'complete',
#   'idiot',
#   'the',
#   'only',
#   'one',
#   'who',
#   'doe',
#   'not',
#   'get',
#   'how',
#   'this',
#   'shit',
#   'work',
#   'help',
#   'me'],
#  ['saw',
#   'an',
#   'ad',
#   'on',
#   'craigslist',
#   'for',
#   'casting',
#   'call',
#   'for',
#   'female',
#   'host',
#   'on',
#   'wa',
#   'totally',
#   'psyched',
#   'but',
#   'realized',
#   'it',
#   'wa',
#   'hoax'],
#  ['pepperoni',
#   'roll',
#   'in',
#   'called',
#   'valentino',
#   'they',
#   'said',
#   'that',
#   'they',
#   'had',
#   'sausage',
#   'roll',
#   'but',
#   'no',
#   'pepperoni',
#   'roll'],
#  ['yes', 'it', 'will', 'be', 'it', 'only', 'monday'],
#  ['want', 'the', 'new', 'gg', 'episode', 'already'],
#  ['miss', 'watching', 'rocko', 'modern', 'life'],
#  ['rip',
#   'sandra',
#   'it',
#   'so',
#   'sad',
#   'how',
#   'can',
#   'someone',
#   'do',
#   'something',
#   'like',
#   'that'],
#  ['keeping',
#   'my',
#   'finger',
#   'crossed',
#   'for',
#   'my',
#   'buddy',
# ...
#   'come',
#   'back',
#   'no',
#   'nice',
#   'weather',
#   'for',
#   'my',
#   'birthday'],
#  ['rock', 'band', 'is', 'hard', 'on', 'expert'],
#  ['roomie',
#   'wa',
#   'home',
#   'all',
#   'day',
#   'all',
#   'he',
#   'had',
#   'to',
#   'do',
#   'wa',
#   'scratch',
#   'at',
#   'the',
#   'door',
#   'comforter',
#   'ha',
#   'to',
#   'goto',
#   'large',
#   'laundromat',
#   'machine'],
#  ['one',
#   'of',
#   'the',
#   'hardest',
#   'thing',
#   'with',
#   'this',
#   'schedule',
#   'no',
#   'one',
#   'can',
#   'chat',
#   'with',
#   'at',
#   'the',
#   'end',
#   'of',
#   'my',
#   'day',
#   'usually'],
#  ['they',
#   'killed',
#   'off',
#   'character',
#   'on',
#   'one',
#   'of',
#   'my',
#   'favorite',
#   'show',
#   'and',
#   'now',
#   'upset'],
#  ['jealous',
#   'of',
#   'my',
#   'friend',
#   'who',
#   'got',
#   'to',
#   'see',
#   'the',
#   'new',
#   'star',
#   'trek',
#   'film',
#   'in',
#   'austin',
#   'tonight'],
#  ['listening',
#   'to',
#   'got',
#   'really',
#   'bad',
#   'headache',
#   'and',
#   'drivin',
#   'lesson',
#   'in',
#   'ten',
#   'min',
#   'lucky',
#   'me',
#   'just',
#   'wana',
#   'sleeep'],
#  ['shut',
#   'up',
#   'you',
#   'am',
#   'hungry',
#   'and',
#   'in',
#   'britain',
#   'home',
#   'of',
#   'the',
#   'most',
#   'boring',
#   'suckassy',
#   'breakfast',
#   'in',
#   'the',
#   'world',
#   'miss',
#   'dennys'],
#  ['good',
#   'morning',
#   'everybody',
#   'pkoi',
#   'fais',
#   'pa',
#   'beau',
#   'bon',
#   'coffee',
#   'time'],
#  ['work', 'again'],
#  ['essay', 'time'],
#  ['hey',
#   'did',
#   'talk',
#   'to',
#   'mom',
#   'they',
#   'home',
#   'yet',
#   'hope',
#   'they',
#   'ok',
#   'wish',
#   'wa',
#   'coming',
#   'home',
#   'easter'],
#  ['sure',
#   'wish',
#   'could',
#   'go',
#   'with',
#   'you',
#   'guy',
#   'tmrw',
#   'but',
#   'a',
#   'per',
#   'usual',
#   'school',
#   'interferes'],
#  ['say',
#   'what',
#   'kal',
#   'penn',
#   'leaving',
#   'house',
#   'noooooo',
#   'totally',
#   'missed',
#   'it',
#   'tonight'],
#  ['no', 'lost', 'loyal'],
#  ['played',
#   'another',
#   'hand',
#   'very',
#   'bad',
#   'and',
#   'lost',
#   'half',
#   'my',
#   'stack'],
#  ['it', 'pm', 'early', 'day', 'in', 'looooooong', 'night', 'at', 'work'],
#  ['it',
#   'sad',
#   'it',
#   'the',
#   'last',
#   'season',
#   'wan',
#   'na',
#   'see',
#   'when',
#   'spencer',
#   'call',
#   'lauren'],
#  ['so',
#   'im',
#   'done',
#   'editing',
#   'the',
#   'phipstape',
#   'back',
#   'crack',
#   'brew',
#   'and',
#   'see',
#   'what',
#   'we',
#   'got',
#   'no',
#   'tree',
#   'though'],
#  ['do', 'not', 'know', 'what', 'half', 'of', 'that', 'mean'],
#  ['homework', 'homework', 'homework'],
#  ['worked',
#   'his',
#   'heart',
#   'out',
#   'today',
#   'doubling',
#   'my',
#   'weight',
#   'at',
#   'each',
#   'station',
#   'result',
#   'stiff',
#   'and',
#   'pulled',
#   'muscle',
#   'ouch'],
#  ['now', 'feel', 'bad', 'for', 'unfollowing'],
#  ['so',
#   'tired',
#   'god',
#   'hate',
#   'the',
#   'new',
#   'job',
#   'and',
#   'only',
#   'two',
#   'day',
#   'in'],
#  ['sad',
#   'about',
#   'kutner',
#   'being',
#   'killed',
#   'off',
#   'my',
#   'fav',
#   'show',
#   'house'],
#  ['happy',
#   'for',
#   'coach',
#   'stringer',
#   'hof',
#   'now',
#   'if',
#   'can',
#   'only',
#   'finish',
#   'my',
#   'term',
#   'paper',
#   'on',
#   'her'],
#  ['feel',
#   'like',
#   'shit',
#   'this',
#   'is',
#   'not',
#   'the',
#   'way',
#   'want',
#   'to',
#   'spend',
#   'my',
#   'birthday',
#   'eve'],
#  ['so',
#   'far',
#   'have',
#   'on',
#   'all',
#   'my',
#   'site',
#   'put',
#   'together',
#   'most',
#   'of',
#   'them',
#   'were',
#   'me',
#   'checking',
#   'out',
#   'the',
#   'update',
#   'made'],
#  ['ha',
#   'lot',
#   'on',
#   'her',
#   'mind',
#   'need',
#   'to',
#   'make',
#   'some',
#   'money',
#   'and',
#   'idea',
#   'nowhere',
#   'is',
#   'hiring'],
#  ['miss', 'you'],
#  ['so', 'sorry', 'to', 'hear', 'about', 'your', 'dog'],
#  ['too', 'much', 'internet', 'how', 'it', 'plague', 'me'],
#  ['miss', 'my', 'ex', 'soo', 'much'],
#  ['sodding'],
#  ['oh',
#   'thought',
#   'the',
#   'pirate',
#   'bay',
#   'trial',
#   'verdict',
#   'wa',
#   'today',
#   'apparently',
#   'it',
#   'in',
#   'day'],
#  ['call', 'me', 'back'],
#  ['is',
#   'in',
#   'study',
#   'hall',
#   'now',
#   'and',
#   'will',
#   'log',
#   'off',
#   'immediately'],
#  ['it',
#   'so',
#   'tired',
#   'that',
#   'im',
#   'cry',
#   'for',
#   'no',
#   'reason',
#   'at',
#   'all',
#   'im',
#   'about',
#   'to',
#   'try',
#   'to',
#   'get',
#   'an',
#   'hour',
#   'and',
#   'half',
#   'in',
#   'for',
#   'tonight',
#   'half',
#   'what',
#   'got',
#   'last',
#   'night'],
#  ['totally',
#   'have',
#   'like',
#   'four',
#   'girl',
#   'option',
#   'and',
#   'none',
#   'of',
#   'them',
#   'seem',
#   'viable'],
#  ['so',
#   'far',
#   'have',
#   'veiws',
#   'on',
#   'all',
#   'my',
#   'site',
#   'put',
#   'together',
#   'most',
#   'of',
#   'them',
#   'were',
#   'me',
#   'checking',
#   'out',
#   'the',
#   'update',
#   'made'],
#  ['listening', 'to', 'bjork', 'all', 'is', 'full', 'of', 'love', 'cry'],
#  ['omg',
#   'the',
#   'hill',
#   'then',
#   'love',
#   'money',
#   'aww',
#   'think',
#   'becky',
#   'buckwild',
#   'go'],
#  ['is', 'craving', 'for', 'some', 'tantan', 'nabe'],
#  ['mon', 'sean', 'man'],
#  ['watching',
#   'league',
#   'of',
#   'their',
#   'own',
#   'make',
#   'me',
#   'miss',
#   'mint',
#   'chocolate',
#   'ice',
#   'cream',
#   'cone',
#   'and',
#   'my',
#   'grand',
#   'ma',
#   'fuck'],
#  ['lost',
#   'my',
#   'phone',
#   'some',
#   'where',
#   'maybe',
#   'in',
#   'the',
#   'grass',
#   'it',
#   'just',
#   'so',
#   'long',
#   'hope',
#   'it',
#   'doe',
#   'not',
#   'rain'],
#  ['hope',
#   'you',
#   'are',
#   'not',
#   'referring',
#   'to',
#   'me',
#   'say',
#   'hello',
#   'to',
#   'your',
#   'new',
#   'stalker',
#   'lol'],
#  ['why',
#   'were',
#   'sleeping',
#   'ur',
#   'gon',
#   'na',
#   'be',
#   'up',
#   'all',
#   'night',
#   'now',
#   'how',
#   'wa',
#   'ur',
#   'bike',
#   'ride'],
#  ['but', 'but', 'but', 'wan', 'na', 'listen', 'to', 'the', 'master', 'too'],
#  ['ve',
#   'been',
#   'looking',
#   'about',
#   'for',
#   'good',
#   'stuff',
#   'to',
#   'write',
#   'but',
#   'also',
#   'been',
#   'doing',
#   'load',
#   'of',
#   'uni',
#   'work'],
#  ['feel', 'unloved', 'dropped', 'tweeter'],
#  ['off',
#   'to',
#   'london',
#   'for',
#   'the',
#   'day',
#   'on',
#   'thursday',
#   'it',
#   'gon',
#   'na',
#   'be',
#   'raining',
#   'oh',
#   'fab',
#   'will',
#   'not',
#   'see',
#   'much',
#   'on',
#   'the',
#   'london',
#   'eye',
#   'still',
#   'robbie',
#   'will',
#   'not',
#   'care',
#   'bless',
#   'him'],
#  ['completely',
#   'wiped',
#   'and',
#   'reloaded',
#   'the',
#   'lost',
#   'all',
#   'bbm',
#   'contact',
#   'going',
#   'to',
#   'bed',
#   'sad'],
#  ['sayyyy', 'whaaaa', 'wa', 'not', 'invited'],
#  ['did',
#   'not',
#   'sleep',
#   'too',
#   'bad',
#   'considering',
#   'have',
#   'workshop',
#   'starting',
#   'today',
#   'beginning',
#   'of',
#   'sore',
#   'throat',
#   'though'],
#  ['oh',
#   'my',
#   'gosh',
#   'that',
#   'made',
#   'me',
#   'emotional',
#   'haha',
#   'idk',
#   'why',
#   'dont',
#   'want',
#   'to',
#   'get',
#   'old'],
#  ['we',
#   're',
#   'going',
#   'to',
#   'post',
#   'some',
#   'story',
#   'manually',
#   'due',
#   'to',
#   'twitterfeed',
#   'problem',
#   'that',
#   'why',
#   'we',
#   've',
#   'been',
#   'so',
#   'quiet',
#   'lately'],
#  ['do', 'not', 'like', 'lukewarm', 'shower'],
#  ['who',
#   'should',
#   'contact',
#   'if',
#   'need',
#   'for',
#   'freelance',
#   'work',
#   'did',
#   'on',
#   'linux',
#   'com',
#   'throughout',
#   'never',
#   'got',
#   'one'],
#  ['connor',
#   'it',
#   'me',
#   'febi',
#   'are',
#   'you',
#   'really',
#   'really',
#   'mad',
#   'at',
#   'me'],
#  ['need',
#   'some',
#   'help',
#   'want',
#   'to',
#   'buy',
#   'macbook',
#   'pro',
#   'but',
#   'still',
#   'inlove',
#   'with',
#   'my',
#   'old',
#   'powerbook'],
#  ['man',
#   'america',
#   'is',
#   'so',
#   'borez',
#   'anyway',
#   'lol',
#   'just',
#   'realized',
#   'you',
#   'sent',
#   'me',
#   'msg',
#   'on',
#   'here',
#   'had',
#   'no',
#   'idea',
#   'have',
#   'no',
#   'flash'],
#  ['knight', 'lovely', 'lady', 'sleepy', 'now'],
#  ['doe',
#   'anybody',
#   'know',
#   'how',
#   'to',
#   'get',
#   'your',
#   'electrolyte',
#   'back',
#   'in',
#   'order',
#   'with',
#   'vitamin',
#   'work',
#   'feel',
#   'sick'],
#  ['yes', 'someone', 'ha', 'not', 'been', 'reading', 'my', 'post', 'properly'],
#  ['almost',
#   'through',
#   'with',
#   'my',
#   'italian',
#   'homework',
#   'weeeeee',
#   'now',
#   'if',
#   'only',
#   'understood',
#   'what',
#   'wa',
#   'doing'],
#  ['who',
#   'turned',
#   'the',
#   'light',
#   'on',
#   'it',
#   'will',
#   'be',
#   'time',
#   'to',
#   'get',
#   'ip',
#   'then'],
#  ['twitter', 'hate', 'u', 'both', 'then'],
#  ['hate',
#   'the',
#   'fact',
#   'that',
#   'genuinely',
#   'excited',
#   'about',
#   'my',
#   'last',
#   'tweet'],
#  ['can', 'not', 'sleep', 'either'],
#  ['between',
#   'that',
#   'and',
#   'the',
#   'italy',
#   'earthquake',
#   'it',
#   'been',
#   'very',
#   'sad',
#   'news',
#   'day'],
#  ['all',
#   'rain',
#   'today',
#   'garden',
#   'really',
#   'need',
#   'it',
#   'so',
#   'not',
#   'quite',
#   'so',
#   'bad'],
#  ['yawn', 'yawn', 'yawn', 'more', 'minute', 'in', 'bed'],
#  ['ouch', 'sound', 'very', 'sucky'],
#  ['great',
#   'idea',
#   'with',
#   'the',
#   'itunes',
#   'promo',
#   'code',
#   'they',
#   'do',
#   'not',
#   'work',
#   'in',
#   'the',
#   'uk',
#   'itunes',
#   'store',
#   'though'],
#  ['cry'],
#  ['an',
#   'empty',
#   'rum',
#   'barrel',
#   'is',
#   'sad',
#   'rum',
#   'barrel',
#   'shake',
#   'head',
#   'the',
#   'horror',
#   'the',
#   'horror'],
#  ['it', 'wa', 'sleepless', 'night'],
#  ['she', 'admitted', 'to', 'being', 'fake'],
#  ['love', 'chutney'],
#  ['got',
#   'highly',
#   'bored',
#   'today',
#   'scanning',
#   'page',
#   'for',
#   'daddy',
#   'had',
#   'to',
#   'do',
#   'it'],
#  ['you', 'cooked', 'risotto', 'without', 'me'],
#  ['keeeerrrrriiiiii',
#   'really',
#   'have',
#   'nothing',
#   'better',
#   'to',
#   'do',
#   'then',
#   'post',
#   'on',
#   'this',
#   'thing',
#   'at',
#   'am',
#   'wonderfullll',
#   'say',
#   'alot'],
#  ['yay',
#   'for',
#   'baseball',
#   'season',
#   'boo',
#   'to',
#   'yankee',
#   'losing',
#   'their',
#   'first',
#   'game'],
#  ['lost', 'suck', 'because', 'have', 'to', 'work', 'today'],
#  ['omg',
#   'exam',
#   'killed',
#   'me',
#   'how',
#   'could',
#   'not',
#   'know',
#   'the',
#   'difference',
#   'between',
#   'haif',
#   'circle',
#   'and',
#   'hemisphere'],
#  ['in',
#   'bed',
#   'suddenly',
#   'feel',
#   'wish',
#   'ma',
#   'wa',
#   'here',
#   'me',
#   'goodnight',
#   'twitterfam'],
#  ['do', 'not', 'like', 'goodnights'],
#  ['greaaat', 'my', 'lappy', 'will', 'not', 'turn', 'on', 'wtffffff'],
#  ['you',
#   'stuck',
#   'in',
#   'traffic',
#   'then',
#   'my',
#   'journey',
#   'wa',
#   'traffic',
#   'free',
#   'this',
#   'morning',
#   'if',
#   'it',
#   'any',
#   'help'],
#  ['lookin',
#   'like',
#   'an',
#   'all',
#   'nighter',
#   'hate',
#   'it',
#   'when',
#   'do',
#   'this',
#   'to',
#   'myself'],
#  ['you', 're', 'stranger'],
#  ['debbugging',
#   'old',
#   'vb',
#   'code',
#   'the',
#   'day',
#   'could',
#   'have',
#   'started',
#   'better'],
#  ['only', 'quarter', 'of', 'percent', 'babe', 'darn'],
#  ['coming',
#   'down',
#   'with',
#   'cold',
#   'or',
#   'bad',
#   'allergy',
#   'either',
#   'way',
#   'miserable'],
#  ['can',
#   'not',
#   'believe',
#   'cutner',
#   'is',
#   'dead',
#   'on',
#   'house',
#   'sad',
#   'day',
#   'in',
#   'santa',
#   'rosa',
#   'ca'],
#  ['damnit', 'wa', 'really', 'digging', 'this', 'season', 'of', 'reaper'],
#  ['gah',
#   'comcast',
#   'doubled',
#   'our',
#   'cable',
#   'internet',
#   'bill',
#   'out',
#   'telling',
#   'u',
#   'so',
#   'we',
#   'are',
#   'quitting',
#   'can',
#   'anyone',
#   'suggest',
#   'an',
#   'affordable',
#   'company',
#   'in',
#   'bay',
#   'area'],
#  ['another',
#   'early',
#   'morn',
#   'with',
#   'the',
#   'duchess',
#   'although',
#   'she',
#   'had',
#   'not',
#   'managed',
#   'to',
#   'cross',
#   'her',
#   'leg',
#   'this',
#   'time'],
#  ['you', 'left', 'without', 'saying', 'hi'],
#  ['want', 'but', 'can', 'not', 'sleep'],
#  ['when',
#   'an',
#   'xbox',
#   'show',
#   'those',
#   'three',
#   'red',
#   'light',
#   'it',
#   'mean',
#   'it',
#   'dead',
#   'and',
#   'need',
#   'to',
#   'be',
#   'fixed',
#   'for',
#   'month',
#   'at',
#   'microsoft',
#   'hq'],
#  ['king',
#   'sized',
#   'bed',
#   'is',
#   'nice',
#   'but',
#   'sad',
#   'and',
#   'lonely',
#   'with',
#   'no',
#   'hubby',
#   'puppy',
#   'or',
#   'kitty',
#   'am',
#   'over',
#   'this',
#   'whole',
#   'conferenceing',
#   'thing'],
#  ['im',
#   'boredd',
#   'gah',
#   'wish',
#   'could',
#   'just',
#   'sleep',
#   'and',
#   'get',
#   'it',
#   'over',
#   'with',
#   'but',
#   'ive',
#   'had',
#   'toooo',
#   'muchh',
#   'cooooffffeeeeeeeee',
#   'bahaha'],
#  ['if',
#   'may',
#   'butt',
#   'in',
#   'again',
#   'done',
#   'being',
#   'nosey',
#   'sorry',
#   'your',
#   'conversation',
#   'wa',
#   'just',
#   'so',
#   'interesting'],
#  ['you', 'fell', 'off', 'my', 'list', 'did', 'offend', 'you'],
#  ['week',
#   'till',
#   'sister',
#   'home',
#   'missed',
#   'her',
#   'call',
#   'again',
#   'it',
#   'the',
#   'worst',
#   'feeling',
#   'in',
#   'the',
#   'world'],
#  ['gon',
#   'na',
#   'try',
#   'to',
#   'get',
#   'some',
#   'sleep',
#   'in',
#   'this',
#   'hotel',
#   'room'],
#  ['brilliant',
#   'idea',
#   'just',
#   'bring',
#   'a',
#   'much',
#   'a',
#   'you',
#   'think',
#   'you',
#   'll',
#   'spend',
#   'll',
#   'swap',
#   'you',
#   'bring',
#   'brolly'],
#  ['get',
#   'me',
#   'an',
#   'autograph',
#   'and',
#   'shout',
#   'out',
#   'you',
#   'have',
#   'to',
#   'record',
#   'it',
#   'though',
#   'my',
#   'computer',
#   'is',
#   'dead',
#   'so',
#   'can',
#   'not',
#   'listen'],
#  ['rt', 'khloe', 'just', 'got', 'fired', 'from', 'the', 'apprentice'],
#  ['in', 'biology', 'class', 'my', 'lip', 'hurt'],
#  ['sorry', 'for', 'the', 'next', 'tweet'],
#  ['grr', 'not', 'down', 'to', 'go', 'to', 'school', 'today'],
#  ['had',
#   'to',
#   'get',
#   'an',
#   'hd',
#   'tivo',
#   'and',
#   'just',
#   'got',
#   'it',
#   'set',
#   'up',
#   'tonight',
#   'in',
#   'order',
#   'to',
#   'get',
#   'channel'],
#  ['asked',
#   'everyone',
#   'how',
#   'they',
#   'were',
#   'doing',
#   'yesterday',
#   'and',
#   'not',
#   'single',
#   'tweet',
#   'back'],
#  ['ruddy',
#   'money',
#   'like',
#   'it',
#   'still',
#   'waiting',
#   'here',
#   'oh',
#   'what',
#   'surprise',
#   'by',
#   'state',
#   'too',
#   'hmmm',
#   'seriously'],
#  ['am',
#   'so',
#   'sad',
#   'kutner',
#   'wa',
#   'my',
#   'favorite',
#   'of',
#   'the',
#   'new',
#   'team'],
#  ['wow', 'did', 'not', 'get', 'an', 'hello', 'suck'],
#  ['bedtime',
#   'school',
#   'tomorrow',
#   'and',
#   'still',
#   'have',
#   'no',
#   'book',
#   'being',
#   'broke',
#   'suck'],
#  ['seating',
#   'here',
#   'helping',
#   'my',
#   'baby',
#   'with',
#   'his',
#   'paper',
#   'well',
#   'he',
#   'is',
#   'forcing',
#   'me',
#   'too',
#   'seat',
#   'with',
#   'him',
#   'im',
#   'sleepy'],
#  ['synching',
#   'my',
#   'contact',
#   'from',
#   'my',
#   'old',
#   'mobile',
#   'to',
#   'iphone',
#   'import',
#   'doe',
#   'not',
#   'work',
#   'well'],
#  ['can', 'not', 'concentrate'],
#  ['ve',
#   'just',
#   'spent',
#   'hour',
#   'to',
#   'enter',
#   'all',
#   'the',
#   'bureaucratic',
#   'nonsense',
#   'for',
#   'march',
#   'what',
#   'waste',
#   'of',
#   'my',
#   'time'],
#  ['nw', 'more', 'confused', 'then', 'ever'],
#  ['not',
#   'feeling',
#   'well',
#   'again',
#   'stupid',
#   'migraine',
#   'making',
#   'my',
#   'tummy',
#   'upset',
#   'and',
#   'my',
#   'whole',
#   'body',
#   'ache',
#   'shoot',
#   'me',
#   'now'],
#  ['reading',
#   'buyology',
#   'before',
#   'bedtime',
#   'great',
#   'premise',
#   'but',
#   'only',
#   'turning',
#   'out',
#   'to',
#   'be',
#   'an',
#   'ok',
#   'book',
#   'lot',
#   'of',
#   'info',
#   'already',
#   'knew'],
#  ['home',
#   'really',
#   'wana',
#   'sleep',
#   'but',
#   'due',
#   'to',
#   'wasting',
#   'my',
#   'free',
#   'line',
#   'in',
#   'town',
#   'have',
#   'an',
#   'assignment',
#   'to',
#   'finish'],
#  ['also',
#   'send',
#   'some',
#   'update',
#   'in',
#   'plurk',
#   'but',
#   'upload',
#   'photo',
#   'on',
#   'twitter',
#   'you',
#   'didnt',
#   'see',
#   'any',
#   'of',
#   'my',
#   'update',
#   'on',
#   'plurk',
#   'zero'],
#  ['omg', 'the', 'reader', 'is', 'making', 'me'],
#  ['oh',
#   'at',
#   'least',
#   'you',
#   're',
#   'getting',
#   'decent',
#   'exchange',
#   'rate',
#   'at',
#   'the',
#   'moment',
#   'sterling',
#   'is',
#   'still',
#   'getting',
#   'flogged'],
#  ['tried', 'to', 'download', 'tweetdeck', 'but', 'it', 'wont', 'download'],
#  ['there',
#   'an',
#   'inch',
#   'of',
#   'snow',
#   'on',
#   'the',
#   'ground',
#   'and',
#   'counting',
#   'worried',
#   'about',
#   'the',
#   'poor',
#   'flower'],
#  ['why', 'are', 'not', 'you', 'happy', 'camper'],
#  ['thanks',
#   'man',
#   'so',
#   'very',
#   'grateful',
#   'feel',
#   'unworthy',
#   'of',
#   'such',
#   'attention',
#   'though',
#   'because',
#   'in',
#   'this',
#   'because',
#   'of',
#   'myself'],
#  ['miss',
#   'too',
#   'totally',
#   'comin',
#   'back',
#   'tho',
#   'lastnight',
#   'wa',
#   'sooooooo',
#   'much',
#   'fun'],
#  ['ohhh',
#   'love',
#   'it',
#   'p',
#   'sad',
#   'we',
#   'did',
#   'not',
#   'get',
#   'to',
#   'hang',
#   'out'],
#  ['and', 'somehow', 'still', 'end', 'up', 'in', 'this', 'place'],
#  ['oh', 'that', 'is', 'very', 'sad', 'poor', 'boy'],
#  ...]

# %%
#joining words after tokenization

clean_data1 = [ ]
for c in data1:
    a = " ".join(c)
    clean_data1.append(a)

# %%
#print clean_data1

clean_data1
# Out:
# ['awww that bummer you shoulda got david carr of third day to do it',
#  'is upset that he can not update his facebook by texting it and might cry a result school today also blah',
#  'dived many time for the ball managed to save the rest go out of bound',
#  'my whole body feel itchy and like it on fire',
#  'no it not behaving at all mad why am here because can not see you all over there',
#  'not the whole crew',
#  'need hug',
#  'hey long time no see yes rain bit only bit lol fine thanks how you',
#  'nope they did not have it',
#  'que me muera',
#  'spring break in plain city it snowing',
#  'just re pierced my ear',
#  'could not bear to watch it and thought the ua loss wa embarrassing',
#  'it it count idk why did either you never talk to me anymore',
#  'would ve been the first but did not have gun not really though zac snyder just doucheclown',
#  'wish got to watch it with you miss you and how wa the premiere',
#  'hollis death scene will hurt me severely to watch on film wry is director cut not out now',
#  'about to file tax',
#  'ahh ive always wanted to see rent love the soundtrack',
#  'oh dear were you drinking out of the forgotten table drink',
#  'wa out most of the day so did not get much done',
#  'one of my friend called me and asked to meet with her at mid valley today but ve no time sigh',
#  'baked you cake but ated it',
#  'this week is not going a had hoped',
#  'blagh class at tomorrow',
#  'hate when have to call and wake people up',
#  'just going to cry myself to sleep after watching marley and me',
#  'im sad now miss lilly',
#  'ooooh lol that leslie and ok will not do it again so leslie will not get mad again',
#  'meh almost lover is the exception this track get me depressed every time',
#  'some hacked my account on aim now have to make new one',
#  'want to go to promote gear and groove but unfornately no ride there may going to the one in anaheim in may though',
#  'thought sleeping in wa an option tomorrow but realizing that it now is not evaluation in the morning and work in the afternoon',
#  'awe love you too am here miss you',
#  'cry my asian eye to sleep at night',
#  'ok sick and spent an hour sitting in the shower cause wa too sick to stand and held back the puke like champ bed now',
#  'ill tell ya the story later not good day and ill be workin for like three more hour',
#  'sorry bed time came here gmt',
#  'do not either it depressing do not think even want to know about the kid in suitcase',
#  'bed class work gym or then class another day that gon na fly by miss my girlfriend',
#  'really do not feel like getting up today but got to study to for tomorrow practical exam',
#  'he the reason for the teardrop on my guitar the only one who ha enough of me to break my heart',
#  'sad sad sad do not know why but hate this feeling wan na sleep and still can not',
#  'soo wish wa there to see you finally comfortable im sad that missed it',
#  'falling asleep just heard about that tracy girl body being found how sad my heart break for that family',
#  'yay happy for you with your job but that also mean le time for me and you',
#  'just checked my user timeline on my blackberry it look like the twanking is still happening are ppl still having probs bgs and uids',
#  'oh man wa ironing fave top to wear to meeting burnt it',
#  'is strangely sad about lilo and samro breaking up',
#  'oh so sorry did not think about that before retweeting',
#  'broadband plan massive broken promise via still waiting for broadband we are',
#  'wow ton of reply from you may have to unfollow so can see my friend tweet you re scrolling the feed lot',
#  'our duck and chicken are taking wayyy too long to hatch',
#  'put vacation photo online few yr ago pc crashed and now forget the name of the site',
#  'need hug',
#  'not sure what they are only that they are po a much a want to dont think can trade away company asset sorry andy',
#  'hate when that happens',
#  'have sad feeling that dallas is not going to show up got ta say though you think more show would use music from the game mmm',
#  'ugh degree tomorrow',
#  'where did move to thought were already in sd hmmm random found me glad to hear yer doing well',
#  'miss my p it out of commission wutcha playing have you copped blood on the sand',
#  'just leaving the parking lot of work',
#  'the life is cool but not for me',
#  'sadly though ve never gotten to experience the post coitus cigarette before and now never will',
#  'had such nice day too bad the rain come in tomorrow at am',
#  'too bad will not be around lost my job and can not even pay my phone bill lmao aw shuck',
#  'damm back to school tomorrow',
#  'mo job no money how in the hell is min wage here clam an hour',
#  'not forever see you soon',
#  'agreed saw the failwhale allllll day today',
#  'oh haha dude dont really look at em unless someone say hey added you sorry so terrible at that need pop up',
#  'sure you re right need to start working out with you and the nikster or jared at least',
#  'really hate how people dis my band trace is clearly not ugly',
#  'gym attire today wa puma singlet adidas short and black business sock and leather shoe lucky did not run into any cute girl',
#  'why will not you show my location',
#  'no picnic my phone smell like citrus',
#  'my donkey is sensitive about such comment nevertheless he and me be glad to see your mug asap charger is still awol',
#  'no new csi tonight fml',
#  'think my arm are sore from tennis',
#  'wonder why someone that like so much can make you so unhappy in split seccond depressed',
#  'sleep soon just hate saying bye and see you tomorrow for the night',
#  'just got ur newsletter those fare really are unbelievable shame already booked and paid for mine',
#  'missin the boo',
#  'me too itm',
#  'damn do not have any chalk my chalkboard is useless',
#  'had blast at the getty villa but hate that she had sore throat all day it just getting worse too',
#  'hey missed ya at the meeting sup mama',
#  'my tummy hurt wonder if the hypnosis ha anything to do with it if so it working get it stop smoking',
#  'why is it always the fat one',
#  'sorry babe my fam annoys me too thankfully they re asleep right now muahaha evil laugh',
#  'should have paid more attention when we covered photoshop in my webpage design class in undergrad',
#  'wednesday my day do not know what do',
#  'poor cameron the hill',
#  'pray for me please the ex is threatening to start sh at my our baby st birthday party what jerk and still have headache',
#  'hmm do really enjoy being with him if the problem are too constant should think thing more find someone ulike',
#  'strider is sick little puppy',
#  'so rylee grace wana go steve party or not sadly since it easter wnt able do much but ohh well',
#  'hey actually won one of my bracket pool too bad it wa not the one for money',
#  'you do not follow me either and work for you',
#  'bad nite for the favorite team astros and spartan lose the nite out with wa good',
#  'body of missing northern calif girl found police have found the remains of missing northern california girl',
#  'hope they will increase the capacity fast yesterday wa such pain got the fail whale time in hour',
#  'behind on my class for work',
#  'watching house',
#  'remember my bum leg strike back this time it serious',
#  'cool will their are all kind of complaint about this laptop online about overheating but no recall',
#  'emily will be glad when mommy is done training at her new job she miss her',
#  'would rather the first party send bad message than the rd party send mixed one sophmore year all over again',
#  'it overrated',
#  'know heard it this afternoon and wondered the same thing moscow is so behind the time',
#  'laying in bed with no voice',
#  'sooo sad they killed off kutner on house whyyyyyyyy',
#  'sorry tell them mea culpa from me and that really am sorry',
#  'it did not make any sense to me the suicide thing refuse to believe that that is actually what happened',
#  'hope your ok',
#  'damn the grind is inspirational and saddening at the same time do not want you to stop cuz like what do much love',
#  'yeah aw but know wudnt stand chance',
#  'ugh cant sleep it am',
#  'hanging in crooner wan na sing can not suck',
#  'aaw miss ya all too im leaving to bh tomorrow morning think aww wan na go to the beach girl',
#  'is pissed off that there no asba for radio station',
#  'wednesday my day do not know what do',
#  'know my life ha been flipped upside down when just thought in my head that some ramen sound good',
#  'am in pain my back and side hurt not to mention cry is made of fail',
#  'late night snack glass of oj down with the sickness then back to sleep ugh hate getting sick',
#  'but but but not big fan on camilla belle',
#  'wah can not see clip must be el stupido work filter can not wait till get puter something else blame ex he broke mine',
#  'this week just seems to get longer and longer in term of how much need to do and how much actually going to get done',
#  'so cold',
#  'ehhh do not weather gon na take turn for the ugly tomorrow',
#  'haha it so cooooold in the and no but you should still go to the show they do some incredible stuff',
#  'hoping the tummy rumble go away soon',
#  'no no notice they told me be working tomorrow and then called the agency to follow up and they said it wa over',
#  'almost bedtime',
#  'missing you babe but a long a your alive happy ya tired my love imma try to sleep hopefully you had headstart',
#  'agh snow',
#  'miss kenny power',
#  'thank you for letting people know but now sad that the direct message got wa not actually from bridget',
#  'and india missed out it th test victory th consecutive win without loss',
#  'guess that no then',
#  'sadly is going to bed',
#  'shame to hear this stephan',
#  'hey leavin in the morning',
#  'wa intending to finish editing my page novel manuscript tonight but that will probably not happen and only page are left',
#  'laid around too much today now my head hurt',
#  'still have not read the th th princess diary saving francesca made me cry at the end hmm those are easy book',
#  'my nokia died',
#  'my mom might have breast cancer will not find out anything for like week so worried',
#  'going to sleep hoping tomorrow is better day',
#  'lol wish they understood daylight saving ha ended though and breakfast is an hour later they keep waking the kid up too',
#  'that is lame',
#  'do not understand really do not',
#  'hero just is not doing it for me this season',
#  'living not downtown sure is not much fun',
#  'not calorie wise wish junk food wa calorie free ate thing of sour skittle and big as cherry coke',
#  'man work is hard',
#  'getting sick time for some hot tea studying and then sleeeep',
#  'getting eyebrow waxed more pain',
#  'no phantasy star yesterday going to work',
#  'oh just got all my macheist apps sweet did not get the espresso serial no though although they said they sent it oh well',
#  'picked mich st to win it all from the get go wa feeling pretty good about that pick all the way up until tonight lost too',
#  'is alone downstairs working',
#  'feel bad for doing it',
#  'is it just me or she hate anoop mean seriously she kinda mean to him',
#  'yes sprint ha only in baltimore and chicago so far',
#  'stuck awake in the middle of the night for the second day in row and felt terrible yesterday',
#  'thanks for bursting my bubble',
#  'going to school soon can not find anything to wear gosh it so hard',
#  'wa serious lol',
#  'had on my page for sooooo long until it got deleted sad day in history',
#  'crazy wind today no birding',
#  'currently at work',
#  'grrr my ipod acting weird too jai ho and thinking of you are not playing the full song ughh',
#  'send me the dvd co have missed out on heap not happy about that',
#  'do not see the big deal with this website',
#  'so sorry you re having to go through this again therapyfail',
#  'far too out of the way for rail any other tip',
#  'not still up swear why do keep losing gaining losing gaining tweeps so heart wrenching',
#  'today realized am too good at hiding thing even can not find it',
#  'staying at friend house house sitting neighbor are so loud having party',
#  'danny im upset that wasnt here to watch the live chat wa in car for hour on trip im soooo upset',
#  'check out my mug',
#  'border closed at',
#  'downloading nin new album the slip when the hell did this come out so behind the time these day',
#  'just woke up an already have written some mail ve to go early at university today a have to teach at am',
#  'is watching the hill and it making me sad',
#  'so many channel yet so so boring lazy day again may have to find hobby',
#  'miss my buddy ill be in ny on the th',
#  'love the french tell people here in the south qtr french and they snarl at me french are beautiful people',
#  'opps a said still got one day remain and now problem come',
#  'activated my selfcontrol block early meaning can not check out the new qc regularizing my internal clock is might be difficult fb',
#  'oh no',
#  'spencer is not good guy',
#  'what about reese dying on ttsc and season finale next week boring madame president is crazy woman',
#  'hate the limited letter too hope you and the guy are fine pray for my dog she not well',
#  'did not get shit done today so screwed',
#  'wanttss to go out',
#  'is not going to sleep tonite',
#  'too worried and tired to post tonight',
#  'could not get shit done today so screwed',
#  'job interview in cardiff today wish me luck got about hour sleep',
#  'your show is whack way worse than whack it wiggety whack',
#  'really do not think people choose to be that way but think he chose not to accept my family help he might be dead by now',
#  'you re going to kill me but ve not seen d ve been waiting till can do it in one solid week sitting',
#  'think ur right hahaha hr now',
#  'hate to see the spartan so sad',
#  'my mind and body are severely protesting this getting up thing had nightmare to boot',
#  'goin to follow since did not lol go angel',
#  '',
#  'think want to read some book but the library doe not have them',
#  'my nap wa interrupted so many time today going out for japanese with the rent again',
#  'kind of longs for the bus that show up at the end of ghost world right now ugh',
#  'but this is canada canada is weird we re supposed to get snow through wednesday ugh',
#  'awwh babs you look so sad underneith that shop entrance of yesterday musik like the look of the new transformer movie',
#  'sad that the foot of my macbook just fell off',
#  'gon na get up late tomorrow and it am here gon na get tipsy by my lonesome that that just sad',
#  'sweating my forthcoming trip to if can not find someone to crash with while out there may be screwed',
#  'ha now gotten somebody to read his tweet but cant get them to make an account',
#  'omgawd couldnt handle my cat being in heat all the time',
#  'hope can make it to the auburn show but it not looking good for me',
#  'thats people mag haha couldnt fit it all in dont think those picture ever made it in the magazine tho haha',
#  'congrats totally forgot to submit photo',
#  'awww good luck paula please do not work too hard but hope you have fun your new album is gon na be amazing xxx',
#  'now your leaving me get sad',
#  'miss you twitter my phone broke now using stupid nokia phone ughhh miss my advance phone',
#  'shooting outside my house not kidding so scared',
#  'tuesday ll start with reflection then lecture in stress reducing technique that sure might become very useful for u accompaniers',
#  'what tragedy and disaster in the news this week',
#  'yes yes still trying to find picture that will upload correclty',
#  'why oh why wa the red sox game rained out wa so looking forward to opening day',
#  'still can not find my key',
#  'know right dunno what is going on with twitter',
#  'might be getting sore throat again',
#  'my home town my mammy called all depressd pls explain parent let their yr old child walk alone hello it',
#  'think need to find better anti depressant think this paxil wellbutrin combo is losing it efficacy',
#  'restaurant called woodntap ha competitive eating tourney round tourney time we place nd',
#  'is in the bathroom wake up lakin',
#  'want taco and margarhitas telll gay say hello',
#  'im lonely keep me company female california',
#  'bad day at the betfair office',
#  'miss him can not wait to celebrate the tar heel win this weekend though',
#  'really cold do not want to go to sleep yet but there nothing to do',
#  'is this it it officially over me this go round',
#  'monkey just found out you my twin and you wont even write back heartbroken',
#  'aww know felt like that yesterday at work',
#  'treaty is not defined',
#  'missed brent at praise band no fun to not have the your lead guitarist pout',
#  'poor john this is what happens when you play with fruit and microwave seriously though have you seen doctor xxx',
#  'missing my bff watching home and away it reminds me of her and me we it shout out to court',
#  '',
#  'new video card is doa',
#  'feeling lost naked and confused jk sort of no iphone for me',
#  'damn am so late at filling this appraisal form people have almost sent it wa so occupied in work',
#  'missed brent at praise band no fun to not have your lead guitarist pout',
#  'think to much on the past cant change it deserved so much more then wat got but why am still thinking about him gah',
#  'ha lost his ring it no where to be seen',
#  'ooooooh sealclap see download shitloads of zip folder off chan have no internet money fuck yeah alicia mikey',
#  'is still nursing my nile but glad he is feeling better hate when my baby is sick',
#  'is fucked to go back to ic',
#  'yoyoyo my internet ha been rude tonight it just reconnected and about to go to bed',
#  'well have uni stuff and netball but after netbal if ve done uni stuff we can',
#  'me too is poor',
#  'help me forget th april th july',
#  'dierks bentley is comin to columbus oh wan na go so bad',
#  'have to take my sidekick back',
#  'congrats totally jealous only wish my xm wa working',
#  'gr my face is very itchy',
#  'poor sock luvvvvv the golden retriever want one sighhhh',
#  'just saw that they found that tracy girl in piece of luggage how fucking terrible',
#  'aaaaand the nausea is back',
#  'ooh excited and not even going be there long love youtube',
#  'spent hour to reach to axis bank only to find out today is holiday for mahavir jayanti contd',
#  'agree the jobros dont update there very often',
#  'it is hilarious and linked the clip from lj some time ago but when went back just now it wa dead link',
#  'oooooooo who with im not neither but thats because need to study',
#  'have not tweeted nearly all day posted my website tonight hopefully that go well night time',
#  'miss bentley',
#  'seriously need to finish these job application',
#  'my son vinca is sick so stay at home just three tense day at work and am back on holiday with kid',
#  'whinging my client bos do not understand english well rewrote some text unreadable it written by good writer reviewed correctly',
#  'do not want him to ever punch me',
#  'sooo sick of the snow ughh',
#  '',
#  'it doe not work your fan is upset',
#  'would like to apologize for the repeated video game live related tweet am going to have stern discussion with koodo soon stern',
#  'but cant figure out how to get there back pay for hotel etc',
#  'fml so much for seniority bc of technological ineptness now have to register for class again',
#  'feel like she slept the day away not looking forward to any more bout with my gallbladder at least have pill now for the pain',
#  'but what really want is my old bass back',
#  'mad tired today callin it in early tonight nighty night twittas',
#  'take it easy and be good to you',
#  'afraid had bad code',
#  'think going to bed goodniight hate this',
#  'here friend and love you',
#  'all this time you did not notice wa gone just needed db is it',
#  'is in the bathroom and have to pee',
#  'but wanted margarita too',
#  'yup night workout the worst but unfortunetly my work schedule only allows me to go at night it tough',
#  'just called hillsong again they said they could not tell me where wa on the waiting list do not know if it looking so good',
#  'ha of milky bar left and around ml of coke',
#  'it stillllll ha not arrived',
#  'mraow feel like dancing but first art school want to rape me some more',
#  'ah bet it doe ve been like craving to play softball or basketball but have noo time',
#  'is terrified she accidentally deleted reference in her management assignment and hope she doesnt get in trouble when she get back',
#  'amazon plugin not worked in my website it need php but my hosting provider ha only php very sad',
#  'argh wa suuuper sleepy an hour ago now wide awake hope do not stay up all night',
#  'wish wa sold out if you have some time let me know would love to hear more about what you are up to',
#  'just watched tropic thunder dreading tomorrow',
#  'no he still miss',
#  'chiefdelphi is down',
#  'according to my bro our new puppy had poo fight and wa covered in poop picture stolen from him',
#  'playing game at home my new bos did not call me yet',
#  'su yin huen tweeted feel unbearable guilt made my staff cry',
#  'poor joshy is sick those damn tejanos',
#  'my thought are with sandra cantu family at this difficult and sad time',
#  'know just wanted to let everybody know what wa happening',
#  'michigan who do not know them sigh shameful',
#  'have to fill two hour',
#  'so cuuute hey miss you na it not the same not seeing you girl everyday',
#  'oh did mention it gooooood moooorniiiiiiing from germany im back in my cage or better my office',
#  'throat is closing up and had some string cheese not good idea',
#  'aww sandra cantu is found dead in suitcase missing child story never seem to go good poor family',
#  'wishing wa home underneath my cover',
#  'walking home from school drain all my energy',
#  'agree the shapeshifting is copout wa so excited for angela ep thought it wa this week noah wa awesome tho',
#  'dang would have done this if knew it wa there earlier any other outing planned',
#  'wish wa better at writing it taking me so long to write this paper',
#  'and of course have access to my halo mythic map pack re download but bad news not the legendary map pack ugh m',
#  'not yet unfortunately another few week ve been told how are you ve been little bit busy with my latest project',
#  'ha the sun already gone',
#  'day lot harder than day let see how day go tomorrow',
#  'my man crush jake peavy let me down gayforpeavy',
#  'megafast trip you have time during day tom wed or you going out tonight want to see you bad tried to warn you tech fail',
#  'michigan state you make me sad',
#  'omg my mouth is in so much pain just wan na sleep untill it time to take my brace off',
#  'getting annoyed easily today biofuel proposal getting annoyed easily today biof',
#  'hey girl the site is back girlyvue is back and they have even more video',
#  'spending time with my grandma early tomorrow and can not leave skittle by herself',
#  'just got home from watching michigan state get tromped',
#  'oh jew bus two year worth of class work is alot to organize not finishing tonight it not possible my bone ache',
#  'no exchanging for me my laptop ha not arrived',
#  'hope this doe not last too long feel miserable',
#  'rachel hang outage is neccessary wa gon na be home this wekend but dumb folk make me work so im free and sat until',
#  'not fun furious the new mantra for the bay breaker it wa getting rambunctious the city overreacted clamped down',
#  'my hubby for some reason think it more important he ha good spot for red carpet for the trek movie premiere sod',
#  'swear no matter how long ve been getting up at am it never get any easier man my eye hurt wah',
#  'jeffree how do you keep your hair one color my permanent dye fade within the week',
#  'my reaction too whoa did not see that coming',
#  'still sick feeling bit better got some new medicine hope feel good after night of sleep ohh and it suppose to snow wtf',
#  'think maybe you should get couple more hour of sleep hon how productive can you be right now if ur dog tired worry',
#  'thanks lot learned lot of new word but did not find what wa looking for',
#  'wish had all the xblm downloads all on the gamertag hitokyri this gamertag thing is nonsense and tired of it',
#  'new testament test at am',
#  'ton no hay troll ahhhh',
#  'stupid movie we watched mirror ugggggh stooopeeed rip off',
#  'love you buck',
#  'last one but still not done',
#  'homework',
#  'do not understand why thing get taken away did not have enough time with him it unfair want him back he wa like my baby',
#  'scratch that du in heif two in half cooky my tum just can not take anymore shoog poots',
#  'wa just listening to the sweet for the first time in forever miss them so much can we go to chi town for visit plz',
#  'geez what busy afternoon meeting email meeting and email and more meeting pm and the day is still going ah it dark and',
#  'dang another spring break how cool is that too bad have to work all week oh well more money for phone ttyl everbody',
#  'im afraid too ur reply about uni from age ago',
#  'feeling down',
#  'lol they are some emotional as men omg all this late night eating both of u are broke',
#  'aww nick like your hair longer why did you cut it off break my heart',
#  'wonder if jon lost the net',
#  'wow the most depressing thing in the world is losing video that you ve created in matter of second fml',
#  'but all say not in stock',
#  'lmao im sorry poohpot ate it all',
#  'any chance softbelly for is not loud',
#  'time to move my posterior and lose some fat my articulation are creaking so no more running but drool for some swimming',
#  'listening to nathan cry',
#  'today sucked gon na die without chris and callum wahhh',
#  'stou site not update no info about exam and open course must wait for mail notice and doc um',
#  'sorry feeling kinda yucky myself am is going to come too quick',
#  'is in love with scrappy and is missin him already',
#  'want to hear song but myspace is messing with me',
#  'bad news wa dad ha cancer and is dying good news new business started and am now life coach practising holistic weight management',
#  'man intervention is soo sad',
#  'help need new boyfriend stuck in rut',
#  'feel like complete idiot the only one who doe not get how this shit work help me',
#  'saw an ad on craigslist for casting call for female host on wa totally psyched but realized it wa hoax',
#  'pepperoni roll in called valentino they said that they had sausage roll but no pepperoni roll',
#  'yes it will be it only monday',
#  'want the new gg episode already',
#  'miss watching rocko modern life',
#  'rip sandra it so sad how can someone do something like that',
#  'keeping my finger crossed for my buddy he is not feeling well',
#  'wait should eat or be skinny for vega hungry',
#  'tried tweetdeck once and hated it with passion or it hated me not sure',
#  'btw my iphone is acting funny dying quickly and freezing and b not admitting anything just sayin',
#  'sitting here wondering why ed still ha such strong hold on me',
#  'im sorry got you sick lol going to bed too night',
#  'no internet at home have to drive into ox to use internet because of builder',
#  'the weather in canada is freezing',
#  'twiggassssssss been out of range all day back now and hopefully for good',
#  '',
#  'anyone who read this pray for my grandma she in pain',
#  'woke up and wa having an accident it pushing it pushing he wa cry because he could not stop from wetting his pant',
#  'home from franklin street almost jumped over fire someone kicked it before could jenny lost her shoe',
#  'hey you just changed your default',
#  'finally gave in and wa bored enough to start this thing think the is going to be problem for me tho it like myspace status',
#  'if oooonly we were really so lucky eh and awh definitely too early for work',
#  'buttload of homework',
#  'need another copy of visual studio',
#  'why to we the only school in the world be in this week my school is silly anyway look on the bright side when off will be in',
#  'omg ve an economics test and dont know all the thing have to know and omg im gon na fail',
#  'once upon time hundred island wa the pride of philippine tourism but coral clam rare fish poaching did it in kinda sad',
#  'yeah apparently have really bad taste',
#  'know wa really surprised since everyone recommends them on youtube have to call them tomorrow and figure it all out',
#  'waiting at the airport for my ride while get harassed by men trying to sell me ugly hat why me just want to sleep',
#  'left my id at the location and now can not go out to bar fuckkkkkkkkkkkkk',
#  'sorry do not understand your last comment',
#  'when is the announcement stayed up late last night',
#  'this is strange illegal torrent avlbl everywhere legal dvd not in stock what do do now',
#  'it not enough to say that imiss',
#  'this trolley ha up packed in like sardine padre game and they remove car good call mt',
#  'jeez wa just trying to help haha',
#  'that happened to me saturday night along with my glittery green lighter',
#  'trying to reduce the number of cigarette in each day',
#  'yea it is so quiet around here cuz everyone ha to work im bored to death with nobody to talk to',
#  'got ta do my cooking assignment it too hard',
#  'okay about the applepears ve talked to few people and they ve all had them before no one ever told me never',
#  'know night owl by nature hahaha am time zone behind you it almost here',
#  'lol nope but did have complete camerafail',
#  'but useless if do not sleep it not fair want all the fun a well',
#  'my pookie ha uti have to be nurse gabbie and get him back to no more soda',
#  'tweet something damn it and hang out with me please',
#  '',
#  'so behind in video game and everything for that matter yesterday news',
#  'did it wa the only one left but got tempted and ate it soon a got home had chocolate velvet ate mocha',
#  'is stressing out because my blackberry keep flashing red alert status for no reason it faking me out and hate it',
#  'wan na wear my doc marten out have not worn them since december',
#  'when to the shoe repair shop and the guy could not find my shoe so have to go back and see if he can find them in couple day',
#  'did not really see that coming',
#  'just woke up from the most vivid sketchy not cool dream of my life time to stare at the wall with the light on',
#  'it ll take day for my sister to get her passport',
#  'oh my yes miss',
#  'uh oh think am getting sick',
#  'good god they ruined my belly button',
#  'watching who framed roger rabbit make me miss toon town',
#  'renting but very cheap renting and awesome house we had buying attempt fall through',
#  'running nose spinning head not good combination for meeting',
#  'negative you lost my vote of confidence',
#  'nasty budget due and my iphone is being sent to apple today',
#  'that bad',
#  'dammit episode of king will not play for some reason stopped in the middle now will not do anything',
#  'so upset that missed my chat and quiz online because my free internet ha ceased',
#  'can not believe it in disbelief of it all in way really how much can take from people and always get hurt by others',
#  'car show season ha started without me',
#  'my throat is raw',
#  'just do not get it what in person mind could even have them on some ish like this my prayer are with her fam for real',
#  'hate you did not need to see that need to call my therapist now',
#  'twilight did not come yesterday finger crossed for today',
#  'glad wa able help you feel better hate to see you sick love you',
#  'is tireddddddd want to sleep but have an assignment to finish and an exam tomorrow to study for',
#  'you know wa thinking need money',
#  'omg it jst teusday',
#  'ummmmm cant find it',
#  'just heard that they found sandra cantu she wa only yr old',
#  'ive forgotten how to snoo snoo wonder if snoo snoo and will ever meet again',
#  'wow that last tweet made me seem like giant sexist sorry about that',
#  'my bathtub drain is fired it haz job do it iz fail got all drano on it as iz still not draining wan na shower dangit',
#  'stuck at home',
#  'mine is how do you get it up',
#  'duckling in famous child book stolen from boston public garden the boston globe via oh no',
#  'thank you however hate to be on the same list that includes convict',
#  'heading to altrincham again out of hour install',
#  'morning good im bloody knackered work is not for me today helppp xxx',
#  'do not have garage but you can park in my driveway',
#  'what happened',
#  'on popular music by adorno is probably the most difficult reading ever prescribed actually struggling to continue',
#  'cant see the flower falling dont have camera just my cellphone',
#  'we ve been good not liking the snow right now wa getting used to the nice spring like weather how about you',
#  'what pity youtube is currently blocked in china can not see the vids',
#  'what happened to your show it wa the hightlight of my life',
#  'this is the best leather sofa in the world it in the office though which mean still here working',
#  'still more day until my internet get uncapped',
#  'if he doe not get better in few day he could have something lodged in his belly',
#  'love my atekinzz so much soo miss her',
#  'wan na sneak into the zoo and play with the kitty',
#  'oh no hope you re not getting sick too',
#  'dont think can cause it my cousin birthday party',
#  'our sweet little man just fell asleep while waiting up for daddy and big brother to get home poor baby he missed them so much today',
#  'the angel is going to miss the athlete this weekend',
#  'trust is hard',
#  'have watched that considering today yaknow shawnna tomomorrow need my bestfriend',
#  'grr want to keep reading but if do wont have anything left to read',
#  'atekinzz where in the world are you',
#  'no supposed to be my date',
#  'pear brie bottle of cabernet and win date with tad hamilton oh gawwd my life flashed forward to when with my cat',
#  'crap need more dress too',
#  'yeah know it wa horrible ugh saddening',
#  'geez ur no fun are you',
#  'wan na be in punk rock band again',
#  'that lot of angst for tuesday afternoon',
#  'very glad britney is not crazy anymore that wa one hell of show now sad that it over next up ap at cook county',
#  'ha huuuge headache omg feel like crap',
#  'sorry',
#  'sorry wa rooting for them too',
#  'man that took forever',
#  'see',
#  'am listing more item on ebay to sell take forever meanwhile coleman is watching the hill season premier without me',
#  'just got my presentation done slide done cry for this week will be the hardest of all week',
#  'just lost',
#  'do not like the previously on skin thing that start at season two like it when it went straight into the intro like before',
#  'wish wa there pretty good at scaring the shit out of people',
#  'going to sound vain but running out of my fav lip gloss',
#  'never again will click on link that scream spider spider should have known better yucky',
#  'why is that when you have time off from work you get sick',
#  'same imac came out more in indonesia than the state',
#  'dammit need to stop buying furniture',
#  'no wa half asleep and turned off the laptop after that',
#  'death is peaceful life however bite',
#  'think lost the net sure hope not',
#  'and test footage with my girlfriend in hd the dark one is underxposed',
#  'such tough game to watch tonight for state finally going to bed after also staying up to watch the season premiere of the hill',
#  'seems jruby support for hpricot is now two version behind',
#  'unlike my sister still do not have one',
#  'fraking app store is pissing me off',
#  'logging out need to study',
#  'anyone else having problem accessing ttb cant get on',
#  'strongly dislike people who make stupid comment and dont know the whole story',
#  'sorry emma is swarley goldfish sad for',
#  'all my tweet are already gone are not they missed you guy tonight',
#  'can not sleep again face is kinda swollen do not let me be allergic to the thing that ll get me to thursday school tomorrow doubtful',
#  'if izzy on the cat tree she ll stare him down but if she on the floor he chase and she run',
#  'am officially banning godaddy com from my comp my head hurt from the small print and wasted that could ve happily gone to boba',
#  'pretty much just scary for me',
#  'mine too finding it well hard to get fit',
#  'good morning ready go but want go back bed',
#  'hate waiting for mail',
#  'wheat bread from the dollar store just doe not toast nicely going over my tax and calling it an early night',
#  'why kutner mean knew something wa going to happen to someone but it wa so sad house and it wa well done but still sad',
#  'aw ok goonite',
#  'ill so cant go to the cinema',
#  'fell asleep really did not mean too christina',
#  'hey you remember that time we used to be friend ugh vomit sick need sleep',
#  'my lymph node are a massive a rahm emanuel ball right now',
#  'oh no my computer suck do not think ll be able to listen to the xbox fancast tonite',
#  'is missing playing my trumpet',
#  'my throat is still really sore wa meant to be going on day camp from friday but not so sure now',
#  'know exactly how you feel',
#  'at work',
#  'well bed time now am sigh back to am morning for week on wednesday',
#  'jesus camp yeah',
#  'oh no with everything that happened today forgot we were going dress shopping for the opera tomorrow',
#  'turtle are better than my mac last longer and move faster',
#  'am soaked this is not pleasant',
#  'sorry to hear about maggie thought to your mum',
#  'you may have to email this one to me hope you feel better',
#  'dead yu gettin on wen im leavin',
#  'please tell me that somewhere close to california lol',
#  'where are you',
#  'stupid arranged marriage ll convert so you can marry me love you',
#  'well he said that he is looser and that is what the show implies',
#  'poor sandra cantu the cantu family my prayer go out to them what sick world we live in she wa only',
#  'fuck omg austin always there though man love you',
#  'cried so hard when matthew died',
#  'sad that the foot of my macbook just fell off sad that the foot of my macbook just fell off',
#  'why am the last to find out about these thing like that you re on the twitter too',
#  'absolutely not',
#  'filled with curry the true indian in me is coming out',
#  'im soooo cold right now',
#  'lol kant believe cam got beat upp sooo embarasssiiiin',
#  'good knight hun looking forward to ur tweet again hate that keep missing out on the fun cuz of the time difference',
#  'tumblr this is exactly how it feel wearing tie',
#  'hahaa just realized impune definitely isnt the word wanted dang so unclever',
#  'watching old video of dance team and such make me miss it',
#  'wahh no csi anywhere dvr ed love money though gon na watch it then sleep goodnight tweeter',
#  'struggling hard with inventory',
#  'do you hate u please do not',
#  'haha im not that ballin still got bill to paaaaay',
#  'in one of those day when really just want to work from home crap',
#  'wait is it game or just episode so confused',
#  'haha cried guess he did',
#  'do not get statistic it all bunch of mumbo jumbo for me',
#  'got it sadly only work for uk u at the moment',
#  'evicted',
#  'doe not enjoy learning cs',
#  'brian do not make me fuck up lol replied ur message did get my miss',
#  'dvr it and went to watch it apparently the dish network went down so missed it will have to catch rerun',
#  'lmao may have to wait for another season to come thru it summe boo hot nd dry as weather',
#  'can not set my foot on the ground the missing eyelid people might get me',
#  'my english professor would be ashamed',
#  'wish the frog were not becoming extinct',
#  'came home from cross county tired a',
#  'do not want to walk home in this snow who want to pick me up',
#  'lauren is being stubborn she love you you love her feel so bad for you though it made me cry lol',
#  'is grouchy and want bmar',
#  'my heart is broken every morning dropping foo at pre school now understand when mom say he ha my heart broken',
#  'not feeling well and back hurt',
#  'im in the mood for some chocolate want miniature reeses cup now',
#  'can not take this heat it like an oven in here feel sick nwo',
#  'come to the chat just minute please',
#  'boredd colddd internet keep stuffing up',
#  'had horrible nightmare last night which affected my sleep now really tired',
#  'im lonely keep me company female new york',
#  'lost and it wa st ignacius prepatory school haha',
#  'yeah it wa really depressing stuff like that get to me',
#  'no problem tongue in cheek remark lot of acronym but no nz',
#  'hey you said matt wa gon na go all ballistic wa disappointed good ep tho mostly',
#  'ugh horrible ending to the sandra kantu story prayer go out',
#  'hate allergic want puppy soo bad that ve already thought some cool name',
#  'morning folk am yawn up away to see to horse hope twitter is better behaved today last night wa travesty',
#  'miss mine too',
#  'sorry to hear about your loss there have been many this year so far',
#  'gossip girl wa repeat',
#  'reckon',
#  'finding it really hard to use twitter',
#  've been stuck in this house for two day',
#  'is really sad and doe not really know',
#  'no',
#  'maybe one of these year ll get tax return girl can dream right',
#  'back at work tired a hell and feel cold coming',
#  'april th is not coming soon enough',
#  'cream for his eye and he may have herpes not ocular herpes but different strain he doing okay though',
#  'got ta repeat whole art folio cuz old one with whole term work got wet',
#  'ready for the weekend already it only monday',
#  'umm nope think im an insomniac plus got the flu lll be sleepin like phuckin fish outta water any minute now',
#  'ha finland sleeping for the night not really enough time',
#  'can not wait to try em but prolly have to wait until next weekend at the earliest',
#  'shiner is taking up all my bed and blanket',
#  'april th is not coming soon enough',
#  'want to cry',
#  'need to go to the bank tomorrow before go broke',
#  'this earthquake in italy ha me sadden it only three hour away from naples where my family is',
#  'should be sleeping have stressed out week coming to me',
#  'yea am working tp hack my server to do the player thing for folk',
#  'ha hurt her ankle and is going to the dr',
#  'oh no how did you manage to send something to the trash can and empty it without noticing feel for ya',
#  'lost my free copy of radioactive so can not put it on my ipod grr and can not go out buy nother coz it came with that paper',
#  'doing make up shit',
#  'photoshop hate it when you crash',
#  'vacation make me feel sick',
#  'you should not have gone',
#  'listening to murd and th wonder just chillen out missing my crazy sex life',
#  'shooting be careful luisa',
#  'sure everyone ha ruined my gift to you whitney ha my serious cell we doing easter a well',
#  'is at beso in hollywood so tired',
#  'do not want to wake up early tomorrow damn you work',
#  'just finished watching the movie prayer for bobby broke my heart',
#  'is myki really horrible',
#  'had put my dog down today too someone ran her over',
#  'sorry to hear about your dnf run tonight always risk to get bad coords on an ftf',
#  'did get some disgruntled people when wrote my esn but the hit in one day made up for it bill pull in top',
#  'ohh omg lmao cry right now lol kutnerrrr wa the best',
#  'came back from running and took shower why doe my lower stomach still hurt after exercising',
#  'watching fallon with mom and working on project school is hard',
#  'min till home time and counting have craving to visit the mac store but they will have closed by the time get there',
#  'am so sorry to hear that take care',
#  'hmmm greed is good when it motivates the individual to do better not so much when it take away from others',
#  'brat you have to rub it in do not you want mocha',
#  'kutnerrrr why why and to think that is still on the show ugh kutner kal penn you ve been the bright star in ho',
#  'my mom ha it wish you the best of luck',
#  'so hate homework my head hurt so bad',
#  'got the ebay blue item want jumped from no bidder to over in an hour still ha hour to go better not get my hope up',
#  'know wa little depressed that we ate so much last night there were no leftover today',
#  'well the pc in my living room suffered fatal partion lost all my itunes library is gone and some doc with pic',
#  'sad day manu out for the season',
#  'you poor spunky it so sad my rotti made it to and had to go down the same path know how you feel',
#  'im sooo sad right now need hug',
#  'want her step brother home im so worried you dont even know hope he know how much care for him',
#  'just got done watching the hill loved it excited for the next episode and im sad this is the last season',
#  'aww that stink hug',
#  'tired feel like crap and the world feel all crummy make me happy usb disco mouse',
#  'dont want to believe what im reading buu so sad',
#  'wondering why gamebattles is down',
#  'white trash v u we were outnumbered',
#  'so true have it and do not use it',
#  'spring break is here at last but no one is here to celebrate',
#  'morning bah car will not start waiting for the anwb',
#  'which is pretty anti memorial tattoo but for all but the strictest there no official ban just disapproving family',
#  'balamurugan longterm member of the team is leaving this month we ll miss working with him hope he doe well in his next venture',
#  'it sad knowing how they found her body what crazy world we live in no child deserves that ya know',
#  'wan na rock maxi dress coachella but lacking funding',
#  'of course the baby is screaming in the crib the night before my first day back at work so let him cry it out boooo',
#  'am home missing my baby busy week ahead fri is chill day with my guy and kid egg hunt sat spiral and dmb sat night and easter',
#  'never found her everytime click on her twitter thing through your myspace it go to some dude page',
#  'that horrible sorryto hear that',
#  'cant find it it say dtmafiaofficial doesnt exist there jus dtmafia found dun seem to followin it wht to do',
#  'thought you would support me on this',
#  'augh eff sarth stole some of mil nail polish it pretty',
#  'wish wa on the spring fling tour with dawn neecee sigh knight',
#  'the hoyts distribution nz website is not working for me great and it ha to be like this when need it most',
#  'do not like that they only had him in the first movie cillian murphy is hot',
#  'wish for good old cartoon to come back ie captain planet where wally daria sadness',
#  'not feeling good abt myself',
#  'just got text from sarah',
#  'another day at centre point this time an early start so guessing train will be rammed with commuter',
#  'four game this fall modern warfare halo odst brutal legend and bioshock need more cash',
#  'ugh that disconcerting',
#  'actually the whole site ha finally been taken over by those damn russian',
#  'my tweet arent going through',
#  'just finished delicious breakfast my last in paris ll miss milk europe ha the tastiest milk in the world do not drink it in u',
#  'ilearn is down and out great considering final are this week',
#  'stressed outttt',
#  'also shouldve bern asleep an hour ago',
#  'trying to figure out this twitter thing none of my friend are on yet soo much to see',
#  're pinging custom icon made look cool but the edge could be le square might look bad on diff background',
#  'want to be back in la',
#  'dunno how to use the forum and get frustrated with it ll miss talking to you on here',
#  'not an option',
#  'unfortunately one of those moment wa not giant squid monster',
#  'want one too is the branch in midv open too',
#  'aw sorry to hear that',
#  'change of plan we ordered mac instead time to hit the book',
#  'yup',
#  'did you see donnie tweet stats almost reply and no jrk',
#  'nah have not received my stimulus yet',
#  'just seen ur tweet plz write bak if get this havnt got one reply bak',
#  'and you were trying to go to sleep hour ago',
#  'so sorry to hear that it always sad when we lose those close to u a we loved them',
#  'cant sleep but im still feelin like piece of shit',
#  'oh my sympathy it hard decision always hope my old border collie will go in her sleep she too hug',
#  'well there wa this really cool part where wont spoil it',
#  'doing the time warp without you and am sad',
#  'this is true lol but it still slap in the face after such warm end of march',
#  'hate converting movie just to put em on my itouch',
#  'gross have pimple',
#  'yea ma naaaaaaaaaaaaaaaaaaaam marwan accent lol',
#  'one le follower tonight',
#  'so did your mom last night brb while figure out whether just burned you or myself the most',
#  'feel like am the only twitterer not on tweetdeck',
#  'he ha karate tournament in week',
# ...
#  'up way to late to be working for client am fb',
#  'blegghhhh have to go to work',
#  'back at work john muir dr',
#  'emailed you yesterday and never responded',
#  'it going to be long year for fan',
#  'just got done watching the new house episode definitely one of the saddest episode ever',
#  'man tax suck horrified that did something wrong on them turbotax decided to keep around lot of the stuff turned off',
#  'sleep time tomorrow is gon na suck',
#  'wtf not kutner oh so pissed house mean really wtf',
#  'know dont know why said that',
#  'cash rule everything around me',
#  'just picked up some oat from the market to eat for breakfast with my boy now time to do work at usc late night',
#  'feel sick too much icecream',
#  'this computer doe not have shockwave blah no account yet',
#  'could go but it in sydney',
#  'hahaha suriously feel like everyone know this show is joke except lc',
#  'just can not spell today totally suck',
#  'are you vaccinated against chicken pox should vaccinate my yr old am so confused about this damn thing',
#  'school at least last day',
#  'ya got ta get up early tomorrow who ready for the weekend',
#  'miss being at home for calving season sad that black one died this morning wish had some bottle calf',
#  'so sorry for your loss my brother dog sam is sick cushing disease',
#  'back to work get to spend the next hour alone in the dispatch room',
#  'there new kind of starburst favereds sound fab bc cherry and strawberry are my fav red but they added watermellon and it yucky',
#  'well so much for being productive on my day off from angel',
#  'oh gee insomnia suck have you tried melatonin',
#  'good to hear that we have support in netbeans but then it netbeans you know',
#  'wish we would get it the same time at the rest of world unfornately am in cairo and have to wait for mtva to play it',
#  'heartbroken over little sandra prayer are with the family',
#  'at word it all can do ll finish tomorrow maybe',
#  'how come ur background cover the screen but mine is in the corner',
#  'wrote exactly three line of dialogue tonight then gave up',
#  'my only complaint about facebook is they ve changed it so much it confusing',
#  'sliced my finger',
#  'going thru town and traffic on bypass is stink',
#  'ugh can not sleep wish had good cuddle to make me as out',
#  'hate when software update downloads update without telling me never know what downloading when it is',
#  'went to ihop again great for diet at least there were no kung foo pancake this time rachel',
#  'the internet is hating me night pose',
#  'so jealous missed all of opening day this year',
#  'it so cruel having to wait for review to come in so far it look like star trek will be the best film of the year',
#  'debating if should just shower now so can sleep little later tomorrow',
#  'my stress always culminates with physical pain',
#  'need to sleep but cant',
#  'my little pinky finger hurt so much',
#  'sorry your gift card ran out that suck',
#  'home for spring break no one is home tho',
#  'accessed oneindia mobi from google phone android it doe not support indic language',
#  'why doe school take over your life so much you do not get sleep anymore am still doing school work and have more to do a well',
#  'aw wish could can not really speak to my yia yia because she doe not speak english',
#  'no free comp lol',
#  'getting ready to clean the house from top to bottom',
#  'cry my friend is moving away tomorrow',
#  'stop nomnoms you did not share night people',
#  'think she is getting cold that she caught from daddy oh no my trip would be ruined',
#  'yeah is it bcoz kal penn is visiting lecturer somewhere cant be on the show anymore im gon na miss him',
#  'so the procrastination start early in the quarter do not want to reaaaaad and write paper',
#  'what apparently it degress at pm in washington state miss winter already',
#  'being bored at homee',
#  'massage wa great just spilled coke all over my desk lame watching the simpson a ve finished all my hill dvd',
#  'will wait for you at fanclub chat even tough you re not my favorite',
#  'ha mild left inner ear infection and it got this irritating blocked feeling since sunday',
#  'hey there nope my cuteness is away for awhile',
#  'it only tuesday',
#  'haha not even yo just did not know how to do that to you on twitter haha',
#  'someone alarm clock or phone woke me up at am still got my headache from yesterday night',
#  'puppy is she ok',
#  'might break down and eat some buffalo wing tomorrow',
#  'sittin here kayla really really reallly dis like having brother he doe not know when to stop waiting for the day when one of',
#  'fed bokkie too many birthday treat sicko',
#  'kinda bummed an agency just told me that did not have the look that they were going for lady please help me create the look',
#  'work laptop is officially dead not happy at all',
#  'my goodness it freezing down here',
#  'why do you put up with him you should listen to your mom',
#  'is stucked in paris and can not even travel into france for work',
#  'do not think there one close by last time checked the closest one wa mile away',
#  'aaaaand back to my literature review at least have friendly cup of coffee to keep me company',
#  'am worried that will not get my even though paid buttload of tax last year',
#  'okay so still no school',
#  'is phoneless now off too sleep',
#  'reeked of alcohol at the dentist this morning wa drunk when put on my tshirt realised it had huge stain dentist looked disgusted',
#  'it is really cold',
#  'cant sleep she want to dream',
#  'can not sleep hate these night when try to go to bed early and stay awake for hour poo',
#  'yeah too bad people like certain burrito eating man exist',
#  'that sad',
#  'just found out that my mum and my adopted auntie are on twitter check them out my mum is tessm and my awesome a auntie is tania',
#  'can not sleep wide awake and got ta go to work later too boy am going to have crappy day',
#  'struggling with eam law',
#  'why can not sleep like her',
#  'bout to start poor linny could not keep her eye open she tired and ha to work tomorrow morning night',
#  'my year old year old is driving me around the twist do not want to be like this',
#  'well that sucked',
#  'have to be out of my place in day any help can get packing painting cleaning is much appreciated oh and rip my wall',
#  'opening partially frozen beer beer on the toaster under the oven and all over the counter the kitchen smell like we run speakeasy',
#  'no dont even know how to ride it',
#  'sadly yes think need counciling now',
#  'making myself ready for school do not feel like going but have two test',
#  'smugness gone my train also failed to turn up so heading for victoria followed by an unpleasant tube ride to the city',
#  'anybody know where my ipod went',
#  'aww this earthquake in italy ha made me sad just saw the pic on the news it terrible',
#  'never been able to afford to get them out much rather go through the extraction than continue with what deal with now',
#  'why do other pet care people try to run others out of business or send suspicious mail fishing for info',
#  'codez they ve been mia tho',
#  'doesnt work on my cell go to sleep',
#  'it going to be nice again tomorrow and then the rain come back no nice weather for my birthday',
#  'rock band is hard on expert',
#  'roomie wa home all day all he had to do wa scratch at the door comforter ha to goto large laundromat machine',
#  'one of the hardest thing with this schedule no one can chat with at the end of my day usually',
#  'they killed off character on one of my favorite show and now upset',
#  'jealous of my friend who got to see the new star trek film in austin tonight',
#  'listening to got really bad headache and drivin lesson in ten min lucky me just wana sleeep',
#  'shut up you am hungry and in britain home of the most boring suckassy breakfast in the world miss dennys',
#  'good morning everybody pkoi fais pa beau bon coffee time',
#  'work again',
#  'essay time',
#  'hey did talk to mom they home yet hope they ok wish wa coming home easter',
#  'sure wish could go with you guy tmrw but a per usual school interferes',
#  'say what kal penn leaving house noooooo totally missed it tonight',
#  'no lost loyal',
#  'played another hand very bad and lost half my stack',
#  'it pm early day in looooooong night at work',
#  'it sad it the last season wan na see when spencer call lauren',
#  'so im done editing the phipstape back crack brew and see what we got no tree though',
#  'do not know what half of that mean',
#  'homework homework homework',
#  'worked his heart out today doubling my weight at each station result stiff and pulled muscle ouch',
#  'now feel bad for unfollowing',
#  'so tired god hate the new job and only two day in',
#  'sad about kutner being killed off my fav show house',
#  'happy for coach stringer hof now if can only finish my term paper on her',
#  'feel like shit this is not the way want to spend my birthday eve',
#  'so far have on all my site put together most of them were me checking out the update made',
#  'ha lot on her mind need to make some money and idea nowhere is hiring',
#  'miss you',
#  'so sorry to hear about your dog',
#  'too much internet how it plague me',
#  'miss my ex soo much',
#  'sodding',
#  'oh thought the pirate bay trial verdict wa today apparently it in day',
#  'call me back',
#  'is in study hall now and will log off immediately',
#  'it so tired that im cry for no reason at all im about to try to get an hour and half in for tonight half what got last night',
#  'totally have like four girl option and none of them seem viable',
#  'so far have veiws on all my site put together most of them were me checking out the update made',
#  'listening to bjork all is full of love cry',
#  'omg the hill then love money aww think becky buckwild go',
#  'is craving for some tantan nabe',
#  'mon sean man',
#  'watching league of their own make me miss mint chocolate ice cream cone and my grand ma fuck',
#  'lost my phone some where maybe in the grass it just so long hope it doe not rain',
#  'hope you are not referring to me say hello to your new stalker lol',
#  'why were sleeping ur gon na be up all night now how wa ur bike ride',
#  'but but but wan na listen to the master too',
#  've been looking about for good stuff to write but also been doing load of uni work',
#  'feel unloved dropped tweeter',
#  'off to london for the day on thursday it gon na be raining oh fab will not see much on the london eye still robbie will not care bless him',
#  'completely wiped and reloaded the lost all bbm contact going to bed sad',
#  'sayyyy whaaaa wa not invited',
#  'did not sleep too bad considering have workshop starting today beginning of sore throat though',
#  'oh my gosh that made me emotional haha idk why dont want to get old',
#  'we re going to post some story manually due to twitterfeed problem that why we ve been so quiet lately',
#  'do not like lukewarm shower',
#  'who should contact if need for freelance work did on linux com throughout never got one',
#  'connor it me febi are you really really mad at me',
#  'need some help want to buy macbook pro but still inlove with my old powerbook',
#  'man america is so borez anyway lol just realized you sent me msg on here had no idea have no flash',
#  'knight lovely lady sleepy now',
#  'doe anybody know how to get your electrolyte back in order with vitamin work feel sick',
#  'yes someone ha not been reading my post properly',
#  'almost through with my italian homework weeeeee now if only understood what wa doing',
#  'who turned the light on it will be time to get ip then',
#  'twitter hate u both then',
#  'hate the fact that genuinely excited about my last tweet',
#  'can not sleep either',
#  'between that and the italy earthquake it been very sad news day',
#  'all rain today garden really need it so not quite so bad',
#  'yawn yawn yawn more minute in bed',
#  'ouch sound very sucky',
#  'great idea with the itunes promo code they do not work in the uk itunes store though',
#  'cry',
#  'an empty rum barrel is sad rum barrel shake head the horror the horror',
#  'it wa sleepless night',
#  'she admitted to being fake',
#  'love chutney',
#  'got highly bored today scanning page for daddy had to do it',
#  'you cooked risotto without me',
#  'keeeerrrrriiiiii really have nothing better to do then post on this thing at am wonderfullll say alot',
#  'yay for baseball season boo to yankee losing their first game',
#  'lost suck because have to work today',
#  'omg exam killed me how could not know the difference between haif circle and hemisphere',
#  'in bed suddenly feel wish ma wa here me goodnight twitterfam',
#  'do not like goodnights',
#  'greaaat my lappy will not turn on wtffffff',
#  'you stuck in traffic then my journey wa traffic free this morning if it any help',
#  'lookin like an all nighter hate it when do this to myself',
#  'you re stranger',
#  'debbugging old vb code the day could have started better',
#  'only quarter of percent babe darn',
#  'coming down with cold or bad allergy either way miserable',
#  'can not believe cutner is dead on house sad day in santa rosa ca',
#  'damnit wa really digging this season of reaper',
#  'gah comcast doubled our cable internet bill out telling u so we are quitting can anyone suggest an affordable company in bay area',
#  'another early morn with the duchess although she had not managed to cross her leg this time',
#  'you left without saying hi',
#  'want but can not sleep',
#  'when an xbox show those three red light it mean it dead and need to be fixed for month at microsoft hq',
#  'king sized bed is nice but sad and lonely with no hubby puppy or kitty am over this whole conferenceing thing',
#  'im boredd gah wish could just sleep and get it over with but ive had toooo muchh cooooffffeeeeeeeee bahaha',
#  'if may butt in again done being nosey sorry your conversation wa just so interesting',
#  'you fell off my list did offend you',
#  'week till sister home missed her call again it the worst feeling in the world',
#  'gon na try to get some sleep in this hotel room',
#  'brilliant idea just bring a much a you think you ll spend ll swap you bring brolly',
#  'get me an autograph and shout out you have to record it though my computer is dead so can not listen',
#  'rt khloe just got fired from the apprentice',
#  'in biology class my lip hurt',
#  'sorry for the next tweet',
#  'grr not down to go to school today',
#  'had to get an hd tivo and just got it set up tonight in order to get channel',
#  'asked everyone how they were doing yesterday and not single tweet back',
#  'ruddy money like it still waiting here oh what surprise by state too hmmm seriously',
#  'am so sad kutner wa my favorite of the new team',
#  'wow did not get an hello suck',
#  'bedtime school tomorrow and still have no book being broke suck',
#  'seating here helping my baby with his paper well he is forcing me too seat with him im sleepy',
#  'synching my contact from my old mobile to iphone import doe not work well',
#  'can not concentrate',
#  've just spent hour to enter all the bureaucratic nonsense for march what waste of my time',
#  'nw more confused then ever',
#  'not feeling well again stupid migraine making my tummy upset and my whole body ache shoot me now',
#  'reading buyology before bedtime great premise but only turning out to be an ok book lot of info already knew',
#  'home really wana sleep but due to wasting my free line in town have an assignment to finish',
#  'also send some update in plurk but upload photo on twitter you didnt see any of my update on plurk zero',
#  'omg the reader is making me',
#  'oh at least you re getting decent exchange rate at the moment sterling is still getting flogged',
#  'tried to download tweetdeck but it wont download',
#  'there an inch of snow on the ground and counting worried about the poor flower',
#  'why are not you happy camper',
#  'thanks man so very grateful feel unworthy of such attention though because in this because of myself',
#  'miss too totally comin back tho lastnight wa sooooooo much fun',
#  'ohhh love it p sad we did not get to hang out',
#  'and somehow still end up in this place',
#  'oh that is very sad poor boy',
#  ...]

# %%
#constructing a dataframe of clean_data

clean_df = pd.DataFrame(clean_data1,columns=["tweet"])
clean_df["target"] = data.sentiment

# %%
clean_df.head()
# Out:
#                                                tweet  target
# 0  awww that bummer you shoulda got david carr of...       0
# 1  is upset that he can not update his facebook b...       0
# 2  dived many time for the ball managed to save t...       0
# 3       my whole body feel itchy and like it on fire       0
# 4  no it not behaving at all mad why am here beca...       0

# %%
clean_df.tail()
# Out:
#                                                      tweet  target
# 1599995  just woke up having no school is the best feel...       4
# 1599996    thewdb com very cool to hear old walt interview       4
# 1599997  are you ready for your mojo makeover ask me fo...       4
# 1599998  happy th birthday to my boo of alll time tupac...       4
# 1599999                               happy charitytuesday       4

# %%
#create a new column in the data frame to store the length of each tweet

clean_df['tweet_length']=[len(t) for t in clean_df.tweet]

# %%
clean_df
# Out:
#                                                      tweet  target  \
# 0        awww that bummer you shoulda got david carr of...       0
# 1        is upset that he can not update his facebook b...       0
# 2        dived many time for the ball managed to save t...       0
# 3             my whole body feel itchy and like it on fire       0
# 4        no it not behaving at all mad why am here beca...       0
# ...                                                    ...     ...
# 1599995  just woke up having no school is the best feel...       4
# 1599996    thewdb com very cool to hear old walt interview       4
# 1599997  are you ready for your mojo makeover ask me fo...       4
# 1599998  happy th birthday to my boo of alll time tupac...       4
# 1599999                               happy charitytuesday       4
#
#          tweet_length
# 0                  65
# 1                 104
# 2                  69
# 3                  44
# 4                  80
# ...               ...
# 1599995            54
# 1599996            47
# 1599997            54
# 1599998            59
# 1599999            20
#
# [1600000 rows x 3 columns]

# %%
clean_df.head()
# Out:
#                                                tweet  target  tweet_length
# 0  awww that bummer you shoulda got david carr of...       0            65
# 1  is upset that he can not update his facebook b...       0           104
# 2  dived many time for the ball managed to save t...       0            69
# 3       my whole body feel itchy and like it on fire       0            44
# 4  no it not behaving at all mad why am here beca...       0            80

# %%
clean_df[clean_df.tweet_length>140]
# Out:
# Empty DataFrame
# Columns: [tweet, target, tweet_length]
# Index: []

# %%
#dividing features and targets in variables

X = clean_df.tweet
Y = clean_df.target
print(X.shape)
print(Y.shape)
# Out:
# (1600000,)
# (1600000,)

# %% [markdown]
# # Train Test Split

# %%
#train test split

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=1)

# %% [markdown]
# # TF-IDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vect = TfidfVectorizer(analyzer = "word", ngram_range=(1,3)) #create Tfidf object and save it as vect

# %%
vect.fit(X_train) #fitting training tweets into vect
X_train_dtm = vect.transform(X_train) #transforming our training data

# %%
X_test_dtm = vect.transform(X_test) #transforming our test data

# %%
X_train_dtm
# Out:
# <1120000x8989489 sparse matrix of type '<class 'numpy.float64'>'
# 	with 35241599 stored elements in Compressed Sparse Row format>

# %%
import pickle
vect_file="vect.sav"
pickle.dump(vect,open(vect_file,'wb'))

# %% [markdown]
# # Naive Bayes

# %%
#naive bayes
#model building

from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB(alpha=10)

# %%
nb.fit(X_train_dtm,Y_train)
# Out:
# MultinomialNB(alpha=10, class_prior=None, fit_prior=True)

# %%
from sklearn.model_selection import cross_val_score

# %%
#training accuracy
accuracies = cross_val_score(estimator = nb, X = X_train_dtm, y = Y_train, cv = 10) #K-fold cross validation with K=10

# %%
print("Mean accuracy of train data using Naive Bayes:",accuracies.mean()*100,"%")
# Out:
# Mean accuracy of train data using Naive Bayes: 79.43401800171665 %

# %%
#test set accuracy
y_pred_nb= nb.predict(X_test_dtm)

# %%
from sklearn import metrics
print("Test data accuracy using Naive Bayes: ",metrics.accuracy_score(Y_test,y_pred_nb)*100,"%")
# Out:
# Test data accuracy using Naive Bayes:  79.56354166666667 %

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,y_pred_nb)
# Out:
# array([[207920,  32076],
#        [ 66019, 173985]], dtype=int64)

# %% [markdown]
# # Logistic Regression

# %%
#logistic regression
#model building
from sklearn.linear_model import LogisticRegression
logisticRegression = LogisticRegression(C=1.1) #C is the cost parameter

# %%
#model fitting
logisticRegression.fit(X_train_dtm,Y_train)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = logisticRegression, X = X_train_dtm, y = Y_train, cv = 10) #K-fold cross validation with K=10
print("Mean accuracy of train data using Logistic Regression:",accuracies.mean()*100,"%")
# Out:
# E:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Mean accuracy of train data using Logistic Regression: 82.05214290940872 %

# %%
#test set accuracy
y_pred_lr = logisticRegression.predict(X_test_dtm)

# %%
from sklearn import metrics
print("Test data accuracy using Logistic Regression: ",metrics.accuracy_score(Y_test,y_pred_lr)*100,"%")
# Out:
# Test data accuracy using Logistic Regression:  82.341875 %

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,y_pred_lr)
# Out:
# array([[200533,  39463],
#        [ 45296, 194708]], dtype=int64)

# %% [markdown]
# # Support Vector Machine

# %%
#support vector machine
#model building
from sklearn.svm import LinearSVC
svm = LinearSVC(random_state=0)

# %%
#model fitting
svm.fit(X_train_dtm,Y_train)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#           verbose=0)

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = svm, X = X_train_dtm, y = Y_train, cv = 10) #K-fold cross validation with K=10
print("Mean accuracy of train data using Support Vector Machine:",accuracies.mean()*100,"%")
# Out:
# E:\Anaconda\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Mean accuracy of train data using Support Vector Machine: 82.24821446713855 %

# %%
#test set accuracy
y_pred_svm = svm.predict(X_test_dtm)

# %%
from sklearn import metrics
print("Test data accuracy using Support Vector: ",metrics.accuracy_score(Y_test,y_pred_svm)*100,"%")
# Out:
# Test data accuracy using Support Vector:  82.44687499999999 %

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,y_pred_svm)
# Out:
# array([[200554,  39442],
#        [ 44813, 195191]], dtype=int64)

# %% [markdown]
# # Pickle files

# %%
import pickle

# %% [markdown]
# ### Naive Bayes

# %%
naive_bayes_file = 'nb_model.sav'

# %%
pickle.dump(nb,open(naive_bayes_file,'wb'))

# %% [markdown]
# ### Logistic Regression

# %%
logistic_regression_file = 'lr_model.sav'

# %%
pickle.dump(logisticRegression,open(logistic_regression_file,'wb'))

# %% [markdown]
# ### Support Vector Machine

# %%
support_vector_machine_file = 'svm_model.sav'

# %%
pickle.dump(svm,open(support_vector_machine_file,'wb'))

# %%
X_test[0]
# Out:
# 'awww that bummer you shoulda got david carr of third day to do it'

# %%
logisticRegression.predict_proba(vect.transform(["aww that bummer you"]))
# Out:
# array([[0.9703955, 0.0296045]])

# %%
vect.transform(["hi i am harsh"])
# Out:
# <1x8989489 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>

# %%
#  s = 'I am very sarcastic'
# s = clean_tweet(s)
# logisticRegression.predict_proba(vect.transform(s))

# %% [markdown]
# ### testing
